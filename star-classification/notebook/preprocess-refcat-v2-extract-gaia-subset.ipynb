# %% [markdown]
# # Classification for Stars vs. Non-Stellar Objects
#
# #### In this notebook, we will explore the RefCat data for analyzing and extracting train data sets for **labels of stars**.
#
# #### Some Issues:
# - Imbalanced data due to their HealPix-indexed astropy table. We may need to save them again as a new single PySpark Dataframe. (this job will be done on this notebook)
# - Huge Size of Data. Many in-memory executions also can show some troubles. Hence, only operations from disk to disk can work well.

# %% [markdown]
# ## Import Basic Packages

# %%
import numpy as np
import pandas as pd
import glob
import sys
import h5py
#from netCDF4 import Dataset
from datetime import datetime
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from scipy.spatial import cKDTree

import pyarrow as pa
import pyarrow.parquet as pq

from functools import reduce
import operator
import gc

# Increase display width to 200 characters
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_colwidth', 200)

# %%
import os

from astropy.table import Table
from matplotlib.ticker import MultipleLocator

from astropy.utils.exceptions import AstropyWarning
import warnings
warnings.simplefilter('ignore', category=AstropyWarning)

# %%
# plot settings
#plt.rc('font', family='serif') 
#plt.rc('font', serif='Times New Roman') 
plt.rcParams.update({'font.size': 16})
plt.rcParams['mathtext.fontset'] = 'stix'

# %% [markdown]
# ## PySpark Session

# %%
# %%time
# PySpark packages
from pyspark import SparkContext   
from pyspark.sql import SparkSession

import pyspark.sql.functions as F
import pyspark.sql.types as T
from pyspark import Row
from pyspark.sql.window import Window as W


spark = SparkSession.builder \
    .master("yarn") \
    .appName("spark-shell") \
    .config("spark.driver.maxResultSize", "32g") \
    .config("spark.driver.memory", "32g") \
    .config("spark.executor.memory", "7g") \
    .config("spark.executor.cores", "1") \
    .config("spark.executor.instances", "200") \
    .config("spark.sql.hive.filesourcePartitionFileCacheSize", "1048576000") \
    .getOrCreate()


sc = spark.sparkContext
sc.setCheckpointDir("hdfs://spark00:54310/tmp/checkpoints")

spark.conf.set("spark.sql.debug.maxToStringFields", 500)
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")
# Out:
# CPU times: user 11.9 ms, sys: 7.94 ms, total: 19.8 ms
# Wall time: 32.5 s

# %% [markdown]
# > This takes time to get resources from the Yarn Cluster

# %% [markdown]
# ## Reading Reference Catalog Files
#
# - Read converted spark dataframe in the **Parquet Format**

# %%
hdfsheader = 'hdfs://spark00:54310'
workpath = '/user/shong/work/sedfit/spherex/data/temp/'
datapath = '/user/shong/data/spherex/star-classification/input-ref-cat/'

# %% [markdown]
# #### Check the catalog files

# %%
outlist = !hadoop fs -ls {hdfsheader+datapath}

# %%
len(outlist)
# Out:
# 12289

# %%
outlist[0]
# Out:
# 'Found 12288 items'

# %%
outlist[12288]
# Out:
# 'drwxr-xr-x   - shong supergroup          0 2024-05-11 14:45 hdfs://spark00:54310/user/shong/data/spherex/star-classification/input-ref-cat/Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_012287.parquet.snappy'

# %% [markdown]
# #### Read *only* one catalog file
#
# > The Full catalog itself is too big to fit within in-memory calculations. This is quite rare but indeed it is. Hence, for checking out the schema and displaying some rows, we need this one-file sample to avoid loading all data in memory.

# %%
onedf = spark.read.option("header","true") \
.parquet(hdfsheader+datapath+'Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_012287.parquet.snappy')

# %%
onedf.printSchema()
# Out:
# root
#  |-- SPHERExRefID: long (nullable = true)
#  |-- Gaia_DR3_source_id: long (nullable = true)
#  |-- LegacySurvey_uid: long (nullable = true)
#  |-- PS1_DR1_StackObject_objID: long (nullable = true)
#  |-- CatWISE_source_id: string (nullable = true)
#  |-- AllWISE_designation: string (nullable = true)
#  |-- 2MASS_designation: string (nullable = true)
#  |-- ra: double (nullable = true)
#  |-- dec: double (nullable = true)
#  |-- ra_error: double (nullable = true)
#  |-- dec_error: double (nullable = true)
#  |-- coord_src: long (nullable = true)
#  |-- pmra: double (nullable = true)
#  |-- pmra_error: double (nullable = true)
#  |-- pmdec: double (nullable = true)
#  |-- pmdec_error: double (nullable = true)
#  |-- parallax: double (nullable = true)
#  |-- parallax_error: double (nullable = true)
#  |-- ref_epoch: double (nullable = true)
#  |-- astrometric_params_solved: short (nullable = true)
#  |-- CatWISE_PMRA: double (nullable = true)
#  |-- CatWISE_PMDec: double (nullable = true)
#  |-- CatWISE_sigPMRA: double (nullable = true)
#  |-- CatWISE_sigPMDec: double (nullable = true)
#  |-- Gaia_G: double (nullable = true)
#  |-- Gaia_BP: double (nullable = true)
#  |-- Gaia_RP: double (nullable = true)
#  |-- Gaia_G_error: double (nullable = true)
#  |-- Gaia_BP_error: double (nullable = true)
#  |-- Gaia_RP_error: double (nullable = true)
#  |-- LS_g: double (nullable = true)
#  |-- LS_r: double (nullable = true)
#  |-- LS_z: double (nullable = true)
#  |-- LS_g_error: double (nullable = true)
#  |-- LS_r_error: double (nullable = true)
#  |-- LS_z_error: double (nullable = true)
#  |-- PS1_g: double (nullable = true)
#  |-- PS1_r: double (nullable = true)
#  |-- PS1_i: double (nullable = true)
#  |-- PS1_z: double (nullable = true)
#  |-- PS1_y: double (nullable = true)
#  |-- PS1_g_error: double (nullable = true)
#  |-- PS1_r_error: double (nullable = true)
#  |-- PS1_i_error: double (nullable = true)
#  |-- PS1_z_error: double (nullable = true)
#  |-- PS1_y_error: double (nullable = true)
#  |-- 2MASS_J: double (nullable = true)
#  |-- 2MASS_H: double (nullable = true)
#  |-- 2MASS_Ks: double (nullable = true)
#  |-- 2MASS_J_error: double (nullable = true)
#  |-- 2MASS_H_error: double (nullable = true)
#  |-- 2MASS_Ks_error: double (nullable = true)
#  |-- WISE_W1: double (nullable = true)
#  |-- WISE_W2: double (nullable = true)
#  |-- WISE_W1_error: double (nullable = true)
#  |-- WISE_W2_error: double (nullable = true)
#  |-- WISE_W3: double (nullable = true)
#  |-- WISE_W4: double (nullable = true)
#  |-- WISE_W3_error: double (nullable = true)
#  |-- WISE_W4_error: double (nullable = true)
#  |-- rKronRad: double (nullable = true)
#  |-- rKronMag: double (nullable = true)
#  |-- rKronMagErr: double (nullable = true)
#  |-- rPSFMag: double (nullable = true)
#  |-- rPSFMagErr: double (nullable = true)
#  |-- rSerRadius: double (nullable = true)
#  |-- rSerMag: double (nullable = true)
#  |-- rSerAb: double (nullable = true)
#  |-- rSerNu: double (nullable = true)
#  |-- rSerPhi: double (nullable = true)
#  |-- rSerRa: double (nullable = true)
#  |-- rSerDec: double (nullable = true)
#  |-- rSerRadiusErr: double (nullable = true)
#  |-- rSerMagErr: double (nullable = true)
#  |-- rSerAbErr: double (nullable = true)
#  |-- rSerNuErr: double (nullable = true)
#  |-- rSerPhiErr: double (nullable = true)
#  |-- rSerRaErr: double (nullable = true)
#  |-- rSerDecErr: double (nullable = true)
#  |-- rSerChisq: double (nullable = true)
#  |-- type: string (nullable = true)
#  |-- sersic: double (nullable = true)
#  |-- sersic_ivar: double (nullable = true)
#  |-- shape_r: double (nullable = true)
#  |-- shape_r_ivar: double (nullable = true)
#  |-- shape_e1: double (nullable = true)
#  |-- shape_e1_ivar: double (nullable = true)
#  |-- shape_e2: double (nullable = true)
#  |-- shape_e2_ivar: double (nullable = true)
#  |-- ext_flg: integer (nullable = true)
#  |-- flag_blending: short (nullable = true)
#  |-- nsrc_2pix: short (nullable = true)
#  |-- flag_brightneighbor: short (nullable = true)
#  |-- dist_nearest: double (nullable = true)
#  |-- class: short (nullable = true)
#  |-- spherex_class: integer (nullable = true)
#  |-- z: double (nullable = true)
#  |-- z_err: double (nullable = true)
#  |-- z_dup: short (nullable = true)
#  |-- z_survey: string (nullable = true)
#  |-- z_ID: string (nullable = true)

# %%
# %%time
onedf.limit(4).toPandas().T
# Out:
# CPU times: user 669 µs, sys: 16.6 ms, total: 17.2 ms
# Wall time: 3.61 s
#                                              0                    1  \
# SPHERExRefID               1781226356739145733  1781226357108244482
# Gaia_DR3_source_id                       -9999                -9999
# LegacySurvey_uid              1381033849129578     1381033849129483
# PS1_DR1_StackObject_objID   105943148214193291                -9999
# CatWISE_source_id                          N/A   3146m016_b0-026737
# AllWISE_designation                        N/A  J205916.46-014255.9
# 2MASS_designation                          N/A                  N/A
# ra                                  314.821382           314.818459
# dec                                  -1.714273            -1.715548
# ra_error                              0.000002             0.000012
# dec_error                             0.000002             0.000012
# coord_src                                    6                    6
# pmra                                   -9999.0              -9999.0
# pmra_error                             -9999.0              -9999.0
# pmdec                                  -9999.0              -9999.0
# pmdec_error                            -9999.0              -9999.0
# parallax                               -9999.0              -9999.0
# parallax_error                         -9999.0              -9999.0
# ref_epoch                              -9999.0              -9999.0
# astrometric_params_solved                -9999                -9999
# CatWISE_PMRA                           -9999.0           -61.560001
# CatWISE_PMDec                          -9999.0                 3.91
# CatWISE_sigPMRA                        -9999.0            43.299999
# CatWISE_sigPMDec                       -9999.0            45.900002
# Gaia_G                                 -9999.0              -9999.0
# Gaia_BP                                -9999.0              -9999.0
# Gaia_RP                                -9999.0              -9999.0
# Gaia_G_error                           -9999.0              -9999.0
# Gaia_BP_error                          -9999.0              -9999.0
# Gaia_RP_error                          -9999.0              -9999.0
# LS_g                                  3.703767             0.148445
# LS_r                                  7.474296             0.750109
# LS_z                                 11.044288             3.403544
# LS_g_error                            0.068301             0.063999
# LS_r_error                            0.104817             0.103413
# LS_z_error                            0.209211             0.232334
# PS1_g                                  3.76392              -9999.0
# PS1_r                                  6.54998              -9999.0
# PS1_i                                 9.004923              -9999.0
# PS1_z                                 9.724785              -9999.0
# PS1_y                                10.063744              -9999.0
# PS1_g_error                           0.289988              -9999.0
# PS1_r_error                           0.332692              -9999.0
# PS1_i_error                           0.329467              -9999.0
# PS1_z_error                           0.737893              -9999.0
# PS1_y_error                           2.184741              -9999.0
# 2MASS_J                                -9999.0              -9999.0
# 2MASS_H                                -9999.0              -9999.0
# 2MASS_Ks                               -9999.0              -9999.0
# 2MASS_J_error                          -9999.0              -9999.0
# 2MASS_H_error                          -9999.0              -9999.0
# 2MASS_Ks_error                         -9999.0              -9999.0
# WISE_W1                                -9999.0            50.769163
# WISE_W2                                -9999.0            87.016177
# WISE_W1_error                          -9999.0             2.337438
# WISE_W2_error                          -9999.0              4.00627
# WISE_W3                                -9999.0           622.300285
# WISE_W4                                -9999.0          2691.534804
# WISE_W3_error                          -9999.0              -9999.0
# WISE_W4_error                          -9999.0              -9999.0
# rKronRad                               2.14166              -9999.0
# rKronMag                               21.9224              -9999.0
# rKronMagErr                           0.088242              -9999.0
# rPSFMag                                21.8594              -9999.0
# rPSFMagErr                            0.055161              -9999.0
# rSerRadius                             -9999.0              -9999.0
# rSerMag                                -9999.0              -9999.0
# rSerAb                                 -9999.0              -9999.0
# rSerNu                                 -9999.0              -9999.0
# rSerPhi                                -9999.0              -9999.0
# rSerRa                                 -9999.0              -9999.0
# rSerDec                                -9999.0              -9999.0
# rSerRadiusErr                          -9999.0              -9999.0
# rSerMagErr                             -9999.0              -9999.0
# rSerAbErr                              -9999.0              -9999.0
# rSerNuErr                              -9999.0              -9999.0
# rSerPhiErr                             -9999.0              -9999.0
# rSerRaErr                              -9999.0              -9999.0
# rSerDecErr                             -9999.0              -9999.0
# rSerChisq                              -9999.0              -9999.0
# type                                       PSF                  REX
# sersic                                     0.0                  1.0
# sersic_ivar                                0.0                  0.0
# shape_r                                    0.0             0.254285
# shape_r_ivar                               0.0           432.131531
# shape_e1                                   0.0                  0.0
# shape_e1_ivar                              0.0                  0.0
# shape_e2                                   0.0                  0.0
# shape_e2_ivar                              0.0                  0.0
# ext_flg                                  -9999                    0
# flag_blending                                0                    0
# nsrc_2pix                                    7                    7
# flag_brightneighbor                          0                    0
# dist_nearest                          4.531353             5.039329
# class                                        0                    0
# spherex_class                                0                    0
# z                                      -9999.0              -9999.0
# z_err                                  -9999.0              -9999.0
# z_dup                                    -9999                -9999
# z_survey                                   N/A                  N/A
# z_ID                                       N/A                  N/A
#
#                                              2                    3
# SPHERExRefID               1781226357225684993  1781226361000558592
# Gaia_DR3_source_id         6917053110906356480                -9999
# LegacySurvey_uid              1381033849129619     1381033849129863
# PS1_DR1_StackObject_objID   105933148223679716                -9999
# CatWISE_source_id           3146m016_b0-007758                  N/A
# AllWISE_designation        J205917.35-014302.2                  N/A
# 2MASS_designation             20591737-0143021                  N/A
# ra                                  314.822332           314.829754
# dec                                  -1.717279            -1.719934
# ra_error                                   0.0             0.000007
# dec_error                                  0.0             0.000007
# coord_src                                    1                    6
# pmra                                -12.390017              -9999.0
# pmra_error                            0.077977              -9999.0
# pmdec                                -7.824569              -9999.0
# pmdec_error                           0.058534              -9999.0
# parallax                              0.476567              -9999.0
# parallax_error                        0.082368              -9999.0
# ref_epoch                               2016.0              -9999.0
# astrometric_params_solved                   95                -9999
# CatWISE_PMRA                             15.08              -9999.0
# CatWISE_PMDec                       -25.799999              -9999.0
# CatWISE_sigPMRA                           15.7              -9999.0
# CatWISE_sigPMDec                          15.0              -9999.0
# Gaia_G                              455.751526              -9999.0
# Gaia_BP                             313.447479              -9999.0
# Gaia_RP                             652.660706              -9999.0
# Gaia_G_error                          0.810147              -9999.0
# Gaia_BP_error                         1.831303              -9999.0
# Gaia_RP_error                         2.965371              -9999.0
# LS_g                                 287.14212             1.800521
# LS_r                                555.820923             3.638052
# LS_z                                749.160583             6.884971
# LS_g_error                            0.253899             0.102755
# LS_r_error                            0.321018             0.148475
# LS_z_error                            0.455191             0.325499
# PS1_g                               301.328355              -9999.0
# PS1_r                                512.90815              -9999.0
# PS1_i                               652.889975              -9999.0
# PS1_z                               708.010992              -9999.0
# PS1_y                                729.12166              -9999.0
# PS1_g_error                           0.680347              -9999.0
# PS1_r_error                           0.755666              -9999.0
# PS1_i_error                           0.711806              -9999.0
# PS1_z_error                           1.225654              -9999.0
# PS1_y_error                           3.853066              -9999.0
# 2MASS_J                             851.138038              -9999.0
# 2MASS_H                             883.893622              -9999.0
# 2MASS_Ks                            569.639373              -9999.0
# 2MASS_J_error                        57.212778              -9999.0
# 2MASS_H_error                        91.156617              -9999.0
# 2MASS_Ks_error                       74.483233              -9999.0
# WISE_W1                             266.195065              -9999.0
# WISE_W2                             128.587869              -9999.0
# WISE_W1_error                         4.412073              -9999.0
# WISE_W2_error                         4.144176              -9999.0
# WISE_W3                             284.446111              -9999.0
# WISE_W4                            3253.868518              -9999.0
# WISE_W3_error                          -9999.0              -9999.0
# WISE_W4_error                          -9999.0              -9999.0
# rKronRad                               2.77594              -9999.0
# rKronMag                               17.1654              -9999.0
# rKronMagErr                           0.001763              -9999.0
# rPSFMag                              17.124901              -9999.0
# rPSFMagErr                              0.0016              -9999.0
# rSerRadius                             -9999.0              -9999.0
# rSerMag                                -9999.0              -9999.0
# rSerAb                                 -9999.0              -9999.0
# rSerNu                                 -9999.0              -9999.0
# rSerPhi                                -9999.0              -9999.0
# rSerRa                                 -9999.0              -9999.0
# rSerDec                                -9999.0              -9999.0
# rSerRadiusErr                          -9999.0              -9999.0
# rSerMagErr                             -9999.0              -9999.0
# rSerAbErr                              -9999.0              -9999.0
# rSerNuErr                              -9999.0              -9999.0
# rSerPhiErr                             -9999.0              -9999.0
# rSerRaErr                              -9999.0              -9999.0
# rSerDecErr                             -9999.0              -9999.0
# rSerChisq                              -9999.0              -9999.0
# type                                       PSF                  DEV
# sersic                                     0.0                  4.0
# sersic_ivar                                0.0                  0.0
# shape_r                                    0.0             0.664946
# shape_r_ivar                               0.0           495.805176
# shape_e1                                   0.0             0.108905
# shape_e1_ivar                              0.0           135.567688
# shape_e2                                   0.0             0.289885
# shape_e2_ivar                              0.0           222.062714
# ext_flg                                      0                -9999
# flag_blending                                0                    0
# nsrc_2pix                                    4                    8
# flag_brightneighbor                          0                    0
# dist_nearest                         10.412971             3.133348
# class                                        1                    0
# spherex_class                                0                    0
# z                                      -9999.0              -9999.0
# z_err                                  -9999.0              -9999.0
# z_dup                                    -9999                -9999
# z_survey                                   N/A                  N/A
# z_ID                                       N/A                  N/A

# %%
len(onedf.columns)
# Out:
# 101

# %% [markdown]
# > The total number of data columns is **101**.

# %% [markdown]
# #### Now read all reference catalog files to a single dataframe

# %%
# %%time
rawdf = spark.read.option("header","true").option("recursiveFileLookup","true").parquet(hdfsheader+datapath)
# Out:
# CPU times: user 1.29 ms, sys: 1.49 ms, total: 2.78 ms
# Wall time: 8.1 s

# %% [markdown]
# > As explained above, we need to handle this full dataframe with care, though our Spark/Hadoop cluster is big and great enough.

# %% [markdown]
# ## Gaia SubSets and Other Catalogs' Photometries

# %% [markdown]
# #### Choose columns we need

# %%
listcol = rawdf.columns
print(len(listcol))
# Out:
# 101

# %%
colbasic = ['SPHERExRefID', 'Gaia_DR3_source_id', 'ra', 'dec']

# %%
colphot = ['Gaia_G','Gaia_BP','Gaia_RP','LS_g','LS_r','LS_z',
           'PS1_g','PS1_r','PS1_i','PS1_z','PS1_y',
           '2MASS_J','2MASS_H','2MASS_Ks','WISE_W1','WISE_W2','WISE_W3','WISE_W4']

# %%
colphoterror = ['Gaia_G_error','Gaia_BP_error','Gaia_RP_error','LS_g_error','LS_r_error','LS_z_error',
           'PS1_g_error','PS1_r_error','PS1_i_error','PS1_z_error','PS1_y_error',
           '2MASS_J_error','2MASS_H_error','2MASS_Ks_error',
           'WISE_W1_error','WISE_W2_error','WISE_W3_error','WISE_W4_error']

# %%
collabel = ['class']

# %%
#%%time
#rawdf.select(colbasic+colphot+collabel).toPandas().set_index('summary').transpose()

# %% [markdown]
# #### What is the `class` column?

# %%
#%%time
#rawdf.select('class').distinct().collect()

# %% [markdown]
# > output: four classes <br> [Row(class=1), Row(class=4), Row(class=2), Row(class=0)]

# %% [markdown]
# ### Now Gaia-Compatible SubSet from the RefCat

# %%
df = rawdf.select(colbasic+colphot+colphoterror+collabel).filter(F.col("Gaia_DR3_source_id") > 0)

# %%
df.printSchema()
# Out:
# root
#  |-- SPHERExRefID: long (nullable = true)
#  |-- Gaia_DR3_source_id: long (nullable = true)
#  |-- ra: double (nullable = true)
#  |-- dec: double (nullable = true)
#  |-- Gaia_G: double (nullable = true)
#  |-- Gaia_BP: double (nullable = true)
#  |-- Gaia_RP: double (nullable = true)
#  |-- LS_g: double (nullable = true)
#  |-- LS_r: double (nullable = true)
#  |-- LS_z: double (nullable = true)
#  |-- PS1_g: double (nullable = true)
#  |-- PS1_r: double (nullable = true)
#  |-- PS1_i: double (nullable = true)
#  |-- PS1_z: double (nullable = true)
#  |-- PS1_y: double (nullable = true)
#  |-- 2MASS_J: double (nullable = true)
#  |-- 2MASS_H: double (nullable = true)
#  |-- 2MASS_Ks: double (nullable = true)
#  |-- WISE_W1: double (nullable = true)
#  |-- WISE_W2: double (nullable = true)
#  |-- WISE_W3: double (nullable = true)
#  |-- WISE_W4: double (nullable = true)
#  |-- Gaia_G_error: double (nullable = true)
#  |-- Gaia_BP_error: double (nullable = true)
#  |-- Gaia_RP_error: double (nullable = true)
#  |-- LS_g_error: double (nullable = true)
#  |-- LS_r_error: double (nullable = true)
#  |-- LS_z_error: double (nullable = true)
#  |-- PS1_g_error: double (nullable = true)
#  |-- PS1_r_error: double (nullable = true)
#  |-- PS1_i_error: double (nullable = true)
#  |-- PS1_z_error: double (nullable = true)
#  |-- PS1_y_error: double (nullable = true)
#  |-- 2MASS_J_error: double (nullable = true)
#  |-- 2MASS_H_error: double (nullable = true)
#  |-- 2MASS_Ks_error: double (nullable = true)
#  |-- WISE_W1_error: double (nullable = true)
#  |-- WISE_W2_error: double (nullable = true)
#  |-- WISE_W3_error: double (nullable = true)
#  |-- WISE_W4_error: double (nullable = true)
#  |-- class: short (nullable = true)

# %%
df = df.repartition(2000)

# %% [markdown]
# > our current parquet files were direct convertions from HealPix astro tables. this caused imbalanced funny partitions. we need to repartition and save them.

# %%
df.cache()
# Out:
# DataFrame[SPHERExRefID: bigint, Gaia_DR3_source_id: bigint, ra: double, dec: double, Gaia_G: double, Gaia_BP: double, Gaia_RP: double, LS_g: double, LS_r: double, LS_z: double, PS1_g: double, PS1_r: double, PS1_i: double, PS1_z: double, PS1_y: double, 2MASS_J: double, 2MASS_H: double, 2MASS_Ks: double, WISE_W1: double, WISE_W2: double, WISE_W3: double, WISE_W4: double, Gaia_G_error: double, Gaia_BP_error: double, Gaia_RP_error: double, LS_g_error: double, LS_r_error: double, LS_z_error: double, PS1_g_error: double, PS1_r_error: double, PS1_i_error: double, PS1_z_error: double, PS1_y_error: double, 2MASS_J_error: double, 2MASS_H_error: double, 2MASS_Ks_error: double, WISE_W1_error: double, WISE_W2_error: double, WISE_W3_error: double, WISE_W4_error: double, class: smallint]

# %%
#df.show(3,truncate=True)

# %%
#%%time
#df.limit(3).toPandas().T

# %%
#%%time
#df.select(colbasic+colphot+collabel).toPandas().set_index('summary').transpose()

# %% [markdown]
# ### Save the trimmed dataframe

# %%
outdatapath = '/user/shong/data/spherex/star-classification/reduced-data/'

# %%
hdfsheader+outdatapath
# Out:
# 'hdfs://spark00:54310/user/shong/data/spherex/star-classification/reduced-data/'

# %%
hdfsheader+outdatapath+'Gaia-Compatible-Subset.parquet.snappy'
# Out:
# 'hdfs://spark00:54310/user/shong/data/spherex/star-classification/reduced-data/Gaia-Compatible-Subset.parquet.snappy'

# %%
# %%time
df.write.option("compression", "snappy").mode("overwrite") \
    .save(hdfsheader+outdatapath+'Gaia-Compatible-Subset.parquet.snappy')
# Out:
# CPU times: user 208 ms, sys: 135 ms, total: 343 ms
# Wall time: 1h 19min 55s
