# %% [markdown]
# # Classification for Stars vs. Non-Stellar Objects
#
# #### In this notebook, we will explore the RefCat data for analyze and extract train data sets for **labels of stars**.

# %% [markdown]
# ## Import Basic Packages

# %%
import numpy as np
import pandas as pd
import glob
import sys
import h5py
#from netCDF4 import Dataset
from datetime import datetime
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from scipy.spatial import cKDTree

import pyarrow as pa
import pyarrow.parquet as pq

from functools import reduce
import operator
import gc

# Increase display width to 200 characters
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_colwidth', 200)

# %%
import os

from astropy.table import Table
from matplotlib.ticker import MultipleLocator

from astropy.utils.exceptions import AstropyWarning
import warnings
warnings.simplefilter('ignore', category=AstropyWarning)

# %%
# plot settings
#plt.rc('font', family='serif') 
#plt.rc('font', serif='Times New Roman') 
plt.rcParams.update({'font.size': 16})
plt.rcParams['mathtext.fontset'] = 'stix'

# %% [markdown]
# ## PySpark Session

# %%
# %%time
# PySpark packages
from pyspark import SparkContext   
from pyspark.sql import SparkSession

import pyspark.sql.functions as F
import pyspark.sql.types as T
from pyspark import Row
from pyspark.sql.window import Window as W


spark = SparkSession.builder \
    .master("yarn") \
    .appName("spark-shell") \
    .config("spark.driver.maxResultSize", "32g") \
    .config("spark.driver.memory", "32g") \
    .config("spark.rpc.message.maxSize", "1024") \
    .config("spark.executor.memory", "7g") \
    .config("spark.executor.cores", "1") \
    .config("spark.executor.instances", "20") \
    .getOrCreate()


sc = spark.sparkContext
sc.setCheckpointDir("hdfs://spark00:54310/tmp/checkpoints")

spark.conf.set("spark.sql.debug.maxToStringFields", 500)
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")
# Out:
# CPU times: user 5.12 ms, sys: 13.7 ms, total: 18.8 ms
# Wall time: 26.8 s

# %% [markdown]
# - this takes time to get resources from Yarn Cluster
# - `.config("spark.rpc.message.maxSize", "1024")`: this option is necessary for handling some large pandas dataframe

# %% [markdown]
# ## [1] Reading Reference Catalog Files
#
# - **Parquet Format** of **astropy.Table**.
# - **Not readable from HDFS**.
# - Hence, local file system will be better to save these astropy table data.

# %% [markdown]
# ### [1-1] Read the List of Files

# %% [markdown]
# #### Hadoop File System

# %%
hdfsheader = 'hdfs://spark00:54310'
workpath = '/user/shong/work/sedfit/spherex/data/temp/'
datapath = '/user/shong/data/spherex/star-classification/input-ref-cat/'

# %% [markdown]
# #### Local File System on Spark00

# %%
localrefcatpath = '/mnt/raid5/yyang/SPHEREx_RefCat/'

# %% [markdown]
# #### Pandas DataFrame of RefCat File List

# %%
pdf = pq.read_table('/home/shong/work/sed-fit/pyspark-eazypy/data/refcatlist.parquet').to_pandas()

# %%
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12288 entries, 0 to 12287
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    12288 non-null  object
#  1   size    12288 non-null  float64
#  2   irank   12288 non-null  int32
# dtypes: float64(1), int32(1), object(1)
# memory usage: 240.1+ KB

# %%
pdf.head()
# Out:
#                                                               name     size  \
# 0  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_000030.parquet  18.7712
# 1  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_000028.parquet  19.4544
# 2  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_000024.parquet  20.1404
# 3  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_000031.parquet  20.6769
# 4  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_000025.parquet  20.8368
#
#    irank
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5

# %%
pdf.tail(20)
# Out:
#                                                                   name  \
# 12268  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007316.parquet
# 12269  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007265.parquet
# 12270  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007195.parquet
# 12271  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007319.parquet
# 12272  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007217.parquet
# 12273  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007242.parquet
# 12274  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007318.parquet
# 12275  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007220.parquet
# 12276  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007312.parquet
# 12277  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007296.parquet
# 12278  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007205.parquet
# 12279  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007196.parquet
# 12280  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007264.parquet
# 12281  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007221.parquet
# 12282  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007315.parquet
# 12283  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007198.parquet
# 12284  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007199.parquet
# 12285  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007227.parquet
# 12286  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007193.parquet
# 12287  Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007313.parquet
#
#           size  irank
# 12268  517.627  12269
# 12269  521.287  12270
# 12270  521.818  12271
# 12271  522.251  12272
# 12272  524.478  12273
# 12273  530.077  12274
# 12274  533.152  12275
# 12275  538.911  12276
# 12276  541.143  12277
# 12277  544.204  12278
# 12278  548.447  12279
# 12279  550.993  12280
# 12280  553.128  12281
# 12281  553.236  12282
# 12282  558.169  12283
# 12283  559.985  12284
# 12284  561.910  12285
# 12285  566.999  12286
# 12286  570.862  12287
# 12287  572.447  12288

# %% [markdown]
# ## Explore the RefCat

# %%
listrefcat = pdf['name'].values

# %%
localrefcatpath+listrefcat[0]
# Out:
# '/mnt/raid5/yyang/SPHEREx_RefCat/Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_000030.parquet'

# %%
numrefcat = len(listrefcat)
print(numrefcat)
# Out:
# 12288

# %%
phot = Table.read(localrefcatpath+pdf.name[0])

# %%
photdf = phot.to_pandas()

# %%
photdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102219 entries, 0 to 102218
# Columns: 101 entries, SPHERExRefID to z_ID
# dtypes: float32(21), float64(61), int16(6), int32(2), int64(5), object(6)
# memory usage: 66.3+ MB

# %%
photdf.dtypes
# Out:
# SPHERExRefID                   int64
# Gaia_DR3_source_id             int64
# LegacySurvey_uid               int64
# PS1_DR1_StackObject_objID      int64
# CatWISE_source_id             object
# AllWISE_designation           object
# 2MASS_designation             object
# ra                           float64
# dec                          float64
# ra_error                     float64
# dec_error                    float64
# coord_src                      int64
# pmra                         float64
# pmra_error                   float32
# pmdec                        float64
# pmdec_error                  float32
# parallax                     float64
# parallax_error               float32
# ref_epoch                    float64
# astrometric_params_solved      int16
# CatWISE_PMRA                 float32
# CatWISE_PMDec                float32
# CatWISE_sigPMRA              float32
# CatWISE_sigPMDec             float32
# Gaia_G                       float32
# Gaia_BP                      float32
# Gaia_RP                      float32
# Gaia_G_error                 float64
# Gaia_BP_error                float64
# Gaia_RP_error                float64
# LS_g                         float64
# LS_r                         float64
# LS_z                         float64
# LS_g_error                   float64
# LS_r_error                   float64
# LS_z_error                   float64
# PS1_g                        float64
# PS1_r                        float64
# PS1_i                        float64
# PS1_z                        float64
# PS1_y                        float64
# PS1_g_error                  float64
# PS1_r_error                  float64
# PS1_i_error                  float64
# PS1_z_error                  float64
# PS1_y_error                  float64
# 2MASS_J                      float64
# 2MASS_H                      float64
# 2MASS_Ks                     float64
# 2MASS_J_error                float64
# 2MASS_H_error                float64
# 2MASS_Ks_error               float64
# WISE_W1                      float64
# WISE_W2                      float64
# WISE_W1_error                float64
# WISE_W2_error                float64
# WISE_W3                      float64
# WISE_W4                      float64
# WISE_W3_error                float64
# WISE_W4_error                float64
# rKronRad                     float64
# rKronMag                     float64
# rKronMagErr                  float64
# rPSFMag                      float64
# rPSFMagErr                   float64
# rSerRadius                   float64
# rSerMag                      float64
# rSerAb                       float64
# rSerNu                       float64
# rSerPhi                      float64
# rSerRa                       float64
# rSerDec                      float64
# rSerRadiusErr                float64
# rSerMagErr                   float64
# rSerAbErr                    float64
# rSerNuErr                    float64
# rSerPhiErr                   float64
# rSerRaErr                    float64
# rSerDecErr                   float64
# rSerChisq                    float64
# LS_type                       object
# sersic                       float32
# sersic_ivar                  float32
# shape_r                      float32
# shape_r_ivar                 float32
# shape_e1                     float32
# shape_e1_ivar                float32
# shape_e2                     float32
# shape_e2_ivar                float32
# ext_flg                        int32
# flag_blending                  int16
# nsrc_2pix                      int16
# flag_brightneighbor            int16
# dist_nearest                 float32
# class                          int16
# spherex_class                  int32
# z                            float32
# z_err                        float32
# z_dup                          int16
# z_survey                      object
# z_ID                          object
# dtype: object

# %%
photdf.head(4).T
# Out:
#                                              0                    1  \
# SPHERExRefID               1333155099932884993  1333155099932884994
# Gaia_DR3_source_id                       -9999                -9999
# LegacySurvey_uid                         -9999                -9999
# PS1_DR1_StackObject_objID   123890492204260534   123890492217870778
# CatWISE_source_id                       b'N/A'               b'N/A'
# AllWISE_designation                     b'N/A'               b'N/A'
# 2MASS_designation                       b'N/A'               b'N/A'
# ra                                   49.220482            49.221801
# dec                                  13.241687              13.2419
# ra_error                              0.000012             0.000008
# dec_error                             0.000011             0.000017
# coord_src                                    2                    2
# pmra                                   -9999.0              -9999.0
# pmra_error                             -9999.0              -9999.0
# pmdec                                  -9999.0              -9999.0
# pmdec_error                            -9999.0              -9999.0
# parallax                               -9999.0              -9999.0
# parallax_error                         -9999.0              -9999.0
# ref_epoch                              -9999.0              -9999.0
# astrometric_params_solved                -9999                -9999
# CatWISE_PMRA                           -9999.0              -9999.0
# CatWISE_PMDec                          -9999.0              -9999.0
# CatWISE_sigPMRA                        -9999.0              -9999.0
# CatWISE_sigPMDec                       -9999.0              -9999.0
# Gaia_G                                 -9999.0              -9999.0
# Gaia_BP                                -9999.0              -9999.0
# Gaia_RP                                -9999.0              -9999.0
# Gaia_G_error                           -9999.0              -9999.0
# Gaia_BP_error                          -9999.0              -9999.0
# Gaia_RP_error                          -9999.0              -9999.0
# LS_g                                   -9999.0              -9999.0
# LS_r                                   -9999.0              -9999.0
# LS_z                                   -9999.0              -9999.0
# LS_g_error                             -9999.0              -9999.0
# LS_r_error                             -9999.0              -9999.0
# LS_z_error                             -9999.0              -9999.0
# PS1_g                                  -9999.0             1.064143
# PS1_r                                   2.2229             3.205676
# PS1_i                                 7.544666             8.542803
# PS1_z                                14.535836            11.598451
# PS1_y                                 26.18183            16.930898
# PS1_g_error                            -9999.0             0.327878
# PS1_r_error                           0.353081             0.353469
# PS1_i_error                           0.502853             0.440639
# PS1_z_error                           0.859863              0.84391
# PS1_y_error                           2.343491             2.517668
# 2MASS_J                                -9999.0              -9999.0
# 2MASS_H                                -9999.0              -9999.0
# 2MASS_Ks                               -9999.0              -9999.0
# 2MASS_J_error                          -9999.0              -9999.0
# 2MASS_H_error                          -9999.0              -9999.0
# 2MASS_Ks_error                         -9999.0              -9999.0
# WISE_W1                                -9999.0              -9999.0
# WISE_W2                                -9999.0              -9999.0
# WISE_W1_error                          -9999.0              -9999.0
# WISE_W2_error                          -9999.0              -9999.0
# WISE_W3                                -9999.0              -9999.0
# WISE_W4                                -9999.0              -9999.0
# WISE_W3_error                          -9999.0              -9999.0
# WISE_W4_error                          -9999.0              -9999.0
# rKronRad                               1.80567              2.83297
# rKronMag                             23.448999              21.8402
# rKronMagErr                           0.324375             0.116412
# rPSFMag                                23.0327            22.635201
# rPSFMagErr                            0.172498             0.119746
# rSerRadius                             -9999.0              1.95621
# rSerMag                                -9999.0              21.5096
# rSerAb                                 -9999.0              0.33367
# rSerNu                                 -9999.0              1.26382
# rSerPhi                                -9999.0           -86.149803
# rSerRa                                 -9999.0            49.221764
# rSerDec                                -9999.0            13.241861
# rSerRadiusErr                          -9999.0             0.005219
# rSerMagErr                             -9999.0             0.003436
# rSerAbErr                              -9999.0             0.001584
# rSerNuErr                              -9999.0                  0.1
# rSerPhiErr                             -9999.0             0.017278
# rSerRaErr                              -9999.0             0.001494
# rSerDecErr                             -9999.0             0.001405
# rSerChisq                              -9999.0              1.46149
# LS_type                                 b'N/A'               b'N/A'
# sersic                                 -9999.0              -9999.0
# sersic_ivar                            -9999.0              -9999.0
# shape_r                                -9999.0              -9999.0
# shape_r_ivar                           -9999.0              -9999.0
# shape_e1                               -9999.0              -9999.0
# shape_e1_ivar                          -9999.0              -9999.0
# shape_e2                               -9999.0              -9999.0
# shape_e2_ivar                          -9999.0              -9999.0
# ext_flg                                  -9999                -9999
# flag_blending                                0                    0
# nsrc_2pix                                    4                    5
# flag_brightneighbor                          0                    0
# dist_nearest                          2.974406             1.768245
# class                                        0                    0
# spherex_class                                0                    0
# z                                      -9999.0              -9999.0
# z_err                                  -9999.0              -9999.0
# z_dup                                    -9999                -9999
# z_survey                                   N/A                  N/A
# z_ID                                       N/A                  N/A
#
#                                                2                      3
# SPHERExRefID                 1333155100033548292    1333155100067102720
# Gaia_DR3_source_id                         -9999                  -9999
# LegacySurvey_uid                           -9999                  -9999
# PS1_DR1_StackObject_objID                  -9999     123880492201128997
# CatWISE_source_id          b'0496p136_b0-061999'  b'0496p136_b0-016795'
# AllWISE_designation                       b'N/A'                 b'N/A'
# 2MASS_designation                         b'N/A'                 b'N/A'
# ra                                      49.22002               49.22015
# dec                                    13.243249              13.240385
# ra_error                                0.000164               0.000016
# dec_error                               0.000162               0.000015
# coord_src                                      3                      2
# pmra                                     -9999.0                -9999.0
# pmra_error                               -9999.0                -9999.0
# pmdec                                    -9999.0                -9999.0
# pmdec_error                              -9999.0                -9999.0
# parallax                                 -9999.0                -9999.0
# parallax_error                           -9999.0                -9999.0
# ref_epoch                                -9999.0                -9999.0
# astrometric_params_solved                  -9999                  -9999
# CatWISE_PMRA                          -456.51001              46.189999
# CatWISE_PMDec                        -813.799988             -25.110001
# CatWISE_sigPMRA                            248.5              53.799999
# CatWISE_sigPMDec                      257.600006              57.400002
# Gaia_G                                   -9999.0                -9999.0
# Gaia_BP                                  -9999.0                -9999.0
# Gaia_RP                                  -9999.0                -9999.0
# Gaia_G_error                             -9999.0                -9999.0
# Gaia_BP_error                            -9999.0                -9999.0
# Gaia_RP_error                            -9999.0                -9999.0
# LS_g                                     -9999.0                -9999.0
# LS_r                                     -9999.0                -9999.0
# LS_z                                     -9999.0                -9999.0
# LS_g_error                               -9999.0                -9999.0
# LS_r_error                               -9999.0                -9999.0
# LS_z_error                               -9999.0                -9999.0
# PS1_g                                    -9999.0               1.204813
# PS1_r                                    -9999.0               2.668333
# PS1_i                                    -9999.0               6.361507
# PS1_z                                    -9999.0               9.229964
# PS1_y                                    -9999.0              17.125356
# PS1_g_error                              -9999.0               0.308432
# PS1_r_error                              -9999.0               0.379235
# PS1_i_error                              -9999.0               0.498722
# PS1_z_error                              -9999.0               0.769793
# PS1_y_error                              -9999.0               2.353932
# 2MASS_J                                  -9999.0                -9999.0
# 2MASS_H                                  -9999.0                -9999.0
# 2MASS_Ks                                 -9999.0                -9999.0
# 2MASS_J_error                            -9999.0                -9999.0
# 2MASS_H_error                            -9999.0                -9999.0
# 2MASS_Ks_error                           -9999.0                -9999.0
# WISE_W1                                14.125375              60.089695
# WISE_W2                                11.492116              37.290654
# WISE_W1_error                            2.39325               2.766561
# WISE_W2_error                           4.719598               4.292202
# WISE_W3                                  -9999.0                -9999.0
# WISE_W4                                  -9999.0                -9999.0
# WISE_W3_error                            -9999.0                -9999.0
# WISE_W4_error                            -9999.0                -9999.0
# rKronRad                                 -9999.0                2.62717
# rKronMag                                 -9999.0              22.487499
# rKronMagErr                              -9999.0                0.20371
# rPSFMag                                  -9999.0                22.8344
# rPSFMagErr                               -9999.0               0.154347
# rSerRadius                               -9999.0                -9999.0
# rSerMag                                  -9999.0                -9999.0
# rSerAb                                   -9999.0                -9999.0
# rSerNu                                   -9999.0                -9999.0
# rSerPhi                                  -9999.0                -9999.0
# rSerRa                                   -9999.0                -9999.0
# rSerDec                                  -9999.0                -9999.0
# rSerRadiusErr                            -9999.0                -9999.0
# rSerMagErr                               -9999.0                -9999.0
# rSerAbErr                                -9999.0                -9999.0
# rSerNuErr                                -9999.0                -9999.0
# rSerPhiErr                               -9999.0                -9999.0
# rSerRaErr                                -9999.0                -9999.0
# rSerDecErr                               -9999.0                -9999.0
# rSerChisq                                -9999.0                -9999.0
# LS_type                                   b'N/A'                 b'N/A'
# sersic                                   -9999.0                -9999.0
# sersic_ivar                              -9999.0                -9999.0
# shape_r                                  -9999.0                -9999.0
# shape_r_ivar                             -9999.0                -9999.0
# shape_e1                                 -9999.0                -9999.0
# shape_e1_ivar                            -9999.0                -9999.0
# shape_e2                                 -9999.0                -9999.0
# shape_e2_ivar                            -9999.0                -9999.0
# ext_flg                                    -9999                  -9999
# flag_blending                                  0                      0
# nsrc_2pix                                      5                      4
# flag_brightneighbor                            1                      1
# dist_nearest                            5.848527               4.831284
# class                                          0                      0
# spherex_class                                  0                      0
# z                                        -9999.0                -9999.0
# z_err                                    -9999.0                -9999.0
# z_dup                                      -9999                  -9999
# z_survey                                     N/A                    N/A
# z_ID                                         N/A                    N/A

# %%
photdf['CatWISE_source_id'][:5]
# Out:
# 0                   b'N/A'
# 1                   b'N/A'
# 2    b'0496p136_b0-061999'
# 3    b'0496p136_b0-016795'
# 4    b'0496p136_b0-006048'
# Name: CatWISE_source_id, dtype: object

# %% [markdown]
# > We have a string decode issue like `b'N/A'`. We will resolve this issue as follows.

# %% [markdown]
# ### Handling the byte encoded columns

# %%
byte_encoded_columns = []

for col in photdf.columns:
    if isinstance(photdf[col].iloc[0], bytes):
        byte_encoded_columns.append(col)

print("Byte encoded columns:", byte_encoded_columns)
# Out:
# Byte encoded columns: ['CatWISE_source_id', 'AllWISE_designation', '2MASS_designation', 'LS_type']

# %%
for col in byte_encoded_columns:
    photdf[col] = photdf[col].str.decode('utf-8')

# %%
photdf.head(4).T
# Out:
#                                              0                    1  \
# SPHERExRefID               1333155099932884993  1333155099932884994
# Gaia_DR3_source_id                       -9999                -9999
# LegacySurvey_uid                         -9999                -9999
# PS1_DR1_StackObject_objID   123890492204260534   123890492217870778
# CatWISE_source_id                          N/A                  N/A
# AllWISE_designation                        N/A                  N/A
# 2MASS_designation                          N/A                  N/A
# ra                                   49.220482            49.221801
# dec                                  13.241687              13.2419
# ra_error                              0.000012             0.000008
# dec_error                             0.000011             0.000017
# coord_src                                    2                    2
# pmra                                   -9999.0              -9999.0
# pmra_error                             -9999.0              -9999.0
# pmdec                                  -9999.0              -9999.0
# pmdec_error                            -9999.0              -9999.0
# parallax                               -9999.0              -9999.0
# parallax_error                         -9999.0              -9999.0
# ref_epoch                              -9999.0              -9999.0
# astrometric_params_solved                -9999                -9999
# CatWISE_PMRA                           -9999.0              -9999.0
# CatWISE_PMDec                          -9999.0              -9999.0
# CatWISE_sigPMRA                        -9999.0              -9999.0
# CatWISE_sigPMDec                       -9999.0              -9999.0
# Gaia_G                                 -9999.0              -9999.0
# Gaia_BP                                -9999.0              -9999.0
# Gaia_RP                                -9999.0              -9999.0
# Gaia_G_error                           -9999.0              -9999.0
# Gaia_BP_error                          -9999.0              -9999.0
# Gaia_RP_error                          -9999.0              -9999.0
# LS_g                                   -9999.0              -9999.0
# LS_r                                   -9999.0              -9999.0
# LS_z                                   -9999.0              -9999.0
# LS_g_error                             -9999.0              -9999.0
# LS_r_error                             -9999.0              -9999.0
# LS_z_error                             -9999.0              -9999.0
# PS1_g                                  -9999.0             1.064143
# PS1_r                                   2.2229             3.205676
# PS1_i                                 7.544666             8.542803
# PS1_z                                14.535836            11.598451
# PS1_y                                 26.18183            16.930898
# PS1_g_error                            -9999.0             0.327878
# PS1_r_error                           0.353081             0.353469
# PS1_i_error                           0.502853             0.440639
# PS1_z_error                           0.859863              0.84391
# PS1_y_error                           2.343491             2.517668
# 2MASS_J                                -9999.0              -9999.0
# 2MASS_H                                -9999.0              -9999.0
# 2MASS_Ks                               -9999.0              -9999.0
# 2MASS_J_error                          -9999.0              -9999.0
# 2MASS_H_error                          -9999.0              -9999.0
# 2MASS_Ks_error                         -9999.0              -9999.0
# WISE_W1                                -9999.0              -9999.0
# WISE_W2                                -9999.0              -9999.0
# WISE_W1_error                          -9999.0              -9999.0
# WISE_W2_error                          -9999.0              -9999.0
# WISE_W3                                -9999.0              -9999.0
# WISE_W4                                -9999.0              -9999.0
# WISE_W3_error                          -9999.0              -9999.0
# WISE_W4_error                          -9999.0              -9999.0
# rKronRad                               1.80567              2.83297
# rKronMag                             23.448999              21.8402
# rKronMagErr                           0.324375             0.116412
# rPSFMag                                23.0327            22.635201
# rPSFMagErr                            0.172498             0.119746
# rSerRadius                             -9999.0              1.95621
# rSerMag                                -9999.0              21.5096
# rSerAb                                 -9999.0              0.33367
# rSerNu                                 -9999.0              1.26382
# rSerPhi                                -9999.0           -86.149803
# rSerRa                                 -9999.0            49.221764
# rSerDec                                -9999.0            13.241861
# rSerRadiusErr                          -9999.0             0.005219
# rSerMagErr                             -9999.0             0.003436
# rSerAbErr                              -9999.0             0.001584
# rSerNuErr                              -9999.0                  0.1
# rSerPhiErr                             -9999.0             0.017278
# rSerRaErr                              -9999.0             0.001494
# rSerDecErr                             -9999.0             0.001405
# rSerChisq                              -9999.0              1.46149
# LS_type                                    N/A                  N/A
# sersic                                 -9999.0              -9999.0
# sersic_ivar                            -9999.0              -9999.0
# shape_r                                -9999.0              -9999.0
# shape_r_ivar                           -9999.0              -9999.0
# shape_e1                               -9999.0              -9999.0
# shape_e1_ivar                          -9999.0              -9999.0
# shape_e2                               -9999.0              -9999.0
# shape_e2_ivar                          -9999.0              -9999.0
# ext_flg                                  -9999                -9999
# flag_blending                                0                    0
# nsrc_2pix                                    4                    5
# flag_brightneighbor                          0                    0
# dist_nearest                          2.974406             1.768245
# class                                        0                    0
# spherex_class                                0                    0
# z                                      -9999.0              -9999.0
# z_err                                  -9999.0              -9999.0
# z_dup                                    -9999                -9999
# z_survey                                   N/A                  N/A
# z_ID                                       N/A                  N/A
#
#                                              2                    3
# SPHERExRefID               1333155100033548292  1333155100067102720
# Gaia_DR3_source_id                       -9999                -9999
# LegacySurvey_uid                         -9999                -9999
# PS1_DR1_StackObject_objID                -9999   123880492201128997
# CatWISE_source_id           0496p136_b0-061999   0496p136_b0-016795
# AllWISE_designation                        N/A                  N/A
# 2MASS_designation                          N/A                  N/A
# ra                                    49.22002             49.22015
# dec                                  13.243249            13.240385
# ra_error                              0.000164             0.000016
# dec_error                             0.000162             0.000015
# coord_src                                    3                    2
# pmra                                   -9999.0              -9999.0
# pmra_error                             -9999.0              -9999.0
# pmdec                                  -9999.0              -9999.0
# pmdec_error                            -9999.0              -9999.0
# parallax                               -9999.0              -9999.0
# parallax_error                         -9999.0              -9999.0
# ref_epoch                              -9999.0              -9999.0
# astrometric_params_solved                -9999                -9999
# CatWISE_PMRA                        -456.51001            46.189999
# CatWISE_PMDec                      -813.799988           -25.110001
# CatWISE_sigPMRA                          248.5            53.799999
# CatWISE_sigPMDec                    257.600006            57.400002
# Gaia_G                                 -9999.0              -9999.0
# Gaia_BP                                -9999.0              -9999.0
# Gaia_RP                                -9999.0              -9999.0
# Gaia_G_error                           -9999.0              -9999.0
# Gaia_BP_error                          -9999.0              -9999.0
# Gaia_RP_error                          -9999.0              -9999.0
# LS_g                                   -9999.0              -9999.0
# LS_r                                   -9999.0              -9999.0
# LS_z                                   -9999.0              -9999.0
# LS_g_error                             -9999.0              -9999.0
# LS_r_error                             -9999.0              -9999.0
# LS_z_error                             -9999.0              -9999.0
# PS1_g                                  -9999.0             1.204813
# PS1_r                                  -9999.0             2.668333
# PS1_i                                  -9999.0             6.361507
# PS1_z                                  -9999.0             9.229964
# PS1_y                                  -9999.0            17.125356
# PS1_g_error                            -9999.0             0.308432
# PS1_r_error                            -9999.0             0.379235
# PS1_i_error                            -9999.0             0.498722
# PS1_z_error                            -9999.0             0.769793
# PS1_y_error                            -9999.0             2.353932
# 2MASS_J                                -9999.0              -9999.0
# 2MASS_H                                -9999.0              -9999.0
# 2MASS_Ks                               -9999.0              -9999.0
# 2MASS_J_error                          -9999.0              -9999.0
# 2MASS_H_error                          -9999.0              -9999.0
# 2MASS_Ks_error                         -9999.0              -9999.0
# WISE_W1                              14.125375            60.089695
# WISE_W2                              11.492116            37.290654
# WISE_W1_error                          2.39325             2.766561
# WISE_W2_error                         4.719598             4.292202
# WISE_W3                                -9999.0              -9999.0
# WISE_W4                                -9999.0              -9999.0
# WISE_W3_error                          -9999.0              -9999.0
# WISE_W4_error                          -9999.0              -9999.0
# rKronRad                               -9999.0              2.62717
# rKronMag                               -9999.0            22.487499
# rKronMagErr                            -9999.0              0.20371
# rPSFMag                                -9999.0              22.8344
# rPSFMagErr                             -9999.0             0.154347
# rSerRadius                             -9999.0              -9999.0
# rSerMag                                -9999.0              -9999.0
# rSerAb                                 -9999.0              -9999.0
# rSerNu                                 -9999.0              -9999.0
# rSerPhi                                -9999.0              -9999.0
# rSerRa                                 -9999.0              -9999.0
# rSerDec                                -9999.0              -9999.0
# rSerRadiusErr                          -9999.0              -9999.0
# rSerMagErr                             -9999.0              -9999.0
# rSerAbErr                              -9999.0              -9999.0
# rSerNuErr                              -9999.0              -9999.0
# rSerPhiErr                             -9999.0              -9999.0
# rSerRaErr                              -9999.0              -9999.0
# rSerDecErr                             -9999.0              -9999.0
# rSerChisq                              -9999.0              -9999.0
# LS_type                                    N/A                  N/A
# sersic                                 -9999.0              -9999.0
# sersic_ivar                            -9999.0              -9999.0
# shape_r                                -9999.0              -9999.0
# shape_r_ivar                           -9999.0              -9999.0
# shape_e1                               -9999.0              -9999.0
# shape_e1_ivar                          -9999.0              -9999.0
# shape_e2                               -9999.0              -9999.0
# shape_e2_ivar                          -9999.0              -9999.0
# ext_flg                                  -9999                -9999
# flag_blending                                0                    0
# nsrc_2pix                                    5                    4
# flag_brightneighbor                          1                    1
# dist_nearest                          5.848527             4.831284
# class                                        0                    0
# spherex_class                                0                    0
# z                                      -9999.0              -9999.0
# z_err                                  -9999.0              -9999.0
# z_dup                                    -9999                -9999
# z_survey                                   N/A                  N/A
# z_ID                                       N/A                  N/A

# %%
photdf.dtypes
# Out:
# SPHERExRefID                   int64
# Gaia_DR3_source_id             int64
# LegacySurvey_uid               int64
# PS1_DR1_StackObject_objID      int64
# CatWISE_source_id             object
# AllWISE_designation           object
# 2MASS_designation             object
# ra                           float64
# dec                          float64
# ra_error                     float64
# dec_error                    float64
# coord_src                      int64
# pmra                         float64
# pmra_error                   float32
# pmdec                        float64
# pmdec_error                  float32
# parallax                     float64
# parallax_error               float32
# ref_epoch                    float64
# astrometric_params_solved      int16
# CatWISE_PMRA                 float32
# CatWISE_PMDec                float32
# CatWISE_sigPMRA              float32
# CatWISE_sigPMDec             float32
# Gaia_G                       float32
# Gaia_BP                      float32
# Gaia_RP                      float32
# Gaia_G_error                 float64
# Gaia_BP_error                float64
# Gaia_RP_error                float64
# LS_g                         float64
# LS_r                         float64
# LS_z                         float64
# LS_g_error                   float64
# LS_r_error                   float64
# LS_z_error                   float64
# PS1_g                        float64
# PS1_r                        float64
# PS1_i                        float64
# PS1_z                        float64
# PS1_y                        float64
# PS1_g_error                  float64
# PS1_r_error                  float64
# PS1_i_error                  float64
# PS1_z_error                  float64
# PS1_y_error                  float64
# 2MASS_J                      float64
# 2MASS_H                      float64
# 2MASS_Ks                     float64
# 2MASS_J_error                float64
# 2MASS_H_error                float64
# 2MASS_Ks_error               float64
# WISE_W1                      float64
# WISE_W2                      float64
# WISE_W1_error                float64
# WISE_W2_error                float64
# WISE_W3                      float64
# WISE_W4                      float64
# WISE_W3_error                float64
# WISE_W4_error                float64
# rKronRad                     float64
# rKronMag                     float64
# rKronMagErr                  float64
# rPSFMag                      float64
# rPSFMagErr                   float64
# rSerRadius                   float64
# rSerMag                      float64
# rSerAb                       float64
# rSerNu                       float64
# rSerPhi                      float64
# rSerRa                       float64
# rSerDec                      float64
# rSerRadiusErr                float64
# rSerMagErr                   float64
# rSerAbErr                    float64
# rSerNuErr                    float64
# rSerPhiErr                   float64
# rSerRaErr                    float64
# rSerDecErr                   float64
# rSerChisq                    float64
# LS_type                       object
# sersic                       float32
# sersic_ivar                  float32
# shape_r                      float32
# shape_r_ivar                 float32
# shape_e1                     float32
# shape_e1_ivar                float32
# shape_e2                     float32
# shape_e2_ivar                float32
# ext_flg                        int32
# flag_blending                  int16
# nsrc_2pix                      int16
# flag_brightneighbor            int16
# dist_nearest                 float32
# class                          int16
# spherex_class                  int32
# z                            float32
# z_err                        float32
# z_dup                          int16
# z_survey                      object
# z_ID                          object
# dtype: object

# %% [markdown]
# ### Change `object` to `string`

# %%
# Select object columns
object_cols = photdf.select_dtypes(include=['object']).columns

# %%
print(object_cols)
# Out:
# Index(['CatWISE_source_id', 'AllWISE_designation', '2MASS_designation',
#        'LS_type', 'z_survey', 'z_ID'],
#       dtype='object')

# %%
# Convert object columns to string type
photdf[object_cols] = photdf[object_cols].astype("string")

# %%
photdf.dtypes
# Out:
# SPHERExRefID                   int64
# Gaia_DR3_source_id             int64
# LegacySurvey_uid               int64
# PS1_DR1_StackObject_objID      int64
# CatWISE_source_id             string
# AllWISE_designation           string
# 2MASS_designation             string
# ra                           float64
# dec                          float64
# ra_error                     float64
# dec_error                    float64
# coord_src                      int64
# pmra                         float64
# pmra_error                   float32
# pmdec                        float64
# pmdec_error                  float32
# parallax                     float64
# parallax_error               float32
# ref_epoch                    float64
# astrometric_params_solved      int16
# CatWISE_PMRA                 float32
# CatWISE_PMDec                float32
# CatWISE_sigPMRA              float32
# CatWISE_sigPMDec             float32
# Gaia_G                       float32
# Gaia_BP                      float32
# Gaia_RP                      float32
# Gaia_G_error                 float64
# Gaia_BP_error                float64
# Gaia_RP_error                float64
# LS_g                         float64
# LS_r                         float64
# LS_z                         float64
# LS_g_error                   float64
# LS_r_error                   float64
# LS_z_error                   float64
# PS1_g                        float64
# PS1_r                        float64
# PS1_i                        float64
# PS1_z                        float64
# PS1_y                        float64
# PS1_g_error                  float64
# PS1_r_error                  float64
# PS1_i_error                  float64
# PS1_z_error                  float64
# PS1_y_error                  float64
# 2MASS_J                      float64
# 2MASS_H                      float64
# 2MASS_Ks                     float64
# 2MASS_J_error                float64
# 2MASS_H_error                float64
# 2MASS_Ks_error               float64
# WISE_W1                      float64
# WISE_W2                      float64
# WISE_W1_error                float64
# WISE_W2_error                float64
# WISE_W3                      float64
# WISE_W4                      float64
# WISE_W3_error                float64
# WISE_W4_error                float64
# rKronRad                     float64
# rKronMag                     float64
# rKronMagErr                  float64
# rPSFMag                      float64
# rPSFMagErr                   float64
# rSerRadius                   float64
# rSerMag                      float64
# rSerAb                       float64
# rSerNu                       float64
# rSerPhi                      float64
# rSerRa                       float64
# rSerDec                      float64
# rSerRadiusErr                float64
# rSerMagErr                   float64
# rSerAbErr                    float64
# rSerNuErr                    float64
# rSerPhiErr                   float64
# rSerRaErr                    float64
# rSerDecErr                   float64
# rSerChisq                    float64
# LS_type                       string
# sersic                       float32
# sersic_ivar                  float32
# shape_r                      float32
# shape_r_ivar                 float32
# shape_e1                     float32
# shape_e1_ivar                float32
# shape_e2                     float32
# shape_e2_ivar                float32
# ext_flg                        int32
# flag_blending                  int16
# nsrc_2pix                      int16
# flag_brightneighbor            int16
# dist_nearest                 float32
# class                          int16
# spherex_class                  int32
# z                            float32
# z_err                        float32
# z_dup                          int16
# z_survey                      string
# z_ID                          string
# dtype: object

# %% [markdown]
# ### Change `float32` to `float64`
#
# > There are some conversion bugs from pandas float to spark double. I will see all float32 to float64

# %%
# Select object columns
float_cols = photdf.select_dtypes(include=['float32']).columns

# %%
print(float_cols)
# Out:
# Index([], dtype='object')

# %%
# Convert object columns to string type
photdf[float_cols] = photdf[float_cols].astype("float64")

# %%
photdf.dtypes
# Out:
# SPHERExRefID                   int64
# Gaia_DR3_source_id             int64
# LegacySurvey_uid               int64
# PS1_DR1_StackObject_objID      int64
# CatWISE_source_id             string
# AllWISE_designation           string
# 2MASS_designation             string
# ra                           float64
# dec                          float64
# ra_error                     float64
# dec_error                    float64
# coord_src                      int64
# pmra                         float64
# pmra_error                   float64
# pmdec                        float64
# pmdec_error                  float64
# parallax                     float64
# parallax_error               float64
# ref_epoch                    float64
# astrometric_params_solved      int16
# CatWISE_PMRA                 float64
# CatWISE_PMDec                float64
# CatWISE_sigPMRA              float64
# CatWISE_sigPMDec             float64
# Gaia_G                       float64
# Gaia_BP                      float64
# Gaia_RP                      float64
# Gaia_G_error                 float64
# Gaia_BP_error                float64
# Gaia_RP_error                float64
# LS_g                         float64
# LS_r                         float64
# LS_z                         float64
# LS_g_error                   float64
# LS_r_error                   float64
# LS_z_error                   float64
# PS1_g                        float64
# PS1_r                        float64
# PS1_i                        float64
# PS1_z                        float64
# PS1_y                        float64
# PS1_g_error                  float64
# PS1_r_error                  float64
# PS1_i_error                  float64
# PS1_z_error                  float64
# PS1_y_error                  float64
# 2MASS_J                      float64
# 2MASS_H                      float64
# 2MASS_Ks                     float64
# 2MASS_J_error                float64
# 2MASS_H_error                float64
# 2MASS_Ks_error               float64
# WISE_W1                      float64
# WISE_W2                      float64
# WISE_W1_error                float64
# WISE_W2_error                float64
# WISE_W3                      float64
# WISE_W4                      float64
# WISE_W3_error                float64
# WISE_W4_error                float64
# rKronRad                     float64
# rKronMag                     float64
# rKronMagErr                  float64
# rPSFMag                      float64
# rPSFMagErr                   float64
# rSerRadius                   float64
# rSerMag                      float64
# rSerAb                       float64
# rSerNu                       float64
# rSerPhi                      float64
# rSerRa                       float64
# rSerDec                      float64
# rSerRadiusErr                float64
# rSerMagErr                   float64
# rSerAbErr                    float64
# rSerNuErr                    float64
# rSerPhiErr                   float64
# rSerRaErr                    float64
# rSerDecErr                   float64
# rSerChisq                    float64
# LS_type                       string
# sersic                       float64
# sersic_ivar                  float64
# shape_r                      float64
# shape_r_ivar                 float64
# shape_e1                     float64
# shape_e1_ivar                float64
# shape_e2                     float64
# shape_e2_ivar                float64
# ext_flg                        int32
# flag_blending                  int16
# nsrc_2pix                      int16
# flag_brightneighbor            int16
# dist_nearest                 float64
# class                          int16
# spherex_class                  int32
# z                            float64
# z_err                        float64
# z_dup                          int16
# z_survey                      string
# z_ID                          string
# dtype: object

# %% [markdown]
# ### Change `pandas dataframe` to `pyspark dataframe`

# %%
photsdf = spark.createDataFrame(photdf)

# %%
photsdf.printSchema()
# Out:
# root
#  |-- SPHERExRefID: long (nullable = true)
#  |-- Gaia_DR3_source_id: long (nullable = true)
#  |-- LegacySurvey_uid: long (nullable = true)
#  |-- PS1_DR1_StackObject_objID: long (nullable = true)
#  |-- CatWISE_source_id: string (nullable = true)
#  |-- AllWISE_designation: string (nullable = true)
#  |-- 2MASS_designation: string (nullable = true)
#  |-- ra: double (nullable = true)
#  |-- dec: double (nullable = true)
#  |-- ra_error: double (nullable = true)
#  |-- dec_error: double (nullable = true)
#  |-- coord_src: long (nullable = true)
#  |-- pmra: double (nullable = true)
#  |-- pmra_error: double (nullable = true)
#  |-- pmdec: double (nullable = true)
#  |-- pmdec_error: double (nullable = true)
#  |-- parallax: double (nullable = true)
#  |-- parallax_error: double (nullable = true)
#  |-- ref_epoch: double (nullable = true)
#  |-- astrometric_params_solved: short (nullable = true)
#  |-- CatWISE_PMRA: double (nullable = true)
#  |-- CatWISE_PMDec: double (nullable = true)
#  |-- CatWISE_sigPMRA: double (nullable = true)
#  |-- CatWISE_sigPMDec: double (nullable = true)
#  |-- Gaia_G: double (nullable = true)
#  |-- Gaia_BP: double (nullable = true)
#  |-- Gaia_RP: double (nullable = true)
#  |-- Gaia_G_error: double (nullable = true)
#  |-- Gaia_BP_error: double (nullable = true)
#  |-- Gaia_RP_error: double (nullable = true)
#  |-- LS_g: double (nullable = true)
#  |-- LS_r: double (nullable = true)
#  |-- LS_z: double (nullable = true)
#  |-- LS_g_error: double (nullable = true)
#  |-- LS_r_error: double (nullable = true)
#  |-- LS_z_error: double (nullable = true)
#  |-- PS1_g: double (nullable = true)
#  |-- PS1_r: double (nullable = true)
#  |-- PS1_i: double (nullable = true)
#  |-- PS1_z: double (nullable = true)
#  |-- PS1_y: double (nullable = true)
#  |-- PS1_g_error: double (nullable = true)
#  |-- PS1_r_error: double (nullable = true)
#  |-- PS1_i_error: double (nullable = true)
#  |-- PS1_z_error: double (nullable = true)
#  |-- PS1_y_error: double (nullable = true)
#  |-- 2MASS_J: double (nullable = true)
#  |-- 2MASS_H: double (nullable = true)
#  |-- 2MASS_Ks: double (nullable = true)
#  |-- 2MASS_J_error: double (nullable = true)
#  |-- 2MASS_H_error: double (nullable = true)
#  |-- 2MASS_Ks_error: double (nullable = true)
#  |-- WISE_W1: double (nullable = true)
#  |-- WISE_W2: double (nullable = true)
#  |-- WISE_W1_error: double (nullable = true)
#  |-- WISE_W2_error: double (nullable = true)
#  |-- WISE_W3: double (nullable = true)
#  |-- WISE_W4: double (nullable = true)
#  |-- WISE_W3_error: double (nullable = true)
#  |-- WISE_W4_error: double (nullable = true)
#  |-- rKronRad: double (nullable = true)
#  |-- rKronMag: double (nullable = true)
#  |-- rKronMagErr: double (nullable = true)
#  |-- rPSFMag: double (nullable = true)
#  |-- rPSFMagErr: double (nullable = true)
#  |-- rSerRadius: double (nullable = true)
#  |-- rSerMag: double (nullable = true)
#  |-- rSerAb: double (nullable = true)
#  |-- rSerNu: double (nullable = true)
#  |-- rSerPhi: double (nullable = true)
#  |-- rSerRa: double (nullable = true)
#  |-- rSerDec: double (nullable = true)
#  |-- rSerRadiusErr: double (nullable = true)
#  |-- rSerMagErr: double (nullable = true)
#  |-- rSerAbErr: double (nullable = true)
#  |-- rSerNuErr: double (nullable = true)
#  |-- rSerPhiErr: double (nullable = true)
#  |-- rSerRaErr: double (nullable = true)
#  |-- rSerDecErr: double (nullable = true)
#  |-- rSerChisq: double (nullable = true)
#  |-- LS_type: string (nullable = true)
#  |-- sersic: double (nullable = true)
#  |-- sersic_ivar: double (nullable = true)
#  |-- shape_r: double (nullable = true)
#  |-- shape_r_ivar: double (nullable = true)
#  |-- shape_e1: double (nullable = true)
#  |-- shape_e1_ivar: double (nullable = true)
#  |-- shape_e2: double (nullable = true)
#  |-- shape_e2_ivar: double (nullable = true)
#  |-- ext_flg: integer (nullable = true)
#  |-- flag_blending: short (nullable = true)
#  |-- nsrc_2pix: short (nullable = true)
#  |-- flag_brightneighbor: short (nullable = true)
#  |-- dist_nearest: double (nullable = true)
#  |-- class: short (nullable = true)
#  |-- spherex_class: integer (nullable = true)
#  |-- z: double (nullable = true)
#  |-- z_err: double (nullable = true)
#  |-- z_dup: short (nullable = true)
#  |-- z_survey: string (nullable = true)
#  |-- z_ID: string (nullable = true)

# %%
photsdf.show(3,truncate=True)
# Out:
# +-------------------+------------------+----------------+-------------------------+------------------+-------------------+-----------------+------------------+------------------+--------------------+--------------------+---------+-------+----------+-------+-----------+--------+--------------+---------+-------------------------+-----------------+------------------+---------------+-----------------+-------+-------+-------+------------+-------------+-------------+-------+-------+-------+----------+----------+----------+-----------------+-----------------+-----------------+------------------+------------------+-------------------+------------------+------------------+------------------+------------------+-------+-------+--------+-------------+-------------+--------------+------------------+------------------+-----------------+-----------------+-------+-------+-------------+-------------+---------+---------+-----------+---------+----------+------------------+------------------+------------------+------------------+-----------------+----------------+----------------+-------------------+--------------------+--------------------+-------------------+--------------------+--------------------+--------------------+------------------+-------+-------+-----------+-------+------------+--------+-------------+--------+-------------+-------+-------------+---------+-------------------+------------------+-----+-------------+-------+-------+-----+--------+----+
# |       SPHERExRefID|Gaia_DR3_source_id|LegacySurvey_uid|PS1_DR1_StackObject_objID| CatWISE_source_id|AllWISE_designation|2MASS_designation|                ra|               dec|            ra_error|           dec_error|coord_src|   pmra|pmra_error|  pmdec|pmdec_error|parallax|parallax_error|ref_epoch|astrometric_params_solved|     CatWISE_PMRA|     CatWISE_PMDec|CatWISE_sigPMRA| CatWISE_sigPMDec| Gaia_G|Gaia_BP|Gaia_RP|Gaia_G_error|Gaia_BP_error|Gaia_RP_error|   LS_g|   LS_r|   LS_z|LS_g_error|LS_r_error|LS_z_error|            PS1_g|            PS1_r|            PS1_i|             PS1_z|             PS1_y|        PS1_g_error|       PS1_r_error|       PS1_i_error|       PS1_z_error|       PS1_y_error|2MASS_J|2MASS_H|2MASS_Ks|2MASS_J_error|2MASS_H_error|2MASS_Ks_error|           WISE_W1|           WISE_W2|    WISE_W1_error|    WISE_W2_error|WISE_W3|WISE_W4|WISE_W3_error|WISE_W4_error| rKronRad| rKronMag|rKronMagErr|  rPSFMag|rPSFMagErr|        rSerRadius|           rSerMag|            rSerAb|            rSerNu|          rSerPhi|          rSerRa|         rSerDec|      rSerRadiusErr|          rSerMagErr|           rSerAbErr|          rSerNuErr|          rSerPhiErr|           rSerRaErr|          rSerDecErr|         rSerChisq|LS_type| sersic|sersic_ivar|shape_r|shape_r_ivar|shape_e1|shape_e1_ivar|shape_e2|shape_e2_ivar|ext_flg|flag_blending|nsrc_2pix|flag_brightneighbor|      dist_nearest|class|spherex_class|      z|  z_err|z_dup|z_survey|z_ID|
# +-------------------+------------------+----------------+-------------------------+------------------+-------------------+-----------------+------------------+------------------+--------------------+--------------------+---------+-------+----------+-------+-----------+--------+--------------+---------+-------------------------+-----------------+------------------+---------------+-----------------+-------+-------+-------+------------+-------------+-------------+-------+-------+-------+----------+----------+----------+-----------------+-----------------+-----------------+------------------+------------------+-------------------+------------------+------------------+------------------+------------------+-------+-------+--------+-------------+-------------+--------------+------------------+------------------+-----------------+-----------------+-------+-------+-------------+-------------+---------+---------+-----------+---------+----------+------------------+------------------+------------------+------------------+-----------------+----------------+----------------+-------------------+--------------------+--------------------+-------------------+--------------------+--------------------+--------------------+------------------+-------+-------+-----------+-------+------------+--------+-------------+--------+-------------+-------+-------------+---------+-------------------+------------------+-----+-------------+-------+-------+-----+--------+----+
# |1333155099932884993|             -9999|           -9999|       123890492204260534|               N/A|                N/A|              N/A|49.220481641412704|13.241687291162014|1.206237532974069...|1.130277805555555...|        2|-9999.0|   -9999.0|-9999.0|    -9999.0| -9999.0|       -9999.0|  -9999.0|                    -9999|          -9999.0|           -9999.0|        -9999.0|          -9999.0|-9999.0|-9999.0|-9999.0|     -9999.0|      -9999.0|      -9999.0|-9999.0|-9999.0|-9999.0|   -9999.0|   -9999.0|   -9999.0|          -9999.0|2.222900379553022|7.544665679369033|14.535835517458075| 26.18183008218981|            -9999.0|0.3530809113003105|0.5028526830921606|0.8598629062991441| 2.343490696522884|-9999.0|-9999.0| -9999.0|      -9999.0|      -9999.0|       -9999.0|           -9999.0|           -9999.0|          -9999.0|          -9999.0|-9999.0|-9999.0|      -9999.0|      -9999.0|  1.80567|23.448999|   0.324375|  23.0327|  0.172498|           -9999.0|           -9999.0|           -9999.0|           -9999.0|          -9999.0|         -9999.0|         -9999.0|            -9999.0|             -9999.0|             -9999.0|            -9999.0|             -9999.0|             -9999.0|             -9999.0|           -9999.0|    N/A|-9999.0|    -9999.0|-9999.0|     -9999.0| -9999.0|      -9999.0| -9999.0|      -9999.0|  -9999|            0|        4|                  0|2.9744057655334473|    0|            0|-9999.0|-9999.0|-9999|     N/A| N/A|
# |1333155099932884994|             -9999|           -9999|       123890492217870778|               N/A|                N/A|              N/A| 49.22180092141347|13.241899851162014|8.064419596502049E-6|1.693333305555555...|        2|-9999.0|   -9999.0|-9999.0|    -9999.0| -9999.0|       -9999.0|  -9999.0|                    -9999|          -9999.0|           -9999.0|        -9999.0|          -9999.0|-9999.0|-9999.0|-9999.0|     -9999.0|      -9999.0|      -9999.0|-9999.0|-9999.0|-9999.0|   -9999.0|   -9999.0|   -9999.0|1.064143018224315|3.205675809725977|8.542803167257336|11.598451211901645|16.930898260467725|0.32787756377118293|0.3534685594028056| 0.440638747055887|0.8439101133210779|2.5176683796410457|-9999.0|-9999.0| -9999.0|      -9999.0|      -9999.0|       -9999.0|           -9999.0|           -9999.0|          -9999.0|          -9999.0|-9999.0|-9999.0|      -9999.0|      -9999.0|2.8329699|  21.8402|   0.116412|22.635201|  0.119746|1.9562100172042847|21.509599685668945|0.3336699903011322|1.2638200521469116|-86.1498031616211|49.2217636108398|13.2418613433838|0.00521906977519393|0.003435730002820492|0.001584229990839...|0.10000000149011612|0.017278200015425682|0.001493699965067...|0.001404509996064...|1.4614900350570679|    N/A|-9999.0|    -9999.0|-9999.0|     -9999.0| -9999.0|      -9999.0| -9999.0|      -9999.0|  -9999|            0|        5|                  0|1.7682452201843262|    0|            0|-9999.0|-9999.0|-9999|     N/A| N/A|
# |1333155100033548292|             -9999|           -9999|                    -9999|0496p136_b0-061999|                N/A|              N/A|  49.2200203704391|13.243248601336816|1.636863661042760...|1.623888888888889E-4|        3|-9999.0|   -9999.0|-9999.0|    -9999.0| -9999.0|       -9999.0|  -9999.0|                    -9999|-456.510009765625|-813.7999877929688|          248.5|257.6000061035156|-9999.0|-9999.0|-9999.0|     -9999.0|      -9999.0|      -9999.0|-9999.0|-9999.0|-9999.0|   -9999.0|   -9999.0|   -9999.0|          -9999.0|          -9999.0|          -9999.0|           -9999.0|           -9999.0|            -9999.0|           -9999.0|           -9999.0|           -9999.0|           -9999.0|-9999.0|-9999.0| -9999.0|      -9999.0|      -9999.0|       -9999.0|14.125375446227547|11.492115972032408|2.393249615198774|4.719598272123807|-9999.0|-9999.0|      -9999.0|      -9999.0|  -9999.0|  -9999.0|    -9999.0|  -9999.0|   -9999.0|           -9999.0|           -9999.0|           -9999.0|           -9999.0|          -9999.0|         -9999.0|         -9999.0|            -9999.0|             -9999.0|             -9999.0|            -9999.0|             -9999.0|             -9999.0|             -9999.0|           -9999.0|    N/A|-9999.0|    -9999.0|-9999.0|     -9999.0| -9999.0|      -9999.0| -9999.0|      -9999.0|  -9999|            0|        5|                  1| 5.848526954650879|    0|            0|-9999.0|-9999.0|-9999|     N/A| N/A|
# +-------------------+------------------+----------------+-------------------------+------------------+-------------------+-----------------+------------------+------------------+--------------------+--------------------+---------+-------+----------+-------+-----------+--------+--------------+---------+-------------------------+-----------------+------------------+---------------+-----------------+-------+-------+-------+------------+-------------+-------------+-------+-------+-------+----------+----------+----------+-----------------+-----------------+-----------------+------------------+------------------+-------------------+------------------+------------------+------------------+------------------+-------+-------+--------+-------------+-------------+--------------+------------------+------------------+-----------------+-----------------+-------+-------+-------------+-------------+---------+---------+-----------+---------+----------+------------------+------------------+------------------+------------------+-----------------+----------------+----------------+-------------------+--------------------+--------------------+-------------------+--------------------+--------------------+--------------------+------------------+-------+-------+-----------+-------+------------+--------+-------------+--------+-------------+-------+-------------+---------+-------------------+------------------+-----+-------------+-------+-------+-----+--------+----+
# only showing top 3 rows

# %% [markdown]
# ## Save the spark dataframe in HDFS

# %%
hdfsheader+datapath
# Out:
# 'hdfs://spark00:54310/user/shong/data/spherex/star-classification/input-ref-cat/'

# %%
localrefcatpath+listrefcat[0]
# Out:
# '/mnt/raid5/yyang/SPHEREx_RefCat/Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_000030.parquet'

# %%
nrefcatfile = len(listrefcat)
print(nrefcatfile)
# Out:
# 12288

# %%
listrefcat[0]+'.snappy'
# Out:
# 'Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_000030.parquet.snappy'

# %%
outname = hdfsheader+datapath+listrefcat[0]+'.snappy'
print(outname)
# Out:
# hdfs://spark00:54310/user/shong/data/spherex/star-classification/input-ref-cat/Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_000030.parquet.snappy

# %%
#photsdf.cache()

# %%
#%%time
#photsdf \
#    .write.option("compression", "snappy") \
#    .mode("overwrite") \
#    .save(outname)

# %% [markdown]
# # Loop the conversion job
#
# **from astropy.table parquet to pyspark dataframe parquet**

# %%
nrefcatfile = len(listrefcat)
print(nrefcatfile)
# Out:
# 12288

# %%
# for testing .. 
#nrefcatfile = 5

# %% [markdown]
# #### Sanity Check for Paths

# %%
hdfsheader = 'hdfs://spark00:54310'
workpath = '/user/shong/work/sedfit/spherex/data/temp/'
datapath = '/user/shong/data/spherex/star-classification/input-ref-cat/'
localrefcatpath = '/mnt/raid5/yyang/SPHEREx_RefCat/'

# %%
localrefcatpath+listrefcat[12287]
# Out:
# '/mnt/raid5/yyang/SPHEREx_RefCat/Gaia_DR3.LS.PS1DR1.CatWISE.AllWISE.2MASS_NSIDE32_007313.parquet'

# %% [markdown]
# #### Loop the conversion on All RefCat Files

# %%
from tqdm import tqdm

# %%
# %%time
for ifile in tqdm(range(nrefcatfile), position=0, leave=True):
#for imore in tqdm(range(88), position=0, leave=True):
    #ifile = imore + 12200
    phot = Table.read(localrefcatpath+listrefcat[ifile])
    photdf = phot.to_pandas()
    
    # Handle byte encoded columns 
    byte_encoded_columns = []
    for col in photdf.columns:
        if isinstance(photdf[col].iloc[0], bytes):
            byte_encoded_columns.append(col)
    
    for col in byte_encoded_columns:
        photdf[col] = photdf[col].str.decode('utf-8')
    
    # Handle object columns
    object_cols = photdf.select_dtypes(include=['object']).columns
    photdf[object_cols] = photdf[object_cols].astype("string")
    
    # Handle float32 columns 
    float_cols = photdf.select_dtypes(include=['float32']).columns
    photdf[float_cols] = photdf[float_cols].astype("float64")
    
    
    # Save photdf as a pyspark dataframe on HDFS
    outname = hdfsheader+datapath+listrefcat[ifile]+'.snappy'
    
    spark.createDataFrame(photdf) \
        .write.option("compression", "snappy") \
        .mode("overwrite") \
        .save(outname)
# Out:
# 100%|██████████| 12288/12288 [32:00:19<00:00,  9.38s/it]
# CPU times: user 7h 42min 19s, sys: 2h 3min 12s, total: 9h 45min 32s
# Wall time: 1d 8h 19s

# %% [markdown]
# ## Check out the outputs

# %%
nrefcatfile * 3 / 3600
# Out:
# 10.24

# %%
#!hadoop fs -ls {hdfsheader+datapath}

# %%
import pyarrow as pa
import pyarrow.parquet as pq

# %%
# %%time
rawdf = spark.read.option("header","true").option("recursiveFileLookup","true").parquet(hdfsheader+datapath)
# Out:
# CPU times: user 3 ms, sys: 0 ns, total: 3 ms
# Wall time: 8.73 s

# %%
#%%time
#rawdf.count()

# %%
rawdf.printSchema()
# Out:
# root
#  |-- SPHERExRefID: long (nullable = true)
#  |-- Gaia_DR3_source_id: long (nullable = true)
#  |-- LegacySurvey_uid: long (nullable = true)
#  |-- PS1_DR1_StackObject_objID: long (nullable = true)
#  |-- CatWISE_source_id: string (nullable = true)
#  |-- AllWISE_designation: string (nullable = true)
#  |-- 2MASS_designation: string (nullable = true)
#  |-- ra: double (nullable = true)
#  |-- dec: double (nullable = true)
#  |-- ra_error: double (nullable = true)
#  |-- dec_error: double (nullable = true)
#  |-- coord_src: long (nullable = true)
#  |-- pmra: double (nullable = true)
#  |-- pmra_error: double (nullable = true)
#  |-- pmdec: double (nullable = true)
#  |-- pmdec_error: double (nullable = true)
#  |-- parallax: double (nullable = true)
#  |-- parallax_error: double (nullable = true)
#  |-- ref_epoch: double (nullable = true)
#  |-- astrometric_params_solved: short (nullable = true)
#  |-- CatWISE_PMRA: double (nullable = true)
#  |-- CatWISE_PMDec: double (nullable = true)
#  |-- CatWISE_sigPMRA: double (nullable = true)
#  |-- CatWISE_sigPMDec: double (nullable = true)
#  |-- Gaia_G: double (nullable = true)
#  |-- Gaia_BP: double (nullable = true)
#  |-- Gaia_RP: double (nullable = true)
#  |-- Gaia_G_error: double (nullable = true)
#  |-- Gaia_BP_error: double (nullable = true)
#  |-- Gaia_RP_error: double (nullable = true)
#  |-- LS_g: double (nullable = true)
#  |-- LS_r: double (nullable = true)
#  |-- LS_z: double (nullable = true)
#  |-- LS_g_error: double (nullable = true)
#  |-- LS_r_error: double (nullable = true)
#  |-- LS_z_error: double (nullable = true)
#  |-- PS1_g: double (nullable = true)
#  |-- PS1_r: double (nullable = true)
#  |-- PS1_i: double (nullable = true)
#  |-- PS1_z: double (nullable = true)
#  |-- PS1_y: double (nullable = true)
#  |-- PS1_g_error: double (nullable = true)
#  |-- PS1_r_error: double (nullable = true)
#  |-- PS1_i_error: double (nullable = true)
#  |-- PS1_z_error: double (nullable = true)
#  |-- PS1_y_error: double (nullable = true)
#  |-- 2MASS_J: double (nullable = true)
#  |-- 2MASS_H: double (nullable = true)
#  |-- 2MASS_Ks: double (nullable = true)
#  |-- 2MASS_J_error: double (nullable = true)
#  |-- 2MASS_H_error: double (nullable = true)
#  |-- 2MASS_Ks_error: double (nullable = true)
#  |-- WISE_W1: double (nullable = true)
#  |-- WISE_W2: double (nullable = true)
#  |-- WISE_W1_error: double (nullable = true)
#  |-- WISE_W2_error: double (nullable = true)
#  |-- WISE_W3: double (nullable = true)
#  |-- WISE_W4: double (nullable = true)
#  |-- WISE_W3_error: double (nullable = true)
#  |-- WISE_W4_error: double (nullable = true)
#  |-- rKronRad: double (nullable = true)
#  |-- rKronMag: double (nullable = true)
#  |-- rKronMagErr: double (nullable = true)
#  |-- rPSFMag: double (nullable = true)
#  |-- rPSFMagErr: double (nullable = true)
#  |-- rSerRadius: double (nullable = true)
#  |-- rSerMag: double (nullable = true)
#  |-- rSerAb: double (nullable = true)
#  |-- rSerNu: double (nullable = true)
#  |-- rSerPhi: double (nullable = true)
#  |-- rSerRa: double (nullable = true)
#  |-- rSerDec: double (nullable = true)
#  |-- rSerRadiusErr: double (nullable = true)
#  |-- rSerMagErr: double (nullable = true)
#  |-- rSerAbErr: double (nullable = true)
#  |-- rSerNuErr: double (nullable = true)
#  |-- rSerPhiErr: double (nullable = true)
#  |-- rSerRaErr: double (nullable = true)
#  |-- rSerDecErr: double (nullable = true)
#  |-- rSerChisq: double (nullable = true)
#  |-- type: string (nullable = true)
#  |-- sersic: double (nullable = true)
#  |-- sersic_ivar: double (nullable = true)
#  |-- shape_r: double (nullable = true)
#  |-- shape_r_ivar: double (nullable = true)
#  |-- shape_e1: double (nullable = true)
#  |-- shape_e1_ivar: double (nullable = true)
#  |-- shape_e2: double (nullable = true)
#  |-- shape_e2_ivar: double (nullable = true)
#  |-- ext_flg: integer (nullable = true)
#  |-- flag_blending: short (nullable = true)
#  |-- nsrc_2pix: short (nullable = true)
#  |-- flag_brightneighbor: short (nullable = true)
#  |-- dist_nearest: double (nullable = true)
#  |-- class: short (nullable = true)
#  |-- spherex_class: integer (nullable = true)
#  |-- z: double (nullable = true)
#  |-- z_err: double (nullable = true)
#  |-- z_dup: short (nullable = true)
#  |-- z_survey: string (nullable = true)
#  |-- z_ID: string (nullable = true)

# %%
#rawdf.show(3,truncate=True)
