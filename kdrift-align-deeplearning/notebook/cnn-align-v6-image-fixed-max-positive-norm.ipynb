# %% [markdown]
# # PyTorch DL for KDRIFT G1 Alignment
#
# - EDA the training set
# - Train using the baseline by the student's work
# - Image Normalization .. Let's find out what is the best "Fixed Max" value for ultimate normalization .. some modification.. not -1 to +1 .. 0 to 1 at absolute full normalization

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
#import tensorflow as tf
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense, SimpleRNN, Conv2D, MaxPooling2D, Flatten
import os
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
#from tensorflow.keras import backend as K
from tqdm import trange, notebook
#from livelossplot import PlotLossesKeras

import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib
# Basic Settings for matplotlib
matplotlib.rcParams["font.family"] = "serif"
matplotlib.rcParams["mathtext.fontset"] = "stix"
#%matplotlib inline
#matplotlib_inline.backend_inline.set_matplotlib_formats("svg", "pdf")  # For export
matplotlib.rcParams["lines.linewidth"] = 2.0

# %% [markdown]
# ## Browsing the working directories

# %%
# %pwd
# Out:
# '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/notebook'

# %%
# %ls
# Out:
# cnn-align-v1-no-rescale.ipynb
# cnn-align-v1-pix-norm.ipynb
# cnn-align-v2-image-norm.ipynb
# cnn-align-v3-image-zero-abs-norm.ipynb
# cnn-align-v4-image-both-sign-norm.ipynb
# cnn-align-v4a-image-both-sign-norm.ipynb
# cnn-align-v5-image-fixed-max-norm.ipynb
# cnn-align-v6-image-fixed-max-positive-norm.ipynb
# lightning_logs/
# vit-align-v1.ipynb

# %%
data_path = '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/data/'

# %%
# !ls {data_path}
# Out:
# X_f32.npy  y_f32.npy

# %% [markdown]
# ## Explore the training set

# %%
# %%time
X = np.load(data_path+'X_f32.npy')
y = np.load(data_path+'y_f32.npy')
# Out:
# CPU times: user 0 ns, sys: 217 ms, total: 217 ms
# Wall time: 217 ms

# %%
len(y),len(X)
# Out:
# (20000, 20000)

# %%
def np_array_info(a):
    print(f"shape     : {a.shape}")
    print(f"dtype     : {a.dtype}")
    print(f"ndim      : {a.ndim}")
    print(f"size      : {a.size}")
    print(f"itemsize  : {a.itemsize} bytes")
    print(f"nbytes    : {a.nbytes / 1024**2:.2f} MB")
    print(f"min / max : {a.min()} / {a.max()}")

# %%
np_array_info(y)
# Out:
# shape     : (20000, 6)
# dtype     : float32
# ndim      : 2
# size      : 120000
# itemsize  : 4 bytes
# nbytes    : 0.46 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(X)
# Out:
# shape     : (20000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 409600000
# itemsize  : 4 bytes
# nbytes    : 1562.50 MB
# min / max : -44.47488021850586 / 41.380958557128906

# %% [markdown]
# > I may need learn about what `X` and `y` mean. I am an instrument noob.

# %% [markdown]
# #### Visualize the training set

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_trainingsample(X, y, selected_index_list):
    n_samples = len(selected_index_list)
    n_views = X.shape[1]

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2)
    )

    vmin, vmax = X.min(), X.max()
    im = None

    for row, idx in enumerate(selected_index_list):
        for j in range(n_views):
            ax = axes[row, j]
            img = X[idx, j, :, :, 0]

            im = ax.imshow(
                img,
                cmap="rainbow",
                vmin=vmin,
                vmax=vmax,
                aspect="equal"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            if row == 0:
                ax.set_title(f"image {j+1}")

            # --- min / max labels (항상 포함)
            img_min = img.min()
            img_max = img.max()

            labels = [
                f"min: {img_min:.2f}",
                f"max: {img_max:.2f}",
            ]

            # --- image 1 패널에는 y 값도 같이 추가
            if y is not None and j == 0:
                yvals = y[idx]
                labels += [
                    f"y{i+1}: {val:.3f}" for i, val in enumerate(yvals)
                ]
                ax.set_ylabel(f"idx {idx}")

            handles = [
                plt.Line2D([0], [0], color="none", label=lab)
                for lab in labels
            ]

            ax.legend(
                handles=handles,
                loc="upper left" if j == 0 else "upper right",
                fontsize=7 if j != 0 else 8,
                frameon=True,
                borderpad=0.3,
                handlelength=0,
                handletextpad=0
            )

    fig.subplots_adjust(
        bottom=0.12,
        hspace=0.05,
        wspace=0.02
    )

    fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02
    )

    plt.show()

# %%
selected_index_list = [0, 5, 12, 128, 2048, 9999, 15000, 19999]
plot_trainingsample(X, y, selected_index_list)

# %% [markdown]
# ## PyTorching the Model

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
import pytorch_lightning as pl
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import torchvision
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from torchvision import transforms
from torchvision.datasets import CIFAR10

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce RTX 3090 (UUID: GPU-81ef84f4-69df-ce9c-b89c-0b05c8f72ebf)

# %%
#%load_ext tensorboard
# I will not use tensorboard .. though..

# %%
# Setting the seed
pl.seed_everything(42)

# Ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Seed set to 42

# %% [markdown]
# #### Checkpoints

# %%
CHECKPOINT_ROOT = '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/'

# %%
from time import gmtime, strftime

base_name = 'cnn'
#try_name = strftime('%Y.%m.%d_%H:%M', gmtime())
try_name = 'take6'
experiment_name = f"{base_name}_{try_name}"
print("experiment:", experiment_name)
# Out:
# experiment: cnn_take6

# %%
import os
import shutil

CHECKPOINT_PATH = os.path.join(CHECKPOINT_ROOT, experiment_name)

if os.path.exists(CHECKPOINT_PATH):
    print(f"⚠️ Directory exists: {CHECKPOINT_PATH}")
    print("🧹 Removing all contents...")

    # Clear all files/subfolders inside the directory
    for filename in os.listdir(CHECKPOINT_PATH):
        file_path = os.path.join(CHECKPOINT_PATH, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print(f"❌ Failed to delete {file_path}: {e}")

    print("✅ Directory has been cleared.")
else:
    os.makedirs(CHECKPOINT_PATH)
    print(f"✅ Directory created: {CHECKPOINT_PATH}")

print(f"📂 Experiment directory is ready: {os.path.abspath(CHECKPOINT_PATH)}")
# Out:
# ✅ Directory created: /app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take6
# 📂 Experiment directory is ready: /app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take6

# %% [markdown]
# ### Follow the min/max/scaler of the original keras code for reproduction

# %%
num_samples = len(y)
print(num_samples)
# Out:
# 20000

# %%
indices=range(num_samples)

# %%
X_train, X_test, y_train, y_test, train_indices, test_indices = \
train_test_split(X, y, indices, test_size=0.2, random_state=42)

# %%
# %%time
X_train_train, X_train_val, \
y_train_train, y_train_val, \
train_train_indices, train_val_indices = \
    train_test_split(
        X_train,
        y_train,
        train_indices,
        test_size=0.2,
        random_state=42
    )
# Out:
# CPU times: user 89 ms, sys: 44.4 ms, total: 133 ms
# Wall time: 132 ms

# %%
np_array_info(X_train_train)
# Out:
# shape     : (12800, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 262144000
# itemsize  : 4 bytes
# nbytes    : 1000.00 MB
# min / max : -44.47488021850586 / 38.766319274902344

# %%
np_array_info(X_train_val)
# Out:
# shape     : (3200, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 65536000
# itemsize  : 4 bytes
# nbytes    : 250.00 MB
# min / max : -40.51784896850586 / 41.380958557128906

# %%
np_array_info(X_test)
# Out:
# shape     : (4000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 81920000
# itemsize  : 4 bytes
# nbytes    : 312.50 MB
# min / max : -38.55973815917969 / 38.85308074951172

# %% [markdown]
# ### normalization by a fixed max value

# %% [markdown]
# #### Max Min Histograms

# %%
# X shape: (N, C, H, W, 1)
# squeeze 마지막 채널
X0 = X_train_train[..., 0]   # (12800, 5, 64, 64)

# 채널별 min / max (per-sample)
# 결과 shape: (12800, 5)
max_vals = X0.max(axis=(2, 3))
min_vals = X0.min(axis=(2, 3))

print(max_vals.shape, min_vals.shape)
# Out:
# (12800, 5) (12800, 5)

# %%
# 채널별 max of max_vals
max_of_max = max_vals.max(axis=0)   # shape (5,)

# 채널별 min of min_vals
min_of_min = min_vals.min(axis=0)   # shape (5,)

print("Channel-wise MAX of max_vals:")
for c, v in enumerate(max_of_max):
    print(f"  Channel {c}: {v:.6f}")

print("\nChannel-wise MIN of min_vals:")
for c, v in enumerate(min_of_min):
    print(f"  Channel {c}: {v:.6f}")
# Out:
# Channel-wise MAX of max_vals:
#   Channel 0: 34.031689
#   Channel 1: 36.974529
#   Channel 2: 35.511421
#   Channel 3: 37.356750
#   Channel 4: 38.766319
#
# Channel-wise MIN of min_vals:
#   Channel 0: -38.046089
#   Channel 1: -39.498131
#   Channel 2: -41.253410
#   Channel 3: -42.503021
#   Channel 4: -44.474880

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(5, 2, figsize=(9, 15), sharex=False)

for c in range(5):
    # max histogram
    axes[c, 0].hist(max_vals[:, c], bins=100)
    axes[c, 0].set_title(f'Channel {c} - max')
    axes[c, 0].set_ylabel('Count')

    # min histogram
    axes[c, 1].hist(min_vals[:, c], bins=100)
    axes[c, 1].set_title(f'Channel {c} - min')

axes[-1, 0].set_xlabel('Pixel value')
axes[-1, 1].set_xlabel('Pixel value')

plt.tight_layout()
plt.show()

# %% [markdown]
# > Set the `MAX_CAP = 50`, transforming 0 to 1, not -1 to 1

# %%
MAX_CAP = 50.0
MAX_RANGE = 100.0

# %%
# %%time
import numpy as np

# symmetric rescaling per image
X_train_train_scaled = (X_train_train + MAX_CAP)/MAX_RANGE
# Out:
# CPU times: user 97 ms, sys: 64.5 ms, total: 161 ms
# Wall time: 160 ms

# %%
max_abs = np.max(
    np.abs(X_train_val),
    axis=(2, 3, 4),   # 64x64 + channel=1
    keepdims=True
)
# symmetric rescaling per image
X_train_val_scaled = (X_train_val + MAX_CAP)/MAX_RANGE

# %%
max_abs = np.max(
    np.abs(X_test),
    axis=(2, 3, 4),   # 64x64 + channel=1
    keepdims=True
)
# symmetric rescaling per image
X_test_scaled = (X_test + MAX_CAP)/MAX_RANGE

# %% [markdown]
# #### Plot the rescaled Training Sample
#
# - this could be wrong?!?

# %%
plot_trainingsample(X_train_train_scaled, y,[0,1,2,3,4])

# %%
plot_trainingsample(X_train_val_scaled, y,[0,1,2,3,4])

# %%
plot_trainingsample(X_test_scaled, y,[0,1,2,3,4])

# %%
np_array_info(X_train_train_scaled)
# Out:
# shape     : (12800, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 262144000
# itemsize  : 4 bytes
# nbytes    : 1000.00 MB
# min / max : 0.05525119602680206 / 0.8876631855964661

# %%
np_array_info(X_train_val_scaled)
# Out:
# shape     : (3200, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 65536000
# itemsize  : 4 bytes
# nbytes    : 250.00 MB
# min / max : 0.0948215126991272 / 0.913809597492218

# %%
np_array_info(X_test_scaled)
# Out:
# shape     : (4000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 81920000
# itemsize  : 4 bytes
# nbytes    : 312.50 MB
# min / max : 0.11440262198448181 / 0.8885307908058167

# %%
np_array_info(y_train_train)
# Out:
# shape     : (12800, 6)
# dtype     : float32
# ndim      : 2
# size      : 76800
# itemsize  : 4 bytes
# nbytes    : 0.29 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(y_train_val)
# Out:
# shape     : (3200, 6)
# dtype     : float32
# ndim      : 2
# size      : 19200
# itemsize  : 4 bytes
# nbytes    : 0.07 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(y_test)
# Out:
# shape     : (4000, 6)
# dtype     : float32
# ndim      : 2
# size      : 24000
# itemsize  : 4 bytes
# nbytes    : 0.09 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_y_histograms_splits(y_train_train, y_train_val, y_test, bins=50):
    """
    y_* shape: (N, 6)
    """

    fig, axes = plt.subplots(2, 3, figsize=(12, 7))
    axes = axes.ravel()

    # symmetric range across ALL splits
    all_y = np.concatenate([y_train_train, y_train_val, y_test], axis=0)
    vmin = all_y.min()
    vmax = all_y.max()
    vmax = max(abs(vmin), abs(vmax))
    hist_range = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        ax.hist(
            y_train_train[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='r',
            alpha=0.2,
            label="train"
        )
        ax.hist(
            y_train_val[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='g',
            alpha=0.2,
            label="val"
        )
        ax.hist(
            y_test[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='b',
            alpha=0.2,
            label="test"
        )

        ax.axvline(0, color="k", linestyle="--", linewidth=1)
        ax.set_title(f"y{i}")
        ax.set_xlabel("value")
        ax.set_ylabel("density")

        if i == 0:
            ax.legend()

    fig.suptitle("Distribution of y components (train / val / test)", fontsize=13)
    fig.tight_layout()
    plt.show()

# %%
plot_y_histograms_splits(y_train_train, y_train_val, y_test)

# %% [markdown]
# ## Train the CNN model

# %%
class CNNModelKerasEquivalent(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            # Conv2D(32,(1,1), relu, input_shape=(5,64,64), channels_first)
            nn.Conv2d(in_channels=5, out_channels=32, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # Conv2D(64,(3,3), relu)  (padding='valid' in Keras -> padding=0 in PyTorch)
            nn.Conv2d(32, 64, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(2,2), relu)
            nn.Conv2d(64, 32, kernel_size=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(1,1), relu)
            nn.Conv2d(32, 32, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(1,1), relu)
            nn.Conv2d(32, 32, kernel_size=1),
            nn.ReLU(inplace=True),

            nn.Flatten(),                 # Keras Flatten()
            nn.Linear(32 * 3 * 3, 128),   # 계산 결과: 64->32->30->15->14->7->3 => 32*3*3
            nn.ReLU(inplace=True),
            nn.Linear(128, 6)             # Dense(6)
        )

    def forward(self, x):
        return self.net(x)

# %%
from torch.utils.data import Dataset, DataLoader

class NumpyDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        x = torch.from_numpy(self.X[idx]).float()  # (5,64,64)
        x = x.squeeze(-1) # if (5,64,64,1)
        t = torch.from_numpy(self.y[idx]).float()  # (6,)
        return x, t

# %%
train_ds = NumpyDataset(X_train_train_scaled, y_train_train)
val_ds   = NumpyDataset(X_train_val_scaled,   y_train_val)

# %%
x0, y0 = train_ds[0]
print(x0.shape)   # torch.Size([5, 64, 64])
print(y0.shape)   # torch.Size([6])
# Out:
# torch.Size([5, 64, 64])
# torch.Size([6])

# %%
train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
xb, yb = next(iter(train_loader))
print("xb.shape:", xb.shape)
print("yb.shape:", yb.shape)
print("xb.dtype:", xb.dtype)
# Out:
# xb.shape: torch.Size([32, 5, 64, 64])
# yb.shape: torch.Size([32, 6])
# xb.dtype: torch.float32

# %% [markdown]
# #### Visualize the training dataloader as a sanity check

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow",
                                   linewidth=0.5, vmin=None, vmax=None):
    """
    xb: torch.Tensor, shape (B, 5, 64, 64)
    n_samples: number of rows (samples)
    ngrid: number of grid cells per axis (e.g., 16 => patch size 4 for 64x64)
    """
    # tensor -> numpy
    x = xb[:n_samples].detach().cpu().numpy()  # (n_samples, 5, 64, 64)
    n_samples = x.shape[0]
    n_views = x.shape[1]
    H, W = x.shape[2], x.shape[3]

    assert H % ngrid == 0 and W % ngrid == 0, f"H,W must be divisible by ngrid. got {H},{W}, ngrid={ngrid}"
    patch_h = H // ngrid
    patch_w = W // ngrid

    # global color scale (consistent across all panels)
    if vmin is None:
        vmin = float(x.min())
    if vmax is None:
        vmax = float(x.max())

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2),
        constrained_layout=False
    )

    # in case n_samples == 1
    if n_samples == 1:
        axes = np.expand_dims(axes, axis=0)

    im = None
    for i in range(n_samples):
        for j in range(n_views):
            ax = axes[i, j]
            img = x[i, j]  # (64,64)

            im = ax.imshow(
                img,
                cmap=cmap,
                vmin=vmin,
                vmax=vmax,
                aspect="equal",
                interpolation="nearest"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            # column titles
            if i == 0:
                ax.set_title(f"ch {j}", fontsize=11)

            # row labels
            if j == 0:
                ax.set_ylabel(f"sample {i}", fontsize=11)

            # draw patch grid boundaries
            for gy in range(0, H + 1, patch_h):
                ax.axhline(gy - 0.5, color="w", linewidth=linewidth, alpha=0.9)
            for gx in range(0, W + 1, patch_w):
                ax.axvline(gx - 0.5, color="w", linewidth=linewidth, alpha=0.9)

    # tighter spacing + bottom colorbar
    fig.subplots_adjust(bottom=0.08, hspace=0.02, wspace=0.02)

    cbar = fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02
    )
    cbar.set_label("pixel value")

    plt.show()

# %%
plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow")

# %%
xb, yb = next(iter(val_loader))
print("xb.shape:", xb.shape)
print("yb.shape:", yb.shape)
print("xb.dtype:", xb.dtype)
# Out:
# xb.shape: torch.Size([32, 5, 64, 64])
# yb.shape: torch.Size([32, 6])
# xb.dtype: torch.float32

# %%
plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow")

# %% [markdown]
# #### Callbacks

# %%
import time
import matplotlib.pyplot as plt
from pytorch_lightning.callbacks import Callback

class PlotLossesPL(Callback):
    def __init__(self):
        self.train_losses = []
        self.val_losses = []
        self.epoch_times = []

    def on_train_epoch_start(self, trainer, pl_module):
        self.epoch_start_time = time.time()

    def on_train_epoch_end(self, trainer, pl_module):
        epoch_time = time.time() - self.epoch_start_time
        self.epoch_times.append(epoch_time)

        train_loss = trainer.callback_metrics.get("train_loss")
        val_loss   = trainer.callback_metrics.get("val_loss")

        if train_loss is not None:
            self.train_losses.append(train_loss.item())
        if val_loss is not None:
            self.val_losses.append(val_loss.item())

        print(
            f"Epoch {trainer.current_epoch:03d} | "
            f"train MAE: {self.train_losses[-1]:.6f} | "
            f"val MAE: {self.val_losses[-1]:.6f} | "
            f"time: {epoch_time:.2f}s"
        )

    def on_fit_end(self, trainer, pl_module):
        self.plot()

    def plot(self):
        plt.figure(figsize=(6,4))
        plt.plot(self.train_losses, label="train")
        plt.plot(self.val_losses, label="val")
        plt.xlabel("epoch")
        plt.ylabel("MAE")
        plt.legend()
        plt.tight_layout()
        plt.show()

# %%
import time
from pytorch_lightning.callbacks import Callback

class GPUSleepCallback(Callback):
    def __init__(self, every_n_epochs=5, sleep_seconds=5):
        self.every_n_epochs = every_n_epochs
        self.sleep_seconds = sleep_seconds

    def on_train_epoch_end(self, trainer, pl_module):
        epoch = trainer.current_epoch + 1  # 1-based로 보기 좋게
        if epoch % self.every_n_epochs == 0:
            print(f"😴 Cooling GPU: sleeping {self.sleep_seconds}s after epoch {epoch}")
            time.sleep(self.sleep_seconds)

# %%
import os
from pytorch_lightning.callbacks import ModelCheckpoint

#ckpt_dir = "/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take1"
ckpt_dir = CHECKPOINT_PATH

checkpoint_cb = ModelCheckpoint(
    dirpath=ckpt_dir,
    filename="best-{epoch:03d}-{val_loss:.6f}",  # 파일명 템플릿
    monitor="val_loss",                          # 우리가 log한 키
    mode="min",                                  # 최소가 best
    save_top_k=1,                                # best 1개만 유지
    save_last=True,                              # last.ckpt도 저장
    auto_insert_metric_name=False
)

# %%
import pytorch_lightning as pl
import torch
import torch.nn as nn

class LitCNN(pl.LightningModule):
    def __init__(self, model, lr=1e-3):
        super().__init__()
        self.model = model
        self.criterion = nn.L1Loss()
        self.lr = lr

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.log("train_loss", loss, prog_bar=False)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.log("val_loss", loss, prog_bar=False)
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.lr)

# %%
from pytorch_lightning.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=100,
    mode="min"
)

# %%
from pytorch_lightning import Trainer

plot_cb = PlotLossesPL()
gpu_sleep_cb = GPUSleepCallback(every_n_epochs=5, sleep_seconds=5)

trainer = Trainer(
    max_epochs=400,
    callbacks=[plot_cb, checkpoint_cb, gpu_sleep_cb],
    enable_progress_bar=False,
    enable_model_summary=False,
    accelerator="gpu" if torch.cuda.is_available() else "cpu",
    devices=1,
    log_every_n_steps=999999
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
# %%time
trainer.fit(
    model=LitCNN(CNNModelKerasEquivalent()),
    train_dataloaders=train_loader,
    val_dataloaders=val_loader
)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:317: The number of training batches (400) is smaller than the logging interval Trainer(log_every_n_steps=999999). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 000 | train MAE: 0.177845 | val MAE: 0.189690 | time: 1.55s
# Epoch 001 | train MAE: 0.190210 | val MAE: 0.187510 | time: 1.57s
# Epoch 002 | train MAE: 0.186302 | val MAE: 0.187042 | time: 1.60s
# Epoch 003 | train MAE: 0.196490 | val MAE: 0.186353 | time: 1.61s
# Epoch 004 | train MAE: 0.175080 | val MAE: 0.184845 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 5
# Epoch 005 | train MAE: 0.109654 | val MAE: 0.115163 | time: 1.59s
# Epoch 006 | train MAE: 0.094017 | val MAE: 0.098714 | time: 1.58s
# Epoch 007 | train MAE: 0.080013 | val MAE: 0.084352 | time: 1.54s
# Epoch 008 | train MAE: 0.084143 | val MAE: 0.082476 | time: 1.54s
# Epoch 009 | train MAE: 0.074171 | val MAE: 0.077180 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 10
# Epoch 010 | train MAE: 0.093065 | val MAE: 0.079264 | time: 1.57s
# Epoch 011 | train MAE: 0.077728 | val MAE: 0.077391 | time: 1.61s
# Epoch 012 | train MAE: 0.078264 | val MAE: 0.074946 | time: 1.56s
# Epoch 013 | train MAE: 0.062325 | val MAE: 0.073620 | time: 1.59s
# Epoch 014 | train MAE: 0.093845 | val MAE: 0.078802 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 15
# Epoch 015 | train MAE: 0.091246 | val MAE: 0.075827 | time: 1.59s
# Epoch 016 | train MAE: 0.073454 | val MAE: 0.073518 | time: 1.60s
# Epoch 017 | train MAE: 0.070701 | val MAE: 0.072825 | time: 1.56s
# Epoch 018 | train MAE: 0.078723 | val MAE: 0.073528 | time: 1.60s
# Epoch 019 | train MAE: 0.073044 | val MAE: 0.073151 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 20
# Epoch 020 | train MAE: 0.074680 | val MAE: 0.077787 | time: 1.57s
# Epoch 021 | train MAE: 0.069463 | val MAE: 0.071611 | time: 1.61s
# Epoch 022 | train MAE: 0.076091 | val MAE: 0.072416 | time: 1.62s
# Epoch 023 | train MAE: 0.058949 | val MAE: 0.070772 | time: 1.60s
# Epoch 024 | train MAE: 0.078347 | val MAE: 0.070722 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 25
# Epoch 025 | train MAE: 0.064664 | val MAE: 0.071315 | time: 1.56s
# Epoch 026 | train MAE: 0.057901 | val MAE: 0.071409 | time: 1.59s
# Epoch 027 | train MAE: 0.075311 | val MAE: 0.073223 | time: 1.57s
# Epoch 028 | train MAE: 0.061781 | val MAE: 0.071483 | time: 1.61s
# Epoch 029 | train MAE: 0.059740 | val MAE: 0.070418 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 30
# Epoch 030 | train MAE: 0.071701 | val MAE: 0.067382 | time: 1.56s
# Epoch 031 | train MAE: 0.070458 | val MAE: 0.069962 | time: 1.55s
# Epoch 032 | train MAE: 0.080329 | val MAE: 0.067996 | time: 1.58s
# Epoch 033 | train MAE: 0.060255 | val MAE: 0.067234 | time: 1.61s
# Epoch 034 | train MAE: 0.059469 | val MAE: 0.069475 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 35
# Epoch 035 | train MAE: 0.061887 | val MAE: 0.068427 | time: 1.56s
# Epoch 036 | train MAE: 0.074398 | val MAE: 0.067616 | time: 1.58s
# Epoch 037 | train MAE: 0.062190 | val MAE: 0.065827 | time: 1.63s
# Epoch 038 | train MAE: 0.059694 | val MAE: 0.068416 | time: 1.58s
# Epoch 039 | train MAE: 0.062472 | val MAE: 0.069236 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 40
# Epoch 040 | train MAE: 0.070294 | val MAE: 0.066907 | time: 1.58s
# Epoch 041 | train MAE: 0.061290 | val MAE: 0.067293 | time: 1.60s
# Epoch 042 | train MAE: 0.055727 | val MAE: 0.065082 | time: 1.63s
# Epoch 043 | train MAE: 0.070792 | val MAE: 0.061981 | time: 1.59s
# Epoch 044 | train MAE: 0.060945 | val MAE: 0.056772 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 45
# Epoch 045 | train MAE: 0.049823 | val MAE: 0.052230 | time: 1.56s
# Epoch 046 | train MAE: 0.041571 | val MAE: 0.045515 | time: 1.60s
# Epoch 047 | train MAE: 0.040241 | val MAE: 0.046259 | time: 1.55s
# Epoch 048 | train MAE: 0.032935 | val MAE: 0.031747 | time: 1.58s
# Epoch 049 | train MAE: 0.036545 | val MAE: 0.036635 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 50
# Epoch 050 | train MAE: 0.027925 | val MAE: 0.030757 | time: 1.55s
# Epoch 051 | train MAE: 0.023749 | val MAE: 0.029739 | time: 1.57s
# Epoch 052 | train MAE: 0.034831 | val MAE: 0.031698 | time: 1.63s
# Epoch 053 | train MAE: 0.036418 | val MAE: 0.037313 | time: 1.59s
# Epoch 054 | train MAE: 0.027273 | val MAE: 0.031570 | time: 1.64s
# 😴 Cooling GPU: sleeping 5s after epoch 55
# Epoch 055 | train MAE: 0.030534 | val MAE: 0.025989 | time: 1.57s
# Epoch 056 | train MAE: 0.027717 | val MAE: 0.022310 | time: 1.57s
# Epoch 057 | train MAE: 0.022093 | val MAE: 0.021300 | time: 1.59s
# Epoch 058 | train MAE: 0.025224 | val MAE: 0.021695 | time: 1.59s
# Epoch 059 | train MAE: 0.023357 | val MAE: 0.021414 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 60
# Epoch 060 | train MAE: 0.021235 | val MAE: 0.018536 | time: 1.65s
# Epoch 061 | train MAE: 0.019764 | val MAE: 0.023498 | time: 1.61s
# Epoch 062 | train MAE: 0.020042 | val MAE: 0.021636 | time: 1.59s
# Epoch 063 | train MAE: 0.018440 | val MAE: 0.022834 | time: 1.60s
# Epoch 064 | train MAE: 0.020396 | val MAE: 0.018442 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 65
# Epoch 065 | train MAE: 0.016091 | val MAE: 0.018057 | time: 1.60s
# Epoch 066 | train MAE: 0.017506 | val MAE: 0.017530 | time: 1.59s
# Epoch 067 | train MAE: 0.020294 | val MAE: 0.016981 | time: 1.60s
# Epoch 068 | train MAE: 0.014661 | val MAE: 0.017339 | time: 1.58s
# Epoch 069 | train MAE: 0.017724 | val MAE: 0.020457 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 70
# Epoch 070 | train MAE: 0.016609 | val MAE: 0.018735 | time: 1.59s
# Epoch 071 | train MAE: 0.021492 | val MAE: 0.019855 | time: 1.60s
# Epoch 072 | train MAE: 0.018363 | val MAE: 0.019229 | time: 1.60s
# Epoch 073 | train MAE: 0.019953 | val MAE: 0.024816 | time: 1.61s
# Epoch 074 | train MAE: 0.019384 | val MAE: 0.020103 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 75
# Epoch 075 | train MAE: 0.021499 | val MAE: 0.017609 | time: 1.59s
# Epoch 076 | train MAE: 0.019783 | val MAE: 0.023702 | time: 1.58s
# Epoch 077 | train MAE: 0.015868 | val MAE: 0.017470 | time: 1.57s
# Epoch 078 | train MAE: 0.016856 | val MAE: 0.018603 | time: 1.58s
# Epoch 079 | train MAE: 0.020122 | val MAE: 0.017301 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 80
# Epoch 080 | train MAE: 0.018382 | val MAE: 0.016922 | time: 1.53s
# Epoch 081 | train MAE: 0.016911 | val MAE: 0.019646 | time: 1.55s
# Epoch 082 | train MAE: 0.017903 | val MAE: 0.017936 | time: 1.59s
# Epoch 083 | train MAE: 0.015915 | val MAE: 0.019526 | time: 1.58s
# Epoch 084 | train MAE: 0.016604 | val MAE: 0.015999 | time: 1.55s
# 😴 Cooling GPU: sleeping 5s after epoch 85
# Epoch 085 | train MAE: 0.016746 | val MAE: 0.020170 | time: 1.57s
# Epoch 086 | train MAE: 0.020249 | val MAE: 0.021012 | time: 1.59s
# Epoch 087 | train MAE: 0.017259 | val MAE: 0.021070 | time: 1.61s
# Epoch 088 | train MAE: 0.018183 | val MAE: 0.018944 | time: 1.60s
# Epoch 089 | train MAE: 0.019705 | val MAE: 0.018821 | time: 1.66s
# 😴 Cooling GPU: sleeping 5s after epoch 90
# Epoch 090 | train MAE: 0.017302 | val MAE: 0.016723 | time: 1.63s
# Epoch 091 | train MAE: 0.018144 | val MAE: 0.019295 | time: 1.57s
# Epoch 092 | train MAE: 0.017062 | val MAE: 0.021732 | time: 1.63s
# Epoch 093 | train MAE: 0.021546 | val MAE: 0.017559 | time: 1.58s
# Epoch 094 | train MAE: 0.023718 | val MAE: 0.018078 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 95
# Epoch 095 | train MAE: 0.014004 | val MAE: 0.018093 | time: 1.56s
# Epoch 096 | train MAE: 0.013205 | val MAE: 0.014982 | time: 1.63s
# Epoch 097 | train MAE: 0.019169 | val MAE: 0.018063 | time: 1.59s
# Epoch 098 | train MAE: 0.015663 | val MAE: 0.015254 | time: 1.59s
# Epoch 099 | train MAE: 0.016811 | val MAE: 0.018981 | time: 1.64s
# 😴 Cooling GPU: sleeping 5s after epoch 100
# Epoch 100 | train MAE: 0.021835 | val MAE: 0.021314 | time: 1.62s
# Epoch 101 | train MAE: 0.017177 | val MAE: 0.020042 | time: 1.60s
# Epoch 102 | train MAE: 0.018453 | val MAE: 0.020381 | time: 1.59s
# Epoch 103 | train MAE: 0.016039 | val MAE: 0.015729 | time: 1.57s
# Epoch 104 | train MAE: 0.017552 | val MAE: 0.018590 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 105
# Epoch 105 | train MAE: 0.022997 | val MAE: 0.021929 | time: 1.58s
# Epoch 106 | train MAE: 0.014714 | val MAE: 0.016400 | time: 1.62s
# Epoch 107 | train MAE: 0.013494 | val MAE: 0.018292 | time: 1.59s
# Epoch 108 | train MAE: 0.014300 | val MAE: 0.014527 | time: 1.61s
# Epoch 109 | train MAE: 0.013454 | val MAE: 0.012974 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 110
# Epoch 110 | train MAE: 0.017341 | val MAE: 0.017384 | time: 1.61s
# Epoch 111 | train MAE: 0.017910 | val MAE: 0.018123 | time: 1.60s
# Epoch 112 | train MAE: 0.021726 | val MAE: 0.016050 | time: 1.62s
# Epoch 113 | train MAE: 0.014634 | val MAE: 0.013710 | time: 1.61s
# Epoch 114 | train MAE: 0.015184 | val MAE: 0.014653 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 115
# Epoch 115 | train MAE: 0.014595 | val MAE: 0.014813 | time: 1.56s
# Epoch 116 | train MAE: 0.018481 | val MAE: 0.025642 | time: 1.59s
# Epoch 117 | train MAE: 0.022693 | val MAE: 0.016746 | time: 1.63s
# Epoch 118 | train MAE: 0.021253 | val MAE: 0.018895 | time: 1.62s
# Epoch 119 | train MAE: 0.032381 | val MAE: 0.028170 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 120
# Epoch 120 | train MAE: 0.017277 | val MAE: 0.018902 | time: 1.59s
# Epoch 121 | train MAE: 0.020491 | val MAE: 0.022128 | time: 1.58s
# Epoch 122 | train MAE: 0.021699 | val MAE: 0.023241 | time: 1.59s
# Epoch 123 | train MAE: 0.017641 | val MAE: 0.026144 | time: 1.58s
# Epoch 124 | train MAE: 0.013634 | val MAE: 0.012502 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 125
# Epoch 125 | train MAE: 0.017683 | val MAE: 0.019845 | time: 1.59s
# Epoch 126 | train MAE: 0.013555 | val MAE: 0.014013 | time: 1.63s
# Epoch 127 | train MAE: 0.016475 | val MAE: 0.014586 | time: 1.60s
# Epoch 128 | train MAE: 0.015701 | val MAE: 0.018379 | time: 1.60s
# Epoch 129 | train MAE: 0.018089 | val MAE: 0.019017 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 130
# Epoch 130 | train MAE: 0.015181 | val MAE: 0.016290 | time: 1.59s
# Epoch 131 | train MAE: 0.013088 | val MAE: 0.013770 | time: 1.59s
# Epoch 132 | train MAE: 0.015328 | val MAE: 0.013660 | time: 1.61s
# Epoch 133 | train MAE: 0.019332 | val MAE: 0.017080 | time: 1.59s
# Epoch 134 | train MAE: 0.015501 | val MAE: 0.018008 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 135
# Epoch 135 | train MAE: 0.016443 | val MAE: 0.014211 | time: 1.60s
# Epoch 136 | train MAE: 0.013661 | val MAE: 0.019615 | time: 1.63s
# Epoch 137 | train MAE: 0.015229 | val MAE: 0.015032 | time: 1.59s
# Epoch 138 | train MAE: 0.020251 | val MAE: 0.019991 | time: 1.67s
# Epoch 139 | train MAE: 0.012679 | val MAE: 0.014469 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 140
# Epoch 140 | train MAE: 0.016323 | val MAE: 0.012260 | time: 1.58s
# Epoch 141 | train MAE: 0.014694 | val MAE: 0.015630 | time: 1.60s
# Epoch 142 | train MAE: 0.020915 | val MAE: 0.020613 | time: 1.56s
# Epoch 143 | train MAE: 0.016716 | val MAE: 0.015185 | time: 1.63s
# Epoch 144 | train MAE: 0.014381 | val MAE: 0.015634 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 145
# Epoch 145 | train MAE: 0.018536 | val MAE: 0.018421 | time: 1.58s
# Epoch 146 | train MAE: 0.013901 | val MAE: 0.016248 | time: 1.60s
# Epoch 147 | train MAE: 0.015301 | val MAE: 0.016714 | time: 1.65s
# Epoch 148 | train MAE: 0.018733 | val MAE: 0.025561 | time: 1.64s
# Epoch 149 | train MAE: 0.015076 | val MAE: 0.015537 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 150
# Epoch 150 | train MAE: 0.020610 | val MAE: 0.014926 | time: 1.57s
# Epoch 151 | train MAE: 0.013190 | val MAE: 0.015501 | time: 1.59s
# Epoch 152 | train MAE: 0.015739 | val MAE: 0.014762 | time: 1.59s
# Epoch 153 | train MAE: 0.014205 | val MAE: 0.016084 | time: 1.60s
# Epoch 154 | train MAE: 0.010614 | val MAE: 0.014195 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 155
# Epoch 155 | train MAE: 0.014133 | val MAE: 0.011709 | time: 1.59s
# Epoch 156 | train MAE: 0.012286 | val MAE: 0.013973 | time: 1.61s
# Epoch 157 | train MAE: 0.016988 | val MAE: 0.013324 | time: 1.64s
# Epoch 158 | train MAE: 0.012390 | val MAE: 0.013912 | time: 1.61s
# Epoch 159 | train MAE: 0.014397 | val MAE: 0.014801 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 160
# Epoch 160 | train MAE: 0.013462 | val MAE: 0.013512 | time: 1.57s
# Epoch 161 | train MAE: 0.014873 | val MAE: 0.019078 | time: 1.60s
# Epoch 162 | train MAE: 0.013354 | val MAE: 0.017957 | time: 1.57s
# Epoch 163 | train MAE: 0.016846 | val MAE: 0.018411 | time: 1.59s
# Epoch 164 | train MAE: 0.012186 | val MAE: 0.012537 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 165
# Epoch 165 | train MAE: 0.015714 | val MAE: 0.014158 | time: 1.63s
# Epoch 166 | train MAE: 0.011306 | val MAE: 0.014223 | time: 1.59s
# Epoch 167 | train MAE: 0.015186 | val MAE: 0.014586 | time: 1.63s
# Epoch 168 | train MAE: 0.011846 | val MAE: 0.013853 | time: 1.61s
# Epoch 169 | train MAE: 0.016866 | val MAE: 0.012743 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 170
# Epoch 170 | train MAE: 0.011394 | val MAE: 0.016929 | time: 1.56s
# Epoch 171 | train MAE: 0.020385 | val MAE: 0.015780 | time: 1.58s
# Epoch 172 | train MAE: 0.016808 | val MAE: 0.018495 | time: 1.60s
# Epoch 173 | train MAE: 0.017793 | val MAE: 0.019805 | time: 1.60s
# Epoch 174 | train MAE: 0.015452 | val MAE: 0.014331 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 175
# Epoch 175 | train MAE: 0.023651 | val MAE: 0.021962 | time: 1.59s
# Epoch 176 | train MAE: 0.017448 | val MAE: 0.018036 | time: 1.60s
# Epoch 177 | train MAE: 0.013700 | val MAE: 0.014155 | time: 1.61s
# Epoch 178 | train MAE: 0.012251 | val MAE: 0.013023 | time: 1.60s
# Epoch 179 | train MAE: 0.014509 | val MAE: 0.015366 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 180
# Epoch 180 | train MAE: 0.012826 | val MAE: 0.014342 | time: 1.62s
# Epoch 181 | train MAE: 0.015238 | val MAE: 0.014656 | time: 1.61s
# Epoch 182 | train MAE: 0.017504 | val MAE: 0.020576 | time: 1.71s
# Epoch 183 | train MAE: 0.016277 | val MAE: 0.017419 | time: 1.59s
# Epoch 184 | train MAE: 0.011568 | val MAE: 0.012882 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 185
# Epoch 185 | train MAE: 0.017882 | val MAE: 0.016198 | time: 1.62s
# Epoch 186 | train MAE: 0.013781 | val MAE: 0.011742 | time: 1.59s
# Epoch 187 | train MAE: 0.013807 | val MAE: 0.011536 | time: 1.67s
# Epoch 188 | train MAE: 0.011917 | val MAE: 0.013507 | time: 1.65s
# Epoch 189 | train MAE: 0.013423 | val MAE: 0.012838 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 190
# Epoch 190 | train MAE: 0.017051 | val MAE: 0.014173 | time: 1.64s
# Epoch 191 | train MAE: 0.019732 | val MAE: 0.017924 | time: 1.58s
# Epoch 192 | train MAE: 0.013084 | val MAE: 0.016080 | time: 1.59s
# Epoch 193 | train MAE: 0.013884 | val MAE: 0.011736 | time: 1.61s
# Epoch 194 | train MAE: 0.013098 | val MAE: 0.014476 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 195
# Epoch 195 | train MAE: 0.014261 | val MAE: 0.018722 | time: 1.61s
# Epoch 196 | train MAE: 0.014543 | val MAE: 0.016651 | time: 1.61s
# Epoch 197 | train MAE: 0.014050 | val MAE: 0.012087 | time: 1.60s
# Epoch 198 | train MAE: 0.011772 | val MAE: 0.016188 | time: 1.62s
# Epoch 199 | train MAE: 0.018015 | val MAE: 0.016411 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 200
# Epoch 200 | train MAE: 0.025772 | val MAE: 0.018578 | time: 1.56s
# Epoch 201 | train MAE: 0.012209 | val MAE: 0.014823 | time: 1.64s
# Epoch 202 | train MAE: 0.013932 | val MAE: 0.013671 | time: 1.64s
# Epoch 203 | train MAE: 0.017359 | val MAE: 0.020103 | time: 1.64s
# Epoch 204 | train MAE: 0.014423 | val MAE: 0.011250 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 205
# Epoch 205 | train MAE: 0.013717 | val MAE: 0.011240 | time: 1.61s
# Epoch 206 | train MAE: 0.012077 | val MAE: 0.014815 | time: 1.62s
# Epoch 207 | train MAE: 0.018197 | val MAE: 0.018008 | time: 1.60s
# Epoch 208 | train MAE: 0.010545 | val MAE: 0.016814 | time: 1.59s
# Epoch 209 | train MAE: 0.016929 | val MAE: 0.016499 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 210
# Epoch 210 | train MAE: 0.012491 | val MAE: 0.013004 | time: 1.56s
# Epoch 211 | train MAE: 0.016943 | val MAE: 0.016811 | time: 1.65s
# Epoch 212 | train MAE: 0.014303 | val MAE: 0.011687 | time: 1.64s
# Epoch 213 | train MAE: 0.024328 | val MAE: 0.018945 | time: 1.60s
# Epoch 214 | train MAE: 0.014169 | val MAE: 0.016882 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 215
# Epoch 215 | train MAE: 0.013740 | val MAE: 0.013116 | time: 1.57s
# Epoch 216 | train MAE: 0.015471 | val MAE: 0.015362 | time: 1.65s
# Epoch 217 | train MAE: 0.019391 | val MAE: 0.016760 | time: 1.63s
# Epoch 218 | train MAE: 0.015478 | val MAE: 0.013415 | time: 1.59s
# Epoch 219 | train MAE: 0.021672 | val MAE: 0.021148 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 220
# Epoch 220 | train MAE: 0.018314 | val MAE: 0.022391 | time: 1.58s
# Epoch 221 | train MAE: 0.012779 | val MAE: 0.013484 | time: 1.61s
# Epoch 222 | train MAE: 0.019834 | val MAE: 0.024706 | time: 1.61s
# Epoch 223 | train MAE: 0.014886 | val MAE: 0.013708 | time: 1.61s
# Epoch 224 | train MAE: 0.015684 | val MAE: 0.014678 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 225
# Epoch 225 | train MAE: 0.015163 | val MAE: 0.017661 | time: 1.63s
# Epoch 226 | train MAE: 0.016446 | val MAE: 0.017286 | time: 1.61s
# Epoch 227 | train MAE: 0.020364 | val MAE: 0.016638 | time: 1.63s
# Epoch 228 | train MAE: 0.011253 | val MAE: 0.013778 | time: 1.59s
# Epoch 229 | train MAE: 0.015110 | val MAE: 0.011277 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 230
# Epoch 230 | train MAE: 0.014243 | val MAE: 0.015769 | time: 1.61s
# Epoch 231 | train MAE: 0.013836 | val MAE: 0.012957 | time: 1.56s
# Epoch 232 | train MAE: 0.015879 | val MAE: 0.013676 | time: 1.62s
# Epoch 233 | train MAE: 0.013505 | val MAE: 0.012010 | time: 1.59s
# Epoch 234 | train MAE: 0.016773 | val MAE: 0.019019 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 235
# Epoch 235 | train MAE: 0.012173 | val MAE: 0.012366 | time: 1.61s
# Epoch 236 | train MAE: 0.012792 | val MAE: 0.024527 | time: 1.59s
# Epoch 237 | train MAE: 0.010297 | val MAE: 0.012503 | time: 1.63s
# Epoch 238 | train MAE: 0.014985 | val MAE: 0.013956 | time: 1.59s
# Epoch 239 | train MAE: 0.015152 | val MAE: 0.014253 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 240
# Epoch 240 | train MAE: 0.012483 | val MAE: 0.016555 | time: 1.63s
# Epoch 241 | train MAE: 0.010363 | val MAE: 0.012294 | time: 1.62s
# Epoch 242 | train MAE: 0.012324 | val MAE: 0.016963 | time: 1.60s
# Epoch 243 | train MAE: 0.010637 | val MAE: 0.013010 | time: 1.60s
# Epoch 244 | train MAE: 0.014379 | val MAE: 0.014247 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 245
# Epoch 245 | train MAE: 0.012197 | val MAE: 0.013125 | time: 1.57s
# Epoch 246 | train MAE: 0.021675 | val MAE: 0.022241 | time: 1.57s
# Epoch 247 | train MAE: 0.016811 | val MAE: 0.015509 | time: 1.60s
# Epoch 248 | train MAE: 0.010854 | val MAE: 0.011431 | time: 1.58s
# Epoch 249 | train MAE: 0.013046 | val MAE: 0.012285 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 250
# Epoch 250 | train MAE: 0.013419 | val MAE: 0.015999 | time: 1.64s
# Epoch 251 | train MAE: 0.010031 | val MAE: 0.012688 | time: 1.59s
# Epoch 252 | train MAE: 0.014826 | val MAE: 0.017100 | time: 1.63s
# Epoch 253 | train MAE: 0.013490 | val MAE: 0.016035 | time: 1.64s
# Epoch 254 | train MAE: 0.013708 | val MAE: 0.013721 | time: 1.65s
# 😴 Cooling GPU: sleeping 5s after epoch 255
# Epoch 255 | train MAE: 0.012282 | val MAE: 0.011226 | time: 1.62s
# Epoch 256 | train MAE: 0.011313 | val MAE: 0.012617 | time: 1.61s
# Epoch 257 | train MAE: 0.018402 | val MAE: 0.019734 | time: 1.60s
# Epoch 258 | train MAE: 0.010463 | val MAE: 0.011952 | time: 1.61s
# Epoch 259 | train MAE: 0.012967 | val MAE: 0.017064 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 260
# Epoch 260 | train MAE: 0.014439 | val MAE: 0.014363 | time: 1.59s
# Epoch 261 | train MAE: 0.014422 | val MAE: 0.012505 | time: 1.60s
# Epoch 262 | train MAE: 0.012463 | val MAE: 0.010694 | time: 1.60s
# Epoch 263 | train MAE: 0.014925 | val MAE: 0.020813 | time: 1.58s
# Epoch 264 | train MAE: 0.013234 | val MAE: 0.012511 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 265
# Epoch 265 | train MAE: 0.015694 | val MAE: 0.017846 | time: 1.56s
# Epoch 266 | train MAE: 0.016883 | val MAE: 0.017813 | time: 1.61s
# Epoch 267 | train MAE: 0.017338 | val MAE: 0.014286 | time: 1.61s
# Epoch 268 | train MAE: 0.014878 | val MAE: 0.015193 | time: 1.62s
# Epoch 269 | train MAE: 0.015061 | val MAE: 0.013320 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 270
# Epoch 270 | train MAE: 0.011669 | val MAE: 0.015746 | time: 1.59s
# Epoch 271 | train MAE: 0.011069 | val MAE: 0.016674 | time: 1.58s
# Epoch 272 | train MAE: 0.016398 | val MAE: 0.017521 | time: 1.59s
# Epoch 273 | train MAE: 0.011205 | val MAE: 0.012697 | time: 1.64s
# Epoch 274 | train MAE: 0.010977 | val MAE: 0.011878 | time: 1.65s
# 😴 Cooling GPU: sleeping 5s after epoch 275
# Epoch 275 | train MAE: 0.014376 | val MAE: 0.014444 | time: 1.59s
# Epoch 276 | train MAE: 0.014351 | val MAE: 0.011354 | time: 1.61s
# Epoch 277 | train MAE: 0.016503 | val MAE: 0.014527 | time: 1.62s
# Epoch 278 | train MAE: 0.013899 | val MAE: 0.012294 | time: 1.62s
# Epoch 279 | train MAE: 0.017531 | val MAE: 0.016166 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 280
# Epoch 280 | train MAE: 0.015798 | val MAE: 0.017730 | time: 1.61s
# Epoch 281 | train MAE: 0.014535 | val MAE: 0.014892 | time: 1.61s
# Epoch 282 | train MAE: 0.012918 | val MAE: 0.014402 | time: 1.63s
# Epoch 283 | train MAE: 0.014831 | val MAE: 0.012742 | time: 1.60s
# Epoch 284 | train MAE: 0.019451 | val MAE: 0.012766 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 285
# Epoch 285 | train MAE: 0.011035 | val MAE: 0.014235 | time: 1.61s
# Epoch 286 | train MAE: 0.010621 | val MAE: 0.013454 | time: 1.62s
# Epoch 287 | train MAE: 0.015297 | val MAE: 0.012119 | time: 1.57s
# Epoch 288 | train MAE: 0.012915 | val MAE: 0.015728 | time: 1.61s
# Epoch 289 | train MAE: 0.018970 | val MAE: 0.014827 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 290
# Epoch 290 | train MAE: 0.018400 | val MAE: 0.015608 | time: 1.59s
# Epoch 291 | train MAE: 0.012014 | val MAE: 0.014108 | time: 1.60s
# Epoch 292 | train MAE: 0.010975 | val MAE: 0.014570 | time: 1.59s
# Epoch 293 | train MAE: 0.011519 | val MAE: 0.011902 | time: 1.64s
# Epoch 294 | train MAE: 0.011708 | val MAE: 0.011971 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 295
# Epoch 295 | train MAE: 0.011961 | val MAE: 0.012318 | time: 1.59s
# Epoch 296 | train MAE: 0.012807 | val MAE: 0.013308 | time: 1.62s
# Epoch 297 | train MAE: 0.011810 | val MAE: 0.012687 | time: 1.67s
# Epoch 298 | train MAE: 0.014782 | val MAE: 0.014140 | time: 1.61s
# Epoch 299 | train MAE: 0.014792 | val MAE: 0.012716 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 300
# Epoch 300 | train MAE: 0.013934 | val MAE: 0.014520 | time: 1.58s
# Epoch 301 | train MAE: 0.012529 | val MAE: 0.011398 | time: 1.62s
# Epoch 302 | train MAE: 0.011699 | val MAE: 0.012207 | time: 1.63s
# Epoch 303 | train MAE: 0.016533 | val MAE: 0.014956 | time: 1.59s
# Epoch 304 | train MAE: 0.013672 | val MAE: 0.011058 | time: 1.67s
# 😴 Cooling GPU: sleeping 5s after epoch 305
# Epoch 305 | train MAE: 0.014383 | val MAE: 0.013899 | time: 1.59s
# Epoch 306 | train MAE: 0.014064 | val MAE: 0.014344 | time: 1.61s
# Epoch 307 | train MAE: 0.014474 | val MAE: 0.013772 | time: 1.64s
# Epoch 308 | train MAE: 0.011833 | val MAE: 0.014167 | time: 1.57s
# Epoch 309 | train MAE: 0.021552 | val MAE: 0.019801 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 310
# Epoch 310 | train MAE: 0.016020 | val MAE: 0.013465 | time: 1.61s
# Epoch 311 | train MAE: 0.015525 | val MAE: 0.012170 | time: 1.64s
# Epoch 312 | train MAE: 0.012073 | val MAE: 0.018490 | time: 1.61s
# Epoch 313 | train MAE: 0.012236 | val MAE: 0.011151 | time: 1.62s
# Epoch 314 | train MAE: 0.010416 | val MAE: 0.011855 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 315
# Epoch 315 | train MAE: 0.012210 | val MAE: 0.010941 | time: 1.59s
# Epoch 316 | train MAE: 0.010389 | val MAE: 0.011144 | time: 1.57s
# Epoch 317 | train MAE: 0.012151 | val MAE: 0.016478 | time: 1.61s
# Epoch 318 | train MAE: 0.012323 | val MAE: 0.011857 | time: 1.65s
# Epoch 319 | train MAE: 0.012050 | val MAE: 0.012834 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 320
# Epoch 320 | train MAE: 0.014374 | val MAE: 0.012208 | time: 1.65s
# Epoch 321 | train MAE: 0.011698 | val MAE: 0.013223 | time: 1.59s
# Epoch 322 | train MAE: 0.011851 | val MAE: 0.014279 | time: 1.66s
# Epoch 323 | train MAE: 0.012786 | val MAE: 0.012113 | time: 1.60s
# Epoch 324 | train MAE: 0.014275 | val MAE: 0.014950 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 325
# Epoch 325 | train MAE: 0.011384 | val MAE: 0.013677 | time: 1.60s
# Epoch 326 | train MAE: 0.010812 | val MAE: 0.010348 | time: 1.61s
# Epoch 327 | train MAE: 0.013708 | val MAE: 0.013534 | time: 1.63s
# Epoch 328 | train MAE: 0.011723 | val MAE: 0.013034 | time: 1.60s
# Epoch 329 | train MAE: 0.012089 | val MAE: 0.011094 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 330
# Epoch 330 | train MAE: 0.014610 | val MAE: 0.012986 | time: 1.62s
# Epoch 331 | train MAE: 0.016408 | val MAE: 0.015671 | time: 1.64s
# Epoch 332 | train MAE: 0.018659 | val MAE: 0.016189 | time: 1.59s
# Epoch 333 | train MAE: 0.011614 | val MAE: 0.011466 | time: 1.61s
# Epoch 334 | train MAE: 0.013979 | val MAE: 0.012909 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 335
# Epoch 335 | train MAE: 0.014623 | val MAE: 0.014086 | time: 1.60s
# Epoch 336 | train MAE: 0.010985 | val MAE: 0.011564 | time: 1.66s
# Epoch 337 | train MAE: 0.010628 | val MAE: 0.010260 | time: 1.61s
# Epoch 338 | train MAE: 0.013934 | val MAE: 0.014935 | time: 1.62s
# Epoch 339 | train MAE: 0.017335 | val MAE: 0.021901 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 340
# Epoch 340 | train MAE: 0.012292 | val MAE: 0.014831 | time: 1.62s
# Epoch 341 | train MAE: 0.015557 | val MAE: 0.015288 | time: 1.57s
# Epoch 342 | train MAE: 0.011803 | val MAE: 0.010678 | time: 1.64s
# Epoch 343 | train MAE: 0.012348 | val MAE: 0.014827 | time: 1.61s
# Epoch 344 | train MAE: 0.017359 | val MAE: 0.015648 | time: 1.64s
# 😴 Cooling GPU: sleeping 5s after epoch 345
# Epoch 345 | train MAE: 0.008081 | val MAE: 0.010418 | time: 1.61s
# Epoch 346 | train MAE: 0.013491 | val MAE: 0.015605 | time: 1.61s
# Epoch 347 | train MAE: 0.011883 | val MAE: 0.011432 | time: 1.67s
# Epoch 348 | train MAE: 0.010834 | val MAE: 0.013357 | time: 1.66s
# Epoch 349 | train MAE: 0.012723 | val MAE: 0.013977 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 350
# Epoch 350 | train MAE: 0.012050 | val MAE: 0.013522 | time: 1.60s
# Epoch 351 | train MAE: 0.014775 | val MAE: 0.012888 | time: 1.62s
# Epoch 352 | train MAE: 0.008820 | val MAE: 0.010854 | time: 1.64s
# Epoch 353 | train MAE: 0.010617 | val MAE: 0.010011 | time: 1.66s
# Epoch 354 | train MAE: 0.010714 | val MAE: 0.012442 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 355
# Epoch 355 | train MAE: 0.009413 | val MAE: 0.012293 | time: 1.60s
# Epoch 356 | train MAE: 0.014408 | val MAE: 0.011835 | time: 1.63s
# Epoch 357 | train MAE: 0.013177 | val MAE: 0.015430 | time: 1.62s
# Epoch 358 | train MAE: 0.012645 | val MAE: 0.014338 | time: 1.62s
# Epoch 359 | train MAE: 0.024921 | val MAE: 0.013345 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 360
# Epoch 360 | train MAE: 0.009042 | val MAE: 0.010601 | time: 1.61s
# Epoch 361 | train MAE: 0.016346 | val MAE: 0.012786 | time: 1.60s
# Epoch 362 | train MAE: 0.010763 | val MAE: 0.010480 | time: 1.64s
# Epoch 363 | train MAE: 0.011011 | val MAE: 0.010970 | time: 1.60s
# Epoch 364 | train MAE: 0.012614 | val MAE: 0.012745 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 365
# Epoch 365 | train MAE: 0.010774 | val MAE: 0.012021 | time: 1.62s
# Epoch 366 | train MAE: 0.013066 | val MAE: 0.012195 | time: 1.65s
# Epoch 367 | train MAE: 0.012553 | val MAE: 0.015072 | time: 1.63s
# Epoch 368 | train MAE: 0.015794 | val MAE: 0.014171 | time: 1.60s
# Epoch 369 | train MAE: 0.018856 | val MAE: 0.019339 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 370
# Epoch 370 | train MAE: 0.014730 | val MAE: 0.013896 | time: 1.59s
# Epoch 371 | train MAE: 0.013983 | val MAE: 0.015019 | time: 1.63s
# Epoch 372 | train MAE: 0.012385 | val MAE: 0.012262 | time: 1.59s
# Epoch 373 | train MAE: 0.014648 | val MAE: 0.015325 | time: 1.58s
# Epoch 374 | train MAE: 0.011194 | val MAE: 0.012977 | time: 1.64s
# 😴 Cooling GPU: sleeping 5s after epoch 375
# Epoch 375 | train MAE: 0.012755 | val MAE: 0.011323 | time: 1.60s
# Epoch 376 | train MAE: 0.014057 | val MAE: 0.011859 | time: 1.60s
# Epoch 377 | train MAE: 0.015966 | val MAE: 0.012084 | time: 1.62s
# Epoch 378 | train MAE: 0.011898 | val MAE: 0.011929 | time: 1.62s
# Epoch 379 | train MAE: 0.016803 | val MAE: 0.012091 | time: 1.67s
# 😴 Cooling GPU: sleeping 5s after epoch 380
# Epoch 380 | train MAE: 0.020578 | val MAE: 0.019704 | time: 1.56s
# Epoch 381 | train MAE: 0.009842 | val MAE: 0.010480 | time: 1.58s
# Epoch 382 | train MAE: 0.011248 | val MAE: 0.011882 | time: 1.60s
# Epoch 383 | train MAE: 0.017387 | val MAE: 0.013427 | time: 1.59s
# Epoch 384 | train MAE: 0.011963 | val MAE: 0.010271 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 385
# Epoch 385 | train MAE: 0.018496 | val MAE: 0.016314 | time: 1.61s
# Epoch 386 | train MAE: 0.012076 | val MAE: 0.011873 | time: 1.61s
# Epoch 387 | train MAE: 0.020948 | val MAE: 0.015815 | time: 1.67s
# Epoch 388 | train MAE: 0.009695 | val MAE: 0.012040 | time: 1.58s
# Epoch 389 | train MAE: 0.021096 | val MAE: 0.025541 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 390
# Epoch 390 | train MAE: 0.011121 | val MAE: 0.009474 | time: 1.59s
# Epoch 391 | train MAE: 0.013450 | val MAE: 0.013773 | time: 1.60s
# Epoch 392 | train MAE: 0.022486 | val MAE: 0.015179 | time: 1.62s
# Epoch 393 | train MAE: 0.007505 | val MAE: 0.009745 | time: 1.67s
# Epoch 394 | train MAE: 0.013829 | val MAE: 0.012577 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 395
# Epoch 395 | train MAE: 0.011069 | val MAE: 0.013908 | time: 1.64s
# Epoch 396 | train MAE: 0.016012 | val MAE: 0.017489 | time: 1.65s
# Epoch 397 | train MAE: 0.010782 | val MAE: 0.011048 | time: 1.61s
# Epoch 398 | train MAE: 0.009690 | val MAE: 0.010072 | time: 1.60s
# Epoch 399 | train MAE: 0.015570 | val MAE: 0.012254 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 400
# `Trainer.fit` stopped: `max_epochs=400` reached.
# CPU times: user 10min 15s, sys: 3min 35s, total: 13min 51s
# Wall time: 17min 24s

# %% [markdown]
# #### Save the training history

# %%
CHECKPOINT_PATH
# Out:
# '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take6'

# %%
train_loss = np.array(plot_cb.train_losses, dtype=np.float32)
val_loss   = np.array(plot_cb.val_losses,   dtype=np.float32)
epochs = np.arange(1, len(train_loss) + 1, dtype=np.int32)

# %%
df = pd.DataFrame({
    "epoch": epochs,
    "train_loss": train_loss,
    "val_loss": val_loss,
})

df.to_csv(f"{CHECKPOINT_PATH}/training_history.csv", index=False)

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# best-390-0.009474.ckpt  last.ckpt  training_history.csv

# %%
plt.plot(epochs, train_loss, label="train")
plt.plot(epochs, val_loss, label="val")
plt.xlabel("epoch")
plt.ylabel("MAE")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluation

# %%
test_ds = NumpyDataset(X_test_scaled, y_test)
test_loader   = DataLoader(test_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
x0, y0 = test_ds[0]
print(x0.shape)   # torch.Size([5, 64, 64])
print(y0.shape)   # torch.Size([6])
# Out:
# torch.Size([5, 64, 64])
# torch.Size([6])

# %%
def get_test_predictions(model, test_loader, device):
    model.eval()

    y_true_list = []
    y_pred_list = []

    with torch.no_grad():
        for xb, yb in test_loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)

            y_hat = model(xb)          # (B, 6)

            y_true_list.append(yb.cpu().numpy())
            y_pred_list.append(y_hat.cpu().numpy())

    y_true = np.concatenate(y_true_list, axis=0)  # (N_test, 6)
    y_pred = np.concatenate(y_pred_list, axis=0)  # (N_test, 6)

    return y_true, y_pred

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# best-390-0.009474.ckpt  last.ckpt  training_history.csv

# %%
best_ckpt = f"{CHECKPOINT_PATH}/best-390-0.009474.ckpt"
lit_model = LitCNN.load_from_checkpoint(
    best_ckpt,
    model=CNNModelKerasEquivalent(),  # 🔴 구조 동일해야 함
)

# %%
# %%time
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
y_test_true, y_test_pred = get_test_predictions(lit_model, test_loader, device)
# Out:
# CPU times: user 159 ms, sys: 172 ms, total: 332 ms
# Wall time: 286 ms

# %%
print(y_test_true.shape)  # (N_test, 6)
print(y_test_pred.shape)  # (N_test, 6)
# Out:
# (4000, 6)
# (4000, 6)

# %%
mae = np.mean(np.abs(y_test_pred - y_test_true), axis=0)
print("Test MAE per y:", mae)
print("Test MAE mean :", mae.mean())
# Out:
# Test MAE per y: [0.02549109 0.00589052 0.00391111 0.00610788 0.00734307 0.00849148]
# Test MAE mean : 0.009539193

# %%
import matplotlib as mpl
import seaborn as sns

sns.reset_defaults()                 # seaborn 스타일 제거
mpl.rcParams.update(mpl.rcParamsDefault)  # matplotlib 완전 초기화

# %%
import matplotlib as mpl

mpl.rcParams.update({
    "font.family": "serif",
    "font.size": 14,        # 기본 폰트
    "axes.titlesize": 16,   # subplot title
    "axes.labelsize": 14,   # x,y label
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12,
})

# %%
def plot_error_histograms(err, bins=50):
    """
    err shape: (N, 6)
    """
    fig, axes = plt.subplots(2, 3, figsize=(10, 6))
    axes = axes.ravel()

    # symmetric range for fair comparison
    vmin = err.min()
    vmax = err.max()
    vmax = max(abs(vmin), abs(vmax))
    hist_range = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        ax.hist(
            err[:, i],
            bins=bins,
            range=hist_range,
            alpha=0.8
        )

        ax.axvline(0, color="k", linestyle="--", linewidth=1)
        ax.set_title(f"y{i} error")
        ax.set_xlabel("prediction - truth")
        ax.set_ylabel("count")

    fig.suptitle("Test error distribution (y_pred - y_true)", fontsize=12)
    fig.tight_layout()
    plt.show()

# %%
err = y_test_pred - y_test_true
print(err.shape)
# Out:
# (4000, 6)

# %%
plot_error_histograms(err,bins=200)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(
    style="whitegrid",     # 🔹 whitegrid → white
    context="talk",
    font="serif"
)

# %%
import numpy as np

def plot_error_histograms_seaborn(err, bins=40):
    """
    err shape: (N_test, 6)
    """
    fig, axes = plt.subplots(3, 2, figsize=(15, 12))
    axes = axes.ravel()

    # symmetric x-range
    vmin = err.min()
    vmax = err.max()
    vmax = max(abs(vmin), abs(vmax))
    xlim = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        sns.histplot(
            err[:, i],
            bins=bins,
            stat="count",     # 🔹 COUNT, not density
            kde=False,        # 🔹 no curve
            color="tab:blue",
            alpha=0.8,
            ax=ax
        )

        # zero reference
        ax.axvline(0, color="black", linestyle="--", linewidth=1.5)

        # metrics
        mae  = np.mean(np.abs(err[:, i]))
        rmse = np.sqrt(np.mean(err[:, i] ** 2))

        ax.text(
            0.03, 0.97,
            f"MAE  = {mae:.4f}\nRMSE = {rmse:.4f}",
            transform=ax.transAxes,
            va="top",
            ha="left",
            fontsize=14,
            bbox=dict(boxstyle="round", fc="white", alpha=0.9)
        )

        ax.set_xlim(xlim)
        ax.set_title(f"y{i} error", fontsize=16)
        ax.set_xlabel("prediction − truth", fontsize=14)
        ax.set_ylabel("count", fontsize=14)

    fig.suptitle(
        "Test error distribution (histogram, count)",
        fontsize=20,
        y=0.98
    )

    fig.tight_layout()
    plt.show()

# %%
plot_error_histograms_seaborn(err,bins=200)
