# %% [markdown]
# # PyTorch DL for KDRIFT G1 Alignment
#
# - EDA the training set
# - Train using the baseline by the student's work
# - Image Normalization .. There was some image scaling issue .. try `max(abs(X))` normalization

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
#import tensorflow as tf
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense, SimpleRNN, Conv2D, MaxPooling2D, Flatten
import os
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
#from tensorflow.keras import backend as K
from tqdm import trange, notebook
#from livelossplot import PlotLossesKeras

# %% [markdown]
# ## Browsing the working directories

# %%
# %pwd
# Out:
# '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/notebook'

# %%
# %ls
# Out:
# cnn-align-v1-no-rescale.ipynb
# cnn-align-v1-pix-norm.ipynb
# cnn-align-v2-image-norm.ipynb
# cnn-align-v3-image-abs-norm.ipynb
# cnn-align-v4-image-both-sign-norm-Copy1.ipynb
# cnn-align-v4a-image-both-sign-norm.ipynb
# cnn-align-v5-image-fixed-max-norm.ipynb
# lightning_logs/
# vit-align-v1.ipynb

# %%
data_path = '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/data/'

# %%
# !ls {data_path}
# Out:
# X_f32.npy  y_f32.npy

# %% [markdown]
# ## Explore the training set

# %%
# %%time
X = np.load(data_path+'X_f32.npy')
y = np.load(data_path+'y_f32.npy')
# Out:
# CPU times: user 0 ns, sys: 4.45 s, total: 4.45 s
# Wall time: 4.49 s

# %%
len(y),len(X)
# Out:
# (20000, 20000)

# %%
def np_array_info(a):
    print(f"shape     : {a.shape}")
    print(f"dtype     : {a.dtype}")
    print(f"ndim      : {a.ndim}")
    print(f"size      : {a.size}")
    print(f"itemsize  : {a.itemsize} bytes")
    print(f"nbytes    : {a.nbytes / 1024**2:.2f} MB")
    print(f"min / max : {a.min()} / {a.max()}")

# %%
np_array_info(y)
# Out:
# shape     : (20000, 6)
# dtype     : float32
# ndim      : 2
# size      : 120000
# itemsize  : 4 bytes
# nbytes    : 0.46 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(X)
# Out:
# shape     : (20000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 409600000
# itemsize  : 4 bytes
# nbytes    : 1562.50 MB
# min / max : -44.47488021850586 / 41.380958557128906

# %% [markdown]
# > I may need learn about what `X` and `y` mean. I am an instrument noob.

# %% [markdown]
# #### Visualize the training set

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_trainingsample(X, y, selected_index_list):
    n_samples = len(selected_index_list)
    n_views = X.shape[1]

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2)
    )

    vmin, vmax = X.min(), X.max()
    im = None

    for row, idx in enumerate(selected_index_list):
        for j in range(n_views):
            ax = axes[row, j]
            img = X[idx, j, :, :, 0]

            im = ax.imshow(
                img,
                cmap="rainbow",
                vmin=vmin,
                vmax=vmax,
                aspect="equal"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            if row == 0:
                ax.set_title(f"image {j+1}")

            # --- min / max labels (항상 포함)
            img_min = img.min()
            img_max = img.max()

            labels = [
                f"min: {img_min:.2f}",
                f"max: {img_max:.2f}",
            ]

            # --- image 1 패널에는 y 값도 같이 추가
            if y is not None and j == 0:
                yvals = y[idx]
                labels += [
                    f"y{i+1}: {val:.3f}" for i, val in enumerate(yvals)
                ]
                ax.set_ylabel(f"idx {idx}")

            handles = [
                plt.Line2D([0], [0], color="none", label=lab)
                for lab in labels
            ]

            ax.legend(
                handles=handles,
                loc="upper left" if j == 0 else "upper right",
                fontsize=7 if j != 0 else 8,
                frameon=True,
                borderpad=0.3,
                handlelength=0,
                handletextpad=0
            )

    fig.subplots_adjust(
        bottom=0.12,
        hspace=0.05,
        wspace=0.02
    )

    fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02
    )

    plt.show()

# %%
selected_index_list = [0, 5, 12, 128, 2048, 9999, 15000, 19999]
plot_trainingsample(X, y, selected_index_list)

# %% [markdown]
# ## PyTorching the Model

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
import pytorch_lightning as pl
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import torchvision
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from torchvision import transforms
from torchvision.datasets import CIFAR10

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce RTX 3090 (UUID: GPU-81ef84f4-69df-ce9c-b89c-0b05c8f72ebf)

# %%
#%load_ext tensorboard
# I will not use tensorboard .. though..

# %%
# Setting the seed
pl.seed_everything(42)

# Ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Seed set to 42

# %% [markdown]
# #### Checkpoints

# %%
CHECKPOINT_ROOT = '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/'

# %%
from time import gmtime, strftime

base_name = 'cnn'
#try_name = strftime('%Y.%m.%d_%H:%M', gmtime())
try_name = 'take3'
experiment_name = f"{base_name}_{try_name}"
print("experiment:", experiment_name)
# Out:
# experiment: cnn_take3

# %%
import os
import shutil

CHECKPOINT_PATH = os.path.join(CHECKPOINT_ROOT, experiment_name)

if os.path.exists(CHECKPOINT_PATH):
    print(f"⚠️ Directory exists: {CHECKPOINT_PATH}")
    print("🧹 Removing all contents...")

    # Clear all files/subfolders inside the directory
    for filename in os.listdir(CHECKPOINT_PATH):
        file_path = os.path.join(CHECKPOINT_PATH, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print(f"❌ Failed to delete {file_path}: {e}")

    print("✅ Directory has been cleared.")
else:
    os.makedirs(CHECKPOINT_PATH)
    print(f"✅ Directory created: {CHECKPOINT_PATH}")

print(f"📂 Experiment directory is ready: {os.path.abspath(CHECKPOINT_PATH)}")
# Out:
# ✅ Directory created: /app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take3
# 📂 Experiment directory is ready: /app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take3

# %% [markdown]
# ### Follow the min/max/scaler of the original keras code for reproduction

# %%
num_samples = len(y)
print(num_samples)
# Out:
# 20000

# %%
indices=range(num_samples)

# %%
X_train, X_test, y_train, y_test, train_indices, test_indices = \
train_test_split(X, y, indices, test_size=0.2, random_state=42)

# %%
# %%time
X_train_train, X_train_val, \
y_train_train, y_train_val, \
train_train_indices, train_val_indices = \
    train_test_split(
        X_train,
        y_train,
        train_indices,
        test_size=0.2,
        random_state=42
    )
# Out:
# CPU times: user 70 ms, sys: 2.02 s, total: 2.09 s
# Wall time: 2.11 s

# %%
np_array_info(X_train_train)
# Out:
# shape     : (12800, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 262144000
# itemsize  : 4 bytes
# nbytes    : 1000.00 MB
# min / max : -44.47488021850586 / 38.766319274902344

# %%
np_array_info(X_train_val)
# Out:
# shape     : (3200, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 65536000
# itemsize  : 4 bytes
# nbytes    : 250.00 MB
# min / max : -40.51784896850586 / 41.380958557128906

# %%
np_array_info(X_test)
# Out:
# shape     : (4000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 81920000
# itemsize  : 4 bytes
# nbytes    : 312.50 MB
# min / max : -38.55973815917969 / 38.85308074951172

# %% [markdown]
# #### normalization by scaler

# %%
# %%time
import numpy as np

# X_train_train shape: (N, 5, 64, 64, 1)

max_abs = np.max(
    np.abs(X_train_train),
    axis=(2, 3, 4),   # 64x64 + channel=1
    keepdims=True
)
# symmetric rescaling per image
X_train_train_scaled = X_train_train / (2.0 * max_abs + 1e-8) + 0.5
# Out:
# CPU times: user 230 ms, sys: 2.48 s, total: 2.71 s
# Wall time: 2.73 s

# %%
max_abs = np.max(
    np.abs(X_train_val),
    axis=(2, 3, 4),   # 64x64 + channel=1
    keepdims=True
)
# symmetric rescaling per image
X_train_val_scaled = X_train_val / (2.0 * max_abs + 1e-8) + 0.5

# %%
max_abs = np.max(
    np.abs(X_test),
    axis=(2, 3, 4),   # 64x64 + channel=1
    keepdims=True
)
# symmetric rescaling per image
X_test_scaled = X_test / (2.0 * max_abs + 1e-8) + 0.5

# %% [markdown]
# #### Plot the rescaled Training Sample
#
# - this could be wrong?!?

# %%
plot_trainingsample(X_train_train_scaled, y,[0,1,2,3,4])

# %%
plot_trainingsample(X_train_val_scaled, y,[0,1,2,3,4])

# %%
plot_trainingsample(X_test_scaled, y,[0,1,2,3,4])

# %% [markdown]
# - I guess this normalization is sane, `0 -> 0.5` and `max(abs(image)) -> 1.0`

# %%
np_array_info(X_train_train_scaled)
# Out:
# shape     : (12800, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 262144000
# itemsize  : 4 bytes
# nbytes    : 1000.00 MB
# min / max : 0.0 / 1.0

# %%
np_array_info(X_train_val_scaled)
# Out:
# shape     : (3200, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 65536000
# itemsize  : 4 bytes
# nbytes    : 250.00 MB
# min / max : 0.0 / 1.0

# %%
np_array_info(X_test_scaled)
# Out:
# shape     : (4000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 81920000
# itemsize  : 4 bytes
# nbytes    : 312.50 MB
# min / max : 0.0 / 1.0

# %%
np_array_info(y_train_train)
# Out:
# shape     : (12800, 6)
# dtype     : float32
# ndim      : 2
# size      : 76800
# itemsize  : 4 bytes
# nbytes    : 0.29 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(y_train_val)
# Out:
# shape     : (3200, 6)
# dtype     : float32
# ndim      : 2
# size      : 19200
# itemsize  : 4 bytes
# nbytes    : 0.07 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(y_test)
# Out:
# shape     : (4000, 6)
# dtype     : float32
# ndim      : 2
# size      : 24000
# itemsize  : 4 bytes
# nbytes    : 0.09 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_y_histograms_splits(y_train_train, y_train_val, y_test, bins=50):
    """
    y_* shape: (N, 6)
    """

    fig, axes = plt.subplots(2, 3, figsize=(12, 7))
    axes = axes.ravel()

    # symmetric range across ALL splits
    all_y = np.concatenate([y_train_train, y_train_val, y_test], axis=0)
    vmin = all_y.min()
    vmax = all_y.max()
    vmax = max(abs(vmin), abs(vmax))
    hist_range = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        ax.hist(
            y_train_train[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='r',
            alpha=0.2,
            label="train"
        )
        ax.hist(
            y_train_val[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='g',
            alpha=0.2,
            label="val"
        )
        ax.hist(
            y_test[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='b',
            alpha=0.2,
            label="test"
        )

        ax.axvline(0, color="k", linestyle="--", linewidth=1)
        ax.set_title(f"y{i}")
        ax.set_xlabel("value")
        ax.set_ylabel("density")

        if i == 0:
            ax.legend()

    fig.suptitle("Distribution of y components (train / val / test)", fontsize=13)
    fig.tight_layout()
    plt.show()

# %%
plot_y_histograms_splits(y_train_train, y_train_val, y_test)

# %% [markdown]
# ## Train the CNN model

# %%
class CNNModelKerasEquivalent(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            # Conv2D(32,(1,1), relu, input_shape=(5,64,64), channels_first)
            nn.Conv2d(in_channels=5, out_channels=32, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # Conv2D(64,(3,3), relu)  (padding='valid' in Keras -> padding=0 in PyTorch)
            nn.Conv2d(32, 64, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(2,2), relu)
            nn.Conv2d(64, 32, kernel_size=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(1,1), relu)
            nn.Conv2d(32, 32, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(1,1), relu)
            nn.Conv2d(32, 32, kernel_size=1),
            nn.ReLU(inplace=True),

            nn.Flatten(),                 # Keras Flatten()
            nn.Linear(32 * 3 * 3, 128),   # 계산 결과: 64->32->30->15->14->7->3 => 32*3*3
            nn.ReLU(inplace=True),
            nn.Linear(128, 6)             # Dense(6)
        )

    def forward(self, x):
        return self.net(x)

# %%
from torch.utils.data import Dataset, DataLoader

class NumpyDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        x = torch.from_numpy(self.X[idx]).float()  # (5,64,64)
        x = x.squeeze(-1) # if (5,64,64,1)
        t = torch.from_numpy(self.y[idx]).float()  # (6,)
        return x, t

# %%
train_ds = NumpyDataset(X_train_train_scaled, y_train_train)
val_ds   = NumpyDataset(X_train_val_scaled,   y_train_val)

# %%
x0, y0 = train_ds[0]
print(x0.shape)   # torch.Size([5, 64, 64])
print(y0.shape)   # torch.Size([6])
# Out:
# torch.Size([5, 64, 64])
# torch.Size([6])

# %%
train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
xb, yb = next(iter(train_loader))
print("xb.shape:", xb.shape)
print("yb.shape:", yb.shape)
print("xb.dtype:", xb.dtype)
# Out:
# xb.shape: torch.Size([32, 5, 64, 64])
# yb.shape: torch.Size([32, 6])
# xb.dtype: torch.float32

# %% [markdown]
# #### Visualize the training dataloader as a sanity check

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow",
                                   linewidth=0.5, vmin=None, vmax=None):
    """
    xb: torch.Tensor, shape (B, 5, 64, 64)
    n_samples: number of rows (samples)
    ngrid: number of grid cells per axis (e.g., 16 => patch size 4 for 64x64)
    """
    # tensor -> numpy
    x = xb[:n_samples].detach().cpu().numpy()  # (n_samples, 5, 64, 64)
    n_samples = x.shape[0]
    n_views = x.shape[1]
    H, W = x.shape[2], x.shape[3]

    assert H % ngrid == 0 and W % ngrid == 0, f"H,W must be divisible by ngrid. got {H},{W}, ngrid={ngrid}"
    patch_h = H // ngrid
    patch_w = W // ngrid

    # global color scale (consistent across all panels)
    if vmin is None:
        vmin = float(x.min())
    if vmax is None:
        vmax = float(x.max())

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2),
        constrained_layout=False
    )

    # in case n_samples == 1
    if n_samples == 1:
        axes = np.expand_dims(axes, axis=0)

    im = None
    for i in range(n_samples):
        for j in range(n_views):
            ax = axes[i, j]
            img = x[i, j]  # (64,64)

            im = ax.imshow(
                img,
                cmap=cmap,
                vmin=vmin,
                vmax=vmax,
                aspect="equal",
                interpolation="nearest"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            # column titles
            if i == 0:
                ax.set_title(f"ch {j}", fontsize=11)

            # row labels
            if j == 0:
                ax.set_ylabel(f"sample {i}", fontsize=11)

            # draw patch grid boundaries
            for gy in range(0, H + 1, patch_h):
                ax.axhline(gy - 0.5, color="w", linewidth=linewidth, alpha=0.9)
            for gx in range(0, W + 1, patch_w):
                ax.axvline(gx - 0.5, color="w", linewidth=linewidth, alpha=0.9)

    # tighter spacing + bottom colorbar
    fig.subplots_adjust(bottom=0.08, hspace=0.02, wspace=0.02)

    cbar = fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02
    )
    cbar.set_label("pixel value")

    plt.show()

# %%
plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow")

# %%
xb, yb = next(iter(val_loader))
print("xb.shape:", xb.shape)
print("yb.shape:", yb.shape)
print("xb.dtype:", xb.dtype)
# Out:
# xb.shape: torch.Size([32, 5, 64, 64])
# yb.shape: torch.Size([32, 6])
# xb.dtype: torch.float32

# %%
plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow")

# %% [markdown]
# #### Callbacks

# %%
import time
import matplotlib.pyplot as plt
from pytorch_lightning.callbacks import Callback

class PlotLossesPL(Callback):
    def __init__(self):
        self.train_losses = []
        self.val_losses = []
        self.epoch_times = []

    def on_train_epoch_start(self, trainer, pl_module):
        self.epoch_start_time = time.time()

    def on_train_epoch_end(self, trainer, pl_module):
        epoch_time = time.time() - self.epoch_start_time
        self.epoch_times.append(epoch_time)

        train_loss = trainer.callback_metrics.get("train_loss")
        val_loss   = trainer.callback_metrics.get("val_loss")

        if train_loss is not None:
            self.train_losses.append(train_loss.item())
        if val_loss is not None:
            self.val_losses.append(val_loss.item())

        print(
            f"Epoch {trainer.current_epoch:03d} | "
            f"train MAE: {self.train_losses[-1]:.6f} | "
            f"val MAE: {self.val_losses[-1]:.6f} | "
            f"time: {epoch_time:.2f}s"
        )

    def on_fit_end(self, trainer, pl_module):
        self.plot()

    def plot(self):
        plt.figure(figsize=(6,4))
        plt.plot(self.train_losses, label="train")
        plt.plot(self.val_losses, label="val")
        plt.xlabel("epoch")
        plt.ylabel("MAE")
        plt.legend()
        plt.tight_layout()
        plt.show()

# %%
import time
from pytorch_lightning.callbacks import Callback

class GPUSleepCallback(Callback):
    def __init__(self, every_n_epochs=5, sleep_seconds=5):
        self.every_n_epochs = every_n_epochs
        self.sleep_seconds = sleep_seconds

    def on_train_epoch_end(self, trainer, pl_module):
        epoch = trainer.current_epoch + 1  # 1-based로 보기 좋게
        if epoch % self.every_n_epochs == 0:
            print(f"😴 Cooling GPU: sleeping {self.sleep_seconds}s after epoch {epoch}")
            time.sleep(self.sleep_seconds)

# %%
import os
from pytorch_lightning.callbacks import ModelCheckpoint

#ckpt_dir = "/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take1"
ckpt_dir = CHECKPOINT_PATH

checkpoint_cb = ModelCheckpoint(
    dirpath=ckpt_dir,
    filename="best-{epoch:03d}-{val_loss:.6f}",  # 파일명 템플릿
    monitor="val_loss",                          # 우리가 log한 키
    mode="min",                                  # 최소가 best
    save_top_k=1,                                # best 1개만 유지
    save_last=True,                              # last.ckpt도 저장
    auto_insert_metric_name=False
)

# %%
import pytorch_lightning as pl
import torch
import torch.nn as nn

class LitCNN(pl.LightningModule):
    def __init__(self, model, lr=1e-3):
        super().__init__()
        self.model = model
        self.criterion = nn.L1Loss()
        self.lr = lr

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.log("train_loss", loss, prog_bar=False)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.log("val_loss", loss, prog_bar=False)
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.lr)

# %%
from pytorch_lightning.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=100,
    mode="min"
)

# %%
from pytorch_lightning import Trainer

plot_cb = PlotLossesPL()
gpu_sleep_cb = GPUSleepCallback(every_n_epochs=5, sleep_seconds=5)

trainer = Trainer(
    max_epochs=400,
    callbacks=[plot_cb, checkpoint_cb, gpu_sleep_cb],
    enable_progress_bar=False,
    enable_model_summary=False,
    accelerator="gpu" if torch.cuda.is_available() else "cpu",
    devices=1,
    log_every_n_steps=999999
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
# %%time
trainer.fit(
    model=LitCNN(CNNModelKerasEquivalent()),
    train_dataloaders=train_loader,
    val_dataloaders=val_loader
)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:317: The number of training batches (400) is smaller than the logging interval Trainer(log_every_n_steps=999999). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 000 | train MAE: 0.191483 | val MAE: 0.203403 | time: 1.55s
# Epoch 001 | train MAE: 0.193935 | val MAE: 0.197783 | time: 1.59s
# Epoch 002 | train MAE: 0.155161 | val MAE: 0.161580 | time: 1.56s
# Epoch 003 | train MAE: 0.138082 | val MAE: 0.137322 | time: 1.60s
# Epoch 004 | train MAE: 0.126455 | val MAE: 0.126919 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 5
# Epoch 005 | train MAE: 0.125954 | val MAE: 0.120453 | time: 1.59s
# Epoch 006 | train MAE: 0.113390 | val MAE: 0.115988 | time: 1.60s
# Epoch 007 | train MAE: 0.106416 | val MAE: 0.111132 | time: 1.56s
# Epoch 008 | train MAE: 0.127212 | val MAE: 0.109958 | time: 1.57s
# Epoch 009 | train MAE: 0.105239 | val MAE: 0.109976 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 10
# Epoch 010 | train MAE: 0.115598 | val MAE: 0.110199 | time: 1.57s
# Epoch 011 | train MAE: 0.107673 | val MAE: 0.105804 | time: 1.58s
# Epoch 012 | train MAE: 0.100955 | val MAE: 0.105085 | time: 1.61s
# Epoch 013 | train MAE: 0.087891 | val MAE: 0.100639 | time: 1.60s
# Epoch 014 | train MAE: 0.106193 | val MAE: 0.099229 | time: 1.55s
# 😴 Cooling GPU: sleeping 5s after epoch 15
# Epoch 015 | train MAE: 0.104690 | val MAE: 0.098300 | time: 1.60s
# Epoch 016 | train MAE: 0.092764 | val MAE: 0.097352 | time: 1.59s
# Epoch 017 | train MAE: 0.097670 | val MAE: 0.095088 | time: 1.63s
# Epoch 018 | train MAE: 0.092990 | val MAE: 0.094488 | time: 1.61s
# Epoch 019 | train MAE: 0.091259 | val MAE: 0.095229 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 20
# Epoch 020 | train MAE: 0.091739 | val MAE: 0.087553 | time: 1.58s
# Epoch 021 | train MAE: 0.094679 | val MAE: 0.088381 | time: 1.59s
# Epoch 022 | train MAE: 0.079858 | val MAE: 0.082698 | time: 1.60s
# Epoch 023 | train MAE: 0.065396 | val MAE: 0.083037 | time: 1.60s
# Epoch 024 | train MAE: 0.069498 | val MAE: 0.078955 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 25
# Epoch 025 | train MAE: 0.071833 | val MAE: 0.076542 | time: 1.62s
# Epoch 026 | train MAE: 0.068062 | val MAE: 0.072456 | time: 1.56s
# Epoch 027 | train MAE: 0.071173 | val MAE: 0.068539 | time: 1.58s
# Epoch 028 | train MAE: 0.061947 | val MAE: 0.067105 | time: 1.58s
# Epoch 029 | train MAE: 0.063913 | val MAE: 0.066960 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 30
# Epoch 030 | train MAE: 0.053993 | val MAE: 0.060462 | time: 1.59s
# Epoch 031 | train MAE: 0.060138 | val MAE: 0.060971 | time: 1.60s
# Epoch 032 | train MAE: 0.066932 | val MAE: 0.067270 | time: 1.55s
# Epoch 033 | train MAE: 0.063303 | val MAE: 0.060165 | time: 1.61s
# Epoch 034 | train MAE: 0.051287 | val MAE: 0.059281 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 35
# Epoch 035 | train MAE: 0.050898 | val MAE: 0.057504 | time: 1.60s
# Epoch 036 | train MAE: 0.059800 | val MAE: 0.054527 | time: 1.56s
# Epoch 037 | train MAE: 0.045788 | val MAE: 0.052314 | time: 1.59s
# Epoch 038 | train MAE: 0.047170 | val MAE: 0.057469 | time: 1.62s
# Epoch 039 | train MAE: 0.054122 | val MAE: 0.051074 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 40
# Epoch 040 | train MAE: 0.057653 | val MAE: 0.050773 | time: 1.59s
# Epoch 041 | train MAE: 0.062622 | val MAE: 0.059209 | time: 1.61s
# Epoch 042 | train MAE: 0.045501 | val MAE: 0.049914 | time: 1.54s
# Epoch 043 | train MAE: 0.049337 | val MAE: 0.049415 | time: 1.59s
# Epoch 044 | train MAE: 0.046374 | val MAE: 0.053807 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 45
# Epoch 045 | train MAE: 0.053522 | val MAE: 0.054756 | time: 1.58s
# Epoch 046 | train MAE: 0.051708 | val MAE: 0.050921 | time: 1.60s
# Epoch 047 | train MAE: 0.050792 | val MAE: 0.050680 | time: 1.60s
# Epoch 048 | train MAE: 0.042421 | val MAE: 0.047464 | time: 1.64s
# Epoch 049 | train MAE: 0.050039 | val MAE: 0.046769 | time: 1.66s
# 😴 Cooling GPU: sleeping 5s after epoch 50
# Epoch 050 | train MAE: 0.048330 | val MAE: 0.048146 | time: 1.59s
# Epoch 051 | train MAE: 0.042881 | val MAE: 0.047795 | time: 1.56s
# Epoch 052 | train MAE: 0.044173 | val MAE: 0.042548 | time: 1.55s
# Epoch 053 | train MAE: 0.044050 | val MAE: 0.045376 | time: 1.58s
# Epoch 054 | train MAE: 0.045430 | val MAE: 0.047160 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 55
# Epoch 055 | train MAE: 0.041904 | val MAE: 0.043783 | time: 1.59s
# Epoch 056 | train MAE: 0.048811 | val MAE: 0.044333 | time: 1.61s
# Epoch 057 | train MAE: 0.043023 | val MAE: 0.044749 | time: 1.59s
# Epoch 058 | train MAE: 0.039279 | val MAE: 0.045626 | time: 1.60s
# Epoch 059 | train MAE: 0.036882 | val MAE: 0.043476 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 60
# Epoch 060 | train MAE: 0.041767 | val MAE: 0.044017 | time: 1.59s
# Epoch 061 | train MAE: 0.044006 | val MAE: 0.043975 | time: 1.59s
# Epoch 062 | train MAE: 0.039364 | val MAE: 0.044069 | time: 1.61s
# Epoch 063 | train MAE: 0.036905 | val MAE: 0.041275 | time: 1.56s
# Epoch 064 | train MAE: 0.041338 | val MAE: 0.043235 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 65
# Epoch 065 | train MAE: 0.039837 | val MAE: 0.040840 | time: 1.58s
# Epoch 066 | train MAE: 0.039860 | val MAE: 0.039322 | time: 1.61s
# Epoch 067 | train MAE: 0.042049 | val MAE: 0.038254 | time: 1.56s
# Epoch 068 | train MAE: 0.039484 | val MAE: 0.042508 | time: 1.61s
# Epoch 069 | train MAE: 0.047498 | val MAE: 0.042689 | time: 1.55s
# 😴 Cooling GPU: sleeping 5s after epoch 70
# Epoch 070 | train MAE: 0.044990 | val MAE: 0.037621 | time: 1.55s
# Epoch 071 | train MAE: 0.032469 | val MAE: 0.041585 | time: 1.58s
# Epoch 072 | train MAE: 0.035681 | val MAE: 0.037856 | time: 1.57s
# Epoch 073 | train MAE: 0.040585 | val MAE: 0.038709 | time: 1.57s
# Epoch 074 | train MAE: 0.031951 | val MAE: 0.037917 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 75
# Epoch 075 | train MAE: 0.043487 | val MAE: 0.042527 | time: 1.58s
# Epoch 076 | train MAE: 0.035340 | val MAE: 0.036790 | time: 1.59s
# Epoch 077 | train MAE: 0.040034 | val MAE: 0.043208 | time: 1.53s
# Epoch 078 | train MAE: 0.044211 | val MAE: 0.039670 | time: 1.57s
# Epoch 079 | train MAE: 0.031785 | val MAE: 0.040239 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 80
# Epoch 080 | train MAE: 0.039330 | val MAE: 0.036759 | time: 1.58s
# Epoch 081 | train MAE: 0.032396 | val MAE: 0.041024 | time: 1.62s
# Epoch 082 | train MAE: 0.029263 | val MAE: 0.035182 | time: 1.62s
# Epoch 083 | train MAE: 0.035596 | val MAE: 0.041801 | time: 1.58s
# Epoch 084 | train MAE: 0.039943 | val MAE: 0.042101 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 85
# Epoch 085 | train MAE: 0.037433 | val MAE: 0.042836 | time: 1.61s
# Epoch 086 | train MAE: 0.029709 | val MAE: 0.035449 | time: 1.59s
# Epoch 087 | train MAE: 0.035618 | val MAE: 0.038974 | time: 1.57s
# Epoch 088 | train MAE: 0.033165 | val MAE: 0.037175 | time: 1.60s
# Epoch 089 | train MAE: 0.032035 | val MAE: 0.036810 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 90
# Epoch 090 | train MAE: 0.028478 | val MAE: 0.034807 | time: 1.62s
# Epoch 091 | train MAE: 0.042945 | val MAE: 0.041841 | time: 1.59s
# Epoch 092 | train MAE: 0.035242 | val MAE: 0.035338 | time: 1.58s
# Epoch 093 | train MAE: 0.036357 | val MAE: 0.036979 | time: 1.65s
# Epoch 094 | train MAE: 0.029964 | val MAE: 0.036279 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 95
# Epoch 095 | train MAE: 0.035421 | val MAE: 0.035629 | time: 1.57s
# Epoch 096 | train MAE: 0.032720 | val MAE: 0.039609 | time: 1.62s
# Epoch 097 | train MAE: 0.033069 | val MAE: 0.035104 | time: 1.62s
# Epoch 098 | train MAE: 0.029819 | val MAE: 0.034717 | time: 1.56s
# Epoch 099 | train MAE: 0.040421 | val MAE: 0.039244 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 100
# Epoch 100 | train MAE: 0.036931 | val MAE: 0.040058 | time: 1.55s
# Epoch 101 | train MAE: 0.033006 | val MAE: 0.035508 | time: 1.61s
# Epoch 102 | train MAE: 0.034399 | val MAE: 0.034736 | time: 1.61s
# Epoch 103 | train MAE: 0.031147 | val MAE: 0.036447 | time: 1.56s
# Epoch 104 | train MAE: 0.034613 | val MAE: 0.035329 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 105
# Epoch 105 | train MAE: 0.034103 | val MAE: 0.035439 | time: 1.62s
# Epoch 106 | train MAE: 0.033017 | val MAE: 0.036368 | time: 1.65s
# Epoch 107 | train MAE: 0.029873 | val MAE: 0.034801 | time: 1.62s
# Epoch 108 | train MAE: 0.031938 | val MAE: 0.035680 | time: 1.69s
# Epoch 109 | train MAE: 0.029371 | val MAE: 0.038292 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 110
# Epoch 110 | train MAE: 0.031204 | val MAE: 0.033362 | time: 1.61s
# Epoch 111 | train MAE: 0.034607 | val MAE: 0.035935 | time: 1.59s
# Epoch 112 | train MAE: 0.043278 | val MAE: 0.038973 | time: 1.64s
# Epoch 113 | train MAE: 0.034284 | val MAE: 0.038320 | time: 1.65s
# Epoch 114 | train MAE: 0.040783 | val MAE: 0.038112 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 115
# Epoch 115 | train MAE: 0.031157 | val MAE: 0.035961 | time: 1.58s
# Epoch 116 | train MAE: 0.035621 | val MAE: 0.039236 | time: 1.63s
# Epoch 117 | train MAE: 0.032170 | val MAE: 0.035247 | time: 1.58s
# Epoch 118 | train MAE: 0.030503 | val MAE: 0.034620 | time: 1.66s
# Epoch 119 | train MAE: 0.033463 | val MAE: 0.034855 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 120
# Epoch 120 | train MAE: 0.034377 | val MAE: 0.037234 | time: 1.59s
# Epoch 121 | train MAE: 0.027530 | val MAE: 0.035495 | time: 1.59s
# Epoch 122 | train MAE: 0.027440 | val MAE: 0.033508 | time: 1.55s
# Epoch 123 | train MAE: 0.033347 | val MAE: 0.033653 | time: 1.59s
# Epoch 124 | train MAE: 0.033305 | val MAE: 0.036930 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 125
# Epoch 125 | train MAE: 0.028510 | val MAE: 0.036284 | time: 1.63s
# Epoch 126 | train MAE: 0.028786 | val MAE: 0.032474 | time: 1.56s
# Epoch 127 | train MAE: 0.028142 | val MAE: 0.034214 | time: 1.61s
# Epoch 128 | train MAE: 0.025303 | val MAE: 0.034842 | time: 1.62s
# Epoch 129 | train MAE: 0.032663 | val MAE: 0.034832 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 130
# Epoch 130 | train MAE: 0.030836 | val MAE: 0.032066 | time: 1.60s
# Epoch 131 | train MAE: 0.027577 | val MAE: 0.035206 | time: 1.60s
# Epoch 132 | train MAE: 0.031601 | val MAE: 0.033968 | time: 1.56s
# Epoch 133 | train MAE: 0.027382 | val MAE: 0.033664 | time: 1.58s
# Epoch 134 | train MAE: 0.028481 | val MAE: 0.034953 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 135
# Epoch 135 | train MAE: 0.034744 | val MAE: 0.033232 | time: 1.67s
# Epoch 136 | train MAE: 0.030888 | val MAE: 0.032413 | time: 1.62s
# Epoch 137 | train MAE: 0.027887 | val MAE: 0.032065 | time: 1.58s
# Epoch 138 | train MAE: 0.030634 | val MAE: 0.033467 | time: 1.62s
# Epoch 139 | train MAE: 0.030072 | val MAE: 0.034576 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 140
# Epoch 140 | train MAE: 0.032714 | val MAE: 0.036044 | time: 1.62s
# Epoch 141 | train MAE: 0.029248 | val MAE: 0.032981 | time: 1.60s
# Epoch 142 | train MAE: 0.025355 | val MAE: 0.033118 | time: 1.59s
# Epoch 143 | train MAE: 0.029288 | val MAE: 0.034686 | time: 1.62s
# Epoch 144 | train MAE: 0.029127 | val MAE: 0.031980 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 145
# Epoch 145 | train MAE: 0.029524 | val MAE: 0.037220 | time: 1.59s
# Epoch 146 | train MAE: 0.025933 | val MAE: 0.030859 | time: 1.56s
# Epoch 147 | train MAE: 0.025235 | val MAE: 0.033294 | time: 1.63s
# Epoch 148 | train MAE: 0.027643 | val MAE: 0.030753 | time: 1.63s
# Epoch 149 | train MAE: 0.028911 | val MAE: 0.033577 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 150
# Epoch 150 | train MAE: 0.034407 | val MAE: 0.032414 | time: 1.62s
# Epoch 151 | train MAE: 0.029538 | val MAE: 0.032828 | time: 1.64s
# Epoch 152 | train MAE: 0.034501 | val MAE: 0.033715 | time: 1.62s
# Epoch 153 | train MAE: 0.032259 | val MAE: 0.033506 | time: 1.57s
# Epoch 154 | train MAE: 0.028242 | val MAE: 0.033201 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 155
# Epoch 155 | train MAE: 0.028986 | val MAE: 0.034321 | time: 1.59s
# Epoch 156 | train MAE: 0.028195 | val MAE: 0.032492 | time: 1.62s
# Epoch 157 | train MAE: 0.026282 | val MAE: 0.032118 | time: 1.65s
# Epoch 158 | train MAE: 0.030588 | val MAE: 0.035453 | time: 1.59s
# Epoch 159 | train MAE: 0.027516 | val MAE: 0.033515 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 160
# Epoch 160 | train MAE: 0.029556 | val MAE: 0.033580 | time: 1.56s
# Epoch 161 | train MAE: 0.025263 | val MAE: 0.032248 | time: 1.59s
# Epoch 162 | train MAE: 0.026529 | val MAE: 0.032631 | time: 1.59s
# Epoch 163 | train MAE: 0.026660 | val MAE: 0.029961 | time: 1.62s
# Epoch 164 | train MAE: 0.032670 | val MAE: 0.032660 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 165
# Epoch 165 | train MAE: 0.027737 | val MAE: 0.031679 | time: 1.56s
# Epoch 166 | train MAE: 0.026662 | val MAE: 0.033750 | time: 1.58s
# Epoch 167 | train MAE: 0.026984 | val MAE: 0.033390 | time: 1.58s
# Epoch 168 | train MAE: 0.030264 | val MAE: 0.032068 | time: 1.59s
# Epoch 169 | train MAE: 0.034964 | val MAE: 0.033866 | time: 1.69s
# 😴 Cooling GPU: sleeping 5s after epoch 170
# Epoch 170 | train MAE: 0.030543 | val MAE: 0.033830 | time: 1.61s
# Epoch 171 | train MAE: 0.026913 | val MAE: 0.030008 | time: 1.62s
# Epoch 172 | train MAE: 0.029633 | val MAE: 0.033908 | time: 1.59s
# Epoch 173 | train MAE: 0.026992 | val MAE: 0.029919 | time: 1.59s
# Epoch 174 | train MAE: 0.027747 | val MAE: 0.031484 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 175
# Epoch 175 | train MAE: 0.026622 | val MAE: 0.032086 | time: 1.65s
# Epoch 176 | train MAE: 0.025814 | val MAE: 0.030613 | time: 1.57s
# Epoch 177 | train MAE: 0.031165 | val MAE: 0.030012 | time: 1.57s
# Epoch 178 | train MAE: 0.031627 | val MAE: 0.032109 | time: 1.60s
# Epoch 179 | train MAE: 0.026176 | val MAE: 0.030509 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 180
# Epoch 180 | train MAE: 0.030093 | val MAE: 0.032380 | time: 1.61s
# Epoch 181 | train MAE: 0.030313 | val MAE: 0.032351 | time: 1.61s
# Epoch 182 | train MAE: 0.026209 | val MAE: 0.032810 | time: 1.59s
# Epoch 183 | train MAE: 0.032617 | val MAE: 0.032633 | time: 1.59s
# Epoch 184 | train MAE: 0.025925 | val MAE: 0.029558 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 185
# Epoch 185 | train MAE: 0.025815 | val MAE: 0.029980 | time: 1.60s
# Epoch 186 | train MAE: 0.030088 | val MAE: 0.032205 | time: 1.57s
# Epoch 187 | train MAE: 0.025654 | val MAE: 0.032141 | time: 1.57s
# Epoch 188 | train MAE: 0.029781 | val MAE: 0.032060 | time: 1.59s
# Epoch 189 | train MAE: 0.026434 | val MAE: 0.029940 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 190
# Epoch 190 | train MAE: 0.027612 | val MAE: 0.029711 | time: 1.64s
# Epoch 191 | train MAE: 0.024118 | val MAE: 0.030837 | time: 1.66s
# Epoch 192 | train MAE: 0.021666 | val MAE: 0.031362 | time: 1.62s
# Epoch 193 | train MAE: 0.026839 | val MAE: 0.032317 | time: 1.58s
# Epoch 194 | train MAE: 0.029354 | val MAE: 0.036127 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 195
# Epoch 195 | train MAE: 0.024614 | val MAE: 0.030903 | time: 1.60s
# Epoch 196 | train MAE: 0.029058 | val MAE: 0.032550 | time: 1.61s
# Epoch 197 | train MAE: 0.027957 | val MAE: 0.029763 | time: 1.59s
# Epoch 198 | train MAE: 0.025713 | val MAE: 0.032074 | time: 1.56s
# Epoch 199 | train MAE: 0.036301 | val MAE: 0.035066 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 200
# Epoch 200 | train MAE: 0.023310 | val MAE: 0.032414 | time: 1.60s
# Epoch 201 | train MAE: 0.026157 | val MAE: 0.029462 | time: 1.58s
# Epoch 202 | train MAE: 0.026686 | val MAE: 0.034279 | time: 1.58s
# Epoch 203 | train MAE: 0.031620 | val MAE: 0.032623 | time: 1.62s
# Epoch 204 | train MAE: 0.027355 | val MAE: 0.031543 | time: 1.66s
# 😴 Cooling GPU: sleeping 5s after epoch 205
# Epoch 205 | train MAE: 0.034201 | val MAE: 0.031644 | time: 1.61s
# Epoch 206 | train MAE: 0.025767 | val MAE: 0.030346 | time: 1.59s
# Epoch 207 | train MAE: 0.025361 | val MAE: 0.033993 | time: 1.62s
# Epoch 208 | train MAE: 0.030024 | val MAE: 0.028600 | time: 1.62s
# Epoch 209 | train MAE: 0.025409 | val MAE: 0.030974 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 210
# Epoch 210 | train MAE: 0.028526 | val MAE: 0.031774 | time: 1.59s
# Epoch 211 | train MAE: 0.025746 | val MAE: 0.030435 | time: 1.58s
# Epoch 212 | train MAE: 0.031431 | val MAE: 0.034159 | time: 1.62s
# Epoch 213 | train MAE: 0.029049 | val MAE: 0.031976 | time: 1.61s
# Epoch 214 | train MAE: 0.030652 | val MAE: 0.031159 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 215
# Epoch 215 | train MAE: 0.030278 | val MAE: 0.033887 | time: 1.59s
# Epoch 216 | train MAE: 0.027862 | val MAE: 0.032782 | time: 1.62s
# Epoch 217 | train MAE: 0.028037 | val MAE: 0.029947 | time: 1.61s
# Epoch 218 | train MAE: 0.026568 | val MAE: 0.031903 | time: 1.59s
# Epoch 219 | train MAE: 0.031908 | val MAE: 0.032933 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 220
# Epoch 220 | train MAE: 0.030719 | val MAE: 0.029461 | time: 1.61s
# Epoch 221 | train MAE: 0.025665 | val MAE: 0.031641 | time: 1.64s
# Epoch 222 | train MAE: 0.023629 | val MAE: 0.029374 | time: 1.63s
# Epoch 223 | train MAE: 0.024152 | val MAE: 0.029551 | time: 1.60s
# Epoch 224 | train MAE: 0.030869 | val MAE: 0.030277 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 225
# Epoch 225 | train MAE: 0.027074 | val MAE: 0.029697 | time: 1.62s
# Epoch 226 | train MAE: 0.027230 | val MAE: 0.029004 | time: 1.65s
# Epoch 227 | train MAE: 0.024805 | val MAE: 0.027873 | time: 1.60s
# Epoch 228 | train MAE: 0.025263 | val MAE: 0.030266 | time: 1.64s
# Epoch 229 | train MAE: 0.025101 | val MAE: 0.030863 | time: 1.64s
# 😴 Cooling GPU: sleeping 5s after epoch 230
# Epoch 230 | train MAE: 0.028220 | val MAE: 0.031640 | time: 1.59s
# Epoch 231 | train MAE: 0.024032 | val MAE: 0.029208 | time: 1.61s
# Epoch 232 | train MAE: 0.024256 | val MAE: 0.029124 | time: 1.64s
# Epoch 233 | train MAE: 0.032822 | val MAE: 0.031583 | time: 1.61s
# Epoch 234 | train MAE: 0.022556 | val MAE: 0.029670 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 235
# Epoch 235 | train MAE: 0.023667 | val MAE: 0.029454 | time: 1.59s
# Epoch 236 | train MAE: 0.030004 | val MAE: 0.030653 | time: 1.63s
# Epoch 237 | train MAE: 0.025674 | val MAE: 0.032030 | time: 1.57s
# Epoch 238 | train MAE: 0.030030 | val MAE: 0.029072 | time: 1.60s
# Epoch 239 | train MAE: 0.027287 | val MAE: 0.032006 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 240
# Epoch 240 | train MAE: 0.039301 | val MAE: 0.035104 | time: 1.59s
# Epoch 241 | train MAE: 0.023709 | val MAE: 0.028303 | time: 1.60s
# Epoch 242 | train MAE: 0.029222 | val MAE: 0.029844 | time: 1.59s
# Epoch 243 | train MAE: 0.025246 | val MAE: 0.029579 | time: 1.63s
# Epoch 244 | train MAE: 0.022393 | val MAE: 0.030883 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 245
# Epoch 245 | train MAE: 0.028273 | val MAE: 0.030635 | time: 1.57s
# Epoch 246 | train MAE: 0.022501 | val MAE: 0.029069 | time: 1.57s
# Epoch 247 | train MAE: 0.025330 | val MAE: 0.030049 | time: 1.58s
# Epoch 248 | train MAE: 0.029076 | val MAE: 0.029216 | time: 1.60s
# Epoch 249 | train MAE: 0.024416 | val MAE: 0.029984 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 250
# Epoch 250 | train MAE: 0.028139 | val MAE: 0.032254 | time: 1.57s
# Epoch 251 | train MAE: 0.022324 | val MAE: 0.029574 | time: 1.60s
# Epoch 252 | train MAE: 0.027853 | val MAE: 0.029819 | time: 1.60s
# Epoch 253 | train MAE: 0.028495 | val MAE: 0.030095 | time: 1.62s
# Epoch 254 | train MAE: 0.025793 | val MAE: 0.029656 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 255
# Epoch 255 | train MAE: 0.029633 | val MAE: 0.032337 | time: 1.57s
# Epoch 256 | train MAE: 0.025000 | val MAE: 0.032615 | time: 1.61s
# Epoch 257 | train MAE: 0.023714 | val MAE: 0.028218 | time: 1.58s
# Epoch 258 | train MAE: 0.027788 | val MAE: 0.029373 | time: 1.60s
# Epoch 259 | train MAE: 0.026963 | val MAE: 0.034321 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 260
# Epoch 260 | train MAE: 0.023131 | val MAE: 0.029570 | time: 1.60s
# Epoch 261 | train MAE: 0.024410 | val MAE: 0.030233 | time: 1.58s
# Epoch 262 | train MAE: 0.025532 | val MAE: 0.028632 | time: 1.68s
# Epoch 263 | train MAE: 0.028493 | val MAE: 0.030862 | time: 1.61s
# Epoch 264 | train MAE: 0.023854 | val MAE: 0.030904 | time: 1.65s
# 😴 Cooling GPU: sleeping 5s after epoch 265
# Epoch 265 | train MAE: 0.028316 | val MAE: 0.032003 | time: 1.61s
# Epoch 266 | train MAE: 0.027505 | val MAE: 0.032900 | time: 1.61s
# Epoch 267 | train MAE: 0.023520 | val MAE: 0.030071 | time: 1.57s
# Epoch 268 | train MAE: 0.024293 | val MAE: 0.029812 | time: 1.64s
# Epoch 269 | train MAE: 0.024611 | val MAE: 0.031031 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 270
# Epoch 270 | train MAE: 0.025563 | val MAE: 0.031052 | time: 1.59s
# Epoch 271 | train MAE: 0.021567 | val MAE: 0.029299 | time: 1.60s
# Epoch 272 | train MAE: 0.024491 | val MAE: 0.032297 | time: 1.65s
# Epoch 273 | train MAE: 0.025807 | val MAE: 0.029721 | time: 1.61s
# Epoch 274 | train MAE: 0.027098 | val MAE: 0.030923 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 275
# Epoch 275 | train MAE: 0.032842 | val MAE: 0.031255 | time: 1.63s
# Epoch 276 | train MAE: 0.027073 | val MAE: 0.027143 | time: 1.62s
# Epoch 277 | train MAE: 0.028550 | val MAE: 0.029195 | time: 1.59s
# Epoch 278 | train MAE: 0.030866 | val MAE: 0.030979 | time: 1.64s
# Epoch 279 | train MAE: 0.025670 | val MAE: 0.031534 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 280
# Epoch 280 | train MAE: 0.028174 | val MAE: 0.033551 | time: 1.66s
# Epoch 281 | train MAE: 0.024217 | val MAE: 0.027203 | time: 1.59s
# Epoch 282 | train MAE: 0.021051 | val MAE: 0.028198 | time: 1.63s
# Epoch 283 | train MAE: 0.024632 | val MAE: 0.031442 | time: 1.60s
# Epoch 284 | train MAE: 0.022165 | val MAE: 0.027999 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 285
# Epoch 285 | train MAE: 0.022585 | val MAE: 0.029664 | time: 1.57s
# Epoch 286 | train MAE: 0.023845 | val MAE: 0.029427 | time: 1.62s
# Epoch 287 | train MAE: 0.023125 | val MAE: 0.028300 | time: 1.58s
# Epoch 288 | train MAE: 0.034387 | val MAE: 0.032236 | time: 1.62s
# Epoch 289 | train MAE: 0.022294 | val MAE: 0.028806 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 290
# Epoch 290 | train MAE: 0.026019 | val MAE: 0.030958 | time: 1.62s
# Epoch 291 | train MAE: 0.023422 | val MAE: 0.028904 | time: 1.58s
# Epoch 292 | train MAE: 0.027408 | val MAE: 0.029807 | time: 1.60s
# Epoch 293 | train MAE: 0.023847 | val MAE: 0.029227 | time: 1.62s
# Epoch 294 | train MAE: 0.025896 | val MAE: 0.031730 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 295
# Epoch 295 | train MAE: 0.025334 | val MAE: 0.033226 | time: 1.55s
# Epoch 296 | train MAE: 0.029869 | val MAE: 0.030052 | time: 1.62s
# Epoch 297 | train MAE: 0.023573 | val MAE: 0.028911 | time: 1.66s
# Epoch 298 | train MAE: 0.023707 | val MAE: 0.028225 | time: 1.58s
# Epoch 299 | train MAE: 0.023320 | val MAE: 0.026940 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 300
# Epoch 300 | train MAE: 0.022658 | val MAE: 0.028854 | time: 1.67s
# Epoch 301 | train MAE: 0.023674 | val MAE: 0.027805 | time: 1.62s
# Epoch 302 | train MAE: 0.023122 | val MAE: 0.027030 | time: 1.63s
# Epoch 303 | train MAE: 0.035979 | val MAE: 0.031018 | time: 1.58s
# Epoch 304 | train MAE: 0.025101 | val MAE: 0.030398 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 305
# Epoch 305 | train MAE: 0.021450 | val MAE: 0.026777 | time: 1.62s
# Epoch 306 | train MAE: 0.021448 | val MAE: 0.027567 | time: 1.64s
# Epoch 307 | train MAE: 0.023624 | val MAE: 0.028225 | time: 1.58s
# Epoch 308 | train MAE: 0.025867 | val MAE: 0.034603 | time: 1.60s
# Epoch 309 | train MAE: 0.027770 | val MAE: 0.028018 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 310
# Epoch 310 | train MAE: 0.025967 | val MAE: 0.031047 | time: 1.59s
# Epoch 311 | train MAE: 0.023930 | val MAE: 0.027133 | time: 1.59s
# Epoch 312 | train MAE: 0.025049 | val MAE: 0.030552 | time: 1.59s
# Epoch 313 | train MAE: 0.031116 | val MAE: 0.032730 | time: 1.62s
# Epoch 314 | train MAE: 0.022601 | val MAE: 0.029181 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 315
# Epoch 315 | train MAE: 0.026357 | val MAE: 0.029150 | time: 1.63s
# Epoch 316 | train MAE: 0.025267 | val MAE: 0.028057 | time: 1.59s
# Epoch 317 | train MAE: 0.023984 | val MAE: 0.029861 | time: 1.66s
# Epoch 318 | train MAE: 0.023730 | val MAE: 0.026966 | time: 1.59s
# Epoch 319 | train MAE: 0.028062 | val MAE: 0.029835 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 320
# Epoch 320 | train MAE: 0.021415 | val MAE: 0.024969 | time: 1.57s
# Epoch 321 | train MAE: 0.025967 | val MAE: 0.029710 | time: 1.63s
# Epoch 322 | train MAE: 0.027737 | val MAE: 0.027778 | time: 1.66s
# Epoch 323 | train MAE: 0.027000 | val MAE: 0.029236 | time: 1.61s
# Epoch 324 | train MAE: 0.027889 | val MAE: 0.028584 | time: 1.67s
# 😴 Cooling GPU: sleeping 5s after epoch 325
# Epoch 325 | train MAE: 0.027544 | val MAE: 0.029126 | time: 1.59s
# Epoch 326 | train MAE: 0.023504 | val MAE: 0.027068 | time: 1.60s
# Epoch 327 | train MAE: 0.027702 | val MAE: 0.027827 | time: 1.57s
# Epoch 328 | train MAE: 0.024644 | val MAE: 0.026382 | time: 1.64s
# Epoch 329 | train MAE: 0.026327 | val MAE: 0.032062 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 330
# Epoch 330 | train MAE: 0.029916 | val MAE: 0.034219 | time: 1.63s
# Epoch 331 | train MAE: 0.022190 | val MAE: 0.029517 | time: 1.60s
# Epoch 332 | train MAE: 0.022234 | val MAE: 0.027512 | time: 1.63s
# Epoch 333 | train MAE: 0.028995 | val MAE: 0.030099 | time: 1.60s
# Epoch 334 | train MAE: 0.024342 | val MAE: 0.029079 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 335
# Epoch 335 | train MAE: 0.034665 | val MAE: 0.031016 | time: 1.63s
# Epoch 336 | train MAE: 0.023729 | val MAE: 0.028891 | time: 1.59s
# Epoch 337 | train MAE: 0.025124 | val MAE: 0.028658 | time: 1.60s
# Epoch 338 | train MAE: 0.024923 | val MAE: 0.030045 | time: 1.58s
# Epoch 339 | train MAE: 0.024884 | val MAE: 0.030185 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 340
# Epoch 340 | train MAE: 0.028141 | val MAE: 0.029195 | time: 1.64s
# Epoch 341 | train MAE: 0.024117 | val MAE: 0.027884 | time: 1.64s
# Epoch 342 | train MAE: 0.034516 | val MAE: 0.034702 | time: 1.59s
# Epoch 343 | train MAE: 0.027800 | val MAE: 0.027725 | time: 1.57s
# Epoch 344 | train MAE: 0.024546 | val MAE: 0.029239 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 345
# Epoch 345 | train MAE: 0.021941 | val MAE: 0.028229 | time: 1.62s
# Epoch 346 | train MAE: 0.026882 | val MAE: 0.028995 | time: 1.66s
# Epoch 347 | train MAE: 0.018868 | val MAE: 0.026353 | time: 1.61s
# Epoch 348 | train MAE: 0.026592 | val MAE: 0.028856 | time: 1.57s
# Epoch 349 | train MAE: 0.024235 | val MAE: 0.030076 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 350
# Epoch 350 | train MAE: 0.021150 | val MAE: 0.026948 | time: 1.59s
# Epoch 351 | train MAE: 0.026416 | val MAE: 0.027359 | time: 1.56s
# Epoch 352 | train MAE: 0.023865 | val MAE: 0.026624 | time: 1.55s
# Epoch 353 | train MAE: 0.024474 | val MAE: 0.027203 | time: 1.58s
# Epoch 354 | train MAE: 0.024447 | val MAE: 0.027672 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 355
# Epoch 355 | train MAE: 0.026458 | val MAE: 0.028133 | time: 1.59s
# Epoch 356 | train MAE: 0.024945 | val MAE: 0.027999 | time: 1.55s
# Epoch 357 | train MAE: 0.023720 | val MAE: 0.027012 | time: 1.60s
# Epoch 358 | train MAE: 0.020187 | val MAE: 0.027457 | time: 1.64s
# Epoch 359 | train MAE: 0.023668 | val MAE: 0.027101 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 360
# Epoch 360 | train MAE: 0.022952 | val MAE: 0.028958 | time: 1.59s
# Epoch 361 | train MAE: 0.025409 | val MAE: 0.028539 | time: 1.59s
# Epoch 362 | train MAE: 0.020395 | val MAE: 0.026513 | time: 1.63s
# Epoch 363 | train MAE: 0.023224 | val MAE: 0.027447 | time: 1.58s
# Epoch 364 | train MAE: 0.023597 | val MAE: 0.028053 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 365
# Epoch 365 | train MAE: 0.020751 | val MAE: 0.029481 | time: 1.59s
# Epoch 366 | train MAE: 0.022573 | val MAE: 0.028884 | time: 1.62s
# Epoch 367 | train MAE: 0.022595 | val MAE: 0.026510 | time: 1.69s
# Epoch 368 | train MAE: 0.027495 | val MAE: 0.027891 | time: 1.60s
# Epoch 369 | train MAE: 0.020762 | val MAE: 0.028786 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 370
# Epoch 370 | train MAE: 0.023021 | val MAE: 0.027140 | time: 1.61s
# Epoch 371 | train MAE: 0.030946 | val MAE: 0.029443 | time: 1.57s
# Epoch 372 | train MAE: 0.023888 | val MAE: 0.027241 | time: 1.60s
# Epoch 373 | train MAE: 0.026895 | val MAE: 0.029216 | time: 1.61s
# Epoch 374 | train MAE: 0.020650 | val MAE: 0.026588 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 375
# Epoch 375 | train MAE: 0.025388 | val MAE: 0.026340 | time: 1.62s
# Epoch 376 | train MAE: 0.025696 | val MAE: 0.027547 | time: 1.58s
# Epoch 377 | train MAE: 0.023186 | val MAE: 0.029324 | time: 1.59s
# Epoch 378 | train MAE: 0.020098 | val MAE: 0.027595 | time: 1.58s
# Epoch 379 | train MAE: 0.023840 | val MAE: 0.028790 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 380
# Epoch 380 | train MAE: 0.023922 | val MAE: 0.027383 | time: 1.62s
# Epoch 381 | train MAE: 0.022242 | val MAE: 0.026431 | time: 1.61s
# Epoch 382 | train MAE: 0.024613 | val MAE: 0.028436 | time: 1.61s
# Epoch 383 | train MAE: 0.024982 | val MAE: 0.031570 | time: 1.61s
# Epoch 384 | train MAE: 0.025771 | val MAE: 0.031088 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 385
# Epoch 385 | train MAE: 0.023408 | val MAE: 0.028200 | time: 1.58s
# Epoch 386 | train MAE: 0.021745 | val MAE: 0.027187 | time: 1.62s
# Epoch 387 | train MAE: 0.022880 | val MAE: 0.027255 | time: 1.59s
# Epoch 388 | train MAE: 0.021465 | val MAE: 0.028815 | time: 1.62s
# Epoch 389 | train MAE: 0.024562 | val MAE: 0.026792 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 390
# Epoch 390 | train MAE: 0.026895 | val MAE: 0.028091 | time: 1.62s
# Epoch 391 | train MAE: 0.022361 | val MAE: 0.026110 | time: 1.63s
# Epoch 392 | train MAE: 0.026846 | val MAE: 0.028767 | time: 1.64s
# Epoch 393 | train MAE: 0.026735 | val MAE: 0.031134 | time: 1.62s
# Epoch 394 | train MAE: 0.022935 | val MAE: 0.027321 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 395
# Epoch 395 | train MAE: 0.023826 | val MAE: 0.026423 | time: 1.61s
# Epoch 396 | train MAE: 0.023797 | val MAE: 0.027490 | time: 1.61s
# Epoch 397 | train MAE: 0.023831 | val MAE: 0.026504 | time: 1.57s
# Epoch 398 | train MAE: 0.023403 | val MAE: 0.027135 | time: 1.63s
# Epoch 399 | train MAE: 0.025474 | val MAE: 0.027432 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 400
# `Trainer.fit` stopped: `max_epochs=400` reached.
# CPU times: user 10min 26s, sys: 3min 27s, total: 13min 53s
# Wall time: 17min 23s

# %% [markdown]
# #### Save the training history

# %%
CHECKPOINT_PATH
# Out:
# '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take3'

# %%
train_loss = np.array(plot_cb.train_losses, dtype=np.float32)
val_loss   = np.array(plot_cb.val_losses,   dtype=np.float32)
epochs = np.arange(1, len(train_loss) + 1, dtype=np.int32)

# %%
df = pd.DataFrame({
    "epoch": epochs,
    "train_loss": train_loss,
    "val_loss": val_loss,
})

df.to_csv(f"{CHECKPOINT_PATH}/training_history.csv", index=False)

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# best-320-0.024969.ckpt  last.ckpt  training_history.csv

# %%
plt.plot(epochs, train_loss, label="train")
plt.plot(epochs, val_loss, label="val")
plt.xlabel("epoch")
plt.ylabel("MAE")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluation

# %%
test_ds = NumpyDataset(X_test_scaled, y_test)
test_loader   = DataLoader(test_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
x0, y0 = test_ds[0]
print(x0.shape)   # torch.Size([5, 64, 64])
print(y0.shape)   # torch.Size([6])
# Out:
# torch.Size([5, 64, 64])
# torch.Size([6])

# %%
def get_test_predictions(model, test_loader, device):
    model.eval()

    y_true_list = []
    y_pred_list = []

    with torch.no_grad():
        for xb, yb in test_loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)

            y_hat = model(xb)          # (B, 6)

            y_true_list.append(yb.cpu().numpy())
            y_pred_list.append(y_hat.cpu().numpy())

    y_true = np.concatenate(y_true_list, axis=0)  # (N_test, 6)
    y_pred = np.concatenate(y_pred_list, axis=0)  # (N_test, 6)

    return y_true, y_pred

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# best-320-0.024969.ckpt  last.ckpt  training_history.csv

# %%
best_ckpt = f"{CHECKPOINT_PATH}/best-320-0.024969.ckpt"
lit_model = LitCNN.load_from_checkpoint(
    best_ckpt,
    model=CNNModelKerasEquivalent(),  # 🔴 구조 동일해야 함
)

# %%
# %%time
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
y_test_true, y_test_pred = get_test_predictions(lit_model, test_loader, device)
# Out:
# CPU times: user 133 ms, sys: 172 ms, total: 305 ms
# Wall time: 271 ms

# %%
print(y_test_true.shape)  # (N_test, 6)
print(y_test_pred.shape)  # (N_test, 6)
# Out:
# (4000, 6)
# (4000, 6)

# %%
mae = np.mean(np.abs(y_test_pred - y_test_true), axis=0)
print("Test MAE per y:", mae)
print("Test MAE mean :", mae.mean())
# Out:
# Test MAE per y: [0.04032586 0.02925004 0.01674092 0.0187906  0.0209624  0.02385408]
# Test MAE mean : 0.02498732

# %%
import matplotlib as mpl
import seaborn as sns

sns.reset_defaults()                 # seaborn 스타일 제거
mpl.rcParams.update(mpl.rcParamsDefault)  # matplotlib 완전 초기화

# %%
import matplotlib as mpl

mpl.rcParams.update({
    "font.family": "serif",
    "font.size": 14,        # 기본 폰트
    "axes.titlesize": 16,   # subplot title
    "axes.labelsize": 14,   # x,y label
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12,
})

# %%
def plot_error_histograms(err, bins=50):
    """
    err shape: (N, 6)
    """
    fig, axes = plt.subplots(2, 3, figsize=(10, 6))
    axes = axes.ravel()

    # symmetric range for fair comparison
    vmin = err.min()
    vmax = err.max()
    vmax = max(abs(vmin), abs(vmax))
    hist_range = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        ax.hist(
            err[:, i],
            bins=bins,
            range=hist_range,
            alpha=0.8
        )

        ax.axvline(0, color="k", linestyle="--", linewidth=1)
        ax.set_title(f"y{i} error")
        ax.set_xlabel("prediction - truth")
        ax.set_ylabel("count")

    fig.suptitle("Test error distribution (y_pred - y_true)", fontsize=12)
    fig.tight_layout()
    plt.show()

# %%
err = y_test_pred - y_test_true
print(err.shape)
# Out:
# (4000, 6)

# %%
plot_error_histograms(err,bins=200)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(
    style="whitegrid",     # 🔹 whitegrid → white
    context="talk",
    font="serif"
)

# %%
import numpy as np

def plot_error_histograms_seaborn(err, bins=40):
    """
    err shape: (N_test, 6)
    """
    fig, axes = plt.subplots(3, 2, figsize=(15, 12))
    axes = axes.ravel()

    # symmetric x-range
    vmin = err.min()
    vmax = err.max()
    vmax = max(abs(vmin), abs(vmax))
    xlim = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        sns.histplot(
            err[:, i],
            bins=bins,
            stat="count",     # 🔹 COUNT, not density
            kde=False,        # 🔹 no curve
            color="tab:blue",
            alpha=0.8,
            ax=ax
        )

        # zero reference
        ax.axvline(0, color="black", linestyle="--", linewidth=1.5)

        # metrics
        mae  = np.mean(np.abs(err[:, i]))
        rmse = np.sqrt(np.mean(err[:, i] ** 2))

        ax.text(
            0.03, 0.97,
            f"MAE  = {mae:.4f}\nRMSE = {rmse:.4f}",
            transform=ax.transAxes,
            va="top",
            ha="left",
            fontsize=14,
            bbox=dict(boxstyle="round", fc="white", alpha=0.9)
        )

        ax.set_xlim(xlim)
        ax.set_title(f"y{i} error", fontsize=16)
        ax.set_xlabel("prediction − truth", fontsize=14)
        ax.set_ylabel("count", fontsize=14)

    fig.suptitle(
        "Test error distribution (histogram, count)",
        fontsize=20,
        y=0.98
    )

    fig.tight_layout()
    plt.show()

# %%
plot_error_histograms_seaborn(err,bins=200)
