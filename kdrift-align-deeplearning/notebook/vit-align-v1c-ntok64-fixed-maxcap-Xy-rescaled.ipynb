# %% [markdown]
# # Vision Transformers for KDRIFT G1 Alignment
#
# - `decenter+-0.095mm,tilt+-0.075deg`
# - EDA the training set
# - Train using vision transformer
# - `MAX_CAP = 50` Normalization
# - 64x64 image, 8x8 patch size, 64 tokens (8x8 grids)
#
#
# - Different Learning Rates: `lr=3e-4`
# ```python
#     def configure_optimizers(self):
#         return torch.optim.AdamW(self.parameters(),lr=self.lr, \
#                                  weight_decay=2e-4)
# ```

# %%
import os
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from tqdm import trange, notebook

import matplotlib.pyplot as plt

# %%
import matplotlib
import seaborn as sns

sns.reset_defaults()                 # seaborn 스타일 제거
matplotlib.rcParams.update(matplotlib.rcParamsDefault)  # matplotlib 완전 초기화

# Basic Settings for matplotlib
matplotlib.rcParams["font.family"] = "serif"
matplotlib.rcParams["mathtext.fontset"] = "stix"
#%matplotlib inline
#matplotlib_inline.backend_inline.set_matplotlib_formats("svg", "pdf")  # For export
matplotlib.rcParams["lines.linewidth"] = 2.0

# %% [markdown]
# ## Browsing the working directories

# %%
# %pwd
# Out:
# '/app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/notebook'

# %%
# %ls
# Out:
# cnn-align-v7-fixed-maxcap-Xy-rescaled.ipynb
# cnn_maxcap50_positive_only_norm.png
# cnn_maxcap50_positive_only_norm_y_rescaled.png
# hybrid-align-v3a-tahn-stemch64-ntok64-fixed-maxcap-Xy-rescaled.ipynb
# lightning_logs/
# no-y-rescaled/
# vit-align-v1c-ntok64-fixed-maxcap-Xy-rescaled.ipynb

# %%
data_path = '/app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/data/'

# %%
# !ls {data_path}
# Out:
# X_f32.npy  y_f32.npy

# %% [markdown]
# ## Explore the training set

# %%
# %%time
X = np.load(data_path+'X_f32.npy')
y = np.load(data_path+'y_f32.npy')
# Out:
# CPU times: user 0 ns, sys: 3.11 s, total: 3.11 s
# Wall time: 3.14 s

# %%
len(y),len(X)
# Out:
# (20000, 20000)

# %%
def np_array_info(a):
    print(f"shape     : {a.shape}")
    print(f"dtype     : {a.dtype}")
    print(f"ndim      : {a.ndim}")
    print(f"size      : {a.size}")
    print(f"itemsize  : {a.itemsize} bytes")
    print(f"nbytes    : {a.nbytes / 1024**2:.2f} MB")
    print(f"min / max : {a.min()} / {a.max()}")

# %%
np_array_info(X)
# Out:
# shape     : (20000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 409600000
# itemsize  : 4 bytes
# nbytes    : 1562.50 MB
# min / max : -5.8238911628723145 / 5.863417148590088

# %%
np_array_info(y)
# Out:
# shape     : (20000, 6)
# dtype     : float32
# ndim      : 2
# size      : 120000
# itemsize  : 4 bytes
# nbytes    : 0.46 MB
# min / max : -0.0949999988079071 / 0.09499000012874603

# %%
for i in range(y.shape[1]):
    print(f"channel {i}: min={y[:, i].min()}, max={y[:, i].max()}")
# Out:
# channel 0: min=-0.0949999988079071, max=0.09499000012874603
# channel 1: min=-0.0949999988079071, max=0.09498000144958496
# channel 2: min=-0.0949999988079071, max=0.09499000012874603
# channel 3: min=-0.07500000298023224, max=0.07498999685049057
# channel 4: min=-0.07500000298023224, max=0.07500000298023224
# channel 5: min=-0.07498999685049057, max=0.07498999685049057

# %% [markdown]
# #### Visualize the training set

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_trainingsample(
    X,
    y,
    selected_index_list,
    pix_min=-50.0,
    pix_max=50.0,
):
    n_samples = len(selected_index_list)
    n_views = X.shape[1]

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2)
    )

    im = None

    for row, idx in enumerate(selected_index_list):
        for j in range(n_views):
            ax = axes[row, j]
            img = X[idx, j, :, :, 0]

            im = ax.imshow(
                img,
                cmap="rainbow",
                vmin=pix_min,
                vmax=pix_max,
                aspect="equal"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            if row == 0:
                ax.set_title(f"image {j}")

            # --- min / max labels (always show actual image stats)
            img_min = img.min()
            img_max = img.max()

            labels = [
                f"min: {img_min:.2f}",
                f"max: {img_max:.2f}",
            ]

            # --- include y only on first column
            if y is not None and j == 0:
                yvals = y[idx]
                labels += [
                    f"y{i}: {val:.3f}" for i, val in enumerate(yvals)
                ]
                ax.set_ylabel(f"idx {idx}")

            handles = [
                plt.Line2D([0], [0], color="none", label=lab)
                for lab in labels
            ]

            ax.legend(
                handles=handles,
                loc="upper left" if j == 0 else "upper right",
                fontsize=8,
                frameon=True,
                borderpad=0.3,
                handlelength=0,
                handletextpad=0
            )

    fig.subplots_adjust(
        bottom=0.12,
        hspace=0.05,
        wspace=0.02
    )

    fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02,
        label=f"Pixel value (clipped to [{pix_min}, {pix_max}])"
    )

    plt.show()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import torchvision
import pytorch_lightning as pl
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from torchvision import transforms
from torchvision.datasets import CIFAR10

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce RTX 3090 (UUID: GPU-81ef84f4-69df-ce9c-b89c-0b05c8f72ebf)

# %%
# Setting the seed
pl.seed_everything(42)

# Ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Seed set to 42

# %% [markdown]
# #### Checkpoints

# %%
CHECKPOINT_ROOT = '/app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/checkpoints/'

# %%
from time import gmtime, strftime

base_name = 'vit-ntok64-yscaled'
#try_name = strftime('%Y.%m.%d_%H:%M', gmtime())
try_name = 'take1c'
experiment_name = f"{base_name}_{try_name}"
print("experiment:", experiment_name)
CHECKPOINT_PATH = os.path.join(CHECKPOINT_ROOT, experiment_name)
print("CHECKPOINT_PATH:", CHECKPOINT_PATH)
# Out:
# experiment: vit-ntok64-yscaled_take1c
# CHECKPOINT_PATH: /app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/checkpoints/vit-ntok64-yscaled_take1c

# %%
import os
import shutil

CHECKPOINT_PATH = os.path.join(CHECKPOINT_ROOT, experiment_name)

if os.path.exists(CHECKPOINT_PATH):
    print(f"⚠️ Directory exists: {CHECKPOINT_PATH}")
    print("🧹 Removing all contents...")

    # Clear all files/subfolders inside the directory
    for filename in os.listdir(CHECKPOINT_PATH):
        file_path = os.path.join(CHECKPOINT_PATH, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print(f"❌ Failed to delete {file_path}: {e}")

    print("✅ Directory has been cleared.")
else:
    os.makedirs(CHECKPOINT_PATH)
    print(f"✅ Directory created: {CHECKPOINT_PATH}")

print(f"📂 Experiment directory is ready: {os.path.abspath(CHECKPOINT_PATH)}")
# Out:
# ✅ Directory created: /app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/checkpoints/vit-ntok64-yscaled_take1c
# 📂 Experiment directory is ready: /app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/checkpoints/vit-ntok64-yscaled_take1c

# %% [markdown]
# ### Training Sample

# %%
num_samples = len(y)
print(num_samples)
# Out:
# 20000

# %%
indices=range(num_samples)

# %%
X_tr, X_test, y_tr, y_test, tr_indices, test_indices = \
train_test_split(X, y, indices, test_size=0.2, random_state=42)

# %%
# %%time
X_train, X_val, \
y_train, y_val, \
train_indices, val_indices = \
    train_test_split(
        X_tr,
        y_tr,
        tr_indices,
        test_size=0.2,
        random_state=42
    )
# Out:
# CPU times: user 40 ms, sys: 2.41 s, total: 2.45 s
# Wall time: 2.47 s

# %% [markdown]
# ### Input Image Normalization by `MAX_CAP=50`

# %%
MAX_CAP = 6.0

# %%
YL_CAP = 0.095
YH_CAP = 0.075

# %%
# %%time
# symmetric rescaling per image
X_train_scaled = X_train / MAX_CAP
X_val_scaled = X_val / MAX_CAP
X_test_scaled = X_test / MAX_CAP
# Out:
# CPU times: user 63 ms, sys: 3.64 s, total: 3.71 s
# Wall time: 3.74 s

# %%
np_array_info(X_train_scaled)
# Out:
# shape     : (12800, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 262144000
# itemsize  : 4 bytes
# nbytes    : 1000.00 MB
# min / max : -0.9706485271453857 / 0.9772362112998962

# %%
np_array_info(X_val_scaled)
# Out:
# shape     : (3200, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 65536000
# itemsize  : 4 bytes
# nbytes    : 250.00 MB
# min / max : -0.919867992401123 / 0.9647147059440613

# %%
np_array_info(X_test_scaled)
# Out:
# shape     : (4000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 81920000
# itemsize  : 4 bytes
# nbytes    : 312.50 MB
# min / max : -0.940781831741333 / 0.9549728035926819

# %%
y_train_scaled = np.zeros_like(y_train)
y_val_scaled = np.zeros_like(y_val)
y_test_scaled = np.zeros_like(y_test)

# 채널 0~2
for i in range(3):
    y_train_scaled[:, i] = y_train[:, i]/YL_CAP
    y_val_scaled[:, i] = y_val[:, i]/YL_CAP
    y_test_scaled[:, i] = y_test[:, i]/YL_CAP

# 채널 3~5
for i in range(3, 6):
    y_train_scaled[:, i] = y_train[:, i]/YH_CAP
    y_val_scaled[:, i] = y_val[:, i]/YH_CAP
    y_test_scaled[:, i] = y_test[:, i]/YH_CAP

# %%
for i in range(y_train_scaled.shape[1]):
    print(f"channel {i}: min={y_train_scaled[:, i].min()}, \
    max={y_train_scaled[:, i].max()}")
# Out:
# channel 0: min=-1.0,     max=0.9998947381973267
# channel 1: min=-0.9996842741966248,     max=0.9996842741966248
# channel 2: min=-1.0,     max=0.9998947381973267
# channel 3: min=-1.0,     max=0.9998666048049927
# channel 4: min=-0.9995999336242676,     max=1.0
# channel 5: min=-0.9998666048049927,     max=0.9998666048049927

# %%
for i in range(y_val_scaled.shape[1]):
    print(f"channel {i}: min={y_val_scaled[:, i].min()}, \
    max={y_val_scaled[:, i].max()}")
# Out:
# channel 0: min=-0.9996842741966248,     max=0.9981052875518799
# channel 1: min=-0.9997894763946533,     max=0.9997894763946533
# channel 2: min=-0.9988421201705933,     max=0.9996842741966248
# channel 3: min=-0.9998666048049927,     max=0.9990665912628174
# channel 4: min=-1.0,     max=0.9997332692146301
# channel 5: min=-0.9997332692146301,     max=0.9982665777206421

# %%
for i in range(y_test_scaled.shape[1]):
    print(f"channel {i}: min={y_test_scaled[:, i].min()}, \
    max={y_test_scaled[:, i].max()}")
# Out:
# channel 0: min=-0.9995789527893066,     max=0.9996842741966248
# channel 1: min=-1.0,     max=0.9996842741966248
# channel 2: min=-0.9996842741966248,     max=0.9998947381973267
# channel 3: min=-0.9997332692146301,     max=0.9995999336242676
# channel 4: min=-0.9994666576385498,     max=0.9997332692146301
# channel 5: min=-0.9998666048049927,     max=0.9998666048049927

# %% [markdown]
# ### DataLoader

# %%
from torch.utils.data import Dataset, DataLoader

class NumpyDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        x = torch.from_numpy(self.X[idx]).float()  # (5,64,64)
        x = x.squeeze(-1) # if (5,64,64,1)
        t = torch.from_numpy(self.y[idx]).float()  # (6,)
        return x, t

# %%
train_ds = NumpyDataset(X_train_scaled, y_train_scaled)
val_ds   = NumpyDataset(X_val_scaled, y_val_scaled)
test_ds  = NumpyDataset(X_test_scaled, y_test_scaled)

# %%
train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
test_loader   = DataLoader(test_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %% [markdown]
# ## Train vision transformer model
#
# - ViT for 5 channels images

# %% [markdown]
# #### Hyperparameters

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow",
                                   linewidth=0.5, vmin=None, vmax=None):
    """
    xb: torch.Tensor, shape (B, 5, 64, 64)
    n_samples: number of rows (samples)
    ngrid: number of grid cells per axis (e.g., 16 => patch size 4 for 64x64)
    """
    # tensor -> numpy
    x = xb[:n_samples].detach().cpu().numpy()  # (n_samples, 5, 64, 64)
    n_samples = x.shape[0]
    n_views = x.shape[1]
    H, W = x.shape[2], x.shape[3]

    assert H % ngrid == 0 and W % ngrid == 0, f"H,W must be divisible by ngrid. got {H},{W}, ngrid={ngrid}"
    patch_h = H // ngrid
    patch_w = W // ngrid

    # global color scale (consistent across all panels)
    if vmin is None:
        vmin = float(x.min())
    if vmax is None:
        vmax = float(x.max())

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2),
        constrained_layout=False
    )

    # in case n_samples == 1
    if n_samples == 1:
        axes = np.expand_dims(axes, axis=0)

    im = None
    for i in range(n_samples):
        for j in range(n_views):
            ax = axes[i, j]
            img = x[i, j]  # (64,64)

            im = ax.imshow(
                img,
                cmap=cmap,
                vmin=vmin,
                vmax=vmax,
                aspect="equal",
                interpolation="nearest"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            # column titles
            if i == 0:
                ax.set_title(f"ch {j}", fontsize=11)

            # row labels
            if j == 0:
                ax.set_ylabel(f"sample {i}", fontsize=11)

            # draw patch grid boundaries
            for gy in range(0, H + 1, patch_h):
                ax.axhline(gy - 0.5, color="w", linewidth=linewidth, alpha=0.9)
            for gx in range(0, W + 1, patch_w):
                ax.axvline(gx - 0.5, color="w", linewidth=linewidth, alpha=0.9)

    # tighter spacing + bottom colorbar
    fig.subplots_adjust(bottom=0.08, hspace=0.02, wspace=0.02)

    cbar = fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02
    )
    cbar.set_label("pixel value")

    plt.show()

# %% [markdown]
# # Vision Transformer Regressor

# %%
class AttentionBlock(nn.Module):
    def __init__(self, embed_dim, hidden_dim, num_heads, dropout=0.0):
        super().__init__()
        self.layer_norm_1 = nn.LayerNorm(embed_dim)
        self.attn = nn.MultiheadAttention(embed_dim, num_heads, batch_first=False)
        self.layer_norm_2 = nn.LayerNorm(embed_dim)
        self.linear = nn.Sequential(
            nn.Linear(embed_dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, embed_dim),
            nn.Dropout(dropout),
        )
        self.last_attn_weights = None  # 🆕 store attention weights here

    def forward(self, x):
        inp_x = self.layer_norm_1(x)
        #attn_out, attn_weights = self.attn(inp_x, inp_x, inp_x, need_weights=True)
        attn_out, attn_weights = self.attn(inp_x, inp_x, inp_x,need_weights=True, \
                                           average_attn_weights=False)  # 🧠 retain all heads!        
        self.last_attn_weights = attn_weights  # 🆕 save for inspection

        x = x + attn_out
        x = x + self.linear(self.layer_norm_2(x))
        return x

# %%
import torch
import torch.nn as nn

class VisionTransformerRegressor(nn.Module):
    """
    ViT-style regressor adapted from your galaxy-classification ViT.

    Input:
      x: (B, 5, 64, 64)  or (B, 5, 64, 64, 1) -> we squeeze last dim
    Output:
      y_hat: (B, 6)
    """
    def __init__(
        self,
        embed_dim: int = 256,
        hidden_dim: int = 512,
        num_channels: int = 5,     # <- 5 channels for our problem
        num_heads: int = 8,
        num_layers: int = 6,       # 4, 6, 
        num_outputs: int = 6,      # <- regression outputs
        patch_size: int = 8,
        img_size: int = 64,
        dropout: float = 0.0,
    ):
        super().__init__()
        assert img_size % patch_size == 0, "img_size must be divisible by patch_size"

        self.patch_size = patch_size
        self.img_size = img_size

        num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.num_patches = num_patches

        # Patch -> embedding (same idea as your code: flatten patch then Linear)
        self.input_layer = nn.Linear(num_channels * (patch_size ** 2), embed_dim)

        # Transformer blocks (same style)
        self.transformer = nn.Sequential(
            *(AttentionBlock(embed_dim, hidden_dim, num_heads, dropout=dropout) for _ in range(num_layers))
        )

        # CLS token + positional encoding
        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embedding = nn.Parameter(torch.zeros(1, 1 + num_patches, embed_dim))
        self.dropout = nn.Dropout(dropout)

        # Regression head (LayerNorm + Linear -> num_outputs)
        self.mlp_head = nn.Sequential(
            nn.LayerNorm(embed_dim),
            nn.Linear(embed_dim, num_outputs)
        )

        self._init_weights()

    def _init_weights(self):
        # Simple, stable init
        nn.init.trunc_normal_(self.pos_embedding, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)
        nn.init.xavier_uniform_(self.input_layer.weight)
        nn.init.zeros_(self.input_layer.bias)
        for m in self.mlp_head.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)

    def _patchify(self, x: torch.Tensor) -> torch.Tensor:
        """
        x: (B, C, H, W) -> patches: (B, num_patches, C*patch_size*patch_size)
        """
        B, C, H, W = x.shape
        P = self.patch_size
        # (B, C, H/P, P, W/P, P)
        x = x.reshape(B, C, H // P, P, W // P, P)
        # (B, H/P, W/P, C, P, P)
        x = x.permute(0, 2, 4, 1, 3, 5)
        # (B, num_patches, C*P*P)
        x = x.reshape(B, (H // P) * (W // P), C * P * P)
        return x

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # Accept (B, 5, 64, 64, 1) too
        if x.ndim == 5 and x.shape[-1] == 1:
            x = x.squeeze(-1)

        # Patchify -> embed
        x = self._patchify(x)                 # (B, T, patch_dim)
        x = self.input_layer(x)               # (B, T, embed_dim)

        # Add CLS token + pos encoding
        B, T, E = x.shape
        cls = self.cls_token.repeat(B, 1, 1)  # (B, 1, E)
        x = torch.cat([cls, x], dim=1)        # (B, 1+T, E)
        x = x + self.pos_embedding[:, : (T + 1)]
        x = self.dropout(x)

        # Transformer expects (T, B, E) because your AttentionBlock uses batch_first=False
        x = x.transpose(0, 1)                 # (1+T, B, E)
        x = self.transformer(x)               # (1+T, B, E)

        # CLS token -> regression output
        cls_out = x[0]                        # (B, E)
        y_hat = self.mlp_head(cls_out)        # (B, 6)
        return y_hat

# %% [markdown]
# #### Callbacks

# %%
import pytorch_lightning as pl
import torch
import torch.nn as nn

class LitViTRegressor(pl.LightningModule):
    def __init__(
        self,
        model: nn.Module,
        lr: float = 1e-3,
    ):
        super().__init__()
        self.model = model
        self.loss_fn = nn.L1Loss()
        self.lr = lr

        self.save_hyperparameters(ignore=["model"])

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.loss_fn(y_hat, y)

        self.log(
            "train_loss",
            loss,
            on_epoch=True,
            prog_bar=False,
            sync_dist=False,
        )
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.loss_fn(y_hat, y)

        self.log(
            "val_loss",
            loss,
            on_epoch=True,
            prog_bar=False,
            sync_dist=False,
        )
        return loss
        
    # optimizer settings .. AdamW vs. Adam..?!?
    #def configure_optimizers(self):
    #    return torch.optim.Adam(self.parameters(), lr=self.lr)
    def configure_optimizers(self):
        return torch.optim.AdamW(self.parameters(),lr=self.lr, \
                                 weight_decay=2e-4)

# %%
from pytorch_lightning.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    dirpath=CHECKPOINT_PATH,
    filename="best-{epoch:03d}-{val_loss:.6f}",
    monitor="val_loss",
    mode="min",
    save_top_k=10,
    save_last=True,
)

# %%
import time
import pytorch_lightning as pl

class LossHistoryAndPrinter(pl.Callback):
    def __init__(self, precision=6, print_every_epoch=True):
        self.precision = precision
        self.print_every_epoch = print_every_epoch

        # history
        self.train_loss_by_epoch = {}
        self.val_loss_by_epoch = {}
        self.epoch_times = {}

        # internal
        self._epoch_start_time = None

        # Lightning 버전/설정에 따라 이름이 달라질 수 있어 후보를 둠
        self._train_keys = ("train_loss", "train_loss_epoch")
        self._val_keys   = ("val_loss", "val_loss_epoch")

    def _get_metric_float(self, metrics, keys):
        for k in keys:
            v = metrics.get(k, None)
            if v is not None:
                try:
                    return float(v)
                except TypeError:
                    # just in case it's a tensor-like object
                    return float(v.item())
        return None

    def on_train_epoch_start(self, trainer, pl_module):
        self._epoch_start_time = time.time()

    def on_validation_epoch_end(self, trainer, pl_module):
        # sanity validation은 제외 (훈련 시작 전에 val만 도는 구간)
        if trainer.sanity_checking:
            return

        m = trainer.callback_metrics
        epoch = trainer.current_epoch

        val_loss = self._get_metric_float(m, self._val_keys)
        if val_loss is not None:
            self.val_loss_by_epoch[epoch] = val_loss

    def on_train_epoch_end(self, trainer, pl_module):
        # epoch time
        if self._epoch_start_time is not None:
            epoch_time = time.time() - self._epoch_start_time
            self.epoch_times[trainer.current_epoch] = epoch_time
        else:
            epoch_time = None

        m = trainer.callback_metrics
        epoch = trainer.current_epoch

        # train loss 저장 (키 후보 2개)
        train_loss = self._get_metric_float(m, self._train_keys)
        if train_loss is not None:
            self.train_loss_by_epoch[epoch] = train_loss

        if not self.print_every_epoch:
            return

        # val loss는 validation 훅에서 저장된 값 우선 사용
        val_loss = self.val_loss_by_epoch.get(epoch, None)

        # 출력 (둘 다 없으면 NA로 표시)
        msg = f"Epoch {epoch:03d} | "
        msg += f"train MAE: {('NA' if train_loss is None else f'{train_loss:.{self.precision}f}')} | "
        msg += f"val MAE: {('NA' if val_loss is None else f'{val_loss:.{self.precision}f}')}"

        if epoch_time is not None:
            msg += f" | time: {epoch_time:.2f}s"

        print(msg)

    def as_lists(self):
        # train/val 둘 다 있는 epoch만 정렬해서 반환 (길이 항상 같음)
        epochs = sorted(set(self.train_loss_by_epoch) & set(self.val_loss_by_epoch))
        train = [self.train_loss_by_epoch[e] for e in epochs]
        val = [self.val_loss_by_epoch[e] for e in epochs]
        times = [self.epoch_times.get(e, None) for e in epochs]
        return epochs, train, val, times

# %%
import time

class GPUSleepCallback(pl.Callback):
    def __init__(self, sleep_sec=10, every_n_epochs=10):
        self.sleep_sec = sleep_sec
        self.every_n_epochs = every_n_epochs

    def on_train_epoch_end(self, trainer, pl_module):
        stop_modulo = self.every_n_epochs - 1
        if trainer.current_epoch % self.every_n_epochs == stop_modulo:
            print(f"😴 Cooling GPU: sleeping {self.sleep_sec}s after epoch {trainer.current_epoch}")
            time.sleep(self.sleep_sec)

# %% [markdown]
# #### Hyper-parameters 64 tokens

# %%
vit_model = VisionTransformerRegressor(
    img_size=64,
    patch_size=8,      # ✅ 64 tokens
    num_channels=5,
    num_outputs=6,
    embed_dim=128,     # ✅ 줄이기
    hidden_dim=256,    # ✅ 줄이기
    num_heads=4,       # ✅ 줄이기
    num_layers=4,      # ✅ 줄이기
    dropout=0.1,
)

lit_model = LitViTRegressor(
    model=vit_model,
    lr=5e-4,
)

# %%
#loss_history_cb = LossHistoryCallback()
#metric_printer_cb = EpochMetricPrinter()
loss_cb = LossHistoryAndPrinter(precision=6)
gpu_sleep_cb = GPUSleepCallback(sleep_sec=10, every_n_epochs=5)

# %%
trainer = pl.Trainer(
    max_epochs=2000,
    accelerator="gpu" if torch.cuda.is_available() else "cpu",

    logger=False,                 # 👈 NO logs saved
    enable_progress_bar=False,    # 👈 no tqdm bar
    log_every_n_steps=1,          # 👈 suppress warning

    callbacks=[
        checkpoint_callback,       # (model weights only)
        loss_cb,
        gpu_sleep_cb,
    ],
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
# %%time
trainer.fit(
    lit_model,
    train_dataloaders=train_loader,
    val_dataloaders=val_loader,
)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type                       | Params | Mode  | FLOPs
# -----------------------------------------------------------------------
# 0 | model   | VisionTransformerRegressor | 580 K  | train | 0
# 1 | loss_fn | L1Loss                     | 0      | train | 0
# -----------------------------------------------------------------------
# 580 K     Trainable params
# 0         Non-trainable params
# 580 K     Total params
# 2.322     Total estimated model params size (MB)
# 52        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Epoch 000 | train MAE: 0.312937 | val MAE: 0.188425 | time: 3.56s
# Epoch 001 | train MAE: 0.182421 | val MAE: 0.147725 | time: 3.70s
# Epoch 002 | train MAE: 0.147730 | val MAE: 0.135118 | time: 3.72s
# Epoch 003 | train MAE: 0.126450 | val MAE: 0.092626 | time: 3.73s
# Epoch 004 | train MAE: 0.117571 | val MAE: 0.099560 | time: 3.73s
# 😴 Cooling GPU: sleeping 10s after epoch 4
# Epoch 005 | train MAE: 0.104633 | val MAE: 0.067981 | time: 3.74s
# Epoch 006 | train MAE: 0.097113 | val MAE: 0.083639 | time: 3.73s
# Epoch 007 | train MAE: 0.093278 | val MAE: 0.063834 | time: 3.70s
# Epoch 008 | train MAE: 0.085879 | val MAE: 0.059508 | time: 3.76s
# Epoch 009 | train MAE: 0.079988 | val MAE: 0.068183 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 9
# Epoch 010 | train MAE: 0.077407 | val MAE: 0.080087 | time: 3.69s
# Epoch 011 | train MAE: 0.071525 | val MAE: 0.103064 | time: 3.75s
# Epoch 012 | train MAE: 0.068214 | val MAE: 0.077898 | time: 3.72s
# Epoch 013 | train MAE: 0.065326 | val MAE: 0.062344 | time: 3.75s
# Epoch 014 | train MAE: 0.061454 | val MAE: 0.084963 | time: 3.68s
# 😴 Cooling GPU: sleeping 10s after epoch 14
# Epoch 015 | train MAE: 0.060336 | val MAE: 0.047453 | time: 3.74s
# Epoch 016 | train MAE: 0.059564 | val MAE: 0.073631 | time: 3.73s
# Epoch 017 | train MAE: 0.058852 | val MAE: 0.048911 | time: 3.76s
# Epoch 018 | train MAE: 0.055480 | val MAE: 0.067530 | time: 3.78s
# Epoch 019 | train MAE: 0.054105 | val MAE: 0.047376 | time: 3.75s
# 😴 Cooling GPU: sleeping 10s after epoch 19
# Epoch 020 | train MAE: 0.052611 | val MAE: 0.042259 | time: 3.75s
# Epoch 021 | train MAE: 0.051722 | val MAE: 0.042875 | time: 3.72s
# Epoch 022 | train MAE: 0.049706 | val MAE: 0.055069 | time: 3.72s
# Epoch 023 | train MAE: 0.049607 | val MAE: 0.040824 | time: 3.75s
# Epoch 024 | train MAE: 0.048107 | val MAE: 0.042804 | time: 3.77s
# 😴 Cooling GPU: sleeping 10s after epoch 24
# Epoch 025 | train MAE: 0.047538 | val MAE: 0.042533 | time: 3.79s
# Epoch 026 | train MAE: 0.048161 | val MAE: 0.040458 | time: 3.79s
# Epoch 027 | train MAE: 0.048217 | val MAE: 0.046973 | time: 3.76s
# Epoch 028 | train MAE: 0.047392 | val MAE: 0.032903 | time: 3.84s
# Epoch 029 | train MAE: 0.045356 | val MAE: 0.047049 | time: 3.77s
# 😴 Cooling GPU: sleeping 10s after epoch 29
# Epoch 030 | train MAE: 0.044104 | val MAE: 0.038976 | time: 3.81s
# Epoch 031 | train MAE: 0.045062 | val MAE: 0.057883 | time: 3.80s
# Epoch 032 | train MAE: 0.042774 | val MAE: 0.045465 | time: 3.82s
# Epoch 033 | train MAE: 0.043020 | val MAE: 0.040852 | time: 3.79s
# Epoch 034 | train MAE: 0.043908 | val MAE: 0.041897 | time: 3.76s
# 😴 Cooling GPU: sleeping 10s after epoch 34
# Epoch 035 | train MAE: 0.042778 | val MAE: 0.042749 | time: 3.72s
# Epoch 036 | train MAE: 0.042890 | val MAE: 0.045305 | time: 3.81s
# Epoch 037 | train MAE: 0.041663 | val MAE: 0.046214 | time: 3.73s
# Epoch 038 | train MAE: 0.041309 | val MAE: 0.040221 | time: 3.76s
# Epoch 039 | train MAE: 0.040614 | val MAE: 0.036641 | time: 3.77s
# 😴 Cooling GPU: sleeping 10s after epoch 39
# Epoch 040 | train MAE: 0.039455 | val MAE: 0.043506 | time: 3.75s
# Epoch 041 | train MAE: 0.040211 | val MAE: 0.032980 | time: 3.77s
# Epoch 042 | train MAE: 0.039835 | val MAE: 0.038100 | time: 3.76s
# Epoch 043 | train MAE: 0.037720 | val MAE: 0.045224 | time: 3.76s
# Epoch 044 | train MAE: 0.039060 | val MAE: 0.035855 | time: 3.74s
# 😴 Cooling GPU: sleeping 10s after epoch 44
# Epoch 045 | train MAE: 0.037005 | val MAE: 0.044686 | time: 3.79s
# Epoch 046 | train MAE: 0.038179 | val MAE: 0.042204 | time: 3.77s
# Epoch 047 | train MAE: 0.037487 | val MAE: 0.031775 | time: 3.79s
# Epoch 048 | train MAE: 0.036133 | val MAE: 0.042616 | time: 3.79s
# Epoch 049 | train MAE: 0.036830 | val MAE: 0.042902 | time: 3.78s
# 😴 Cooling GPU: sleeping 10s after epoch 49
# Epoch 050 | train MAE: 0.035794 | val MAE: 0.036910 | time: 3.82s
# Epoch 051 | train MAE: 0.036500 | val MAE: 0.037155 | time: 3.83s
# Epoch 052 | train MAE: 0.036105 | val MAE: 0.034071 | time: 3.80s
# Epoch 053 | train MAE: 0.034459 | val MAE: 0.043140 | time: 3.77s
# Epoch 054 | train MAE: 0.035935 | val MAE: 0.036550 | time: 3.74s
# 😴 Cooling GPU: sleeping 10s after epoch 54
# Epoch 055 | train MAE: 0.033837 | val MAE: 0.025293 | time: 3.74s
# Epoch 056 | train MAE: 0.035223 | val MAE: 0.036461 | time: 3.78s
# Epoch 057 | train MAE: 0.035300 | val MAE: 0.048171 | time: 3.74s
# Epoch 058 | train MAE: 0.034825 | val MAE: 0.037048 | time: 3.79s
# Epoch 059 | train MAE: 0.032338 | val MAE: 0.025047 | time: 3.76s
# 😴 Cooling GPU: sleeping 10s after epoch 59
# Epoch 060 | train MAE: 0.032324 | val MAE: 0.051220 | time: 3.79s
# Epoch 061 | train MAE: 0.034158 | val MAE: 0.033456 | time: 3.78s
# Epoch 062 | train MAE: 0.032943 | val MAE: 0.027791 | time: 3.86s
# Epoch 063 | train MAE: 0.032439 | val MAE: 0.029445 | time: 3.83s
# Epoch 064 | train MAE: 0.032219 | val MAE: 0.044071 | time: 3.76s
# 😴 Cooling GPU: sleeping 10s after epoch 64
# Epoch 065 | train MAE: 0.032498 | val MAE: 0.031641 | time: 3.84s
# Epoch 066 | train MAE: 0.031379 | val MAE: 0.034258 | time: 3.78s
# Epoch 067 | train MAE: 0.030622 | val MAE: 0.029582 | time: 3.75s
# Epoch 068 | train MAE: 0.030707 | val MAE: 0.025704 | time: 3.74s
# Epoch 069 | train MAE: 0.030403 | val MAE: 0.027248 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 69
# Epoch 070 | train MAE: 0.029307 | val MAE: 0.030527 | time: 3.81s
# Epoch 071 | train MAE: 0.030349 | val MAE: 0.028766 | time: 3.80s
# Epoch 072 | train MAE: 0.031130 | val MAE: 0.036930 | time: 3.82s
# Epoch 073 | train MAE: 0.028727 | val MAE: 0.033737 | time: 3.84s
# Epoch 074 | train MAE: 0.030149 | val MAE: 0.027521 | time: 3.72s
# 😴 Cooling GPU: sleeping 10s after epoch 74
# Epoch 075 | train MAE: 0.029219 | val MAE: 0.031004 | time: 3.83s
# Epoch 076 | train MAE: 0.029216 | val MAE: 0.024771 | time: 3.84s
# Epoch 077 | train MAE: 0.027978 | val MAE: 0.029591 | time: 3.71s
# Epoch 078 | train MAE: 0.028482 | val MAE: 0.024965 | time: 3.76s
# Epoch 079 | train MAE: 0.028524 | val MAE: 0.024506 | time: 3.88s
# 😴 Cooling GPU: sleeping 10s after epoch 79
# Epoch 080 | train MAE: 0.028823 | val MAE: 0.034922 | time: 3.75s
# Epoch 081 | train MAE: 0.029331 | val MAE: 0.027554 | time: 3.82s
# Epoch 082 | train MAE: 0.027270 | val MAE: 0.027068 | time: 3.79s
# Epoch 083 | train MAE: 0.027619 | val MAE: 0.021596 | time: 3.82s
# Epoch 084 | train MAE: 0.027501 | val MAE: 0.028508 | time: 3.78s
# 😴 Cooling GPU: sleeping 10s after epoch 84
# Epoch 085 | train MAE: 0.028220 | val MAE: 0.026558 | time: 3.83s
# Epoch 086 | train MAE: 0.027933 | val MAE: 0.027522 | time: 3.77s
# Epoch 087 | train MAE: 0.028082 | val MAE: 0.034011 | time: 3.74s
# Epoch 088 | train MAE: 0.027632 | val MAE: 0.034033 | time: 3.83s
# Epoch 089 | train MAE: 0.026999 | val MAE: 0.026149 | time: 3.89s
# 😴 Cooling GPU: sleeping 10s after epoch 89
# Epoch 090 | train MAE: 0.026134 | val MAE: 0.027146 | time: 3.80s
# Epoch 091 | train MAE: 0.026307 | val MAE: 0.023940 | time: 3.76s
# Epoch 092 | train MAE: 0.026443 | val MAE: 0.022929 | time: 3.85s
# Epoch 093 | train MAE: 0.027354 | val MAE: 0.019549 | time: 3.87s
# Epoch 094 | train MAE: 0.025814 | val MAE: 0.022241 | time: 3.82s
# 😴 Cooling GPU: sleeping 10s after epoch 94
# Epoch 095 | train MAE: 0.027251 | val MAE: 0.025216 | time: 3.79s
# Epoch 096 | train MAE: 0.026155 | val MAE: 0.022585 | time: 3.80s
# Epoch 097 | train MAE: 0.026015 | val MAE: 0.032749 | time: 3.87s
# Epoch 098 | train MAE: 0.026305 | val MAE: 0.028773 | time: 3.81s
# Epoch 099 | train MAE: 0.026021 | val MAE: 0.021609 | time: 3.82s
# 😴 Cooling GPU: sleeping 10s after epoch 99
# Epoch 100 | train MAE: 0.026016 | val MAE: 0.033930 | time: 3.86s
# Epoch 101 | train MAE: 0.025229 | val MAE: 0.028813 | time: 3.79s
# Epoch 102 | train MAE: 0.025415 | val MAE: 0.020532 | time: 3.86s
# Epoch 103 | train MAE: 0.025334 | val MAE: 0.023516 | time: 3.83s
# Epoch 104 | train MAE: 0.025633 | val MAE: 0.024492 | time: 3.78s
# 😴 Cooling GPU: sleeping 10s after epoch 104
# Epoch 105 | train MAE: 0.026153 | val MAE: 0.029817 | time: 3.81s
# Epoch 106 | train MAE: 0.024644 | val MAE: 0.020944 | time: 3.80s
# Epoch 107 | train MAE: 0.025485 | val MAE: 0.025639 | time: 3.85s
# Epoch 108 | train MAE: 0.025252 | val MAE: 0.026426 | time: 3.86s
# Epoch 109 | train MAE: 0.025087 | val MAE: 0.020608 | time: 3.77s
# 😴 Cooling GPU: sleeping 10s after epoch 109
# Epoch 110 | train MAE: 0.024795 | val MAE: 0.018861 | time: 3.81s
# Epoch 111 | train MAE: 0.024330 | val MAE: 0.024987 | time: 3.79s
# Epoch 112 | train MAE: 0.024568 | val MAE: 0.026806 | time: 3.87s
# Epoch 113 | train MAE: 0.025659 | val MAE: 0.022961 | time: 3.89s
# Epoch 114 | train MAE: 0.024563 | val MAE: 0.023916 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 114
# Epoch 115 | train MAE: 0.024394 | val MAE: 0.031532 | time: 3.82s
# Epoch 116 | train MAE: 0.025464 | val MAE: 0.019876 | time: 3.88s
# Epoch 117 | train MAE: 0.024500 | val MAE: 0.024933 | time: 3.82s
# Epoch 118 | train MAE: 0.023548 | val MAE: 0.021028 | time: 3.83s
# Epoch 119 | train MAE: 0.023374 | val MAE: 0.022757 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 119
# Epoch 120 | train MAE: 0.024790 | val MAE: 0.032673 | time: 3.83s
# Epoch 121 | train MAE: 0.024579 | val MAE: 0.045468 | time: 3.80s
# Epoch 122 | train MAE: 0.024381 | val MAE: 0.022383 | time: 3.77s
# Epoch 123 | train MAE: 0.023362 | val MAE: 0.022976 | time: 3.82s
# Epoch 124 | train MAE: 0.024138 | val MAE: 0.020702 | time: 3.80s
# 😴 Cooling GPU: sleeping 10s after epoch 124
# Epoch 125 | train MAE: 0.023536 | val MAE: 0.026197 | time: 3.78s
# Epoch 126 | train MAE: 0.023773 | val MAE: 0.024183 | time: 3.82s
# Epoch 127 | train MAE: 0.024766 | val MAE: 0.023523 | time: 3.80s
# Epoch 128 | train MAE: 0.023893 | val MAE: 0.028594 | time: 3.86s
# Epoch 129 | train MAE: 0.024002 | val MAE: 0.026052 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 129
# Epoch 130 | train MAE: 0.022508 | val MAE: 0.021854 | time: 3.82s
# Epoch 131 | train MAE: 0.023122 | val MAE: 0.024353 | time: 3.81s
# Epoch 132 | train MAE: 0.024030 | val MAE: 0.020767 | time: 3.84s
# Epoch 133 | train MAE: 0.023217 | val MAE: 0.027447 | time: 3.80s
# Epoch 134 | train MAE: 0.023207 | val MAE: 0.026548 | time: 3.78s
# 😴 Cooling GPU: sleeping 10s after epoch 134
# Epoch 135 | train MAE: 0.023729 | val MAE: 0.024072 | time: 3.81s
# Epoch 136 | train MAE: 0.022727 | val MAE: 0.024266 | time: 3.74s
# Epoch 137 | train MAE: 0.022881 | val MAE: 0.027928 | time: 3.79s
# Epoch 138 | train MAE: 0.022647 | val MAE: 0.031267 | time: 3.80s
# Epoch 139 | train MAE: 0.022962 | val MAE: 0.019143 | time: 3.85s
# 😴 Cooling GPU: sleeping 10s after epoch 139
# Epoch 140 | train MAE: 0.022825 | val MAE: 0.025807 | time: 3.81s
# Epoch 141 | train MAE: 0.023369 | val MAE: 0.023945 | time: 3.79s
# Epoch 142 | train MAE: 0.022984 | val MAE: 0.020712 | time: 3.82s
# Epoch 143 | train MAE: 0.022142 | val MAE: 0.023846 | time: 3.73s
# Epoch 144 | train MAE: 0.023248 | val MAE: 0.019970 | time: 3.80s
# 😴 Cooling GPU: sleeping 10s after epoch 144
# Epoch 145 | train MAE: 0.022479 | val MAE: 0.022688 | time: 3.81s
# Epoch 146 | train MAE: 0.023188 | val MAE: 0.024264 | time: 3.79s
# Epoch 147 | train MAE: 0.022486 | val MAE: 0.027422 | time: 3.84s
# Epoch 148 | train MAE: 0.023400 | val MAE: 0.020587 | time: 3.78s
# Epoch 149 | train MAE: 0.022895 | val MAE: 0.020454 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 149
# Epoch 150 | train MAE: 0.022436 | val MAE: 0.022725 | time: 3.79s
# Epoch 151 | train MAE: 0.022098 | val MAE: 0.021767 | time: 3.78s
# Epoch 152 | train MAE: 0.022537 | val MAE: 0.023443 | time: 3.88s
# Epoch 153 | train MAE: 0.022041 | val MAE: 0.024481 | time: 3.85s
# Epoch 154 | train MAE: 0.022607 | val MAE: 0.021454 | time: 3.86s
# 😴 Cooling GPU: sleeping 10s after epoch 154
# Epoch 155 | train MAE: 0.021789 | val MAE: 0.020983 | time: 3.87s
# Epoch 156 | train MAE: 0.022253 | val MAE: 0.024235 | time: 3.82s
# Epoch 157 | train MAE: 0.021530 | val MAE: 0.019827 | time: 3.77s
# Epoch 158 | train MAE: 0.022519 | val MAE: 0.021948 | time: 3.80s
# Epoch 159 | train MAE: 0.021976 | val MAE: 0.020597 | time: 3.77s
# 😴 Cooling GPU: sleeping 10s after epoch 159
# Epoch 160 | train MAE: 0.021794 | val MAE: 0.023601 | time: 3.84s
# Epoch 161 | train MAE: 0.021545 | val MAE: 0.020415 | time: 3.88s
# Epoch 162 | train MAE: 0.021273 | val MAE: 0.027440 | time: 3.87s
# Epoch 163 | train MAE: 0.021710 | val MAE: 0.023218 | time: 3.82s
# Epoch 164 | train MAE: 0.021056 | val MAE: 0.023229 | time: 3.88s
# 😴 Cooling GPU: sleeping 10s after epoch 164
# Epoch 165 | train MAE: 0.021502 | val MAE: 0.022693 | time: 3.78s
# Epoch 166 | train MAE: 0.021679 | val MAE: 0.029106 | time: 3.80s
# Epoch 167 | train MAE: 0.021493 | val MAE: 0.024804 | time: 3.83s
# Epoch 168 | train MAE: 0.021209 | val MAE: 0.020708 | time: 3.83s
# Epoch 169 | train MAE: 0.021726 | val MAE: 0.022745 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 169
# Epoch 170 | train MAE: 0.021948 | val MAE: 0.017266 | time: 3.76s
# Epoch 171 | train MAE: 0.020581 | val MAE: 0.022672 | time: 3.78s
# Epoch 172 | train MAE: 0.022028 | val MAE: 0.019514 | time: 3.80s
# Epoch 173 | train MAE: 0.022354 | val MAE: 0.021904 | time: 3.85s
# Epoch 174 | train MAE: 0.021598 | val MAE: 0.019005 | time: 3.82s
# 😴 Cooling GPU: sleeping 10s after epoch 174
# Epoch 175 | train MAE: 0.021631 | val MAE: 0.024567 | time: 3.76s
# Epoch 176 | train MAE: 0.021324 | val MAE: 0.025510 | time: 3.80s
# Epoch 177 | train MAE: 0.021894 | val MAE: 0.021121 | time: 3.78s
# Epoch 178 | train MAE: 0.021226 | val MAE: 0.023216 | time: 3.81s
# Epoch 179 | train MAE: 0.021425 | val MAE: 0.023670 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 179
# Epoch 180 | train MAE: 0.020937 | val MAE: 0.020207 | time: 3.86s
# Epoch 181 | train MAE: 0.021077 | val MAE: 0.022291 | time: 3.79s
# Epoch 182 | train MAE: 0.021040 | val MAE: 0.020138 | time: 3.80s
# Epoch 183 | train MAE: 0.021654 | val MAE: 0.028418 | time: 3.87s
# Epoch 184 | train MAE: 0.020611 | val MAE: 0.018354 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 184
# Epoch 185 | train MAE: 0.020564 | val MAE: 0.019620 | time: 3.86s
# Epoch 186 | train MAE: 0.020549 | val MAE: 0.021888 | time: 3.83s
# Epoch 187 | train MAE: 0.020807 | val MAE: 0.024957 | time: 3.78s
# Epoch 188 | train MAE: 0.021065 | val MAE: 0.024800 | time: 3.79s
# Epoch 189 | train MAE: 0.020418 | val MAE: 0.020018 | time: 3.78s
# 😴 Cooling GPU: sleeping 10s after epoch 189
# Epoch 190 | train MAE: 0.020438 | val MAE: 0.023671 | time: 3.87s
# Epoch 191 | train MAE: 0.021271 | val MAE: 0.023695 | time: 3.80s
# Epoch 192 | train MAE: 0.020593 | val MAE: 0.030357 | time: 3.84s
# Epoch 193 | train MAE: 0.020775 | val MAE: 0.018288 | time: 3.83s
# Epoch 194 | train MAE: 0.020775 | val MAE: 0.019737 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 194
# Epoch 195 | train MAE: 0.020969 | val MAE: 0.019833 | time: 3.81s
# Epoch 196 | train MAE: 0.020617 | val MAE: 0.023208 | time: 3.82s
# Epoch 197 | train MAE: 0.020804 | val MAE: 0.029098 | time: 3.82s
# Epoch 198 | train MAE: 0.020442 | val MAE: 0.019548 | time: 3.85s
# Epoch 199 | train MAE: 0.020466 | val MAE: 0.028122 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 199
# Epoch 200 | train MAE: 0.021283 | val MAE: 0.021246 | time: 3.87s
# Epoch 201 | train MAE: 0.020125 | val MAE: 0.021623 | time: 3.84s
# Epoch 202 | train MAE: 0.020637 | val MAE: 0.019345 | time: 3.86s
# Epoch 203 | train MAE: 0.020231 | val MAE: 0.019498 | time: 3.86s
# Epoch 204 | train MAE: 0.019647 | val MAE: 0.024731 | time: 3.86s
# 😴 Cooling GPU: sleeping 10s after epoch 204
# Epoch 205 | train MAE: 0.020363 | val MAE: 0.018346 | time: 3.83s
# Epoch 206 | train MAE: 0.020221 | val MAE: 0.020190 | time: 3.78s
# Epoch 207 | train MAE: 0.020694 | val MAE: 0.023626 | time: 3.79s
# Epoch 208 | train MAE: 0.020620 | val MAE: 0.025925 | time: 3.75s
# Epoch 209 | train MAE: 0.020539 | val MAE: 0.022887 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 209
# Epoch 210 | train MAE: 0.020315 | val MAE: 0.021420 | time: 3.86s
# Epoch 211 | train MAE: 0.019550 | val MAE: 0.020505 | time: 3.82s
# Epoch 212 | train MAE: 0.019964 | val MAE: 0.024887 | time: 3.82s
# Epoch 213 | train MAE: 0.019744 | val MAE: 0.020287 | time: 3.83s
# Epoch 214 | train MAE: 0.020339 | val MAE: 0.018781 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 214
# Epoch 215 | train MAE: 0.020250 | val MAE: 0.023686 | time: 3.82s
# Epoch 216 | train MAE: 0.020117 | val MAE: 0.019020 | time: 3.85s
# Epoch 217 | train MAE: 0.019824 | val MAE: 0.021629 | time: 3.82s
# Epoch 218 | train MAE: 0.019635 | val MAE: 0.018742 | time: 3.76s
# Epoch 219 | train MAE: 0.019447 | val MAE: 0.020104 | time: 3.72s
# 😴 Cooling GPU: sleeping 10s after epoch 219
# Epoch 220 | train MAE: 0.019788 | val MAE: 0.019700 | time: 3.82s
# Epoch 221 | train MAE: 0.020361 | val MAE: 0.017801 | time: 3.80s
# Epoch 222 | train MAE: 0.019694 | val MAE: 0.021806 | time: 3.83s
# Epoch 223 | train MAE: 0.019637 | val MAE: 0.017907 | time: 3.89s
# Epoch 224 | train MAE: 0.019749 | val MAE: 0.019563 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 224
# Epoch 225 | train MAE: 0.019304 | val MAE: 0.020844 | time: 3.87s
# Epoch 226 | train MAE: 0.020268 | val MAE: 0.022481 | time: 3.81s
# Epoch 227 | train MAE: 0.019751 | val MAE: 0.023589 | time: 3.92s
# Epoch 228 | train MAE: 0.019930 | val MAE: 0.021866 | time: 3.82s
# Epoch 229 | train MAE: 0.019009 | val MAE: 0.020173 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 229
# Epoch 230 | train MAE: 0.019990 | val MAE: 0.023876 | time: 3.86s
# Epoch 231 | train MAE: 0.019574 | val MAE: 0.020119 | time: 3.77s
# Epoch 232 | train MAE: 0.019116 | val MAE: 0.017071 | time: 3.92s
# Epoch 233 | train MAE: 0.020070 | val MAE: 0.021768 | time: 3.84s
# Epoch 234 | train MAE: 0.019352 | val MAE: 0.018867 | time: 3.86s
# 😴 Cooling GPU: sleeping 10s after epoch 234
# Epoch 235 | train MAE: 0.019477 | val MAE: 0.021048 | time: 3.92s
# Epoch 236 | train MAE: 0.019090 | val MAE: 0.022346 | time: 3.74s
# Epoch 237 | train MAE: 0.019188 | val MAE: 0.022699 | time: 3.82s
# Epoch 238 | train MAE: 0.019536 | val MAE: 0.017042 | time: 3.80s
# Epoch 239 | train MAE: 0.020047 | val MAE: 0.020236 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 239
# Epoch 240 | train MAE: 0.019357 | val MAE: 0.021038 | time: 3.83s
# Epoch 241 | train MAE: 0.018919 | val MAE: 0.019846 | time: 3.91s
# Epoch 242 | train MAE: 0.019072 | val MAE: 0.020285 | time: 3.78s
# Epoch 243 | train MAE: 0.019548 | val MAE: 0.024956 | time: 3.85s
# Epoch 244 | train MAE: 0.019203 | val MAE: 0.016652 | time: 3.90s
# 😴 Cooling GPU: sleeping 10s after epoch 244
# Epoch 245 | train MAE: 0.018909 | val MAE: 0.021637 | time: 3.79s
# Epoch 246 | train MAE: 0.019755 | val MAE: 0.023510 | time: 3.86s
# Epoch 247 | train MAE: 0.019381 | val MAE: 0.019412 | time: 3.81s
# Epoch 248 | train MAE: 0.018650 | val MAE: 0.018721 | time: 3.81s
# Epoch 249 | train MAE: 0.019264 | val MAE: 0.015751 | time: 3.89s
# 😴 Cooling GPU: sleeping 10s after epoch 249
# Epoch 250 | train MAE: 0.019080 | val MAE: 0.020072 | time: 3.77s
# Epoch 251 | train MAE: 0.018802 | val MAE: 0.018994 | time: 3.72s
# Epoch 252 | train MAE: 0.019232 | val MAE: 0.020780 | time: 3.80s
# Epoch 253 | train MAE: 0.019198 | val MAE: 0.019897 | time: 3.81s
# Epoch 254 | train MAE: 0.019279 | val MAE: 0.019118 | time: 3.73s
# 😴 Cooling GPU: sleeping 10s after epoch 254
# Epoch 255 | train MAE: 0.019007 | val MAE: 0.018943 | time: 3.84s
# Epoch 256 | train MAE: 0.018475 | val MAE: 0.022040 | time: 3.79s
# Epoch 257 | train MAE: 0.019270 | val MAE: 0.024264 | time: 3.81s
# Epoch 258 | train MAE: 0.019317 | val MAE: 0.020102 | time: 3.80s
# Epoch 259 | train MAE: 0.018625 | val MAE: 0.022283 | time: 3.79s
# 😴 Cooling GPU: sleeping 10s after epoch 259
# Epoch 260 | train MAE: 0.018966 | val MAE: 0.017470 | time: 3.81s
# Epoch 261 | train MAE: 0.019447 | val MAE: 0.023238 | time: 3.77s
# Epoch 262 | train MAE: 0.018464 | val MAE: 0.016236 | time: 3.84s
# Epoch 263 | train MAE: 0.018675 | val MAE: 0.022235 | time: 3.76s
# Epoch 264 | train MAE: 0.019307 | val MAE: 0.024444 | time: 3.78s
# 😴 Cooling GPU: sleeping 10s after epoch 264
# Epoch 265 | train MAE: 0.018751 | val MAE: 0.019658 | time: 3.81s
# Epoch 266 | train MAE: 0.019247 | val MAE: 0.020889 | time: 3.79s
# Epoch 267 | train MAE: 0.017935 | val MAE: 0.025504 | time: 3.77s
# Epoch 268 | train MAE: 0.018507 | val MAE: 0.015782 | time: 3.81s
# Epoch 269 | train MAE: 0.018669 | val MAE: 0.021361 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 269
# Epoch 270 | train MAE: 0.018570 | val MAE: 0.021085 | time: 3.85s
# Epoch 271 | train MAE: 0.018496 | val MAE: 0.021425 | time: 3.82s
# Epoch 272 | train MAE: 0.018259 | val MAE: 0.017574 | time: 3.89s
# Epoch 273 | train MAE: 0.018933 | val MAE: 0.018616 | time: 3.79s
# Epoch 274 | train MAE: 0.018868 | val MAE: 0.018779 | time: 3.75s
# 😴 Cooling GPU: sleeping 10s after epoch 274
# Epoch 275 | train MAE: 0.018340 | val MAE: 0.020470 | time: 3.81s
# Epoch 276 | train MAE: 0.018477 | val MAE: 0.023643 | time: 3.76s
# Epoch 277 | train MAE: 0.018584 | val MAE: 0.022365 | time: 3.74s
# Epoch 278 | train MAE: 0.018149 | val MAE: 0.019782 | time: 3.86s
# Epoch 279 | train MAE: 0.018759 | val MAE: 0.020549 | time: 3.76s
# 😴 Cooling GPU: sleeping 10s after epoch 279
# Epoch 280 | train MAE: 0.018521 | val MAE: 0.020453 | time: 3.84s
# Epoch 281 | train MAE: 0.018545 | val MAE: 0.018959 | time: 3.81s
# Epoch 282 | train MAE: 0.018475 | val MAE: 0.020949 | time: 3.77s
# Epoch 283 | train MAE: 0.018674 | val MAE: 0.017188 | time: 3.77s
# Epoch 284 | train MAE: 0.018586 | val MAE: 0.017987 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 284
# Epoch 285 | train MAE: 0.018065 | val MAE: 0.018711 | time: 3.88s
# Epoch 286 | train MAE: 0.017919 | val MAE: 0.017190 | time: 3.82s
# Epoch 287 | train MAE: 0.018172 | val MAE: 0.019214 | time: 3.77s
# Epoch 288 | train MAE: 0.017764 | val MAE: 0.019361 | time: 3.73s
# Epoch 289 | train MAE: 0.018449 | val MAE: 0.026907 | time: 3.80s
# 😴 Cooling GPU: sleeping 10s after epoch 289
# Epoch 290 | train MAE: 0.018834 | val MAE: 0.019650 | time: 3.75s
# Epoch 291 | train MAE: 0.017867 | val MAE: 0.016532 | time: 3.81s
# Epoch 292 | train MAE: 0.018232 | val MAE: 0.019525 | time: 3.77s
# Epoch 293 | train MAE: 0.017937 | val MAE: 0.019593 | time: 3.79s
# Epoch 294 | train MAE: 0.017756 | val MAE: 0.018178 | time: 3.79s
# 😴 Cooling GPU: sleeping 10s after epoch 294
# Epoch 295 | train MAE: 0.018300 | val MAE: 0.018218 | time: 3.83s
# Epoch 296 | train MAE: 0.018222 | val MAE: 0.017508 | time: 3.79s
# Epoch 297 | train MAE: 0.018164 | val MAE: 0.018028 | time: 3.71s
# Epoch 298 | train MAE: 0.017965 | val MAE: 0.020898 | time: 3.85s
# Epoch 299 | train MAE: 0.018271 | val MAE: 0.017326 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 299
# Epoch 300 | train MAE: 0.018461 | val MAE: 0.016693 | time: 3.82s
# Epoch 301 | train MAE: 0.019106 | val MAE: 0.019031 | time: 3.81s
# Epoch 302 | train MAE: 0.017867 | val MAE: 0.015936 | time: 3.85s
# Epoch 303 | train MAE: 0.017870 | val MAE: 0.018112 | time: 3.89s
# Epoch 304 | train MAE: 0.017741 | val MAE: 0.018741 | time: 3.79s
# 😴 Cooling GPU: sleeping 10s after epoch 304
# Epoch 305 | train MAE: 0.017624 | val MAE: 0.022162 | time: 3.86s
# Epoch 306 | train MAE: 0.017632 | val MAE: 0.020103 | time: 3.85s
# Epoch 307 | train MAE: 0.017838 | val MAE: 0.017867 | time: 3.81s
# Epoch 308 | train MAE: 0.018135 | val MAE: 0.019497 | time: 3.81s
# Epoch 309 | train MAE: 0.018391 | val MAE: 0.019545 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 309
# Epoch 310 | train MAE: 0.017508 | val MAE: 0.018667 | time: 3.83s
# Epoch 311 | train MAE: 0.018164 | val MAE: 0.020813 | time: 3.80s
# Epoch 312 | train MAE: 0.017116 | val MAE: 0.018873 | time: 3.79s
# Epoch 313 | train MAE: 0.017810 | val MAE: 0.022220 | time: 3.79s
# Epoch 314 | train MAE: 0.018096 | val MAE: 0.019124 | time: 3.86s
# 😴 Cooling GPU: sleeping 10s after epoch 314
# Epoch 315 | train MAE: 0.017858 | val MAE: 0.020813 | time: 3.82s
# Epoch 316 | train MAE: 0.017814 | val MAE: 0.018170 | time: 3.84s
# Epoch 317 | train MAE: 0.017836 | val MAE: 0.017089 | time: 3.88s
# Epoch 318 | train MAE: 0.017877 | val MAE: 0.016249 | time: 3.84s
# Epoch 319 | train MAE: 0.017961 | val MAE: 0.018813 | time: 3.78s
# 😴 Cooling GPU: sleeping 10s after epoch 319
# Epoch 320 | train MAE: 0.017760 | val MAE: 0.017139 | time: 3.80s
# Epoch 321 | train MAE: 0.017826 | val MAE: 0.016162 | time: 3.76s
# Epoch 322 | train MAE: 0.017464 | val MAE: 0.020845 | time: 3.82s
# Epoch 323 | train MAE: 0.017585 | val MAE: 0.018398 | time: 3.85s
# Epoch 324 | train MAE: 0.017628 | val MAE: 0.018390 | time: 3.78s
# 😴 Cooling GPU: sleeping 10s after epoch 324
# Epoch 325 | train MAE: 0.017888 | val MAE: 0.019699 | time: 3.77s
# Epoch 326 | train MAE: 0.017857 | val MAE: 0.020807 | time: 3.81s
# Epoch 327 | train MAE: 0.017404 | val MAE: 0.018344 | time: 3.83s
# Epoch 328 | train MAE: 0.017265 | val MAE: 0.021579 | time: 3.86s
# Epoch 329 | train MAE: 0.017897 | val MAE: 0.018690 | time: 3.85s
# 😴 Cooling GPU: sleeping 10s after epoch 329
# Epoch 330 | train MAE: 0.017990 | val MAE: 0.017398 | time: 3.82s
# Epoch 331 | train MAE: 0.017735 | val MAE: 0.028301 | time: 3.78s
# Epoch 332 | train MAE: 0.017906 | val MAE: 0.016546 | time: 3.77s
# Epoch 333 | train MAE: 0.017481 | val MAE: 0.014108 | time: 3.81s
# Epoch 334 | train MAE: 0.017445 | val MAE: 0.022387 | time: 3.87s
# 😴 Cooling GPU: sleeping 10s after epoch 334
# Epoch 335 | train MAE: 0.017858 | val MAE: 0.019026 | time: 3.82s
# Epoch 336 | train MAE: 0.017481 | val MAE: 0.022805 | time: 3.79s
# Epoch 337 | train MAE: 0.017471 | val MAE: 0.021561 | time: 3.80s
# Epoch 338 | train MAE: 0.017212 | val MAE: 0.024037 | time: 3.82s
# Epoch 339 | train MAE: 0.017278 | val MAE: 0.018855 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 339
# Epoch 340 | train MAE: 0.017323 | val MAE: 0.019714 | time: 3.80s
# Epoch 341 | train MAE: 0.017246 | val MAE: 0.024967 | time: 3.75s
# Epoch 342 | train MAE: 0.017789 | val MAE: 0.017151 | time: 3.77s
# Epoch 343 | train MAE: 0.017681 | val MAE: 0.019575 | time: 3.90s
# Epoch 344 | train MAE: 0.017509 | val MAE: 0.015272 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 344
# Epoch 345 | train MAE: 0.017001 | val MAE: 0.021381 | time: 3.83s
# Epoch 346 | train MAE: 0.017629 | val MAE: 0.018869 | time: 3.83s
# Epoch 347 | train MAE: 0.017312 | val MAE: 0.017665 | time: 3.81s
# Epoch 348 | train MAE: 0.017401 | val MAE: 0.019976 | time: 3.81s
# Epoch 349 | train MAE: 0.017536 | val MAE: 0.023478 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 349
# Epoch 350 | train MAE: 0.017672 | val MAE: 0.019064 | time: 3.75s
# Epoch 351 | train MAE: 0.017677 | val MAE: 0.018508 | time: 3.77s
# Epoch 352 | train MAE: 0.017550 | val MAE: 0.017344 | time: 3.76s
# Epoch 353 | train MAE: 0.017309 | val MAE: 0.018084 | time: 3.82s
# Epoch 354 | train MAE: 0.016805 | val MAE: 0.018964 | time: 3.78s
# 😴 Cooling GPU: sleeping 10s after epoch 354
# Epoch 355 | train MAE: 0.017102 | val MAE: 0.018726 | time: 3.84s
# Epoch 356 | train MAE: 0.016934 | val MAE: 0.015373 | time: 3.82s
# Epoch 357 | train MAE: 0.017211 | val MAE: 0.019973 | time: 3.85s
# Epoch 358 | train MAE: 0.017160 | val MAE: 0.016982 | time: 3.82s
# Epoch 359 | train MAE: 0.016933 | val MAE: 0.020539 | time: 3.87s
# 😴 Cooling GPU: sleeping 10s after epoch 359
# Epoch 360 | train MAE: 0.017141 | val MAE: 0.024291 | time: 3.84s
# Epoch 361 | train MAE: 0.017348 | val MAE: 0.016921 | time: 3.84s
# Epoch 362 | train MAE: 0.017393 | val MAE: 0.021204 | time: 3.92s
# Epoch 363 | train MAE: 0.016824 | val MAE: 0.020866 | time: 3.83s
# Epoch 364 | train MAE: 0.016859 | val MAE: 0.020537 | time: 3.75s
# 😴 Cooling GPU: sleeping 10s after epoch 364
# Epoch 365 | train MAE: 0.017616 | val MAE: 0.017087 | time: 3.82s
# Epoch 366 | train MAE: 0.016599 | val MAE: 0.019282 | time: 3.79s
# Epoch 367 | train MAE: 0.017271 | val MAE: 0.021145 | time: 3.87s
# Epoch 368 | train MAE: 0.017154 | val MAE: 0.021879 | time: 3.81s
# Epoch 369 | train MAE: 0.016629 | val MAE: 0.017433 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 369
# Epoch 370 | train MAE: 0.016971 | val MAE: 0.019063 | time: 3.79s
# Epoch 371 | train MAE: 0.017253 | val MAE: 0.022127 | time: 3.83s
# Epoch 372 | train MAE: 0.016892 | val MAE: 0.014373 | time: 3.81s
# Epoch 373 | train MAE: 0.016780 | val MAE: 0.020606 | time: 3.82s
# Epoch 374 | train MAE: 0.017268 | val MAE: 0.017851 | time: 3.78s
# 😴 Cooling GPU: sleeping 10s after epoch 374
# Epoch 375 | train MAE: 0.016866 | val MAE: 0.019448 | time: 3.82s
# Epoch 376 | train MAE: 0.016551 | val MAE: 0.018620 | time: 3.72s
# Epoch 377 | train MAE: 0.016790 | val MAE: 0.017580 | time: 3.83s
# Epoch 378 | train MAE: 0.016599 | val MAE: 0.021829 | time: 3.85s
# Epoch 379 | train MAE: 0.017432 | val MAE: 0.017524 | time: 3.82s
# 😴 Cooling GPU: sleeping 10s after epoch 379
# Epoch 380 | train MAE: 0.016816 | val MAE: 0.017972 | time: 3.84s
# Epoch 381 | train MAE: 0.016692 | val MAE: 0.021310 | time: 3.78s
# Epoch 382 | train MAE: 0.016899 | val MAE: 0.021758 | time: 3.83s
# Epoch 383 | train MAE: 0.016598 | val MAE: 0.020168 | time: 3.87s
# Epoch 384 | train MAE: 0.016858 | val MAE: 0.019658 | time: 3.86s
# 😴 Cooling GPU: sleeping 10s after epoch 384
# Epoch 385 | train MAE: 0.017172 | val MAE: 0.017648 | time: 3.85s
# Epoch 386 | train MAE: 0.017272 | val MAE: 0.018042 | time: 3.78s
# Epoch 387 | train MAE: 0.016673 | val MAE: 0.016782 | time: 3.80s
# Epoch 388 | train MAE: 0.016782 | val MAE: 0.019373 | time: 3.83s
# Epoch 389 | train MAE: 0.016609 | val MAE: 0.015165 | time: 3.88s
# 😴 Cooling GPU: sleeping 10s after epoch 389
# Epoch 405 | train MAE: 0.016694 | val MAE: 0.018379 | time: 3.78s
# Epoch 406 | train MAE: 0.016871 | val MAE: 0.016710 | time: 3.82s
# Epoch 407 | train MAE: 0.016272 | val MAE: 0.019944 | time: 3.77s
# Epoch 408 | train MAE: 0.017051 | val MAE: 0.018803 | time: 3.80s
# Epoch 409 | train MAE: 0.016275 | val MAE: 0.020365 | time: 3.89s
# 😴 Cooling GPU: sleeping 10s after epoch 409
# Epoch 410 | train MAE: 0.016676 | val MAE: 0.020859 | time: 3.82s
# Epoch 411 | train MAE: 0.017168 | val MAE: 0.021079 | time: 3.78s
# Epoch 412 | train MAE: 0.016687 | val MAE: 0.019173 | time: 3.81s
# Epoch 413 | train MAE: 0.016219 | val MAE: 0.017218 | time: 3.84s
# Epoch 414 | train MAE: 0.016952 | val MAE: 0.019781 | time: 3.74s
# 😴 Cooling GPU: sleeping 10s after epoch 414
# Epoch 415 | train MAE: 0.016287 | val MAE: 0.019802 | time: 3.86s
# Epoch 416 | train MAE: 0.016793 | val MAE: 0.018024 | time: 3.84s
# Epoch 417 | train MAE: 0.016309 | val MAE: 0.017132 | time: 3.75s
# Epoch 418 | train MAE: 0.016260 | val MAE: 0.019159 | time: 3.80s
# Epoch 419 | train MAE: 0.016550 | val MAE: 0.024248 | time: 3.75s
# 😴 Cooling GPU: sleeping 10s after epoch 419
# Epoch 420 | train MAE: 0.016766 | val MAE: 0.020439 | time: 3.85s
# Epoch 421 | train MAE: 0.016476 | val MAE: 0.019727 | time: 3.83s
# Epoch 422 | train MAE: 0.016213 | val MAE: 0.017826 | time: 3.81s
# Epoch 423 | train MAE: 0.016236 | val MAE: 0.019186 | time: 3.86s
# Epoch 424 | train MAE: 0.016362 | val MAE: 0.016364 | time: 3.86s
# 😴 Cooling GPU: sleeping 10s after epoch 424
# Epoch 425 | train MAE: 0.016377 | val MAE: 0.018142 | time: 3.79s
# Epoch 426 | train MAE: 0.016317 | val MAE: 0.021567 | time: 3.81s
# Epoch 427 | train MAE: 0.016709 | val MAE: 0.020496 | time: 3.85s
# Epoch 428 | train MAE: 0.016658 | val MAE: 0.019360 | time: 3.81s
# Epoch 429 | train MAE: 0.016821 | val MAE: 0.018895 | time: 3.87s
# 😴 Cooling GPU: sleeping 10s after epoch 429
# Epoch 430 | train MAE: 0.016327 | val MAE: 0.021820 | time: 3.81s
# Epoch 431 | train MAE: 0.016316 | val MAE: 0.016849 | time: 3.79s
# Epoch 432 | train MAE: 0.016357 | val MAE: 0.019586 | time: 3.83s
# Epoch 433 | train MAE: 0.016083 | val MAE: 0.019101 | time: 3.86s
# Epoch 434 | train MAE: 0.016276 | val MAE: 0.016133 | time: 3.77s
# 😴 Cooling GPU: sleeping 10s after epoch 434
# Epoch 435 | train MAE: 0.016408 | val MAE: 0.017295 | time: 3.86s
# Epoch 436 | train MAE: 0.016334 | val MAE: 0.020228 | time: 3.87s
# Epoch 437 | train MAE: 0.016275 | val MAE: 0.017608 | time: 3.87s
# Epoch 438 | train MAE: 0.016313 | val MAE: 0.021526 | time: 3.82s
# Epoch 439 | train MAE: 0.015971 | val MAE: 0.016344 | time: 3.87s
# 😴 Cooling GPU: sleeping 10s after epoch 439
# Epoch 440 | train MAE: 0.016009 | val MAE: 0.019002 | time: 3.86s
# Epoch 441 | train MAE: 0.016306 | val MAE: 0.017091 | time: 3.83s
# Epoch 442 | train MAE: 0.015868 | val MAE: 0.016779 | time: 3.81s
# Epoch 443 | train MAE: 0.016273 | val MAE: 0.017733 | time: 3.82s
# Epoch 444 | train MAE: 0.016355 | val MAE: 0.021731 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 444
# Epoch 445 | train MAE: 0.016307 | val MAE: 0.018147 | time: 3.82s
# Epoch 446 | train MAE: 0.016029 | val MAE: 0.020984 | time: 3.86s
# Epoch 447 | train MAE: 0.016312 | val MAE: 0.018467 | time: 3.80s
# Epoch 448 | train MAE: 0.016157 | val MAE: 0.018756 | time: 3.84s
# Epoch 449 | train MAE: 0.016156 | val MAE: 0.019618 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 449
# Epoch 450 | train MAE: 0.016121 | val MAE: 0.019404 | time: 3.85s
# Epoch 451 | train MAE: 0.016574 | val MAE: 0.020717 | time: 3.81s
# Epoch 452 | train MAE: 0.016072 | val MAE: 0.016039 | time: 3.80s
# Epoch 453 | train MAE: 0.016212 | val MAE: 0.019236 | time: 3.82s
# Epoch 454 | train MAE: 0.016449 | val MAE: 0.019437 | time: 3.86s
# 😴 Cooling GPU: sleeping 10s after epoch 454
# Epoch 455 | train MAE: 0.016229 | val MAE: 0.019049 | time: 3.82s
# Epoch 456 | train MAE: 0.016003 | val MAE: 0.020447 | time: 3.88s
# Epoch 457 | train MAE: 0.016083 | val MAE: 0.017915 | time: 3.83s
# Epoch 458 | train MAE: 0.015959 | val MAE: 0.020402 | time: 3.82s
# Epoch 459 | train MAE: 0.015878 | val MAE: 0.018704 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 459
# Epoch 460 | train MAE: 0.015827 | val MAE: 0.019134 | time: 3.80s
# Epoch 461 | train MAE: 0.015999 | val MAE: 0.021068 | time: 3.80s
# Epoch 462 | train MAE: 0.016408 | val MAE: 0.017720 | time: 3.79s
# Epoch 463 | train MAE: 0.016500 | val MAE: 0.015539 | time: 3.80s
# Epoch 464 | train MAE: 0.016048 | val MAE: 0.019059 | time: 3.77s
# 😴 Cooling GPU: sleeping 10s after epoch 464
# Epoch 465 | train MAE: 0.015881 | val MAE: 0.024296 | time: 3.83s
# Epoch 466 | train MAE: 0.016139 | val MAE: 0.016647 | time: 3.86s
# Epoch 467 | train MAE: 0.015958 | val MAE: 0.014102 | time: 3.83s
# Epoch 468 | train MAE: 0.016036 | val MAE: 0.022664 | time: 3.83s
# Epoch 469 | train MAE: 0.016113 | val MAE: 0.018683 | time: 3.77s
# 😴 Cooling GPU: sleeping 10s after epoch 469
# Epoch 470 | train MAE: 0.016080 | val MAE: 0.015997 | time: 3.77s
# Epoch 471 | train MAE: 0.016210 | val MAE: 0.021599 | time: 3.79s
# Epoch 472 | train MAE: 0.015705 | val MAE: 0.016144 | time: 3.80s
# Epoch 473 | train MAE: 0.016459 | val MAE: 0.020293 | time: 3.73s
# Epoch 474 | train MAE: 0.015917 | val MAE: 0.020283 | time: 3.78s
# 😴 Cooling GPU: sleeping 10s after epoch 474
# Epoch 475 | train MAE: 0.016170 | val MAE: 0.016087 | time: 3.80s
# Epoch 476 | train MAE: 0.015875 | val MAE: 0.017123 | time: 3.88s
# Epoch 477 | train MAE: 0.015969 | val MAE: 0.017991 | time: 3.80s
# Epoch 478 | train MAE: 0.015571 | val MAE: 0.019265 | time: 3.82s
# Epoch 479 | train MAE: 0.016011 | val MAE: 0.017890 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 479
# Epoch 480 | train MAE: 0.015971 | val MAE: 0.019233 | time: 3.80s
# Epoch 481 | train MAE: 0.015934 | val MAE: 0.018718 | time: 3.84s
# Epoch 482 | train MAE: 0.016186 | val MAE: 0.021738 | time: 3.81s
# Epoch 483 | train MAE: 0.015813 | val MAE: 0.018570 | time: 3.75s
# Epoch 484 | train MAE: 0.016112 | val MAE: 0.022212 | time: 3.74s
# 😴 Cooling GPU: sleeping 10s after epoch 484
# Epoch 485 | train MAE: 0.015684 | val MAE: 0.019162 | time: 3.81s
# Epoch 486 | train MAE: 0.015483 | val MAE: 0.017164 | time: 3.83s
# Epoch 487 | train MAE: 0.015636 | val MAE: 0.016425 | time: 3.82s
# Epoch 488 | train MAE: 0.015598 | val MAE: 0.020747 | time: 3.78s
# Epoch 489 | train MAE: 0.015491 | val MAE: 0.016512 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 489
# Epoch 490 | train MAE: 0.015746 | val MAE: 0.020951 | time: 3.82s
# Epoch 491 | train MAE: 0.016241 | val MAE: 0.017713 | time: 3.95s
# Epoch 492 | train MAE: 0.015681 | val MAE: 0.016511 | time: 3.86s
# Epoch 493 | train MAE: 0.015615 | val MAE: 0.020680 | time: 3.81s
# Epoch 494 | train MAE: 0.015897 | val MAE: 0.019414 | time: 3.80s
# 😴 Cooling GPU: sleeping 10s after epoch 494
# Epoch 495 | train MAE: 0.015739 | val MAE: 0.018981 | time: 3.77s
# Epoch 496 | train MAE: 0.015845 | val MAE: 0.016784 | time: 3.83s
# Epoch 497 | train MAE: 0.015826 | val MAE: 0.022228 | time: 3.81s
# Epoch 498 | train MAE: 0.016309 | val MAE: 0.021034 | time: 3.83s
# Epoch 499 | train MAE: 0.015486 | val MAE: 0.019770 | time: 3.85s
# 😴 Cooling GPU: sleeping 10s after epoch 499
# Epoch 500 | train MAE: 0.015511 | val MAE: 0.016925 | time: 3.86s
# Epoch 501 | train MAE: 0.015812 | val MAE: 0.016644 | time: 3.82s
# Epoch 502 | train MAE: 0.015399 | val MAE: 0.017369 | time: 3.85s
# Epoch 503 | train MAE: 0.015664 | val MAE: 0.016492 | time: 3.83s
# Epoch 504 | train MAE: 0.015653 | val MAE: 0.018923 | time: 3.87s
# 😴 Cooling GPU: sleeping 10s after epoch 504
# Epoch 505 | train MAE: 0.015628 | val MAE: 0.018267 | time: 3.84s
# Epoch 506 | train MAE: 0.016011 | val MAE: 0.019504 | time: 3.87s
# Epoch 507 | train MAE: 0.015685 | val MAE: 0.016986 | time: 3.83s
# Epoch 508 | train MAE: 0.015964 | val MAE: 0.017698 | time: 3.79s
# Epoch 509 | train MAE: 0.015521 | val MAE: 0.017547 | time: 3.88s
# 😴 Cooling GPU: sleeping 10s after epoch 509
# Epoch 510 | train MAE: 0.015616 | val MAE: 0.022347 | time: 3.82s
# Epoch 511 | train MAE: 0.015967 | val MAE: 0.018524 | time: 3.82s
# Epoch 512 | train MAE: 0.015573 | val MAE: 0.017980 | time: 3.83s
# Epoch 513 | train MAE: 0.015748 | val MAE: 0.022022 | time: 3.82s
# Epoch 514 | train MAE: 0.015555 | val MAE: 0.020353 | time: 3.87s
# 😴 Cooling GPU: sleeping 10s after epoch 514
# Epoch 515 | train MAE: 0.015995 | val MAE: 0.019522 | time: 3.86s
# Epoch 516 | train MAE: 0.015972 | val MAE: 0.019809 | time: 3.87s
# Epoch 517 | train MAE: 0.015090 | val MAE: 0.017976 | time: 3.86s
# Epoch 518 | train MAE: 0.015442 | val MAE: 0.022491 | time: 3.82s
# Epoch 519 | train MAE: 0.015754 | val MAE: 0.020768 | time: 3.91s
# 😴 Cooling GPU: sleeping 10s after epoch 519
# Epoch 520 | train MAE: 0.015844 | val MAE: 0.017238 | time: 3.81s
# Epoch 521 | train MAE: 0.015586 | val MAE: 0.020309 | time: 3.79s
# Epoch 522 | train MAE: 0.015627 | val MAE: 0.018909 | time: 3.82s
# Epoch 523 | train MAE: 0.015088 | val MAE: 0.017940 | time: 3.81s
# Epoch 524 | train MAE: 0.015121 | val MAE: 0.017408 | time: 3.85s
# 😴 Cooling GPU: sleeping 10s after epoch 524
# Epoch 525 | train MAE: 0.015720 | val MAE: 0.022403 | time: 3.86s
# Epoch 526 | train MAE: 0.015146 | val MAE: 0.020603 | time: 3.84s
# Epoch 527 | train MAE: 0.015885 | val MAE: 0.016805 | time: 3.79s
# Epoch 528 | train MAE: 0.015369 | val MAE: 0.018538 | time: 3.81s
# Epoch 529 | train MAE: 0.015282 | val MAE: 0.019516 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 529
# Epoch 530 | train MAE: 0.015559 | val MAE: 0.020058 | time: 3.82s
# Epoch 531 | train MAE: 0.015344 | val MAE: 0.017323 | time: 3.86s
# Epoch 532 | train MAE: 0.015332 | val MAE: 0.015425 | time: 3.79s
# Epoch 533 | train MAE: 0.015443 | val MAE: 0.016626 | time: 3.85s
# Epoch 534 | train MAE: 0.015346 | val MAE: 0.020611 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 534
# Epoch 535 | train MAE: 0.015280 | val MAE: 0.017042 | time: 3.80s
# Epoch 536 | train MAE: 0.015818 | val MAE: 0.016851 | time: 3.93s
# Epoch 537 | train MAE: 0.015436 | val MAE: 0.016195 | time: 3.84s
# Epoch 538 | train MAE: 0.015596 | val MAE: 0.016616 | time: 3.85s
# Epoch 539 | train MAE: 0.015220 | val MAE: 0.018042 | time: 3.79s
# 😴 Cooling GPU: sleeping 10s after epoch 539
# Epoch 540 | train MAE: 0.015474 | val MAE: 0.018056 | time: 3.81s
# Epoch 541 | train MAE: 0.015493 | val MAE: 0.019575 | time: 3.78s
# Epoch 542 | train MAE: 0.015420 | val MAE: 0.018109 | time: 3.82s
# Epoch 543 | train MAE: 0.015932 | val MAE: 0.021477 | time: 3.74s
# Epoch 544 | train MAE: 0.015598 | val MAE: 0.019497 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 544
# Epoch 545 | train MAE: 0.015297 | val MAE: 0.017498 | time: 3.86s
# Epoch 546 | train MAE: 0.015581 | val MAE: 0.017105 | time: 3.82s
# Epoch 547 | train MAE: 0.015354 | val MAE: 0.020542 | time: 3.83s
# Epoch 548 | train MAE: 0.015334 | val MAE: 0.018293 | time: 3.82s
# Epoch 549 | train MAE: 0.015288 | val MAE: 0.015950 | time: 3.85s
# 😴 Cooling GPU: sleeping 10s after epoch 549
# Epoch 550 | train MAE: 0.015722 | val MAE: 0.016887 | time: 3.81s
# Epoch 551 | train MAE: 0.015444 | val MAE: 0.018293 | time: 3.82s
# Epoch 552 | train MAE: 0.015374 | val MAE: 0.016508 | time: 3.85s
# Epoch 553 | train MAE: 0.015497 | val MAE: 0.019978 | time: 3.89s
# Epoch 554 | train MAE: 0.015565 | val MAE: 0.021342 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 554
# Epoch 555 | train MAE: 0.015315 | val MAE: 0.016752 | time: 3.82s
# Epoch 556 | train MAE: 0.015778 | val MAE: 0.016252 | time: 3.81s
# Epoch 557 | train MAE: 0.014959 | val MAE: 0.021765 | time: 3.85s
# Epoch 558 | train MAE: 0.015208 | val MAE: 0.015917 | time: 3.83s
# Epoch 559 | train MAE: 0.015370 | val MAE: 0.021050 | time: 3.85s
# 😴 Cooling GPU: sleeping 10s after epoch 559
# Epoch 560 | train MAE: 0.015373 | val MAE: 0.022138 | time: 3.84s
# Epoch 561 | train MAE: 0.015160 | val MAE: 0.018753 | time: 3.85s
# Epoch 562 | train MAE: 0.015287 | val MAE: 0.019389 | time: 3.80s
# Epoch 563 | train MAE: 0.015236 | val MAE: 0.020457 | time: 3.86s
# Epoch 564 | train MAE: 0.015813 | val MAE: 0.017565 | time: 3.91s
# 😴 Cooling GPU: sleeping 10s after epoch 564
# Epoch 565 | train MAE: 0.015629 | val MAE: 0.019087 | time: 3.78s
# Epoch 566 | train MAE: 0.015254 | val MAE: 0.015553 | time: 3.77s
# Epoch 567 | train MAE: 0.015327 | val MAE: 0.020984 | time: 3.83s
# Epoch 568 | train MAE: 0.014716 | val MAE: 0.014787 | time: 3.84s
# Epoch 569 | train MAE: 0.015142 | val MAE: 0.019581 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 569
# Epoch 570 | train MAE: 0.014893 | val MAE: 0.017751 | time: 3.80s
# Epoch 571 | train MAE: 0.015320 | val MAE: 0.015870 | time: 3.81s
# Epoch 572 | train MAE: 0.014896 | val MAE: 0.016448 | time: 3.83s
# Epoch 573 | train MAE: 0.015445 | val MAE: 0.018334 | time: 3.86s
# Epoch 574 | train MAE: 0.014937 | val MAE: 0.018271 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 574
# Epoch 575 | train MAE: 0.014919 | val MAE: 0.016744 | time: 3.77s
# Epoch 576 | train MAE: 0.014971 | val MAE: 0.018976 | time: 3.87s
# Epoch 577 | train MAE: 0.015203 | val MAE: 0.016003 | time: 3.88s
# Epoch 578 | train MAE: 0.015265 | val MAE: 0.020041 | time: 3.84s
# Epoch 579 | train MAE: 0.015170 | val MAE: 0.016113 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 579
# Epoch 580 | train MAE: 0.015502 | val MAE: 0.016402 | time: 3.87s
# Epoch 581 | train MAE: 0.015138 | val MAE: 0.019374 | time: 3.83s
# Epoch 582 | train MAE: 0.015002 | val MAE: 0.019560 | time: 3.82s
# Epoch 583 | train MAE: 0.015083 | val MAE: 0.017073 | time: 3.89s
# Epoch 584 | train MAE: 0.015419 | val MAE: 0.016655 | time: 3.85s
# 😴 Cooling GPU: sleeping 10s after epoch 584
# Epoch 585 | train MAE: 0.014935 | val MAE: 0.019345 | time: 3.84s
# Epoch 586 | train MAE: 0.014953 | val MAE: 0.019586 | time: 3.87s
# Epoch 587 | train MAE: 0.015128 | val MAE: 0.014839 | time: 3.81s
# Epoch 588 | train MAE: 0.015227 | val MAE: 0.020845 | time: 3.82s
# Epoch 589 | train MAE: 0.015235 | val MAE: 0.016981 | time: 3.82s
# 😴 Cooling GPU: sleeping 10s after epoch 589
# Epoch 590 | train MAE: 0.014992 | val MAE: 0.017748 | time: 3.86s
# Epoch 591 | train MAE: 0.015758 | val MAE: 0.020456 | time: 3.82s
# Epoch 592 | train MAE: 0.014937 | val MAE: 0.015260 | time: 3.83s
# Epoch 593 | train MAE: 0.015225 | val MAE: 0.019533 | time: 3.78s
# Epoch 594 | train MAE: 0.015067 | val MAE: 0.019395 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 594
# Epoch 595 | train MAE: 0.015167 | val MAE: 0.015965 | time: 3.77s
# Epoch 596 | train MAE: 0.014698 | val MAE: 0.018496 | time: 3.76s
# Epoch 597 | train MAE: 0.015251 | val MAE: 0.016796 | time: 3.86s
# Epoch 598 | train MAE: 0.014858 | val MAE: 0.016888 | time: 3.89s
# Epoch 599 | train MAE: 0.015021 | val MAE: 0.014281 | time: 3.76s
# 😴 Cooling GPU: sleeping 10s after epoch 599
# Epoch 600 | train MAE: 0.015092 | val MAE: 0.015272 | time: 3.77s
# Epoch 601 | train MAE: 0.014697 | val MAE: 0.019658 | time: 3.84s
# Epoch 602 | train MAE: 0.014794 | val MAE: 0.021019 | time: 3.89s
# Epoch 603 | train MAE: 0.015158 | val MAE: 0.016582 | time: 3.82s
# Epoch 604 | train MAE: 0.015076 | val MAE: 0.019430 | time: 3.87s
# 😴 Cooling GPU: sleeping 10s after epoch 604
# Epoch 605 | train MAE: 0.014901 | val MAE: 0.017899 | time: 3.81s
# Epoch 606 | train MAE: 0.015019 | val MAE: 0.019275 | time: 3.83s
# Epoch 607 | train MAE: 0.015157 | val MAE: 0.018577 | time: 3.76s
# Epoch 608 | train MAE: 0.014847 | val MAE: 0.016058 | time: 3.80s
# Epoch 609 | train MAE: 0.015000 | val MAE: 0.018593 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 609
# Epoch 610 | train MAE: 0.015019 | val MAE: 0.019669 | time: 3.81s
# Epoch 611 | train MAE: 0.014434 | val MAE: 0.015195 | time: 3.85s
# Epoch 612 | train MAE: 0.014439 | val MAE: 0.018896 | time: 3.84s
# Epoch 613 | train MAE: 0.014901 | val MAE: 0.015867 | time: 3.82s
# Epoch 614 | train MAE: 0.015051 | val MAE: 0.019249 | time: 3.82s
# 😴 Cooling GPU: sleeping 10s after epoch 614
# Epoch 615 | train MAE: 0.015147 | val MAE: 0.018266 | time: 3.86s
# Epoch 616 | train MAE: 0.014801 | val MAE: 0.017654 | time: 3.80s
# Epoch 617 | train MAE: 0.014694 | val MAE: 0.019433 | time: 3.82s
# Epoch 618 | train MAE: 0.015016 | val MAE: 0.016189 | time: 3.76s
# Epoch 619 | train MAE: 0.015166 | val MAE: 0.020005 | time: 3.79s
# 😴 Cooling GPU: sleeping 10s after epoch 619
# Epoch 620 | train MAE: 0.014934 | val MAE: 0.018022 | time: 3.78s
# Epoch 621 | train MAE: 0.014639 | val MAE: 0.017015 | time: 3.89s
# Epoch 622 | train MAE: 0.014535 | val MAE: 0.018371 | time: 3.85s
# Epoch 623 | train MAE: 0.014834 | val MAE: 0.019014 | time: 3.79s
# Epoch 624 | train MAE: 0.014894 | val MAE: 0.016940 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 624
# Epoch 625 | train MAE: 0.014814 | val MAE: 0.018151 | time: 3.80s
# Epoch 626 | train MAE: 0.015105 | val MAE: 0.020169 | time: 3.79s
# Epoch 627 | train MAE: 0.014860 | val MAE: 0.017135 | time: 3.83s
# Epoch 628 | train MAE: 0.014461 | val MAE: 0.018582 | time: 3.83s
# Epoch 629 | train MAE: 0.014767 | val MAE: 0.019183 | time: 3.82s
# 😴 Cooling GPU: sleeping 10s after epoch 629
# Epoch 630 | train MAE: 0.015139 | val MAE: 0.016780 | time: 3.87s
# Epoch 631 | train MAE: 0.014619 | val MAE: 0.018147 | time: 3.78s
# Epoch 632 | train MAE: 0.014951 | val MAE: 0.017735 | time: 3.83s
# Epoch 633 | train MAE: 0.014654 | val MAE: 0.016770 | time: 3.81s
# Epoch 634 | train MAE: 0.014804 | val MAE: 0.021739 | time: 3.80s
# 😴 Cooling GPU: sleeping 10s after epoch 634
# Epoch 635 | train MAE: 0.015025 | val MAE: 0.020058 | time: 3.80s
# Epoch 636 | train MAE: 0.014693 | val MAE: 0.019067 | time: 3.86s
# Epoch 637 | train MAE: 0.014841 | val MAE: 0.017121 | time: 3.84s
# Epoch 638 | train MAE: 0.014810 | val MAE: 0.017688 | time: 3.82s
# Epoch 639 | train MAE: 0.014895 | val MAE: 0.020049 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 639
# Epoch 640 | train MAE: 0.014992 | val MAE: 0.020100 | time: 3.91s
# Epoch 641 | train MAE: 0.014544 | val MAE: 0.020654 | time: 3.79s
# Epoch 642 | train MAE: 0.014908 | val MAE: 0.018181 | time: 3.85s
# Epoch 643 | train MAE: 0.014724 | val MAE: 0.016026 | time: 3.84s
# ...
# Epoch 1792 | train MAE: 0.011539 | val MAE: 0.013600 | time: 3.80s
# Epoch 1793 | train MAE: 0.011542 | val MAE: 0.014639 | time: 3.83s
# Epoch 1794 | train MAE: 0.011434 | val MAE: 0.017528 | time: 3.87s
# 😴 Cooling GPU: sleeping 10s after epoch 1794
# Epoch 1795 | train MAE: 0.011322 | val MAE: 0.018026 | time: 3.79s
# Epoch 1796 | train MAE: 0.011495 | val MAE: 0.016094 | time: 3.83s
# Epoch 1797 | train MAE: 0.011523 | val MAE: 0.015555 | time: 3.80s
# Epoch 1798 | train MAE: 0.011488 | val MAE: 0.015122 | time: 3.87s
# Epoch 1799 | train MAE: 0.011646 | val MAE: 0.016764 | time: 3.80s
# 😴 Cooling GPU: sleeping 10s after epoch 1799
# Epoch 1800 | train MAE: 0.011295 | val MAE: 0.014671 | time: 3.82s
# Epoch 1801 | train MAE: 0.011320 | val MAE: 0.015029 | time: 3.84s
# Epoch 1802 | train MAE: 0.011477 | val MAE: 0.014767 | time: 3.81s
# Epoch 1803 | train MAE: 0.011491 | val MAE: 0.018372 | time: 3.84s
# Epoch 1804 | train MAE: 0.011537 | val MAE: 0.016157 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 1804
# Epoch 1805 | train MAE: 0.011561 | val MAE: 0.014716 | time: 3.83s
# Epoch 1806 | train MAE: 0.011251 | val MAE: 0.016558 | time: 3.87s
# Epoch 1807 | train MAE: 0.011555 | val MAE: 0.016131 | time: 3.80s
# Epoch 1808 | train MAE: 0.011280 | val MAE: 0.013881 | time: 3.81s
# Epoch 1809 | train MAE: 0.011431 | val MAE: 0.016955 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 1809
# Epoch 1810 | train MAE: 0.011569 | val MAE: 0.016782 | time: 3.80s
# Epoch 1811 | train MAE: 0.011486 | val MAE: 0.016070 | time: 3.81s
# Epoch 1812 | train MAE: 0.011324 | val MAE: 0.016265 | time: 3.78s
# Epoch 1813 | train MAE: 0.011350 | val MAE: 0.015177 | time: 3.81s
# Epoch 1814 | train MAE: 0.011239 | val MAE: 0.014219 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 1814
# Epoch 1815 | train MAE: 0.011434 | val MAE: 0.016751 | time: 3.85s
# Epoch 1816 | train MAE: 0.011312 | val MAE: 0.016904 | time: 3.79s
# Epoch 1817 | train MAE: 0.011492 | val MAE: 0.013933 | time: 3.79s
# Epoch 1818 | train MAE: 0.011430 | val MAE: 0.015250 | time: 3.78s
# Epoch 1819 | train MAE: 0.011480 | val MAE: 0.016311 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 1819
# Epoch 1820 | train MAE: 0.011517 | val MAE: 0.017797 | time: 3.87s
# Epoch 1821 | train MAE: 0.011368 | val MAE: 0.014156 | time: 3.81s
# Epoch 1822 | train MAE: 0.011327 | val MAE: 0.016844 | time: 3.81s
# Epoch 1823 | train MAE: 0.011638 | val MAE: 0.012995 | time: 3.81s
# Epoch 1824 | train MAE: 0.011228 | val MAE: 0.015734 | time: 3.89s
# 😴 Cooling GPU: sleeping 10s after epoch 1824
# Epoch 1825 | train MAE: 0.011083 | val MAE: 0.018259 | time: 3.92s
# Epoch 1826 | train MAE: 0.011349 | val MAE: 0.018563 | time: 3.71s
# Epoch 1827 | train MAE: 0.011399 | val MAE: 0.013866 | time: 3.86s
# Epoch 1828 | train MAE: 0.011320 | val MAE: 0.014464 | time: 3.87s
# Epoch 1829 | train MAE: 0.011530 | val MAE: 0.015977 | time: 3.85s
# 😴 Cooling GPU: sleeping 10s after epoch 1829
# Epoch 1830 | train MAE: 0.011415 | val MAE: 0.015938 | time: 3.80s
# Epoch 1831 | train MAE: 0.011487 | val MAE: 0.015799 | time: 3.79s
# Epoch 1832 | train MAE: 0.011204 | val MAE: 0.011319 | time: 3.93s
# Epoch 1833 | train MAE: 0.011298 | val MAE: 0.017574 | time: 3.81s
# Epoch 1834 | train MAE: 0.011348 | val MAE: 0.016267 | time: 3.80s
# 😴 Cooling GPU: sleeping 10s after epoch 1834
# Epoch 1835 | train MAE: 0.011454 | val MAE: 0.013893 | time: 3.85s
# Epoch 1836 | train MAE: 0.011131 | val MAE: 0.015903 | time: 3.87s
# Epoch 1837 | train MAE: 0.011497 | val MAE: 0.015135 | time: 3.81s
# Epoch 1838 | train MAE: 0.011258 | val MAE: 0.014033 | time: 3.87s
# Epoch 1839 | train MAE: 0.011398 | val MAE: 0.014307 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 1839
# Epoch 1840 | train MAE: 0.011129 | val MAE: 0.016286 | time: 3.86s
# Epoch 1841 | train MAE: 0.011424 | val MAE: 0.015580 | time: 3.85s
# Epoch 1842 | train MAE: 0.011322 | val MAE: 0.015949 | time: 3.83s
# Epoch 1843 | train MAE: 0.011247 | val MAE: 0.016655 | time: 3.84s
# Epoch 1844 | train MAE: 0.011387 | val MAE: 0.014540 | time: 3.79s
# 😴 Cooling GPU: sleeping 10s after epoch 1844
# Epoch 1845 | train MAE: 0.011368 | val MAE: 0.015426 | time: 3.82s
# Epoch 1846 | train MAE: 0.011195 | val MAE: 0.014239 | time: 3.79s
# Epoch 1847 | train MAE: 0.011190 | val MAE: 0.014368 | time: 3.83s
# Epoch 1848 | train MAE: 0.011419 | val MAE: 0.016729 | time: 3.77s
# Epoch 1849 | train MAE: 0.011313 | val MAE: 0.015059 | time: 3.88s
# 😴 Cooling GPU: sleeping 10s after epoch 1849
# Epoch 1850 | train MAE: 0.011283 | val MAE: 0.015511 | time: 3.93s
# Epoch 1851 | train MAE: 0.011359 | val MAE: 0.013420 | time: 3.88s
# Epoch 1852 | train MAE: 0.011367 | val MAE: 0.016161 | time: 3.84s
# Epoch 1853 | train MAE: 0.011429 | val MAE: 0.016710 | time: 3.81s
# Epoch 1854 | train MAE: 0.011134 | val MAE: 0.012625 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 1854
# Epoch 1855 | train MAE: 0.011274 | val MAE: 0.013785 | time: 3.84s
# Epoch 1856 | train MAE: 0.011317 | val MAE: 0.016478 | time: 3.80s
# Epoch 1857 | train MAE: 0.011245 | val MAE: 0.015192 | time: 3.85s
# Epoch 1858 | train MAE: 0.011416 | val MAE: 0.014159 | time: 3.86s
# Epoch 1859 | train MAE: 0.011266 | val MAE: 0.014527 | time: 3.82s
# 😴 Cooling GPU: sleeping 10s after epoch 1859
# Epoch 1860 | train MAE: 0.011305 | val MAE: 0.016302 | time: 3.80s
# Epoch 1861 | train MAE: 0.011241 | val MAE: 0.016083 | time: 3.90s
# Epoch 1862 | train MAE: 0.011257 | val MAE: 0.013768 | time: 3.83s
# Epoch 1863 | train MAE: 0.011263 | val MAE: 0.014746 | time: 3.79s
# Epoch 1864 | train MAE: 0.011392 | val MAE: 0.015777 | time: 3.82s
# 😴 Cooling GPU: sleeping 10s after epoch 1864
# Epoch 1865 | train MAE: 0.011392 | val MAE: 0.014180 | time: 3.83s
# Epoch 1866 | train MAE: 0.011357 | val MAE: 0.016933 | time: 3.85s
# Epoch 1867 | train MAE: 0.011081 | val MAE: 0.015595 | time: 3.79s
# Epoch 1868 | train MAE: 0.011421 | val MAE: 0.014870 | time: 3.85s
# Epoch 1869 | train MAE: 0.011102 | val MAE: 0.013427 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 1869
# Epoch 1870 | train MAE: 0.011441 | val MAE: 0.014323 | time: 3.81s
# Epoch 1871 | train MAE: 0.011171 | val MAE: 0.014567 | time: 3.80s
# Epoch 1872 | train MAE: 0.011270 | val MAE: 0.014608 | time: 3.76s
# Epoch 1873 | train MAE: 0.011156 | val MAE: 0.016288 | time: 3.86s
# Epoch 1874 | train MAE: 0.011378 | val MAE: 0.017662 | time: 3.77s
# 😴 Cooling GPU: sleeping 10s after epoch 1874
# Epoch 1875 | train MAE: 0.011566 | val MAE: 0.014961 | time: 3.84s
# Epoch 1876 | train MAE: 0.011056 | val MAE: 0.015125 | time: 3.82s
# Epoch 1877 | train MAE: 0.011051 | val MAE: 0.016222 | time: 3.86s
# Epoch 1878 | train MAE: 0.011334 | val MAE: 0.015214 | time: 3.82s
# Epoch 1879 | train MAE: 0.011225 | val MAE: 0.015898 | time: 3.83s
# 😴 Cooling GPU: sleeping 10s after epoch 1879
# Epoch 1880 | train MAE: 0.011206 | val MAE: 0.014387 | time: 3.82s
# Epoch 1881 | train MAE: 0.011316 | val MAE: 0.016858 | time: 3.79s
# Epoch 1882 | train MAE: 0.011471 | val MAE: 0.014393 | time: 3.81s
# Epoch 1883 | train MAE: 0.011257 | val MAE: 0.016211 | time: 3.86s
# Epoch 1884 | train MAE: 0.011188 | val MAE: 0.015739 | time: 3.87s
# 😴 Cooling GPU: sleeping 10s after epoch 1884
# Epoch 1885 | train MAE: 0.011309 | val MAE: 0.015449 | time: 3.87s
# Epoch 1886 | train MAE: 0.011199 | val MAE: 0.013511 | time: 3.76s
# Epoch 1887 | train MAE: 0.011138 | val MAE: 0.017792 | time: 3.76s
# Epoch 1888 | train MAE: 0.011431 | val MAE: 0.014209 | time: 3.88s
# Epoch 1889 | train MAE: 0.011469 | val MAE: 0.014966 | time: 3.85s
# 😴 Cooling GPU: sleeping 10s after epoch 1889
# Epoch 1890 | train MAE: 0.011409 | val MAE: 0.014133 | time: 3.81s
# Epoch 1891 | train MAE: 0.011041 | val MAE: 0.017312 | time: 3.87s
# Epoch 1892 | train MAE: 0.011285 | val MAE: 0.015366 | time: 3.79s
# Epoch 1893 | train MAE: 0.011142 | val MAE: 0.014867 | time: 3.78s
# Epoch 1894 | train MAE: 0.011003 | val MAE: 0.018249 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 1894
# Epoch 1895 | train MAE: 0.011330 | val MAE: 0.014244 | time: 3.89s
# Epoch 1896 | train MAE: 0.011372 | val MAE: 0.015147 | time: 3.84s
# Epoch 1897 | train MAE: 0.011238 | val MAE: 0.013124 | time: 3.85s
# Epoch 1898 | train MAE: 0.011376 | val MAE: 0.017044 | time: 3.86s
# Epoch 1899 | train MAE: 0.011355 | val MAE: 0.014060 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 1899
# Epoch 1900 | train MAE: 0.011133 | val MAE: 0.016042 | time: 3.85s
# Epoch 1901 | train MAE: 0.011045 | val MAE: 0.013283 | time: 3.86s
# Epoch 1902 | train MAE: 0.011250 | val MAE: 0.017847 | time: 3.79s
# Epoch 1903 | train MAE: 0.011372 | val MAE: 0.015602 | time: 3.82s
# Epoch 1904 | train MAE: 0.011105 | val MAE: 0.015444 | time: 3.79s
# 😴 Cooling GPU: sleeping 10s after epoch 1904
# Epoch 1905 | train MAE: 0.011377 | val MAE: 0.015039 | time: 3.77s
# Epoch 1906 | train MAE: 0.011214 | val MAE: 0.014201 | time: 3.83s
# Epoch 1907 | train MAE: 0.011308 | val MAE: 0.014623 | time: 3.82s
# Epoch 1908 | train MAE: 0.011343 | val MAE: 0.016474 | time: 3.85s
# Epoch 1909 | train MAE: 0.011202 | val MAE: 0.016824 | time: 3.81s
# 😴 Cooling GPU: sleeping 10s after epoch 1909
# Epoch 1910 | train MAE: 0.011154 | val MAE: 0.017073 | time: 3.86s
# Epoch 1911 | train MAE: 0.011309 | val MAE: 0.014967 | time: 3.83s
# Epoch 1912 | train MAE: 0.011184 | val MAE: 0.016574 | time: 3.79s
# Epoch 1913 | train MAE: 0.011266 | val MAE: 0.015263 | time: 3.85s
# Epoch 1914 | train MAE: 0.011283 | val MAE: 0.016391 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 1914
# Epoch 1915 | train MAE: 0.011271 | val MAE: 0.016570 | time: 3.83s
# Epoch 1916 | train MAE: 0.011050 | val MAE: 0.015060 | time: 3.86s
# Epoch 1917 | train MAE: 0.011162 | val MAE: 0.016017 | time: 3.83s
# Epoch 1918 | train MAE: 0.011056 | val MAE: 0.015914 | time: 3.78s
# Epoch 1919 | train MAE: 0.011200 | val MAE: 0.017263 | time: 3.86s
# 😴 Cooling GPU: sleeping 10s after epoch 1919
# Epoch 1920 | train MAE: 0.011355 | val MAE: 0.015379 | time: 3.82s
# Epoch 1921 | train MAE: 0.011426 | val MAE: 0.013714 | time: 3.80s
# Epoch 1922 | train MAE: 0.011115 | val MAE: 0.016575 | time: 3.84s
# Epoch 1923 | train MAE: 0.011113 | val MAE: 0.016421 | time: 3.88s
# Epoch 1924 | train MAE: 0.011188 | val MAE: 0.017029 | time: 3.86s
# 😴 Cooling GPU: sleeping 10s after epoch 1924
# Epoch 1925 | train MAE: 0.011370 | val MAE: 0.013122 | time: 3.84s
# Epoch 1926 | train MAE: 0.011188 | val MAE: 0.015107 | time: 3.81s
# Epoch 1927 | train MAE: 0.011226 | val MAE: 0.015160 | time: 3.87s
# Epoch 1928 | train MAE: 0.011079 | val MAE: 0.016902 | time: 3.88s
# Epoch 1929 | train MAE: 0.011092 | val MAE: 0.015483 | time: 3.85s
# 😴 Cooling GPU: sleeping 10s after epoch 1929
# Epoch 1930 | train MAE: 0.011290 | val MAE: 0.014866 | time: 3.89s
# Epoch 1931 | train MAE: 0.011005 | val MAE: 0.015824 | time: 3.82s
# Epoch 1932 | train MAE: 0.011098 | val MAE: 0.013995 | time: 3.80s
# Epoch 1933 | train MAE: 0.011192 | val MAE: 0.016816 | time: 3.80s
# Epoch 1934 | train MAE: 0.011041 | val MAE: 0.016550 | time: 3.80s
# 😴 Cooling GPU: sleeping 10s after epoch 1934
# Epoch 1935 | train MAE: 0.011249 | val MAE: 0.017333 | time: 3.83s
# Epoch 1936 | train MAE: 0.011128 | val MAE: 0.014311 | time: 3.84s
# Epoch 1937 | train MAE: 0.011285 | val MAE: 0.014478 | time: 3.91s
# Epoch 1938 | train MAE: 0.011204 | val MAE: 0.013337 | time: 3.82s
# Epoch 1939 | train MAE: 0.010897 | val MAE: 0.014432 | time: 3.79s
# 😴 Cooling GPU: sleeping 10s after epoch 1939
# Epoch 1940 | train MAE: 0.011250 | val MAE: 0.012986 | time: 3.89s
# Epoch 1941 | train MAE: 0.011206 | val MAE: 0.016340 | time: 3.95s
# Epoch 1942 | train MAE: 0.011055 | val MAE: 0.013268 | time: 3.82s
# Epoch 1943 | train MAE: 0.011053 | val MAE: 0.016141 | time: 3.86s
# Epoch 1944 | train MAE: 0.011167 | val MAE: 0.015652 | time: 3.88s
# 😴 Cooling GPU: sleeping 10s after epoch 1944
# Epoch 1945 | train MAE: 0.011143 | val MAE: 0.013540 | time: 3.81s
# Epoch 1946 | train MAE: 0.011192 | val MAE: 0.018638 | time: 3.83s
# Epoch 1947 | train MAE: 0.011023 | val MAE: 0.013515 | time: 3.77s
# Epoch 1948 | train MAE: 0.011148 | val MAE: 0.017015 | time: 3.79s
# Epoch 1949 | train MAE: 0.010967 | val MAE: 0.015630 | time: 3.90s
# 😴 Cooling GPU: sleeping 10s after epoch 1949
# Epoch 1950 | train MAE: 0.011059 | val MAE: 0.016902 | time: 3.81s
# Epoch 1951 | train MAE: 0.010991 | val MAE: 0.014733 | time: 3.77s
# Epoch 1952 | train MAE: 0.011056 | val MAE: 0.016037 | time: 3.82s
# Epoch 1953 | train MAE: 0.011155 | val MAE: 0.013813 | time: 3.92s
# Epoch 1954 | train MAE: 0.010996 | val MAE: 0.016043 | time: 3.74s
# 😴 Cooling GPU: sleeping 10s after epoch 1954
# Epoch 1955 | train MAE: 0.011146 | val MAE: 0.015151 | time: 3.79s
# Epoch 1956 | train MAE: 0.011238 | val MAE: 0.016678 | time: 3.88s
# Epoch 1957 | train MAE: 0.011046 | val MAE: 0.016269 | time: 3.87s
# Epoch 1958 | train MAE: 0.011040 | val MAE: 0.015132 | time: 3.76s
# Epoch 1959 | train MAE: 0.011261 | val MAE: 0.014948 | time: 3.88s
# 😴 Cooling GPU: sleeping 10s after epoch 1959
# Epoch 1960 | train MAE: 0.011118 | val MAE: 0.014467 | time: 3.86s
# Epoch 1961 | train MAE: 0.011013 | val MAE: 0.014386 | time: 3.79s
# Epoch 1962 | train MAE: 0.010919 | val MAE: 0.015358 | time: 3.88s
# Epoch 1963 | train MAE: 0.011120 | val MAE: 0.016280 | time: 3.81s
# Epoch 1964 | train MAE: 0.011177 | val MAE: 0.015046 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 1964
# Epoch 1965 | train MAE: 0.011002 | val MAE: 0.015355 | time: 3.76s
# Epoch 1966 | train MAE: 0.011209 | val MAE: 0.014496 | time: 3.83s
# Epoch 1967 | train MAE: 0.011157 | val MAE: 0.016299 | time: 3.80s
# Epoch 1968 | train MAE: 0.010987 | val MAE: 0.015450 | time: 3.79s
# Epoch 1969 | train MAE: 0.010943 | val MAE: 0.016341 | time: 3.82s
# 😴 Cooling GPU: sleeping 10s after epoch 1969
# Epoch 1970 | train MAE: 0.011078 | val MAE: 0.015800 | time: 3.85s
# Epoch 1971 | train MAE: 0.011123 | val MAE: 0.015337 | time: 3.78s
# Epoch 1972 | train MAE: 0.011024 | val MAE: 0.012938 | time: 3.84s
# Epoch 1973 | train MAE: 0.011094 | val MAE: 0.014988 | time: 3.83s
# Epoch 1974 | train MAE: 0.011128 | val MAE: 0.014601 | time: 3.84s
# 😴 Cooling GPU: sleeping 10s after epoch 1974
# Epoch 1975 | train MAE: 0.011078 | val MAE: 0.015795 | time: 3.77s
# Epoch 1976 | train MAE: 0.010998 | val MAE: 0.019006 | time: 3.81s
# Epoch 1977 | train MAE: 0.011141 | val MAE: 0.016758 | time: 3.78s
# Epoch 1978 | train MAE: 0.011103 | val MAE: 0.013979 | time: 3.79s
# Epoch 1979 | train MAE: 0.011129 | val MAE: 0.014060 | time: 3.85s
# 😴 Cooling GPU: sleeping 10s after epoch 1979
# Epoch 1980 | train MAE: 0.011067 | val MAE: 0.017281 | time: 3.90s
# Epoch 1981 | train MAE: 0.011214 | val MAE: 0.015943 | time: 3.90s
# Epoch 1982 | train MAE: 0.011051 | val MAE: 0.016918 | time: 3.83s
# Epoch 1983 | train MAE: 0.011307 | val MAE: 0.015984 | time: 3.79s
# Epoch 1984 | train MAE: 0.011020 | val MAE: 0.016391 | time: 3.82s
# 😴 Cooling GPU: sleeping 10s after epoch 1984
# Epoch 1985 | train MAE: 0.011111 | val MAE: 0.015532 | time: 3.86s
# Epoch 1986 | train MAE: 0.011176 | val MAE: 0.012580 | time: 3.83s
# Epoch 1987 | train MAE: 0.011104 | val MAE: 0.014724 | time: 3.83s
# Epoch 1988 | train MAE: 0.011150 | val MAE: 0.015802 | time: 3.83s
# Epoch 1989 | train MAE: 0.010909 | val MAE: 0.016124 | time: 3.76s
# 😴 Cooling GPU: sleeping 10s after epoch 1989
# Epoch 1990 | train MAE: 0.011053 | val MAE: 0.014694 | time: 3.82s
# Epoch 1991 | train MAE: 0.011087 | val MAE: 0.015786 | time: 3.79s
# Epoch 1992 | train MAE: 0.011111 | val MAE: 0.013976 | time: 3.79s
# Epoch 1993 | train MAE: 0.010956 | val MAE: 0.015897 | time: 3.73s
# Epoch 1994 | train MAE: 0.011039 | val MAE: 0.015090 | time: 3.80s
# 😴 Cooling GPU: sleeping 10s after epoch 1994
# Epoch 1995 | train MAE: 0.011166 | val MAE: 0.014861 | time: 3.89s
# Epoch 1996 | train MAE: 0.010913 | val MAE: 0.014568 | time: 3.80s
# Epoch 1997 | train MAE: 0.010986 | val MAE: 0.017787 | time: 3.82s
# Epoch 1998 | train MAE: 0.011085 | val MAE: 0.014209 | time: 3.87s
# Epoch 1999 | train MAE: 0.010927 | val MAE: 0.017634 | time: 3.76s
# 😴 Cooling GPU: sleeping 10s after epoch 1999
# `Trainer.fit` stopped: `max_epochs=2000` reached.
# CPU times: user 1h 56min 45s, sys: 25min 8s, total: 2h 21min 53s
# Wall time: 3h 14min 20s

# %% [markdown]
# #### Save the training history

# %%
CHECKPOINT_PATH
# Out:
# '/app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/checkpoints/vit-ntok64-yscaled_take1c'

# %%
epochs, train_losses, val_losses, times = loss_cb.as_lists()

print("n_epochs:", len(epochs))
print("n_train_losses:", len(train_losses))
print("n_val_losses:", len(val_losses))
print("train_losses[-3:]:", train_losses[-3:])
print("val_losses[-3:]:", val_losses[-3:])
# Out:
# n_epochs: 2000
# n_train_losses: 2000
# n_val_losses: 2000
# train_losses[-3:]: [0.010985630564391613, 0.01108471304178238, 0.010927009396255016]
# val_losses[-3:]: [0.017787493765354156, 0.014209075830876827, 0.017633840441703796]

# %%
df = pd.DataFrame({
    "epoch": epochs,
    "train_loss": train_losses,
    "val_loss": val_losses,
})

df.to_csv(f"{CHECKPOINT_PATH}/training_history.csv", index=False)

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# 'best-epoch=1341-val_loss=0.012868.ckpt'
# 'best-epoch=1740-val_loss=0.012914.ckpt'
# 'best-epoch=1823-val_loss=0.012995.ckpt'
# 'best-epoch=1832-val_loss=0.011319.ckpt'
# 'best-epoch=1854-val_loss=0.012625.ckpt'
# 'best-epoch=1940-val_loss=0.012986.ckpt'
# 'best-epoch=1972-val_loss=0.012938.ckpt'
# 'best-epoch=1986-val_loss=0.012580.ckpt'
# 'best-epoch=747-val_loss=0.013014.ckpt'
# 'best-epoch=897-val_loss=0.012922.ckpt'
#  last.ckpt
#  training_history.csv

# %%
plt.figure(figsize=(6, 4))

plt.plot(epochs, train_losses, label="train", alpha=0.6)
plt.plot(epochs, val_losses, label="val", alpha=0.6)

plt.xlabel("epoch")
plt.ylabel("MAE")

plt.yscale("log")          # 👈 y축 로그 스케일
plt.grid(True, which="both", linestyle="--", alpha=0.6)  # 👈 grid

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluation

# %%
def get_test_predictions(model, test_loader, device):
    model.eval()

    y_true_list = []
    y_pred_list = []

    with torch.no_grad():
        for xb, yb in test_loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)

            y_hat = model(xb)          # (B, 6)

            y_true_list.append(yb.cpu().numpy())
            y_pred_list.append(y_hat.cpu().numpy())

    y_true = np.concatenate(y_true_list, axis=0)  # (N_test, 6)
    y_pred = np.concatenate(y_pred_list, axis=0)  # (N_test, 6)

    return y_true, y_pred

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# 'best-epoch=1341-val_loss=0.012868.ckpt'
# 'best-epoch=1740-val_loss=0.012914.ckpt'
# 'best-epoch=1823-val_loss=0.012995.ckpt'
# 'best-epoch=1832-val_loss=0.011319.ckpt'
# 'best-epoch=1854-val_loss=0.012625.ckpt'
# 'best-epoch=1940-val_loss=0.012986.ckpt'
# 'best-epoch=1972-val_loss=0.012938.ckpt'
# 'best-epoch=1986-val_loss=0.012580.ckpt'
# 'best-epoch=747-val_loss=0.013014.ckpt'
# 'best-epoch=897-val_loss=0.012922.ckpt'
#  last.ckpt
#  training_history.csv

# %%
best_ckpt = f"{CHECKPOINT_PATH}/best-epoch=1832-val_loss=0.011319.ckpt"

vit_model = VisionTransformerRegressor(
    img_size=64,
    patch_size=8,      # ✅ 64 tokens
    num_channels=5,
    num_outputs=6,
    embed_dim=128,     # ✅ 줄이기
    hidden_dim=256,    # ✅ 줄이기
    num_heads=4,       # ✅ 줄이기
    num_layers=4,      # ✅ 줄이기
    dropout=0.1,
)

lit_model = LitViTRegressor.load_from_checkpoint(
    checkpoint_path=best_ckpt,  # ✅ 여기서만 씀
    model=vit_model,            # ✅ 반드시 넘겨야 함
    lr=5e-4,
)

# %%
# %%time
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
y_test_true, y_test_pred = get_test_predictions(lit_model, test_loader, device)
# Out:
# CPU times: user 295 ms, sys: 293 ms, total: 588 ms
# Wall time: 529 ms

# %% [markdown]
# #### Descale y values

# %%
YL_CAP, YH_CAP
# Out:
# (0.095, 0.075)

# %%
scales = np.array([YL_CAP]*3 + [YH_CAP]*3)  # shape: (6,)

y_test_true_descaled = y_test_true * scales
y_test_pred_descaled = y_test_pred * scales

# %%
mae = np.mean(np.abs(y_test_pred - y_test_true), axis=0)
print("Test MAE per y:", mae)
print("Test MAE mean :", mae.mean())
# Out:
# Test MAE per y: [0.01738431 0.01276982 0.00555153 0.008287   0.01379032 0.01012466]
# Test MAE mean : 0.011317942

# %%
mae = np.mean(np.abs(y_test_pred_descaled - y_test_true_descaled), axis=0)
print("Test MAE per y:", mae)
print("Test MAE mean :", mae.mean())
# Out:
# Test MAE per y: [0.00165151 0.00121313 0.0005274  0.00062152 0.00103427 0.00075935]
# Test MAE mean : 0.0009678651306277006

# %%
err = y_test_pred_descaled - y_test_true_descaled
print(err.shape)
# Out:
# (4000, 6)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(
    style="whitegrid",     # 🔹 whitegrid → white
    context="talk",
    font="serif"
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import MaxNLocator

def plot_error_histograms_seaborn(
    err,
    bins=40,
    xmin=-0.1,
    xmax=0.1,
    save_name="default.pdf",   # 👈 디폴트 파일명
):
    fig, axes = plt.subplots(3, 2, figsize=(15, 12))
    axes = axes.ravel()

    xlim = (xmin, xmax)

    for i in range(6):
        ax = axes[i]

        sns.histplot(
            err[:, i],
            bins=bins,
            stat="count",
            kde=False,
            color="tab:blue",
            alpha=0.8,
            ax=ax
        )

        ax.axvline(0, color="black", linestyle="--", linewidth=1.5)

        mae  = np.mean(np.abs(err[:, i]))
        rmse = np.sqrt(np.mean(err[:, i] ** 2))

        ax.text(
            0.03, 0.97,
            f"MAE  = {mae:.4f}\nRMSE = {rmse:.4f}",
            transform=ax.transAxes,
            va="top",
            ha="left",
            fontsize=14,
            bbox=dict(boxstyle="round", fc="white", alpha=0.9)
        )

        ax.set_xlim(xlim)
        ax.xaxis.set_major_locator(MaxNLocator(nbins=5))

        ax.set_title(f"y{i} error", fontsize=16)
        ax.set_xlabel("prediction − truth", fontsize=14)
        ax.set_ylabel("count", fontsize=14)

    fig.suptitle(
        "Test error distribution : ViT 64NTok MaxCap6 Y Rescaled",
        fontsize=20,
        y=0.98
    )

    fig.tight_layout()

    # ✅ PDF 저장 (show 전에!)
    if save_name is not None:
        plt.savefig(save_name, bbox_inches="tight")
        print(f"Saved figure to: {save_name}")

    plt.show()

# %%
plot_error_histograms_seaborn(err,bins=200,xmin=-0.005,xmax=0.005, \
                             save_name='vit_64ntok_maxcap_y_rescaled_both_signs_1c.png')
# Out:
# Saved figure to: vit_64ntok_maxcap_y_rescaled_both_signs_1c.png
