# %% [markdown]
# # PyTorch DL for KDRIFT G1 Alignment
#
# - EDA the training set
# - Train using the baseline by the student's work
# - Image Normalization .. Let's find out what is the best "Fixed Max" value for ultimate normalization

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
#import tensorflow as tf
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense, SimpleRNN, Conv2D, MaxPooling2D, Flatten
import os
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
#from tensorflow.keras import backend as K
from tqdm import trange, notebook
#from livelossplot import PlotLossesKeras

import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib
# Basic Settings for matplotlib
matplotlib.rcParams["font.family"] = "serif"
matplotlib.rcParams["mathtext.fontset"] = "stix"
#%matplotlib inline
#matplotlib_inline.backend_inline.set_matplotlib_formats("svg", "pdf")  # For export
matplotlib.rcParams["lines.linewidth"] = 2.0

# %% [markdown]
# ## Browsing the working directories

# %%
# %pwd
# Out:
# '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/notebook'

# %%
# %ls
# Out:
# cnn-align-v1-no-rescale.ipynb
# cnn-align-v1-pix-norm.ipynb
# cnn-align-v2-image-norm.ipynb
# cnn-align-v3-image-abs-norm.ipynb
# cnn-align-v4-image-both-sign-norm-Copy1.ipynb
# cnn-align-v4a-image-both-sign-norm.ipynb
# cnn-align-v5-image-fixed-max-norm.ipynb
# lightning_logs/
# vit-align-v1.ipynb

# %%
data_path = '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/data/'

# %%
# !ls {data_path}
# Out:
# X_f32.npy  y_f32.npy

# %% [markdown]
# ## Explore the training set

# %%
# %%time
X = np.load(data_path+'X_f32.npy')
y = np.load(data_path+'y_f32.npy')
# Out:
# CPU times: user 0 ns, sys: 217 ms, total: 217 ms
# Wall time: 216 ms

# %%
len(y),len(X)
# Out:
# (20000, 20000)

# %%
def np_array_info(a):
    print(f"shape     : {a.shape}")
    print(f"dtype     : {a.dtype}")
    print(f"ndim      : {a.ndim}")
    print(f"size      : {a.size}")
    print(f"itemsize  : {a.itemsize} bytes")
    print(f"nbytes    : {a.nbytes / 1024**2:.2f} MB")
    print(f"min / max : {a.min()} / {a.max()}")

# %%
np_array_info(y)
# Out:
# shape     : (20000, 6)
# dtype     : float32
# ndim      : 2
# size      : 120000
# itemsize  : 4 bytes
# nbytes    : 0.46 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(X)
# Out:
# shape     : (20000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 409600000
# itemsize  : 4 bytes
# nbytes    : 1562.50 MB
# min / max : -44.47488021850586 / 41.380958557128906

# %% [markdown]
# > I may need learn about what `X` and `y` mean. I am an instrument noob.

# %% [markdown]
# #### Visualize the training set

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_trainingsample(X, y, selected_index_list):
    n_samples = len(selected_index_list)
    n_views = X.shape[1]

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2)
    )

    vmin, vmax = X.min(), X.max()
    im = None

    for row, idx in enumerate(selected_index_list):
        for j in range(n_views):
            ax = axes[row, j]
            img = X[idx, j, :, :, 0]

            im = ax.imshow(
                img,
                cmap="rainbow",
                vmin=vmin,
                vmax=vmax,
                aspect="equal"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            if row == 0:
                ax.set_title(f"image {j+1}")

            # --- min / max labels (항상 포함)
            img_min = img.min()
            img_max = img.max()

            labels = [
                f"min: {img_min:.2f}",
                f"max: {img_max:.2f}",
            ]

            # --- image 1 패널에는 y 값도 같이 추가
            if y is not None and j == 0:
                yvals = y[idx]
                labels += [
                    f"y{i+1}: {val:.3f}" for i, val in enumerate(yvals)
                ]
                ax.set_ylabel(f"idx {idx}")

            handles = [
                plt.Line2D([0], [0], color="none", label=lab)
                for lab in labels
            ]

            ax.legend(
                handles=handles,
                loc="upper left" if j == 0 else "upper right",
                fontsize=7 if j != 0 else 8,
                frameon=True,
                borderpad=0.3,
                handlelength=0,
                handletextpad=0
            )

    fig.subplots_adjust(
        bottom=0.12,
        hspace=0.05,
        wspace=0.02
    )

    fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02
    )

    plt.show()

# %%
selected_index_list = [0, 5, 12, 128, 2048, 9999, 15000, 19999]
plot_trainingsample(X, y, selected_index_list)

# %% [markdown]
# ## PyTorching the Model

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
import pytorch_lightning as pl
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import torchvision
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from torchvision import transforms
from torchvision.datasets import CIFAR10

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce RTX 3090 (UUID: GPU-81ef84f4-69df-ce9c-b89c-0b05c8f72ebf)

# %%
#%load_ext tensorboard
# I will not use tensorboard .. though..

# %%
# Setting the seed
pl.seed_everything(42)

# Ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Seed set to 42

# %% [markdown]
# #### Checkpoints

# %%
CHECKPOINT_ROOT = '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/'

# %%
from time import gmtime, strftime

base_name = 'cnn'
#try_name = strftime('%Y.%m.%d_%H:%M', gmtime())
try_name = 'take5'
experiment_name = f"{base_name}_{try_name}"
print("experiment:", experiment_name)
# Out:
# experiment: cnn_take5

# %%
import os
import shutil

CHECKPOINT_PATH = os.path.join(CHECKPOINT_ROOT, experiment_name)

if os.path.exists(CHECKPOINT_PATH):
    print(f"⚠️ Directory exists: {CHECKPOINT_PATH}")
    print("🧹 Removing all contents...")

    # Clear all files/subfolders inside the directory
    for filename in os.listdir(CHECKPOINT_PATH):
        file_path = os.path.join(CHECKPOINT_PATH, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print(f"❌ Failed to delete {file_path}: {e}")

    print("✅ Directory has been cleared.")
else:
    os.makedirs(CHECKPOINT_PATH)
    print(f"✅ Directory created: {CHECKPOINT_PATH}")

print(f"📂 Experiment directory is ready: {os.path.abspath(CHECKPOINT_PATH)}")
# Out:
# ⚠️ Directory exists: /app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take5
# 🧹 Removing all contents...
# ✅ Directory has been cleared.
# 📂 Experiment directory is ready: /app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take5

# %% [markdown]
# ### Follow the min/max/scaler of the original keras code for reproduction

# %%
num_samples = len(y)
print(num_samples)
# Out:
# 20000

# %%
indices=range(num_samples)

# %%
X_train, X_test, y_train, y_test, train_indices, test_indices = \
train_test_split(X, y, indices, test_size=0.2, random_state=42)

# %%
# %%time
X_train_train, X_train_val, \
y_train_train, y_train_val, \
train_train_indices, train_val_indices = \
    train_test_split(
        X_train,
        y_train,
        train_indices,
        test_size=0.2,
        random_state=42
    )
# Out:
# CPU times: user 48.5 ms, sys: 85.2 ms, total: 134 ms
# Wall time: 133 ms

# %%
np_array_info(X_train_train)
# Out:
# shape     : (12800, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 262144000
# itemsize  : 4 bytes
# nbytes    : 1000.00 MB
# min / max : -44.47488021850586 / 38.766319274902344

# %%
np_array_info(X_train_val)
# Out:
# shape     : (3200, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 65536000
# itemsize  : 4 bytes
# nbytes    : 250.00 MB
# min / max : -40.51784896850586 / 41.380958557128906

# %%
np_array_info(X_test)
# Out:
# shape     : (4000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 81920000
# itemsize  : 4 bytes
# nbytes    : 312.50 MB
# min / max : -38.55973815917969 / 38.85308074951172

# %% [markdown]
# ### normalization by a fixed max value

# %% [markdown]
# #### Max Min Histograms

# %%
# X shape: (N, C, H, W, 1)
# squeeze 마지막 채널
X0 = X_train_train[..., 0]   # (12800, 5, 64, 64)

# 채널별 min / max (per-sample)
# 결과 shape: (12800, 5)
max_vals = X0.max(axis=(2, 3))
min_vals = X0.min(axis=(2, 3))

print(max_vals.shape, min_vals.shape)
# Out:
# (12800, 5) (12800, 5)

# %%
# 채널별 max of max_vals
max_of_max = max_vals.max(axis=0)   # shape (5,)

# 채널별 min of min_vals
min_of_min = min_vals.min(axis=0)   # shape (5,)

print("Channel-wise MAX of max_vals:")
for c, v in enumerate(max_of_max):
    print(f"  Channel {c}: {v:.6f}")

print("\nChannel-wise MIN of min_vals:")
for c, v in enumerate(min_of_min):
    print(f"  Channel {c}: {v:.6f}")
# Out:
# Channel-wise MAX of max_vals:
#   Channel 0: 34.031689
#   Channel 1: 36.974529
#   Channel 2: 35.511421
#   Channel 3: 37.356750
#   Channel 4: 38.766319
#
# Channel-wise MIN of min_vals:
#   Channel 0: -38.046089
#   Channel 1: -39.498131
#   Channel 2: -41.253410
#   Channel 3: -42.503021
#   Channel 4: -44.474880

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(5, 2, figsize=(9, 15), sharex=False)

for c in range(5):
    # max histogram
    axes[c, 0].hist(max_vals[:, c], bins=100)
    axes[c, 0].set_title(f'Channel {c} - max')
    axes[c, 0].set_ylabel('Count')

    # min histogram
    axes[c, 1].hist(min_vals[:, c], bins=100)
    axes[c, 1].set_title(f'Channel {c} - min')

axes[-1, 0].set_xlabel('Pixel value')
axes[-1, 1].set_xlabel('Pixel value')

plt.tight_layout()
plt.show()

# %% [markdown]
# > Set the `MAX_CAP = 50`

# %%
MAX_CAP = 50.0

# %%
# %%time
import numpy as np

# symmetric rescaling per image
X_train_train_scaled = X_train_train / MAX_CAP
# Out:
# CPU times: user 53.4 ms, sys: 54.1 ms, total: 108 ms
# Wall time: 107 ms

# %%
max_abs = np.max(
    np.abs(X_train_val),
    axis=(2, 3, 4),   # 64x64 + channel=1
    keepdims=True
)
# symmetric rescaling per image
X_train_val_scaled = X_train_val / MAX_CAP

# %%
max_abs = np.max(
    np.abs(X_test),
    axis=(2, 3, 4),   # 64x64 + channel=1
    keepdims=True
)
# symmetric rescaling per image
X_test_scaled = X_test / MAX_CAP

# %% [markdown]
# #### Plot the rescaled Training Sample
#
# - this could be wrong?!?

# %%
plot_trainingsample(X_train_train_scaled, y,[0,1,2,3,4])

# %%
plot_trainingsample(X_train_val_scaled, y,[0,1,2,3,4])

# %%
plot_trainingsample(X_test_scaled, y,[0,1,2,3,4])

# %% [markdown]
# -  `MAX_CAP = 50` normalization

# %%
np_array_info(X_train_train_scaled)
# Out:
# shape     : (12800, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 262144000
# itemsize  : 4 bytes
# nbytes    : 1000.00 MB
# min / max : -0.8894975781440735 / 0.7753263711929321

# %%
np_array_info(X_train_val_scaled)
# Out:
# shape     : (3200, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 65536000
# itemsize  : 4 bytes
# nbytes    : 250.00 MB
# min / max : -0.8103569746017456 / 0.827619194984436

# %%
np_array_info(X_test_scaled)
# Out:
# shape     : (4000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 81920000
# itemsize  : 4 bytes
# nbytes    : 312.50 MB
# min / max : -0.7711947560310364 / 0.7770616412162781

# %%
np_array_info(y_train_train)
# Out:
# shape     : (12800, 6)
# dtype     : float32
# ndim      : 2
# size      : 76800
# itemsize  : 4 bytes
# nbytes    : 0.29 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(y_train_val)
# Out:
# shape     : (3200, 6)
# dtype     : float32
# ndim      : 2
# size      : 19200
# itemsize  : 4 bytes
# nbytes    : 0.07 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(y_test)
# Out:
# shape     : (4000, 6)
# dtype     : float32
# ndim      : 2
# size      : 24000
# itemsize  : 4 bytes
# nbytes    : 0.09 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_y_histograms_splits(y_train_train, y_train_val, y_test, bins=50):
    """
    y_* shape: (N, 6)
    """

    fig, axes = plt.subplots(2, 3, figsize=(12, 7))
    axes = axes.ravel()

    # symmetric range across ALL splits
    all_y = np.concatenate([y_train_train, y_train_val, y_test], axis=0)
    vmin = all_y.min()
    vmax = all_y.max()
    vmax = max(abs(vmin), abs(vmax))
    hist_range = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        ax.hist(
            y_train_train[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='r',
            alpha=0.2,
            label="train"
        )
        ax.hist(
            y_train_val[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='g',
            alpha=0.2,
            label="val"
        )
        ax.hist(
            y_test[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='b',
            alpha=0.2,
            label="test"
        )

        ax.axvline(0, color="k", linestyle="--", linewidth=1)
        ax.set_title(f"y{i}")
        ax.set_xlabel("value")
        ax.set_ylabel("density")

        if i == 0:
            ax.legend()

    fig.suptitle("Distribution of y components (train / val / test)", fontsize=13)
    fig.tight_layout()
    plt.show()

# %%
plot_y_histograms_splits(y_train_train, y_train_val, y_test)

# %% [markdown]
# ## Train the CNN model

# %%
class CNNModelKerasEquivalent(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            # Conv2D(32,(1,1), relu, input_shape=(5,64,64), channels_first)
            nn.Conv2d(in_channels=5, out_channels=32, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # Conv2D(64,(3,3), relu)  (padding='valid' in Keras -> padding=0 in PyTorch)
            nn.Conv2d(32, 64, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(2,2), relu)
            nn.Conv2d(64, 32, kernel_size=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(1,1), relu)
            nn.Conv2d(32, 32, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(1,1), relu)
            nn.Conv2d(32, 32, kernel_size=1),
            nn.ReLU(inplace=True),

            nn.Flatten(),                 # Keras Flatten()
            nn.Linear(32 * 3 * 3, 128),   # 계산 결과: 64->32->30->15->14->7->3 => 32*3*3
            nn.ReLU(inplace=True),
            nn.Linear(128, 6)             # Dense(6)
        )

    def forward(self, x):
        return self.net(x)

# %%
from torch.utils.data import Dataset, DataLoader

class NumpyDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        x = torch.from_numpy(self.X[idx]).float()  # (5,64,64)
        x = x.squeeze(-1) # if (5,64,64,1)
        t = torch.from_numpy(self.y[idx]).float()  # (6,)
        return x, t

# %%
train_ds = NumpyDataset(X_train_train_scaled, y_train_train)
val_ds   = NumpyDataset(X_train_val_scaled,   y_train_val)

# %%
x0, y0 = train_ds[0]
print(x0.shape)   # torch.Size([5, 64, 64])
print(y0.shape)   # torch.Size([6])
# Out:
# torch.Size([5, 64, 64])
# torch.Size([6])

# %%
train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
xb, yb = next(iter(train_loader))
print("xb.shape:", xb.shape)
print("yb.shape:", yb.shape)
print("xb.dtype:", xb.dtype)
# Out:
# xb.shape: torch.Size([32, 5, 64, 64])
# yb.shape: torch.Size([32, 6])
# xb.dtype: torch.float32

# %% [markdown]
# #### Visualize the training dataloader as a sanity check

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow",
                                   linewidth=0.5, vmin=None, vmax=None):
    """
    xb: torch.Tensor, shape (B, 5, 64, 64)
    n_samples: number of rows (samples)
    ngrid: number of grid cells per axis (e.g., 16 => patch size 4 for 64x64)
    """
    # tensor -> numpy
    x = xb[:n_samples].detach().cpu().numpy()  # (n_samples, 5, 64, 64)
    n_samples = x.shape[0]
    n_views = x.shape[1]
    H, W = x.shape[2], x.shape[3]

    assert H % ngrid == 0 and W % ngrid == 0, f"H,W must be divisible by ngrid. got {H},{W}, ngrid={ngrid}"
    patch_h = H // ngrid
    patch_w = W // ngrid

    # global color scale (consistent across all panels)
    if vmin is None:
        vmin = float(x.min())
    if vmax is None:
        vmax = float(x.max())

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2),
        constrained_layout=False
    )

    # in case n_samples == 1
    if n_samples == 1:
        axes = np.expand_dims(axes, axis=0)

    im = None
    for i in range(n_samples):
        for j in range(n_views):
            ax = axes[i, j]
            img = x[i, j]  # (64,64)

            im = ax.imshow(
                img,
                cmap=cmap,
                vmin=vmin,
                vmax=vmax,
                aspect="equal",
                interpolation="nearest"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            # column titles
            if i == 0:
                ax.set_title(f"ch {j}", fontsize=11)

            # row labels
            if j == 0:
                ax.set_ylabel(f"sample {i}", fontsize=11)

            # draw patch grid boundaries
            for gy in range(0, H + 1, patch_h):
                ax.axhline(gy - 0.5, color="w", linewidth=linewidth, alpha=0.9)
            for gx in range(0, W + 1, patch_w):
                ax.axvline(gx - 0.5, color="w", linewidth=linewidth, alpha=0.9)

    # tighter spacing + bottom colorbar
    fig.subplots_adjust(bottom=0.08, hspace=0.02, wspace=0.02)

    cbar = fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02
    )
    cbar.set_label("pixel value")

    plt.show()

# %%
plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow")

# %%
xb, yb = next(iter(val_loader))
print("xb.shape:", xb.shape)
print("yb.shape:", yb.shape)
print("xb.dtype:", xb.dtype)
# Out:
# xb.shape: torch.Size([32, 5, 64, 64])
# yb.shape: torch.Size([32, 6])
# xb.dtype: torch.float32

# %%
plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow")

# %% [markdown]
# #### Callbacks

# %%
import time
import matplotlib.pyplot as plt
from pytorch_lightning.callbacks import Callback

class PlotLossesPL(Callback):
    def __init__(self):
        self.train_losses = []
        self.val_losses = []
        self.epoch_times = []

    def on_train_epoch_start(self, trainer, pl_module):
        self.epoch_start_time = time.time()

    def on_train_epoch_end(self, trainer, pl_module):
        epoch_time = time.time() - self.epoch_start_time
        self.epoch_times.append(epoch_time)

        train_loss = trainer.callback_metrics.get("train_loss")
        val_loss   = trainer.callback_metrics.get("val_loss")

        if train_loss is not None:
            self.train_losses.append(train_loss.item())
        if val_loss is not None:
            self.val_losses.append(val_loss.item())

        print(
            f"Epoch {trainer.current_epoch:03d} | "
            f"train MAE: {self.train_losses[-1]:.6f} | "
            f"val MAE: {self.val_losses[-1]:.6f} | "
            f"time: {epoch_time:.2f}s"
        )

    def on_fit_end(self, trainer, pl_module):
        self.plot()

    def plot(self):
        plt.figure(figsize=(6,4))
        plt.plot(self.train_losses, label="train")
        plt.plot(self.val_losses, label="val")
        plt.xlabel("epoch")
        plt.ylabel("MAE")
        plt.legend()
        plt.tight_layout()
        plt.show()

# %%
import time
from pytorch_lightning.callbacks import Callback

class GPUSleepCallback(Callback):
    def __init__(self, every_n_epochs=5, sleep_seconds=5):
        self.every_n_epochs = every_n_epochs
        self.sleep_seconds = sleep_seconds

    def on_train_epoch_end(self, trainer, pl_module):
        epoch = trainer.current_epoch + 1  # 1-based로 보기 좋게
        if epoch % self.every_n_epochs == 0:
            print(f"😴 Cooling GPU: sleeping {self.sleep_seconds}s after epoch {epoch}")
            time.sleep(self.sleep_seconds)

# %%
import os
from pytorch_lightning.callbacks import ModelCheckpoint

#ckpt_dir = "/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take1"
ckpt_dir = CHECKPOINT_PATH

checkpoint_cb = ModelCheckpoint(
    dirpath=ckpt_dir,
    filename="best-{epoch:03d}-{val_loss:.6f}",  # 파일명 템플릿
    monitor="val_loss",                          # 우리가 log한 키
    mode="min",                                  # 최소가 best
    save_top_k=1,                                # best 1개만 유지
    save_last=True,                              # last.ckpt도 저장
    auto_insert_metric_name=False
)

# %%
import pytorch_lightning as pl
import torch
import torch.nn as nn

class LitCNN(pl.LightningModule):
    def __init__(self, model, lr=1e-3):
        super().__init__()
        self.model = model
        self.criterion = nn.L1Loss()
        self.lr = lr

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.log("train_loss", loss, prog_bar=False)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.log("val_loss", loss, prog_bar=False)
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.lr)

# %%
from pytorch_lightning.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=100,
    mode="min"
)

# %%
from pytorch_lightning import Trainer

plot_cb = PlotLossesPL()
gpu_sleep_cb = GPUSleepCallback(every_n_epochs=5, sleep_seconds=5)

trainer = Trainer(
    max_epochs=400,
    callbacks=[plot_cb, checkpoint_cb, gpu_sleep_cb],
    enable_progress_bar=False,
    enable_model_summary=False,
    accelerator="gpu" if torch.cuda.is_available() else "cpu",
    devices=1,
    log_every_n_steps=999999
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
# %%time
trainer.fit(
    model=LitCNN(CNNModelKerasEquivalent()),
    train_dataloaders=train_loader,
    val_dataloaders=val_loader
)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:317: The number of training batches (400) is smaller than the logging interval Trainer(log_every_n_steps=999999). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 000 | train MAE: 0.207314 | val MAE: 0.188829 | time: 1.51s
# Epoch 001 | train MAE: 0.157102 | val MAE: 0.181289 | time: 1.57s
# Epoch 002 | train MAE: 0.084100 | val MAE: 0.084357 | time: 1.58s
# Epoch 003 | train MAE: 0.080478 | val MAE: 0.076412 | time: 1.58s
# Epoch 004 | train MAE: 0.058979 | val MAE: 0.076035 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 5
# Epoch 005 | train MAE: 0.089029 | val MAE: 0.078062 | time: 1.61s
# Epoch 006 | train MAE: 0.073108 | val MAE: 0.075004 | time: 1.59s
# Epoch 007 | train MAE: 0.074722 | val MAE: 0.074986 | time: 1.64s
# Epoch 008 | train MAE: 0.072923 | val MAE: 0.073777 | time: 1.56s
# Epoch 009 | train MAE: 0.081178 | val MAE: 0.072352 | time: 1.55s
# 😴 Cooling GPU: sleeping 5s after epoch 10
# Epoch 010 | train MAE: 0.077480 | val MAE: 0.072041 | time: 1.56s
# Epoch 011 | train MAE: 0.065851 | val MAE: 0.072713 | time: 1.57s
# Epoch 012 | train MAE: 0.082634 | val MAE: 0.074219 | time: 1.56s
# Epoch 013 | train MAE: 0.084654 | val MAE: 0.068276 | time: 1.60s
# Epoch 014 | train MAE: 0.069543 | val MAE: 0.068726 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 15
# Epoch 015 | train MAE: 0.066808 | val MAE: 0.064407 | time: 1.66s
# Epoch 016 | train MAE: 0.077896 | val MAE: 0.066021 | time: 1.64s
# Epoch 017 | train MAE: 0.048858 | val MAE: 0.055662 | time: 1.60s
# Epoch 018 | train MAE: 0.053760 | val MAE: 0.055475 | time: 1.58s
# Epoch 019 | train MAE: 0.052529 | val MAE: 0.048931 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 20
# Epoch 020 | train MAE: 0.038350 | val MAE: 0.037954 | time: 1.58s
# Epoch 021 | train MAE: 0.034762 | val MAE: 0.036227 | time: 1.59s
# Epoch 022 | train MAE: 0.034263 | val MAE: 0.032471 | time: 1.56s
# Epoch 023 | train MAE: 0.025583 | val MAE: 0.029089 | time: 1.59s
# Epoch 024 | train MAE: 0.046985 | val MAE: 0.036553 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 25
# Epoch 025 | train MAE: 0.026119 | val MAE: 0.027380 | time: 1.58s
# Epoch 026 | train MAE: 0.026770 | val MAE: 0.031837 | time: 1.56s
# Epoch 027 | train MAE: 0.025281 | val MAE: 0.027746 | time: 1.57s
# Epoch 028 | train MAE: 0.020799 | val MAE: 0.021694 | time: 1.58s
# Epoch 029 | train MAE: 0.024781 | val MAE: 0.029337 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 30
# Epoch 030 | train MAE: 0.025287 | val MAE: 0.024775 | time: 1.62s
# Epoch 031 | train MAE: 0.028341 | val MAE: 0.022746 | time: 1.57s
# Epoch 032 | train MAE: 0.025325 | val MAE: 0.023804 | time: 1.58s
# Epoch 033 | train MAE: 0.024073 | val MAE: 0.023916 | time: 1.58s
# Epoch 034 | train MAE: 0.026142 | val MAE: 0.022417 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 35
# Epoch 035 | train MAE: 0.024098 | val MAE: 0.021390 | time: 1.59s
# Epoch 036 | train MAE: 0.025858 | val MAE: 0.031238 | time: 1.57s
# Epoch 037 | train MAE: 0.023760 | val MAE: 0.024796 | time: 1.59s
# Epoch 038 | train MAE: 0.022760 | val MAE: 0.023170 | time: 1.61s
# Epoch 039 | train MAE: 0.022983 | val MAE: 0.023964 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 40
# Epoch 040 | train MAE: 0.022360 | val MAE: 0.020846 | time: 1.57s
# Epoch 041 | train MAE: 0.021308 | val MAE: 0.018948 | time: 1.61s
# Epoch 042 | train MAE: 0.029311 | val MAE: 0.018383 | time: 1.55s
# Epoch 043 | train MAE: 0.019115 | val MAE: 0.019669 | time: 1.61s
# Epoch 044 | train MAE: 0.014996 | val MAE: 0.016830 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 45
# Epoch 045 | train MAE: 0.020137 | val MAE: 0.025792 | time: 1.58s
# Epoch 046 | train MAE: 0.021971 | val MAE: 0.025043 | time: 1.65s
# Epoch 047 | train MAE: 0.021739 | val MAE: 0.017144 | time: 1.60s
# Epoch 048 | train MAE: 0.018980 | val MAE: 0.018593 | time: 1.58s
# Epoch 049 | train MAE: 0.017101 | val MAE: 0.021222 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 50
# Epoch 050 | train MAE: 0.016494 | val MAE: 0.020211 | time: 1.60s
# Epoch 051 | train MAE: 0.022058 | val MAE: 0.022847 | time: 1.60s
# Epoch 052 | train MAE: 0.018603 | val MAE: 0.019887 | time: 1.57s
# Epoch 053 | train MAE: 0.020360 | val MAE: 0.019729 | time: 1.58s
# Epoch 054 | train MAE: 0.016764 | val MAE: 0.017714 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 55
# Epoch 055 | train MAE: 0.024070 | val MAE: 0.020066 | time: 1.58s
# Epoch 056 | train MAE: 0.017551 | val MAE: 0.019246 | time: 1.60s
# Epoch 057 | train MAE: 0.023294 | val MAE: 0.020971 | time: 1.58s
# Epoch 058 | train MAE: 0.018112 | val MAE: 0.017065 | time: 1.56s
# Epoch 059 | train MAE: 0.020882 | val MAE: 0.019513 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 60
# Epoch 060 | train MAE: 0.020463 | val MAE: 0.017523 | time: 1.62s
# Epoch 061 | train MAE: 0.019744 | val MAE: 0.017521 | time: 1.60s
# Epoch 062 | train MAE: 0.017632 | val MAE: 0.016773 | time: 1.60s
# Epoch 063 | train MAE: 0.014791 | val MAE: 0.014821 | time: 1.56s
# Epoch 064 | train MAE: 0.025220 | val MAE: 0.021417 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 65
# Epoch 065 | train MAE: 0.017545 | val MAE: 0.018698 | time: 1.59s
# Epoch 066 | train MAE: 0.016029 | val MAE: 0.015274 | time: 1.63s
# Epoch 067 | train MAE: 0.020649 | val MAE: 0.018834 | time: 1.57s
# Epoch 068 | train MAE: 0.018385 | val MAE: 0.018413 | time: 1.66s
# Epoch 069 | train MAE: 0.019346 | val MAE: 0.020410 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 70
# Epoch 070 | train MAE: 0.017186 | val MAE: 0.015211 | time: 1.59s
# Epoch 071 | train MAE: 0.018144 | val MAE: 0.017688 | time: 1.57s
# Epoch 072 | train MAE: 0.020479 | val MAE: 0.021001 | time: 1.59s
# Epoch 073 | train MAE: 0.016632 | val MAE: 0.015052 | time: 1.59s
# Epoch 074 | train MAE: 0.017005 | val MAE: 0.015725 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 75
# Epoch 075 | train MAE: 0.013883 | val MAE: 0.013943 | time: 1.57s
# Epoch 076 | train MAE: 0.022497 | val MAE: 0.019490 | time: 1.56s
# Epoch 077 | train MAE: 0.014404 | val MAE: 0.015281 | time: 1.57s
# Epoch 078 | train MAE: 0.016715 | val MAE: 0.013518 | time: 1.57s
# Epoch 079 | train MAE: 0.020470 | val MAE: 0.018237 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 80
# Epoch 080 | train MAE: 0.014007 | val MAE: 0.014417 | time: 1.56s
# Epoch 081 | train MAE: 0.013193 | val MAE: 0.014564 | time: 1.59s
# Epoch 082 | train MAE: 0.014984 | val MAE: 0.014036 | time: 1.61s
# Epoch 083 | train MAE: 0.018618 | val MAE: 0.025165 | time: 1.62s
# Epoch 084 | train MAE: 0.014335 | val MAE: 0.013287 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 85
# Epoch 085 | train MAE: 0.017276 | val MAE: 0.017581 | time: 1.58s
# Epoch 086 | train MAE: 0.015797 | val MAE: 0.020114 | time: 1.60s
# Epoch 087 | train MAE: 0.016097 | val MAE: 0.018226 | time: 1.60s
# Epoch 088 | train MAE: 0.021524 | val MAE: 0.022100 | time: 1.62s
# Epoch 089 | train MAE: 0.020864 | val MAE: 0.016136 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 90
# Epoch 090 | train MAE: 0.015498 | val MAE: 0.016734 | time: 1.59s
# Epoch 091 | train MAE: 0.019486 | val MAE: 0.020036 | time: 1.60s
# Epoch 092 | train MAE: 0.015659 | val MAE: 0.015747 | time: 1.61s
# Epoch 093 | train MAE: 0.015487 | val MAE: 0.015908 | time: 1.59s
# Epoch 094 | train MAE: 0.014850 | val MAE: 0.016948 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 95
# Epoch 095 | train MAE: 0.019001 | val MAE: 0.018780 | time: 1.58s
# Epoch 096 | train MAE: 0.014708 | val MAE: 0.015992 | time: 1.59s
# Epoch 097 | train MAE: 0.010874 | val MAE: 0.013267 | time: 1.58s
# Epoch 098 | train MAE: 0.014197 | val MAE: 0.014750 | time: 1.57s
# Epoch 099 | train MAE: 0.016263 | val MAE: 0.014822 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 100
# Epoch 100 | train MAE: 0.015636 | val MAE: 0.015277 | time: 1.59s
# Epoch 101 | train MAE: 0.015634 | val MAE: 0.019261 | time: 1.61s
# Epoch 102 | train MAE: 0.017486 | val MAE: 0.018083 | time: 1.62s
# Epoch 103 | train MAE: 0.018745 | val MAE: 0.021264 | time: 1.65s
# Epoch 104 | train MAE: 0.013415 | val MAE: 0.014983 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 105
# Epoch 105 | train MAE: 0.019081 | val MAE: 0.016317 | time: 1.57s
# Epoch 106 | train MAE: 0.019406 | val MAE: 0.018424 | time: 1.63s
# Epoch 107 | train MAE: 0.015148 | val MAE: 0.015780 | time: 1.55s
# Epoch 108 | train MAE: 0.019855 | val MAE: 0.018766 | time: 1.58s
# Epoch 109 | train MAE: 0.014110 | val MAE: 0.014887 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 110
# Epoch 110 | train MAE: 0.015972 | val MAE: 0.017554 | time: 1.61s
# Epoch 111 | train MAE: 0.019002 | val MAE: 0.020141 | time: 1.65s
# Epoch 112 | train MAE: 0.015668 | val MAE: 0.015036 | time: 1.58s
# Epoch 113 | train MAE: 0.016838 | val MAE: 0.014617 | time: 1.59s
# Epoch 114 | train MAE: 0.013155 | val MAE: 0.016689 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 115
# Epoch 115 | train MAE: 0.014461 | val MAE: 0.014733 | time: 1.60s
# Epoch 116 | train MAE: 0.012549 | val MAE: 0.015036 | time: 1.62s
# Epoch 117 | train MAE: 0.013557 | val MAE: 0.013143 | time: 1.62s
# Epoch 118 | train MAE: 0.015969 | val MAE: 0.011025 | time: 1.60s
# Epoch 119 | train MAE: 0.015160 | val MAE: 0.015249 | time: 1.68s
# 😴 Cooling GPU: sleeping 5s after epoch 120
# Epoch 120 | train MAE: 0.015695 | val MAE: 0.014846 | time: 1.59s
# Epoch 121 | train MAE: 0.014247 | val MAE: 0.017240 | time: 1.61s
# Epoch 122 | train MAE: 0.013233 | val MAE: 0.013668 | time: 1.62s
# Epoch 123 | train MAE: 0.013982 | val MAE: 0.015753 | time: 1.59s
# Epoch 124 | train MAE: 0.008708 | val MAE: 0.012487 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 125
# Epoch 125 | train MAE: 0.014819 | val MAE: 0.016399 | time: 1.58s
# Epoch 126 | train MAE: 0.018304 | val MAE: 0.015830 | time: 1.63s
# Epoch 127 | train MAE: 0.013226 | val MAE: 0.013174 | time: 1.59s
# Epoch 128 | train MAE: 0.014438 | val MAE: 0.017132 | time: 1.61s
# Epoch 129 | train MAE: 0.015258 | val MAE: 0.014772 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 130
# Epoch 130 | train MAE: 0.010914 | val MAE: 0.012597 | time: 1.64s
# Epoch 131 | train MAE: 0.011630 | val MAE: 0.012739 | time: 1.64s
# Epoch 132 | train MAE: 0.017594 | val MAE: 0.012937 | time: 1.60s
# Epoch 133 | train MAE: 0.014252 | val MAE: 0.016522 | time: 1.59s
# Epoch 134 | train MAE: 0.014562 | val MAE: 0.013504 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 135
# Epoch 135 | train MAE: 0.020327 | val MAE: 0.018203 | time: 1.62s
# Epoch 136 | train MAE: 0.008453 | val MAE: 0.013240 | time: 1.58s
# Epoch 137 | train MAE: 0.013594 | val MAE: 0.017535 | time: 1.59s
# Epoch 138 | train MAE: 0.010395 | val MAE: 0.011709 | time: 1.57s
# Epoch 139 | train MAE: 0.016195 | val MAE: 0.013468 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 140
# Epoch 140 | train MAE: 0.012652 | val MAE: 0.012884 | time: 1.58s
# Epoch 141 | train MAE: 0.010718 | val MAE: 0.013913 | time: 1.57s
# Epoch 142 | train MAE: 0.014175 | val MAE: 0.013656 | time: 1.59s
# Epoch 143 | train MAE: 0.012701 | val MAE: 0.012496 | time: 1.60s
# Epoch 144 | train MAE: 0.016143 | val MAE: 0.014162 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 145
# Epoch 145 | train MAE: 0.012566 | val MAE: 0.014444 | time: 1.60s
# Epoch 146 | train MAE: 0.016101 | val MAE: 0.014673 | time: 1.57s
# Epoch 147 | train MAE: 0.010515 | val MAE: 0.011213 | time: 1.62s
# Epoch 148 | train MAE: 0.014569 | val MAE: 0.014147 | time: 1.59s
# Epoch 149 | train MAE: 0.013273 | val MAE: 0.014691 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 150
# Epoch 150 | train MAE: 0.013193 | val MAE: 0.013053 | time: 1.55s
# Epoch 151 | train MAE: 0.011782 | val MAE: 0.011877 | time: 1.62s
# Epoch 152 | train MAE: 0.017474 | val MAE: 0.014060 | time: 1.62s
# Epoch 153 | train MAE: 0.013223 | val MAE: 0.013563 | time: 1.61s
# Epoch 154 | train MAE: 0.014177 | val MAE: 0.013502 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 155
# Epoch 155 | train MAE: 0.016803 | val MAE: 0.012510 | time: 1.63s
# Epoch 156 | train MAE: 0.016048 | val MAE: 0.016002 | time: 1.59s
# Epoch 157 | train MAE: 0.015538 | val MAE: 0.015473 | time: 1.60s
# Epoch 158 | train MAE: 0.014481 | val MAE: 0.013511 | time: 1.59s
# Epoch 159 | train MAE: 0.012451 | val MAE: 0.013128 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 160
# Epoch 160 | train MAE: 0.012903 | val MAE: 0.013207 | time: 1.63s
# Epoch 161 | train MAE: 0.010183 | val MAE: 0.011324 | time: 1.64s
# Epoch 162 | train MAE: 0.013368 | val MAE: 0.014053 | time: 1.60s
# Epoch 163 | train MAE: 0.011842 | val MAE: 0.013109 | time: 1.65s
# Epoch 164 | train MAE: 0.010612 | val MAE: 0.011613 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 165
# Epoch 165 | train MAE: 0.012659 | val MAE: 0.012952 | time: 1.60s
# Epoch 166 | train MAE: 0.010938 | val MAE: 0.013571 | time: 1.56s
# Epoch 167 | train MAE: 0.012986 | val MAE: 0.010610 | time: 1.57s
# Epoch 168 | train MAE: 0.013824 | val MAE: 0.013357 | time: 1.57s
# Epoch 169 | train MAE: 0.011772 | val MAE: 0.014492 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 170
# Epoch 170 | train MAE: 0.017058 | val MAE: 0.014371 | time: 1.57s
# Epoch 171 | train MAE: 0.011284 | val MAE: 0.012636 | time: 1.63s
# Epoch 172 | train MAE: 0.013099 | val MAE: 0.011591 | time: 1.58s
# Epoch 173 | train MAE: 0.012772 | val MAE: 0.016259 | time: 1.62s
# Epoch 174 | train MAE: 0.014240 | val MAE: 0.012316 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 175
# Epoch 175 | train MAE: 0.011930 | val MAE: 0.012092 | time: 1.58s
# Epoch 176 | train MAE: 0.011133 | val MAE: 0.010841 | time: 1.59s
# Epoch 177 | train MAE: 0.013299 | val MAE: 0.015373 | time: 1.61s
# Epoch 178 | train MAE: 0.012149 | val MAE: 0.011445 | time: 1.62s
# Epoch 179 | train MAE: 0.011761 | val MAE: 0.012574 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 180
# Epoch 180 | train MAE: 0.012789 | val MAE: 0.011550 | time: 1.62s
# Epoch 181 | train MAE: 0.012121 | val MAE: 0.014959 | time: 1.63s
# Epoch 182 | train MAE: 0.014441 | val MAE: 0.015388 | time: 1.59s
# Epoch 183 | train MAE: 0.013076 | val MAE: 0.012677 | time: 1.60s
# Epoch 184 | train MAE: 0.013904 | val MAE: 0.014681 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 185
# Epoch 185 | train MAE: 0.012950 | val MAE: 0.014285 | time: 1.65s
# Epoch 186 | train MAE: 0.012283 | val MAE: 0.013836 | time: 1.60s
# Epoch 187 | train MAE: 0.010532 | val MAE: 0.011598 | time: 1.62s
# Epoch 188 | train MAE: 0.011010 | val MAE: 0.009838 | time: 1.59s
# Epoch 189 | train MAE: 0.014661 | val MAE: 0.014493 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 190
# Epoch 190 | train MAE: 0.009508 | val MAE: 0.009637 | time: 1.58s
# Epoch 191 | train MAE: 0.013537 | val MAE: 0.012066 | time: 1.61s
# Epoch 192 | train MAE: 0.011136 | val MAE: 0.012387 | time: 1.61s
# Epoch 193 | train MAE: 0.015797 | val MAE: 0.015381 | time: 1.60s
# Epoch 194 | train MAE: 0.010751 | val MAE: 0.014687 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 195
# Epoch 195 | train MAE: 0.012593 | val MAE: 0.012770 | time: 1.59s
# Epoch 196 | train MAE: 0.015864 | val MAE: 0.014085 | time: 1.62s
# Epoch 197 | train MAE: 0.009070 | val MAE: 0.010116 | time: 1.60s
# Epoch 198 | train MAE: 0.010397 | val MAE: 0.011971 | time: 1.65s
# Epoch 199 | train MAE: 0.011968 | val MAE: 0.013792 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 200
# Epoch 200 | train MAE: 0.016584 | val MAE: 0.016232 | time: 1.60s
# Epoch 201 | train MAE: 0.010648 | val MAE: 0.010491 | time: 1.61s
# Epoch 202 | train MAE: 0.014692 | val MAE: 0.012932 | time: 1.64s
# Epoch 203 | train MAE: 0.014220 | val MAE: 0.012747 | time: 1.59s
# Epoch 204 | train MAE: 0.011001 | val MAE: 0.012387 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 205
# Epoch 205 | train MAE: 0.012866 | val MAE: 0.010723 | time: 1.58s
# Epoch 206 | train MAE: 0.010247 | val MAE: 0.012551 | time: 1.62s
# Epoch 207 | train MAE: 0.013971 | val MAE: 0.013161 | time: 1.62s
# Epoch 208 | train MAE: 0.010377 | val MAE: 0.011680 | time: 1.60s
# Epoch 209 | train MAE: 0.014026 | val MAE: 0.013480 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 210
# Epoch 210 | train MAE: 0.012749 | val MAE: 0.013066 | time: 1.60s
# Epoch 211 | train MAE: 0.013700 | val MAE: 0.013793 | time: 1.57s
# Epoch 212 | train MAE: 0.009205 | val MAE: 0.011259 | time: 1.61s
# Epoch 213 | train MAE: 0.011305 | val MAE: 0.011917 | time: 1.61s
# Epoch 214 | train MAE: 0.011605 | val MAE: 0.012565 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 215
# Epoch 215 | train MAE: 0.011742 | val MAE: 0.012546 | time: 1.57s
# Epoch 216 | train MAE: 0.008427 | val MAE: 0.011626 | time: 1.62s
# Epoch 217 | train MAE: 0.010074 | val MAE: 0.011013 | time: 1.58s
# Epoch 218 | train MAE: 0.011288 | val MAE: 0.012650 | time: 1.61s
# Epoch 219 | train MAE: 0.010465 | val MAE: 0.015177 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 220
# Epoch 220 | train MAE: 0.011936 | val MAE: 0.012965 | time: 1.58s
# Epoch 221 | train MAE: 0.013862 | val MAE: 0.014168 | time: 1.55s
# Epoch 222 | train MAE: 0.009159 | val MAE: 0.009243 | time: 1.60s
# Epoch 223 | train MAE: 0.011842 | val MAE: 0.010884 | time: 1.62s
# Epoch 224 | train MAE: 0.010132 | val MAE: 0.012243 | time: 1.64s
# 😴 Cooling GPU: sleeping 5s after epoch 225
# Epoch 225 | train MAE: 0.010058 | val MAE: 0.011527 | time: 1.62s
# Epoch 226 | train MAE: 0.014278 | val MAE: 0.017396 | time: 1.61s
# Epoch 227 | train MAE: 0.011588 | val MAE: 0.011926 | time: 1.60s
# Epoch 228 | train MAE: 0.018580 | val MAE: 0.010186 | time: 1.61s
# Epoch 229 | train MAE: 0.011640 | val MAE: 0.013096 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 230
# Epoch 230 | train MAE: 0.008349 | val MAE: 0.008794 | time: 1.59s
# Epoch 231 | train MAE: 0.012966 | val MAE: 0.012430 | time: 1.59s
# Epoch 232 | train MAE: 0.011804 | val MAE: 0.010190 | time: 1.66s
# Epoch 233 | train MAE: 0.012708 | val MAE: 0.012665 | time: 1.59s
# Epoch 234 | train MAE: 0.010099 | val MAE: 0.010371 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 235
# Epoch 235 | train MAE: 0.016281 | val MAE: 0.014335 | time: 1.62s
# Epoch 236 | train MAE: 0.012115 | val MAE: 0.013233 | time: 1.65s
# Epoch 237 | train MAE: 0.012130 | val MAE: 0.012556 | time: 1.63s
# Epoch 238 | train MAE: 0.011603 | val MAE: 0.013974 | time: 1.60s
# Epoch 239 | train MAE: 0.011778 | val MAE: 0.010384 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 240
# Epoch 240 | train MAE: 0.010507 | val MAE: 0.012244 | time: 1.62s
# Epoch 241 | train MAE: 0.010856 | val MAE: 0.011949 | time: 1.62s
# Epoch 242 | train MAE: 0.011004 | val MAE: 0.013505 | time: 1.62s
# Epoch 243 | train MAE: 0.011965 | val MAE: 0.011522 | time: 1.59s
# Epoch 244 | train MAE: 0.017137 | val MAE: 0.011645 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 245
# Epoch 245 | train MAE: 0.011918 | val MAE: 0.009877 | time: 1.59s
# Epoch 246 | train MAE: 0.010990 | val MAE: 0.010094 | time: 1.62s
# Epoch 247 | train MAE: 0.011701 | val MAE: 0.012911 | time: 1.58s
# Epoch 248 | train MAE: 0.011288 | val MAE: 0.009837 | time: 1.63s
# Epoch 249 | train MAE: 0.013646 | val MAE: 0.013367 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 250
# Epoch 250 | train MAE: 0.012949 | val MAE: 0.011337 | time: 1.61s
# Epoch 251 | train MAE: 0.015475 | val MAE: 0.013071 | time: 1.57s
# Epoch 252 | train MAE: 0.010972 | val MAE: 0.011859 | time: 1.61s
# Epoch 253 | train MAE: 0.010101 | val MAE: 0.010539 | time: 1.60s
# Epoch 254 | train MAE: 0.011711 | val MAE: 0.011515 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 255
# Epoch 255 | train MAE: 0.008612 | val MAE: 0.009532 | time: 1.60s
# Epoch 256 | train MAE: 0.011005 | val MAE: 0.010497 | time: 1.62s
# Epoch 257 | train MAE: 0.010812 | val MAE: 0.010944 | time: 1.61s
# Epoch 258 | train MAE: 0.008783 | val MAE: 0.010846 | time: 1.64s
# Epoch 259 | train MAE: 0.009489 | val MAE: 0.010490 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 260
# Epoch 260 | train MAE: 0.009838 | val MAE: 0.010725 | time: 1.59s
# Epoch 261 | train MAE: 0.012053 | val MAE: 0.011726 | time: 1.61s
# Epoch 262 | train MAE: 0.012125 | val MAE: 0.010802 | time: 1.58s
# Epoch 263 | train MAE: 0.009819 | val MAE: 0.009836 | time: 1.62s
# Epoch 264 | train MAE: 0.011411 | val MAE: 0.011103 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 265
# Epoch 265 | train MAE: 0.009666 | val MAE: 0.010478 | time: 1.61s
# Epoch 266 | train MAE: 0.011038 | val MAE: 0.012572 | time: 1.64s
# Epoch 267 | train MAE: 0.010359 | val MAE: 0.009301 | time: 1.63s
# Epoch 268 | train MAE: 0.015123 | val MAE: 0.017648 | time: 1.62s
# Epoch 269 | train MAE: 0.014292 | val MAE: 0.012937 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 270
# Epoch 270 | train MAE: 0.008701 | val MAE: 0.010302 | time: 1.57s
# Epoch 271 | train MAE: 0.009254 | val MAE: 0.009643 | time: 1.59s
# Epoch 272 | train MAE: 0.010974 | val MAE: 0.009669 | time: 1.63s
# Epoch 273 | train MAE: 0.008780 | val MAE: 0.011649 | time: 1.64s
# Epoch 274 | train MAE: 0.009155 | val MAE: 0.010045 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 275
# Epoch 275 | train MAE: 0.010972 | val MAE: 0.012101 | time: 1.64s
# Epoch 276 | train MAE: 0.009466 | val MAE: 0.009412 | time: 1.61s
# Epoch 277 | train MAE: 0.010177 | val MAE: 0.012438 | time: 1.61s
# Epoch 278 | train MAE: 0.012605 | val MAE: 0.012008 | time: 1.60s
# Epoch 279 | train MAE: 0.010283 | val MAE: 0.011464 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 280
# Epoch 280 | train MAE: 0.012405 | val MAE: 0.013133 | time: 1.60s
# Epoch 281 | train MAE: 0.010731 | val MAE: 0.010152 | time: 1.66s
# Epoch 282 | train MAE: 0.010172 | val MAE: 0.010822 | time: 1.59s
# Epoch 283 | train MAE: 0.011963 | val MAE: 0.011065 | time: 1.60s
# Epoch 284 | train MAE: 0.010507 | val MAE: 0.009111 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 285
# Epoch 285 | train MAE: 0.010230 | val MAE: 0.009078 | time: 1.59s
# Epoch 286 | train MAE: 0.009515 | val MAE: 0.010493 | time: 1.61s
# Epoch 287 | train MAE: 0.010783 | val MAE: 0.011956 | time: 1.59s
# Epoch 288 | train MAE: 0.008742 | val MAE: 0.010874 | time: 1.61s
# Epoch 289 | train MAE: 0.009580 | val MAE: 0.009336 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 290
# Epoch 290 | train MAE: 0.009869 | val MAE: 0.009526 | time: 1.60s
# Epoch 291 | train MAE: 0.009450 | val MAE: 0.009283 | time: 1.63s
# Epoch 292 | train MAE: 0.009689 | val MAE: 0.011374 | time: 1.60s
# Epoch 293 | train MAE: 0.009618 | val MAE: 0.011311 | time: 1.61s
# Epoch 294 | train MAE: 0.008528 | val MAE: 0.010762 | time: 1.66s
# 😴 Cooling GPU: sleeping 5s after epoch 295
# Epoch 295 | train MAE: 0.012287 | val MAE: 0.011715 | time: 1.60s
# Epoch 296 | train MAE: 0.012900 | val MAE: 0.010993 | time: 1.61s
# Epoch 297 | train MAE: 0.011803 | val MAE: 0.011886 | time: 1.62s
# Epoch 298 | train MAE: 0.011242 | val MAE: 0.010441 | time: 1.67s
# Epoch 299 | train MAE: 0.008914 | val MAE: 0.010713 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 300
# Epoch 300 | train MAE: 0.009528 | val MAE: 0.012743 | time: 1.58s
# Epoch 301 | train MAE: 0.010432 | val MAE: 0.011895 | time: 1.63s
# Epoch 302 | train MAE: 0.014292 | val MAE: 0.012465 | time: 1.65s
# Epoch 303 | train MAE: 0.010169 | val MAE: 0.009666 | time: 1.59s
# Epoch 304 | train MAE: 0.010286 | val MAE: 0.012665 | time: 1.65s
# 😴 Cooling GPU: sleeping 5s after epoch 305
# Epoch 305 | train MAE: 0.009667 | val MAE: 0.010415 | time: 1.61s
# Epoch 306 | train MAE: 0.010879 | val MAE: 0.012340 | time: 1.60s
# Epoch 307 | train MAE: 0.013615 | val MAE: 0.011068 | time: 1.62s
# Epoch 308 | train MAE: 0.010668 | val MAE: 0.009419 | time: 1.63s
# Epoch 309 | train MAE: 0.010267 | val MAE: 0.010929 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 310
# Epoch 310 | train MAE: 0.012733 | val MAE: 0.012187 | time: 1.59s
# Epoch 311 | train MAE: 0.011149 | val MAE: 0.008537 | time: 1.61s
# Epoch 312 | train MAE: 0.010197 | val MAE: 0.009587 | time: 1.61s
# Epoch 313 | train MAE: 0.013715 | val MAE: 0.012890 | time: 1.64s
# Epoch 314 | train MAE: 0.010527 | val MAE: 0.010090 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 315
# Epoch 315 | train MAE: 0.010878 | val MAE: 0.012737 | time: 1.61s
# Epoch 316 | train MAE: 0.010102 | val MAE: 0.010595 | time: 1.59s
# Epoch 317 | train MAE: 0.011650 | val MAE: 0.014002 | time: 1.63s
# Epoch 318 | train MAE: 0.012533 | val MAE: 0.011932 | time: 1.62s
# Epoch 319 | train MAE: 0.009998 | val MAE: 0.009272 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 320
# Epoch 320 | train MAE: 0.008945 | val MAE: 0.010229 | time: 1.61s
# Epoch 321 | train MAE: 0.012704 | val MAE: 0.016113 | time: 1.61s
# Epoch 322 | train MAE: 0.010982 | val MAE: 0.010969 | time: 1.60s
# Epoch 323 | train MAE: 0.007600 | val MAE: 0.008553 | time: 1.62s
# Epoch 324 | train MAE: 0.010472 | val MAE: 0.011905 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 325
# Epoch 325 | train MAE: 0.014884 | val MAE: 0.011636 | time: 1.62s
# Epoch 326 | train MAE: 0.014537 | val MAE: 0.012053 | time: 1.61s
# Epoch 327 | train MAE: 0.008926 | val MAE: 0.009939 | time: 1.57s
# Epoch 328 | train MAE: 0.011122 | val MAE: 0.009797 | time: 1.61s
# Epoch 329 | train MAE: 0.010036 | val MAE: 0.009700 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 330
# Epoch 330 | train MAE: 0.010654 | val MAE: 0.011596 | time: 1.66s
# Epoch 331 | train MAE: 0.007802 | val MAE: 0.008384 | time: 1.59s
# Epoch 332 | train MAE: 0.008672 | val MAE: 0.010004 | time: 1.63s
# Epoch 333 | train MAE: 0.010188 | val MAE: 0.009620 | time: 1.60s
# Epoch 334 | train MAE: 0.008494 | val MAE: 0.008976 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 335
# Epoch 335 | train MAE: 0.008564 | val MAE: 0.009389 | time: 1.61s
# Epoch 336 | train MAE: 0.007729 | val MAE: 0.010120 | time: 1.62s
# Epoch 337 | train MAE: 0.010554 | val MAE: 0.009825 | time: 1.63s
# Epoch 338 | train MAE: 0.010099 | val MAE: 0.010716 | time: 1.61s
# Epoch 339 | train MAE: 0.011073 | val MAE: 0.012377 | time: 1.62s
# 😴 Cooling GPU: sleeping 5s after epoch 340
# Epoch 340 | train MAE: 0.007397 | val MAE: 0.009313 | time: 1.62s
# Epoch 341 | train MAE: 0.008988 | val MAE: 0.010384 | time: 1.62s
# Epoch 342 | train MAE: 0.008148 | val MAE: 0.008413 | time: 1.60s
# Epoch 343 | train MAE: 0.008853 | val MAE: 0.009485 | time: 1.59s
# Epoch 344 | train MAE: 0.015455 | val MAE: 0.014233 | time: 1.66s
# 😴 Cooling GPU: sleeping 5s after epoch 345
# Epoch 345 | train MAE: 0.010476 | val MAE: 0.011020 | time: 1.58s
# Epoch 346 | train MAE: 0.008576 | val MAE: 0.010295 | time: 1.61s
# Epoch 347 | train MAE: 0.010250 | val MAE: 0.010668 | time: 1.62s
# Epoch 348 | train MAE: 0.013067 | val MAE: 0.012927 | time: 1.60s
# Epoch 349 | train MAE: 0.010081 | val MAE: 0.011042 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 350
# Epoch 350 | train MAE: 0.007981 | val MAE: 0.008601 | time: 1.60s
# Epoch 351 | train MAE: 0.009711 | val MAE: 0.008641 | time: 1.64s
# Epoch 352 | train MAE: 0.009803 | val MAE: 0.009876 | time: 1.62s
# Epoch 353 | train MAE: 0.009428 | val MAE: 0.010293 | time: 1.61s
# Epoch 354 | train MAE: 0.008376 | val MAE: 0.010212 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 355
# Epoch 355 | train MAE: 0.011815 | val MAE: 0.010569 | time: 1.61s
# Epoch 356 | train MAE: 0.011643 | val MAE: 0.010631 | time: 1.64s
# Epoch 357 | train MAE: 0.009632 | val MAE: 0.010289 | time: 1.63s
# Epoch 358 | train MAE: 0.011064 | val MAE: 0.009045 | time: 1.60s
# Epoch 359 | train MAE: 0.011123 | val MAE: 0.011499 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 360
# Epoch 360 | train MAE: 0.007694 | val MAE: 0.009946 | time: 1.63s
# Epoch 361 | train MAE: 0.010149 | val MAE: 0.010657 | time: 1.65s
# Epoch 362 | train MAE: 0.010912 | val MAE: 0.012024 | time: 1.59s
# Epoch 363 | train MAE: 0.009882 | val MAE: 0.009431 | time: 1.67s
# Epoch 364 | train MAE: 0.007050 | val MAE: 0.009717 | time: 1.61s
# 😴 Cooling GPU: sleeping 5s after epoch 365
# Epoch 365 | train MAE: 0.010460 | val MAE: 0.009932 | time: 1.63s
# Epoch 366 | train MAE: 0.009007 | val MAE: 0.009365 | time: 1.58s
# Epoch 367 | train MAE: 0.009319 | val MAE: 0.010710 | time: 1.61s
# Epoch 368 | train MAE: 0.010491 | val MAE: 0.011144 | time: 1.65s
# Epoch 369 | train MAE: 0.010990 | val MAE: 0.009771 | time: 1.64s
# 😴 Cooling GPU: sleeping 5s after epoch 370
# Epoch 370 | train MAE: 0.009166 | val MAE: 0.010860 | time: 1.59s
# Epoch 371 | train MAE: 0.009852 | val MAE: 0.010076 | time: 1.61s
# Epoch 372 | train MAE: 0.010298 | val MAE: 0.010397 | time: 1.60s
# Epoch 373 | train MAE: 0.009654 | val MAE: 0.012830 | time: 1.67s
# Epoch 374 | train MAE: 0.010173 | val MAE: 0.010498 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 375
# Epoch 375 | train MAE: 0.009724 | val MAE: 0.010672 | time: 1.61s
# Epoch 376 | train MAE: 0.013031 | val MAE: 0.011937 | time: 1.61s
# Epoch 377 | train MAE: 0.014894 | val MAE: 0.012873 | time: 1.60s
# Epoch 378 | train MAE: 0.010100 | val MAE: 0.010963 | time: 1.62s
# Epoch 379 | train MAE: 0.008835 | val MAE: 0.007515 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 380
# Epoch 380 | train MAE: 0.007377 | val MAE: 0.009050 | time: 1.60s
# Epoch 381 | train MAE: 0.009449 | val MAE: 0.011262 | time: 1.62s
# Epoch 382 | train MAE: 0.007510 | val MAE: 0.009644 | time: 1.60s
# Epoch 383 | train MAE: 0.011210 | val MAE: 0.012159 | time: 1.61s
# Epoch 384 | train MAE: 0.007072 | val MAE: 0.008039 | time: 1.59s
# 😴 Cooling GPU: sleeping 5s after epoch 385
# Epoch 385 | train MAE: 0.009379 | val MAE: 0.009949 | time: 1.59s
# Epoch 386 | train MAE: 0.009216 | val MAE: 0.011251 | time: 1.65s
# Epoch 387 | train MAE: 0.010245 | val MAE: 0.010625 | time: 1.61s
# Epoch 388 | train MAE: 0.009055 | val MAE: 0.010097 | time: 1.59s
# Epoch 389 | train MAE: 0.008198 | val MAE: 0.011760 | time: 1.66s
# 😴 Cooling GPU: sleeping 5s after epoch 390
# Epoch 390 | train MAE: 0.009645 | val MAE: 0.010727 | time: 1.64s
# Epoch 391 | train MAE: 0.012002 | val MAE: 0.012780 | time: 1.68s
# Epoch 392 | train MAE: 0.008833 | val MAE: 0.008101 | time: 1.65s
# Epoch 393 | train MAE: 0.009653 | val MAE: 0.011844 | time: 1.61s
# Epoch 394 | train MAE: 0.015884 | val MAE: 0.014597 | time: 1.69s
# 😴 Cooling GPU: sleeping 5s after epoch 395
# Epoch 395 | train MAE: 0.008358 | val MAE: 0.009508 | time: 1.61s
# Epoch 396 | train MAE: 0.013243 | val MAE: 0.009284 | time: 1.59s
# Epoch 397 | train MAE: 0.013818 | val MAE: 0.012392 | time: 1.62s
# Epoch 398 | train MAE: 0.009512 | val MAE: 0.009833 | time: 1.62s
# Epoch 399 | train MAE: 0.016674 | val MAE: 0.013826 | time: 1.63s
# 😴 Cooling GPU: sleeping 5s after epoch 400
# `Trainer.fit` stopped: `max_epochs=400` reached.
# CPU times: user 10min 14s, sys: 3min 36s, total: 13min 51s
# Wall time: 17min 23s

# %% [markdown]
# #### Save the training history

# %%
CHECKPOINT_PATH
# Out:
# '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take5'

# %%
train_loss = np.array(plot_cb.train_losses, dtype=np.float32)
val_loss   = np.array(plot_cb.val_losses,   dtype=np.float32)
epochs = np.arange(1, len(train_loss) + 1, dtype=np.int32)

# %%
df = pd.DataFrame({
    "epoch": epochs,
    "train_loss": train_loss,
    "val_loss": val_loss,
})

df.to_csv(f"{CHECKPOINT_PATH}/training_history.csv", index=False)

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# best-379-0.007515.ckpt  last.ckpt  training_history.csv

# %%
plt.plot(epochs, train_loss, label="train")
plt.plot(epochs, val_loss, label="val")
plt.xlabel("epoch")
plt.ylabel("MAE")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluation

# %%
test_ds = NumpyDataset(X_test_scaled, y_test)
test_loader   = DataLoader(test_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
x0, y0 = test_ds[0]
print(x0.shape)   # torch.Size([5, 64, 64])
print(y0.shape)   # torch.Size([6])
# Out:
# torch.Size([5, 64, 64])
# torch.Size([6])

# %%
def get_test_predictions(model, test_loader, device):
    model.eval()

    y_true_list = []
    y_pred_list = []

    with torch.no_grad():
        for xb, yb in test_loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)

            y_hat = model(xb)          # (B, 6)

            y_true_list.append(yb.cpu().numpy())
            y_pred_list.append(y_hat.cpu().numpy())

    y_true = np.concatenate(y_true_list, axis=0)  # (N_test, 6)
    y_pred = np.concatenate(y_pred_list, axis=0)  # (N_test, 6)

    return y_true, y_pred

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# best-379-0.007515.ckpt  last.ckpt  training_history.csv

# %%
best_ckpt = f"{CHECKPOINT_PATH}/best-379-0.007515.ckpt"
lit_model = LitCNN.load_from_checkpoint(
    best_ckpt,
    model=CNNModelKerasEquivalent(),  # 🔴 구조 동일해야 함
)

# %%
# %%time
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
y_test_true, y_test_pred = get_test_predictions(lit_model, test_loader, device)
# Out:
# CPU times: user 147 ms, sys: 180 ms, total: 327 ms
# Wall time: 292 ms

# %%
print(y_test_true.shape)  # (N_test, 6)
print(y_test_pred.shape)  # (N_test, 6)
# Out:
# (4000, 6)
# (4000, 6)

# %%
mae = np.mean(np.abs(y_test_pred - y_test_true), axis=0)
print("Test MAE per y:", mae)
print("Test MAE mean :", mae.mean())
# Out:
# Test MAE per y: [0.01660515 0.00733061 0.00517687 0.00427779 0.0050172  0.00676486]
# Test MAE mean : 0.007528745

# %%
import matplotlib as mpl
import seaborn as sns

sns.reset_defaults()                 # seaborn 스타일 제거
mpl.rcParams.update(mpl.rcParamsDefault)  # matplotlib 완전 초기화

# %%
import matplotlib as mpl

mpl.rcParams.update({
    "font.family": "serif",
    "font.size": 14,        # 기본 폰트
    "axes.titlesize": 16,   # subplot title
    "axes.labelsize": 14,   # x,y label
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12,
})

# %%
def plot_error_histograms(err, bins=50):
    """
    err shape: (N, 6)
    """
    fig, axes = plt.subplots(2, 3, figsize=(10, 6))
    axes = axes.ravel()

    # symmetric range for fair comparison
    vmin = err.min()
    vmax = err.max()
    vmax = max(abs(vmin), abs(vmax))
    hist_range = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        ax.hist(
            err[:, i],
            bins=bins,
            range=hist_range,
            alpha=0.8
        )

        ax.axvline(0, color="k", linestyle="--", linewidth=1)
        ax.set_title(f"y{i} error")
        ax.set_xlabel("prediction - truth")
        ax.set_ylabel("count")

    fig.suptitle("Test error distribution (y_pred - y_true)", fontsize=12)
    fig.tight_layout()
    plt.show()

# %%
err = y_test_pred - y_test_true
print(err.shape)
# Out:
# (4000, 6)

# %%
plot_error_histograms(err,bins=200)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(
    style="whitegrid",     # 🔹 whitegrid → white
    context="talk",
    font="serif"
)

# %%
import numpy as np

def plot_error_histograms_seaborn(err, bins=40):
    """
    err shape: (N_test, 6)
    """
    fig, axes = plt.subplots(3, 2, figsize=(15, 12))
    axes = axes.ravel()

    # symmetric x-range
    vmin = err.min()
    vmax = err.max()
    vmax = max(abs(vmin), abs(vmax))
    xlim = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        sns.histplot(
            err[:, i],
            bins=bins,
            stat="count",     # 🔹 COUNT, not density
            kde=False,        # 🔹 no curve
            color="tab:blue",
            alpha=0.8,
            ax=ax
        )

        # zero reference
        ax.axvline(0, color="black", linestyle="--", linewidth=1.5)

        # metrics
        mae  = np.mean(np.abs(err[:, i]))
        rmse = np.sqrt(np.mean(err[:, i] ** 2))

        ax.text(
            0.03, 0.97,
            f"MAE  = {mae:.4f}\nRMSE = {rmse:.4f}",
            transform=ax.transAxes,
            va="top",
            ha="left",
            fontsize=14,
            bbox=dict(boxstyle="round", fc="white", alpha=0.9)
        )

        ax.set_xlim(xlim)
        ax.set_title(f"y{i} error", fontsize=16)
        ax.set_xlabel("prediction − truth", fontsize=14)
        ax.set_ylabel("count", fontsize=14)

    fig.suptitle(
        "Test error distribution (histogram, count)",
        fontsize=20,
        y=0.98
    )

    fig.tight_layout()
    plt.show()

# %%
plot_error_histograms_seaborn(err,bins=200)
