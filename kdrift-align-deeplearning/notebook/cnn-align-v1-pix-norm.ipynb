# %% [markdown]
# # PyTorch DL for KDRIFT G1 Alignment
#
# - EDA the training set
# - Train using the baseline by the student's work

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
#import tensorflow as tf
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense, SimpleRNN, Conv2D, MaxPooling2D, Flatten
import os
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
#from tensorflow.keras import backend as K
from tqdm import trange, notebook
#from livelossplot import PlotLossesKeras

# %% [markdown]
# ## Browsing the working directories

# %%
# %pwd
# Out:
# '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/notebook'

# %%
# %ls
# Out:
# cnn-align-v1-no-rescale.ipynb
# cnn-align-v1-pix-norm.ipynb
# cnn-align-v2-image-norm.ipynb
# cnn-align-v3-image-abs-norm.ipynb
# cnn-align-v4-image-both-sign-norm-Copy1.ipynb
# cnn-align-v4a-image-both-sign-norm.ipynb
# cnn-align-v5-image-fixed-max-norm.ipynb
# lightning_logs/
# vit-align-v1.ipynb

# %%
data_path = '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/data/'

# %%
# !ls {data_path}
# Out:
# X_f32.npy  y_f32.npy

# %% [markdown]
# ## Explore the training set

# %%
# %%time
X = np.load(data_path+'X_f32.npy')
y = np.load(data_path+'y_f32.npy')
# Out:
# CPU times: user 858 µs, sys: 217 ms, total: 218 ms
# Wall time: 217 ms

# %%
len(y),len(X)
# Out:
# (20000, 20000)

# %%
def np_array_info(a):
    print(f"shape     : {a.shape}")
    print(f"dtype     : {a.dtype}")
    print(f"ndim      : {a.ndim}")
    print(f"size      : {a.size}")
    print(f"itemsize  : {a.itemsize} bytes")
    print(f"nbytes    : {a.nbytes / 1024**2:.2f} MB")
    print(f"min / max : {a.min()} / {a.max()}")

# %%
np_array_info(y)
# Out:
# shape     : (20000, 6)
# dtype     : float32
# ndim      : 2
# size      : 120000
# itemsize  : 4 bytes
# nbytes    : 0.46 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(X)
# Out:
# shape     : (20000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 409600000
# itemsize  : 4 bytes
# nbytes    : 1562.50 MB
# min / max : -44.47488021850586 / 41.380958557128906

# %% [markdown]
# > I may need learn about what `X` and `y` mean. I am an instrument noob.

# %% [markdown]
# #### Visualize the training set

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_trainingsample(X, y, selected_index_list):
    n_samples = len(selected_index_list)
    n_views = X.shape[1]

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2)
    )

    vmin, vmax = X.min(), X.max()
    im = None

    for row, idx in enumerate(selected_index_list):
        for j in range(n_views):
            ax = axes[row, j]
            img = X[idx, j, :, :, 0]

            im = ax.imshow(
                img,
                cmap="rainbow",
                vmin=vmin,
                vmax=vmax,
                aspect="equal"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            if row == 0:
                ax.set_title(f"image {j+1}")

            # --- min / max labels (항상 포함)
            img_min = img.min()
            img_max = img.max()

            labels = [
                f"min: {img_min:.2f}",
                f"max: {img_max:.2f}",
            ]

            # --- image 1 패널에는 y 값도 같이 추가
            if y is not None and j == 0:
                yvals = y[idx]
                labels += [
                    f"y{i+1}: {val:.3f}" for i, val in enumerate(yvals)
                ]
                ax.set_ylabel(f"idx {idx}")

            handles = [
                plt.Line2D([0], [0], color="none", label=lab)
                for lab in labels
            ]

            ax.legend(
                handles=handles,
                loc="upper left" if j == 0 else "upper right",
                fontsize=7 if j != 0 else 8,
                frameon=True,
                borderpad=0.3,
                handlelength=0,
                handletextpad=0
            )

    fig.subplots_adjust(
        bottom=0.12,
        hspace=0.05,
        wspace=0.02
    )

    fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02
    )

    plt.show()

# %%
selected_index_list = [0, 5, 12, 128, 2048, 9999, 15000, 19999]
plot_trainingsample(X, y, selected_index_list)

# %% [markdown]
# ## PyTorching the Model

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
import pytorch_lightning as pl
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import torchvision
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from torchvision import transforms
from torchvision.datasets import CIFAR10

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce RTX 3090 (UUID: GPU-81ef84f4-69df-ce9c-b89c-0b05c8f72ebf)

# %%
#%load_ext tensorboard
# I will not use tensorboard .. though..

# %%
# Setting the seed
pl.seed_everything(42)

# Ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Seed set to 42

# %% [markdown]
# #### Checkpoints

# %%
CHECKPOINT_ROOT = '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/'

# %%
from time import gmtime, strftime

base_name = 'cnn'
#try_name = strftime('%Y.%m.%d_%H:%M', gmtime())
try_name = 'take1'
experiment_name = f"{base_name}_{try_name}"
print("experiment:", experiment_name)
# Out:
# experiment: cnn_take1

# %%
import os
import shutil

CHECKPOINT_PATH = os.path.join(CHECKPOINT_ROOT, experiment_name)

if os.path.exists(CHECKPOINT_PATH):
    print(f"⚠️ Directory exists: {CHECKPOINT_PATH}")
    print("🧹 Removing all contents...")

    # Clear all files/subfolders inside the directory
    for filename in os.listdir(CHECKPOINT_PATH):
        file_path = os.path.join(CHECKPOINT_PATH, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print(f"❌ Failed to delete {file_path}: {e}")

    print("✅ Directory has been cleared.")
else:
    os.makedirs(CHECKPOINT_PATH)
    print(f"✅ Directory created: {CHECKPOINT_PATH}")

print(f"📂 Experiment directory is ready: {os.path.abspath(CHECKPOINT_PATH)}")
# Out:
# ⚠️ Directory exists: /app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take1
# 🧹 Removing all contents...
# ✅ Directory has been cleared.
# 📂 Experiment directory is ready: /app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take1

# %% [markdown]
# ### Follow the min/max/scaler of the original keras code for reproduction

# %%
num_samples = len(y)
print(num_samples)
# Out:
# 20000

# %%
indices=range(num_samples)

# %%
X_train, X_test, y_train, y_test, train_indices, test_indices = \
train_test_split(X, y, indices, test_size=0.2, random_state=42)

# %%
# %%time
X_train_train, X_train_val, \
y_train_train, y_train_val, \
train_train_indices, train_val_indices = \
    train_test_split(
        X_train,
        y_train,
        train_indices,
        test_size=0.2,
        random_state=42
    )
# Out:
# CPU times: user 60.9 ms, sys: 72.4 ms, total: 133 ms
# Wall time: 132 ms

# %%
np_array_info(X_train_train)
# Out:
# shape     : (12800, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 262144000
# itemsize  : 4 bytes
# nbytes    : 1000.00 MB
# min / max : -44.47488021850586 / 38.766319274902344

# %%
np_array_info(X_train_val)
# Out:
# shape     : (3200, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 65536000
# itemsize  : 4 bytes
# nbytes    : 250.00 MB
# min / max : -40.51784896850586 / 41.380958557128906

# %%
np_array_info(X_test)
# Out:
# shape     : (4000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 81920000
# itemsize  : 4 bytes
# nbytes    : 312.50 MB
# min / max : -38.55973815917969 / 38.85308074951172

# %%
train_indices[:12]
# Out:
# [5894, 3728, 8958, 7671, 5999, 5751, 1688, 6836, 6536, 4842, 15844, 196]

# %%
train_train_indices[:12]
# Out:
# [252, 18632, 19138, 1673, 17688, 8687, 17425, 11006, 4157, 3440, 1690, 5485]

# %%
train_val_indices[:12]
# Out:
# [17353, 16081, 8282, 1113, 9546, 9413, 7775, 9407, 964, 13581, 6553, 4659]

# %%
test_indices[:12]
# Out:
# [10650, 2041, 8668, 1114, 13902, 11963, 11072, 3002, 19771, 8115, 3525, 7879]

# %% [markdown]
# #### normalization by scaler

# %%
# %%time
scaler = MinMaxScaler()
X_train_train_reshaped = X_train_train.reshape(-1, 64*64)
scaler.fit(X_train_train_reshaped)
X_train_train_scaled = scaler.transform(X_train_train_reshaped).reshape(-1, 5, 64, 64, 1)
# Out:
# CPU times: user 348 ms, sys: 54.5 ms, total: 403 ms
# Wall time: 401 ms

# %%
X_train_val_reshaped = X_train_val.reshape(-1, 64*64)
scaler.fit(X_train_val_reshaped)
X_train_val_scaled = scaler.transform(X_train_val_reshaped).reshape(-1, 5, 64, 64, 1)

# %%
X_test_reshaped = X_test.reshape(-1, 64*64)
scaler.fit(X_test_reshaped)
X_test_scaled = scaler.transform(X_test_reshaped).reshape(-1, 5, 64, 64, 1)

# %% [markdown]
# #### Plot the rescaled Training Sample
#
# - this could be wrong?!?

# %%
plot_trainingsample(X_train_train_scaled, y,[0,1,2,3,4])

# %%
plot_trainingsample(X_train_val_scaled, y,[0,1,2,3,4])

# %%
plot_trainingsample(X_test_scaled, y,[0,1,2,3,4])

# %%
np_array_info(X_train_train_scaled)
# Out:
# shape     : (12800, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 262144000
# itemsize  : 4 bytes
# nbytes    : 1000.00 MB
# min / max : 0.0 / 1.0000001192092896

# %%
np_array_info(X_train_val_scaled)
# Out:
# shape     : (3200, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 65536000
# itemsize  : 4 bytes
# nbytes    : 250.00 MB
# min / max : 0.0 / 1.0000001192092896

# %%
np_array_info(X_test_scaled)
# Out:
# shape     : (4000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 81920000
# itemsize  : 4 bytes
# nbytes    : 312.50 MB
# min / max : 0.0 / 1.0000001192092896

# %%
np_array_info(y_train_train)
# Out:
# shape     : (12800, 6)
# dtype     : float32
# ndim      : 2
# size      : 76800
# itemsize  : 4 bytes
# nbytes    : 0.29 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(y_train_val)
# Out:
# shape     : (3200, 6)
# dtype     : float32
# ndim      : 2
# size      : 19200
# itemsize  : 4 bytes
# nbytes    : 0.07 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
np_array_info(y_test)
# Out:
# shape     : (4000, 6)
# dtype     : float32
# ndim      : 2
# size      : 24000
# itemsize  : 4 bytes
# nbytes    : 0.09 MB
# min / max : -0.6000000238418579 / 0.6000000238418579

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_y_histograms_splits(y_train_train, y_train_val, y_test, bins=50):
    """
    y_* shape: (N, 6)
    """

    fig, axes = plt.subplots(2, 3, figsize=(12, 7))
    axes = axes.ravel()

    # symmetric range across ALL splits
    all_y = np.concatenate([y_train_train, y_train_val, y_test], axis=0)
    vmin = all_y.min()
    vmax = all_y.max()
    vmax = max(abs(vmin), abs(vmax))
    hist_range = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        ax.hist(
            y_train_train[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='r',
            alpha=0.2,
            label="train"
        )
        ax.hist(
            y_train_val[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='g',
            alpha=0.2,
            label="val"
        )
        ax.hist(
            y_test[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='b',
            alpha=0.2,
            label="test"
        )

        ax.axvline(0, color="k", linestyle="--", linewidth=1)
        ax.set_title(f"y{i}")
        ax.set_xlabel("value")
        ax.set_ylabel("density")

        if i == 0:
            ax.legend()

    fig.suptitle("Distribution of y components (train / val / test)", fontsize=13)
    fig.tight_layout()
    plt.show()

# %%
plot_y_histograms_splits(y_train_train, y_train_val, y_test)

# %% [markdown]
# ## Train the CNN model

# %%
class CNNModelKerasEquivalent(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            # Conv2D(32,(1,1), relu, input_shape=(5,64,64), channels_first)
            nn.Conv2d(in_channels=5, out_channels=32, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # Conv2D(64,(3,3), relu)  (padding='valid' in Keras -> padding=0 in PyTorch)
            nn.Conv2d(32, 64, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(2,2), relu)
            nn.Conv2d(64, 32, kernel_size=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(1,1), relu)
            nn.Conv2d(32, 32, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),

            # Conv2D(32,(1,1), relu)
            nn.Conv2d(32, 32, kernel_size=1),
            nn.ReLU(inplace=True),

            nn.Flatten(),                 # Keras Flatten()
            nn.Linear(32 * 3 * 3, 128),   # 계산 결과: 64->32->30->15->14->7->3 => 32*3*3
            nn.ReLU(inplace=True),
            nn.Linear(128, 6)             # Dense(6)
        )

    def forward(self, x):
        return self.net(x)

# %%
from torch.utils.data import Dataset, DataLoader

class NumpyDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        x = torch.from_numpy(self.X[idx]).float()  # (5,64,64)
        x = x.squeeze(-1) # if (5,64,64,1)
        t = torch.from_numpy(self.y[idx]).float()  # (6,)
        return x, t

# %%
train_ds = NumpyDataset(X_train_train_scaled, y_train_train)
val_ds   = NumpyDataset(X_train_val_scaled,   y_train_val)

# %%
x0, y0 = train_ds[0]
print(x0.shape)   # torch.Size([5, 64, 64])
print(y0.shape)   # torch.Size([6])
# Out:
# torch.Size([5, 64, 64])
# torch.Size([6])

# %%
train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
xb, yb = next(iter(train_loader))
print("xb.shape:", xb.shape)
print("yb.shape:", yb.shape)
print("xb.dtype:", xb.dtype)
# Out:
# xb.shape: torch.Size([32, 5, 64, 64])
# yb.shape: torch.Size([32, 6])
# xb.dtype: torch.float32

# %% [markdown]
# #### Visualize the training dataloader as a sanity check

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow",
                                   linewidth=0.5, vmin=None, vmax=None):
    """
    xb: torch.Tensor, shape (B, 5, 64, 64)
    n_samples: number of rows (samples)
    ngrid: number of grid cells per axis (e.g., 16 => patch size 4 for 64x64)
    """
    # tensor -> numpy
    x = xb[:n_samples].detach().cpu().numpy()  # (n_samples, 5, 64, 64)
    n_samples = x.shape[0]
    n_views = x.shape[1]
    H, W = x.shape[2], x.shape[3]

    assert H % ngrid == 0 and W % ngrid == 0, f"H,W must be divisible by ngrid. got {H},{W}, ngrid={ngrid}"
    patch_h = H // ngrid
    patch_w = W // ngrid

    # global color scale (consistent across all panels)
    if vmin is None:
        vmin = float(x.min())
    if vmax is None:
        vmax = float(x.max())

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2),
        constrained_layout=False
    )

    # in case n_samples == 1
    if n_samples == 1:
        axes = np.expand_dims(axes, axis=0)

    im = None
    for i in range(n_samples):
        for j in range(n_views):
            ax = axes[i, j]
            img = x[i, j]  # (64,64)

            im = ax.imshow(
                img,
                cmap=cmap,
                vmin=vmin,
                vmax=vmax,
                aspect="equal",
                interpolation="nearest"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            # column titles
            if i == 0:
                ax.set_title(f"ch {j}", fontsize=11)

            # row labels
            if j == 0:
                ax.set_ylabel(f"sample {i}", fontsize=11)

            # draw patch grid boundaries
            for gy in range(0, H + 1, patch_h):
                ax.axhline(gy - 0.5, color="w", linewidth=linewidth, alpha=0.9)
            for gx in range(0, W + 1, patch_w):
                ax.axvline(gx - 0.5, color="w", linewidth=linewidth, alpha=0.9)

    # tighter spacing + bottom colorbar
    fig.subplots_adjust(bottom=0.08, hspace=0.02, wspace=0.02)

    cbar = fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02
    )
    cbar.set_label("pixel value")

    plt.show()

# %%
plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow")

# %%
xb, yb = next(iter(val_loader))
print("xb.shape:", xb.shape)
print("yb.shape:", yb.shape)
print("xb.dtype:", xb.dtype)
# Out:
# xb.shape: torch.Size([32, 5, 64, 64])
# yb.shape: torch.Size([32, 6])
# xb.dtype: torch.float32

# %%
plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow")

# %%
import time
import matplotlib.pyplot as plt
from pytorch_lightning.callbacks import Callback

class PlotLossesPL(Callback):
    def __init__(self):
        self.train_losses = []
        self.val_losses = []
        self.epoch_times = []

    def on_train_epoch_start(self, trainer, pl_module):
        self.epoch_start_time = time.time()

    def on_train_epoch_end(self, trainer, pl_module):
        epoch_time = time.time() - self.epoch_start_time
        self.epoch_times.append(epoch_time)

        train_loss = trainer.callback_metrics.get("train_loss")
        val_loss   = trainer.callback_metrics.get("val_loss")

        if train_loss is not None:
            self.train_losses.append(train_loss.item())
        if val_loss is not None:
            self.val_losses.append(val_loss.item())

        print(
            f"Epoch {trainer.current_epoch:03d} | "
            f"train MAE: {self.train_losses[-1]:.6f} | "
            f"val MAE: {self.val_losses[-1]:.6f} | "
            f"time: {epoch_time:.2f}s"
        )

    def on_fit_end(self, trainer, pl_module):
        self.plot()

    def plot(self):
        plt.figure(figsize=(6,4))
        plt.plot(self.train_losses, label="train")
        plt.plot(self.val_losses, label="val")
        plt.xlabel("epoch")
        plt.ylabel("MAE")
        plt.legend()
        plt.tight_layout()
        plt.show()

# %%
import time
from pytorch_lightning.callbacks import Callback

class GPUSleepCallback(Callback):
    def __init__(self, every_n_epochs=5, sleep_seconds=5):
        self.every_n_epochs = every_n_epochs
        self.sleep_seconds = sleep_seconds

    def on_train_epoch_end(self, trainer, pl_module):
        epoch = trainer.current_epoch + 1  # 1-based로 보기 좋게
        if epoch % self.every_n_epochs == 0:
            print(f"😴 Cooling GPU: sleeping {self.sleep_seconds}s after epoch {epoch}")
            time.sleep(self.sleep_seconds)

# %%
import os
from pytorch_lightning.callbacks import ModelCheckpoint

#ckpt_dir = "/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take1"
ckpt_dir = CHECKPOINT_PATH

checkpoint_cb = ModelCheckpoint(
    dirpath=ckpt_dir,
    filename="best-{epoch:03d}-{val_loss:.6f}",  # 파일명 템플릿
    monitor="val_loss",                          # 우리가 log한 키
    mode="min",                                  # 최소가 best
    save_top_k=1,                                # best 1개만 유지
    save_last=True,                              # last.ckpt도 저장
    auto_insert_metric_name=False
)

# %%
import pytorch_lightning as pl
import torch
import torch.nn as nn

class LitCNN(pl.LightningModule):
    def __init__(self, model, lr=1e-3):
        super().__init__()
        self.model = model
        self.criterion = nn.L1Loss()
        self.lr = lr

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.log("train_loss", loss, prog_bar=False)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.log("val_loss", loss, prog_bar=False)
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.lr)

# %%
from pytorch_lightning.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=100,
    mode="min"
)

# %%
from pytorch_lightning import Trainer

plot_cb = PlotLossesPL()
gpu_sleep_cb = GPUSleepCallback(every_n_epochs=5, sleep_seconds=5)

trainer = Trainer(
    max_epochs=400,
    callbacks=[plot_cb, checkpoint_cb, gpu_sleep_cb],
    enable_progress_bar=False,
    enable_model_summary=False,
    accelerator="gpu" if torch.cuda.is_available() else "cpu",
    devices=1,
    log_every_n_steps=999999
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
# %%time
trainer.fit(
    model=LitCNN(CNNModelKerasEquivalent()),
    train_dataloaders=train_loader,
    val_dataloaders=val_loader
)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:317: The number of training batches (400) is smaller than the logging interval Trainer(log_every_n_steps=999999). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 000 | train MAE: 0.189272 | val MAE: 0.196092 | time: 1.46s
# Epoch 001 | train MAE: 0.103342 | val MAE: 0.138853 | time: 1.52s
# Epoch 002 | train MAE: 0.102861 | val MAE: 0.119801 | time: 1.53s
# Epoch 003 | train MAE: 0.078135 | val MAE: 0.102163 | time: 1.58s
# Epoch 004 | train MAE: 0.097560 | val MAE: 0.100861 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 5
# Epoch 005 | train MAE: 0.075575 | val MAE: 0.094931 | time: 1.51s
# Epoch 006 | train MAE: 0.069291 | val MAE: 0.093969 | time: 1.52s
# Epoch 007 | train MAE: 0.048609 | val MAE: 0.066946 | time: 1.48s
# Epoch 008 | train MAE: 0.043665 | val MAE: 0.070588 | time: 1.47s
# Epoch 009 | train MAE: 0.018726 | val MAE: 0.055319 | time: 1.49s
# 😴 Cooling GPU: sleeping 5s after epoch 10
# Epoch 010 | train MAE: 0.018700 | val MAE: 0.052627 | time: 1.55s
# Epoch 011 | train MAE: 0.020027 | val MAE: 0.044404 | time: 1.51s
# Epoch 012 | train MAE: 0.020694 | val MAE: 0.044758 | time: 1.53s
# Epoch 013 | train MAE: 0.018505 | val MAE: 0.045815 | time: 1.55s
# Epoch 014 | train MAE: 0.025347 | val MAE: 0.050059 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 15
# Epoch 015 | train MAE: 0.013809 | val MAE: 0.052830 | time: 1.47s
# Epoch 016 | train MAE: 0.016215 | val MAE: 0.042939 | time: 1.53s
# Epoch 017 | train MAE: 0.012926 | val MAE: 0.046548 | time: 1.50s
# Epoch 018 | train MAE: 0.012625 | val MAE: 0.045055 | time: 1.53s
# Epoch 019 | train MAE: 0.021709 | val MAE: 0.048421 | time: 1.49s
# 😴 Cooling GPU: sleeping 5s after epoch 20
# Epoch 020 | train MAE: 0.018209 | val MAE: 0.048913 | time: 1.48s
# Epoch 021 | train MAE: 0.012850 | val MAE: 0.047670 | time: 1.49s
# Epoch 022 | train MAE: 0.014261 | val MAE: 0.047437 | time: 1.55s
# Epoch 023 | train MAE: 0.014445 | val MAE: 0.043807 | time: 1.49s
# Epoch 024 | train MAE: 0.013829 | val MAE: 0.043873 | time: 1.49s
# 😴 Cooling GPU: sleeping 5s after epoch 25
# Epoch 025 | train MAE: 0.016368 | val MAE: 0.042439 | time: 1.51s
# Epoch 026 | train MAE: 0.012278 | val MAE: 0.046067 | time: 1.50s
# Epoch 027 | train MAE: 0.012536 | val MAE: 0.043862 | time: 1.52s
# Epoch 028 | train MAE: 0.012454 | val MAE: 0.043633 | time: 1.53s
# Epoch 029 | train MAE: 0.013076 | val MAE: 0.044473 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 30
# Epoch 030 | train MAE: 0.010667 | val MAE: 0.047528 | time: 1.53s
# Epoch 031 | train MAE: 0.010904 | val MAE: 0.046930 | time: 1.47s
# Epoch 032 | train MAE: 0.016705 | val MAE: 0.043584 | time: 1.50s
# Epoch 033 | train MAE: 0.012463 | val MAE: 0.047596 | time: 1.54s
# Epoch 034 | train MAE: 0.012424 | val MAE: 0.045224 | time: 1.48s
# 😴 Cooling GPU: sleeping 5s after epoch 35
# Epoch 035 | train MAE: 0.012529 | val MAE: 0.047421 | time: 1.48s
# Epoch 036 | train MAE: 0.013225 | val MAE: 0.042907 | time: 1.52s
# Epoch 037 | train MAE: 0.008892 | val MAE: 0.043718 | time: 1.52s
# Epoch 038 | train MAE: 0.010473 | val MAE: 0.045053 | time: 1.52s
# Epoch 039 | train MAE: 0.010397 | val MAE: 0.043677 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 40
# Epoch 040 | train MAE: 0.011194 | val MAE: 0.044257 | time: 1.52s
# Epoch 041 | train MAE: 0.012386 | val MAE: 0.041081 | time: 1.52s
# Epoch 042 | train MAE: 0.015083 | val MAE: 0.044936 | time: 1.49s
# Epoch 043 | train MAE: 0.011671 | val MAE: 0.043532 | time: 1.52s
# Epoch 044 | train MAE: 0.010441 | val MAE: 0.045250 | time: 1.50s
# 😴 Cooling GPU: sleeping 5s after epoch 45
# Epoch 045 | train MAE: 0.008502 | val MAE: 0.043323 | time: 1.52s
# Epoch 046 | train MAE: 0.013865 | val MAE: 0.045112 | time: 1.52s
# Epoch 047 | train MAE: 0.009414 | val MAE: 0.044152 | time: 1.54s
# Epoch 048 | train MAE: 0.011267 | val MAE: 0.046304 | time: 1.52s
# Epoch 049 | train MAE: 0.008180 | val MAE: 0.044670 | time: 1.55s
# 😴 Cooling GPU: sleeping 5s after epoch 50
# Epoch 050 | train MAE: 0.011298 | val MAE: 0.042126 | time: 1.57s
# Epoch 051 | train MAE: 0.012551 | val MAE: 0.044662 | time: 1.51s
# Epoch 052 | train MAE: 0.012031 | val MAE: 0.046748 | time: 1.50s
# Epoch 053 | train MAE: 0.011045 | val MAE: 0.043450 | time: 1.53s
# Epoch 054 | train MAE: 0.018634 | val MAE: 0.044290 | time: 1.49s
# 😴 Cooling GPU: sleeping 5s after epoch 55
# Epoch 055 | train MAE: 0.008006 | val MAE: 0.045691 | time: 1.52s
# Epoch 056 | train MAE: 0.009283 | val MAE: 0.041477 | time: 1.48s
# Epoch 057 | train MAE: 0.009670 | val MAE: 0.044140 | time: 1.50s
# Epoch 058 | train MAE: 0.006950 | val MAE: 0.045613 | time: 1.53s
# Epoch 059 | train MAE: 0.014085 | val MAE: 0.039016 | time: 1.48s
# 😴 Cooling GPU: sleeping 5s after epoch 60
# Epoch 060 | train MAE: 0.010662 | val MAE: 0.045276 | time: 1.51s
# Epoch 061 | train MAE: 0.008231 | val MAE: 0.042576 | time: 1.51s
# Epoch 062 | train MAE: 0.009594 | val MAE: 0.040986 | time: 1.52s
# Epoch 063 | train MAE: 0.008291 | val MAE: 0.044220 | time: 1.50s
# Epoch 064 | train MAE: 0.010030 | val MAE: 0.042537 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 65
# Epoch 065 | train MAE: 0.016984 | val MAE: 0.043965 | time: 1.50s
# Epoch 066 | train MAE: 0.010245 | val MAE: 0.044477 | time: 1.54s
# Epoch 067 | train MAE: 0.013804 | val MAE: 0.046837 | time: 1.55s
# Epoch 068 | train MAE: 0.007768 | val MAE: 0.041098 | time: 1.55s
# Epoch 069 | train MAE: 0.008900 | val MAE: 0.042734 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 70
# Epoch 070 | train MAE: 0.010780 | val MAE: 0.043066 | time: 1.54s
# Epoch 071 | train MAE: 0.008926 | val MAE: 0.043766 | time: 1.47s
# Epoch 072 | train MAE: 0.007810 | val MAE: 0.043662 | time: 1.49s
# Epoch 073 | train MAE: 0.015151 | val MAE: 0.045156 | time: 1.51s
# Epoch 074 | train MAE: 0.008670 | val MAE: 0.044667 | time: 1.51s
# 😴 Cooling GPU: sleeping 5s after epoch 75
# Epoch 075 | train MAE: 0.009211 | val MAE: 0.046260 | time: 1.49s
# Epoch 076 | train MAE: 0.011852 | val MAE: 0.041453 | time: 1.51s
# Epoch 077 | train MAE: 0.008575 | val MAE: 0.040677 | time: 1.49s
# Epoch 078 | train MAE: 0.008094 | val MAE: 0.044788 | time: 1.57s
# Epoch 079 | train MAE: 0.008174 | val MAE: 0.044644 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 80
# Epoch 080 | train MAE: 0.008651 | val MAE: 0.047191 | time: 1.50s
# Epoch 081 | train MAE: 0.007929 | val MAE: 0.041356 | time: 1.55s
# Epoch 082 | train MAE: 0.008485 | val MAE: 0.045994 | time: 1.53s
# Epoch 083 | train MAE: 0.006699 | val MAE: 0.043189 | time: 1.53s
# Epoch 084 | train MAE: 0.007495 | val MAE: 0.045422 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 85
# Epoch 085 | train MAE: 0.008763 | val MAE: 0.039219 | time: 1.56s
# Epoch 086 | train MAE: 0.009395 | val MAE: 0.047908 | time: 1.54s
# Epoch 087 | train MAE: 0.009544 | val MAE: 0.044139 | time: 1.59s
# Epoch 088 | train MAE: 0.008311 | val MAE: 0.043434 | time: 1.50s
# Epoch 089 | train MAE: 0.009942 | val MAE: 0.043838 | time: 1.49s
# 😴 Cooling GPU: sleeping 5s after epoch 90
# Epoch 090 | train MAE: 0.007261 | val MAE: 0.044342 | time: 1.51s
# Epoch 091 | train MAE: 0.008229 | val MAE: 0.046338 | time: 1.54s
# Epoch 092 | train MAE: 0.006467 | val MAE: 0.043148 | time: 1.57s
# Epoch 093 | train MAE: 0.007945 | val MAE: 0.044522 | time: 1.55s
# Epoch 094 | train MAE: 0.008248 | val MAE: 0.043686 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 95
# Epoch 095 | train MAE: 0.006685 | val MAE: 0.043543 | time: 1.52s
# Epoch 096 | train MAE: 0.007390 | val MAE: 0.044201 | time: 1.53s
# Epoch 097 | train MAE: 0.006652 | val MAE: 0.047773 | time: 1.53s
# Epoch 098 | train MAE: 0.010461 | val MAE: 0.044240 | time: 1.53s
# Epoch 099 | train MAE: 0.011559 | val MAE: 0.039512 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 100
# Epoch 100 | train MAE: 0.009871 | val MAE: 0.041709 | time: 1.53s
# Epoch 101 | train MAE: 0.007510 | val MAE: 0.042565 | time: 1.51s
# Epoch 102 | train MAE: 0.009945 | val MAE: 0.044228 | time: 1.50s
# Epoch 103 | train MAE: 0.007570 | val MAE: 0.043415 | time: 1.49s
# Epoch 104 | train MAE: 0.008981 | val MAE: 0.044603 | time: 1.49s
# 😴 Cooling GPU: sleeping 5s after epoch 105
# Epoch 105 | train MAE: 0.007720 | val MAE: 0.043402 | time: 1.51s
# Epoch 106 | train MAE: 0.006898 | val MAE: 0.044085 | time: 1.58s
# Epoch 107 | train MAE: 0.006719 | val MAE: 0.044449 | time: 1.52s
# Epoch 108 | train MAE: 0.011571 | val MAE: 0.045172 | time: 1.55s
# Epoch 109 | train MAE: 0.008466 | val MAE: 0.046158 | time: 1.55s
# 😴 Cooling GPU: sleeping 5s after epoch 110
# Epoch 110 | train MAE: 0.009546 | val MAE: 0.040281 | time: 1.51s
# Epoch 111 | train MAE: 0.007221 | val MAE: 0.042565 | time: 1.53s
# Epoch 112 | train MAE: 0.007595 | val MAE: 0.042725 | time: 1.54s
# Epoch 113 | train MAE: 0.008177 | val MAE: 0.040859 | time: 1.52s
# Epoch 114 | train MAE: 0.009146 | val MAE: 0.043622 | time: 1.51s
# 😴 Cooling GPU: sleeping 5s after epoch 115
# Epoch 115 | train MAE: 0.007324 | val MAE: 0.042193 | time: 1.52s
# Epoch 116 | train MAE: 0.006848 | val MAE: 0.044015 | time: 1.54s
# Epoch 117 | train MAE: 0.007731 | val MAE: 0.044840 | time: 1.51s
# Epoch 118 | train MAE: 0.008237 | val MAE: 0.044606 | time: 1.52s
# Epoch 119 | train MAE: 0.006152 | val MAE: 0.044795 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 120
# Epoch 120 | train MAE: 0.006714 | val MAE: 0.042832 | time: 1.52s
# Epoch 121 | train MAE: 0.007401 | val MAE: 0.041867 | time: 1.56s
# Epoch 122 | train MAE: 0.008918 | val MAE: 0.043827 | time: 1.57s
# Epoch 123 | train MAE: 0.006750 | val MAE: 0.043835 | time: 1.50s
# Epoch 124 | train MAE: 0.008229 | val MAE: 0.045339 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 125
# Epoch 125 | train MAE: 0.007415 | val MAE: 0.043945 | time: 1.56s
# Epoch 126 | train MAE: 0.009554 | val MAE: 0.044357 | time: 1.49s
# Epoch 127 | train MAE: 0.007825 | val MAE: 0.043407 | time: 1.50s
# Epoch 128 | train MAE: 0.007578 | val MAE: 0.045897 | time: 1.50s
# Epoch 129 | train MAE: 0.011588 | val MAE: 0.042583 | time: 1.50s
# 😴 Cooling GPU: sleeping 5s after epoch 130
# Epoch 130 | train MAE: 0.009436 | val MAE: 0.044484 | time: 1.52s
# Epoch 131 | train MAE: 0.008434 | val MAE: 0.045719 | time: 1.57s
# Epoch 132 | train MAE: 0.008614 | val MAE: 0.045484 | time: 1.53s
# Epoch 133 | train MAE: 0.007072 | val MAE: 0.041134 | time: 1.50s
# Epoch 134 | train MAE: 0.006668 | val MAE: 0.042240 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 135
# Epoch 135 | train MAE: 0.006436 | val MAE: 0.044837 | time: 1.53s
# Epoch 136 | train MAE: 0.006927 | val MAE: 0.042744 | time: 1.55s
# Epoch 137 | train MAE: 0.006153 | val MAE: 0.045030 | time: 1.52s
# Epoch 138 | train MAE: 0.007469 | val MAE: 0.043388 | time: 1.51s
# Epoch 139 | train MAE: 0.006138 | val MAE: 0.045551 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 140
# Epoch 140 | train MAE: 0.007040 | val MAE: 0.043223 | time: 1.49s
# Epoch 141 | train MAE: 0.009708 | val MAE: 0.042379 | time: 1.53s
# Epoch 142 | train MAE: 0.006157 | val MAE: 0.044289 | time: 1.53s
# Epoch 143 | train MAE: 0.008554 | val MAE: 0.042826 | time: 1.52s
# Epoch 144 | train MAE: 0.006199 | val MAE: 0.041579 | time: 1.49s
# 😴 Cooling GPU: sleeping 5s after epoch 145
# Epoch 145 | train MAE: 0.006611 | val MAE: 0.045969 | time: 1.61s
# Epoch 146 | train MAE: 0.007938 | val MAE: 0.042998 | time: 1.57s
# Epoch 147 | train MAE: 0.007022 | val MAE: 0.043925 | time: 1.52s
# Epoch 148 | train MAE: 0.008978 | val MAE: 0.043238 | time: 1.53s
# Epoch 149 | train MAE: 0.007696 | val MAE: 0.040507 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 150
# Epoch 150 | train MAE: 0.006750 | val MAE: 0.045661 | time: 1.50s
# Epoch 151 | train MAE: 0.007734 | val MAE: 0.042293 | time: 1.49s
# Epoch 152 | train MAE: 0.007612 | val MAE: 0.043685 | time: 1.55s
# Epoch 153 | train MAE: 0.007721 | val MAE: 0.045668 | time: 1.53s
# Epoch 154 | train MAE: 0.007266 | val MAE: 0.043428 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 155
# Epoch 155 | train MAE: 0.009065 | val MAE: 0.045281 | time: 1.51s
# Epoch 156 | train MAE: 0.007752 | val MAE: 0.045889 | time: 1.50s
# Epoch 157 | train MAE: 0.008209 | val MAE: 0.046681 | time: 1.51s
# Epoch 158 | train MAE: 0.006538 | val MAE: 0.044105 | time: 1.53s
# Epoch 159 | train MAE: 0.006347 | val MAE: 0.043596 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 160
# Epoch 160 | train MAE: 0.009043 | val MAE: 0.045717 | time: 1.57s
# Epoch 161 | train MAE: 0.007114 | val MAE: 0.043464 | time: 1.52s
# Epoch 162 | train MAE: 0.007271 | val MAE: 0.046397 | time: 1.56s
# Epoch 163 | train MAE: 0.007020 | val MAE: 0.043402 | time: 1.50s
# Epoch 164 | train MAE: 0.006065 | val MAE: 0.047542 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 165
# Epoch 165 | train MAE: 0.006892 | val MAE: 0.045464 | time: 1.53s
# Epoch 166 | train MAE: 0.006223 | val MAE: 0.045079 | time: 1.54s
# Epoch 167 | train MAE: 0.006404 | val MAE: 0.045102 | time: 1.51s
# Epoch 168 | train MAE: 0.006081 | val MAE: 0.044511 | time: 1.50s
# Epoch 169 | train MAE: 0.006277 | val MAE: 0.043757 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 170
# Epoch 170 | train MAE: 0.008089 | val MAE: 0.044575 | time: 1.53s
# Epoch 171 | train MAE: 0.005683 | val MAE: 0.045775 | time: 1.54s
# Epoch 172 | train MAE: 0.006078 | val MAE: 0.042987 | time: 1.54s
# Epoch 173 | train MAE: 0.007371 | val MAE: 0.046012 | time: 1.52s
# Epoch 174 | train MAE: 0.006078 | val MAE: 0.043923 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 175
# Epoch 175 | train MAE: 0.007756 | val MAE: 0.043330 | time: 1.55s
# Epoch 176 | train MAE: 0.005821 | val MAE: 0.045140 | time: 1.54s
# Epoch 177 | train MAE: 0.008754 | val MAE: 0.047086 | time: 1.52s
# Epoch 178 | train MAE: 0.008032 | val MAE: 0.043862 | time: 1.53s
# Epoch 179 | train MAE: 0.008141 | val MAE: 0.046227 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 180
# Epoch 180 | train MAE: 0.004976 | val MAE: 0.043062 | time: 1.50s
# Epoch 181 | train MAE: 0.007819 | val MAE: 0.045738 | time: 1.56s
# Epoch 182 | train MAE: 0.006302 | val MAE: 0.047631 | time: 1.55s
# Epoch 183 | train MAE: 0.006460 | val MAE: 0.045365 | time: 1.52s
# Epoch 184 | train MAE: 0.005364 | val MAE: 0.044305 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 185
# Epoch 185 | train MAE: 0.005895 | val MAE: 0.043941 | time: 1.57s
# Epoch 186 | train MAE: 0.008331 | val MAE: 0.046296 | time: 1.52s
# Epoch 187 | train MAE: 0.005383 | val MAE: 0.043398 | time: 1.53s
# Epoch 188 | train MAE: 0.005957 | val MAE: 0.045184 | time: 1.52s
# Epoch 189 | train MAE: 0.007533 | val MAE: 0.043083 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 190
# Epoch 190 | train MAE: 0.004892 | val MAE: 0.046123 | time: 1.53s
# Epoch 191 | train MAE: 0.006647 | val MAE: 0.045270 | time: 1.51s
# Epoch 192 | train MAE: 0.008003 | val MAE: 0.045157 | time: 1.53s
# Epoch 193 | train MAE: 0.006346 | val MAE: 0.043781 | time: 1.53s
# Epoch 194 | train MAE: 0.007238 | val MAE: 0.045855 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 195
# Epoch 195 | train MAE: 0.007304 | val MAE: 0.042743 | time: 1.57s
# Epoch 196 | train MAE: 0.008444 | val MAE: 0.044243 | time: 1.56s
# Epoch 197 | train MAE: 0.006830 | val MAE: 0.043750 | time: 1.51s
# Epoch 198 | train MAE: 0.005631 | val MAE: 0.045034 | time: 1.54s
# Epoch 199 | train MAE: 0.005264 | val MAE: 0.045755 | time: 1.50s
# 😴 Cooling GPU: sleeping 5s after epoch 200
# Epoch 200 | train MAE: 0.007984 | val MAE: 0.043771 | time: 1.52s
# Epoch 201 | train MAE: 0.006291 | val MAE: 0.041850 | time: 1.55s
# Epoch 202 | train MAE: 0.006185 | val MAE: 0.044290 | time: 1.52s
# Epoch 203 | train MAE: 0.005105 | val MAE: 0.044396 | time: 1.53s
# Epoch 204 | train MAE: 0.007928 | val MAE: 0.044009 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 205
# Epoch 205 | train MAE: 0.005357 | val MAE: 0.046198 | time: 1.50s
# Epoch 206 | train MAE: 0.007231 | val MAE: 0.046835 | time: 1.54s
# Epoch 207 | train MAE: 0.005548 | val MAE: 0.043464 | time: 1.57s
# Epoch 208 | train MAE: 0.008581 | val MAE: 0.041958 | time: 1.56s
# Epoch 209 | train MAE: 0.007416 | val MAE: 0.043341 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 210
# Epoch 210 | train MAE: 0.007478 | val MAE: 0.042344 | time: 1.52s
# Epoch 211 | train MAE: 0.005618 | val MAE: 0.045833 | time: 1.50s
# Epoch 212 | train MAE: 0.008797 | val MAE: 0.043360 | time: 1.54s
# Epoch 213 | train MAE: 0.007967 | val MAE: 0.044746 | time: 1.52s
# Epoch 214 | train MAE: 0.007135 | val MAE: 0.043331 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 215
# Epoch 215 | train MAE: 0.006161 | val MAE: 0.044531 | time: 1.55s
# Epoch 216 | train MAE: 0.007347 | val MAE: 0.046482 | time: 1.54s
# Epoch 217 | train MAE: 0.006520 | val MAE: 0.047648 | time: 1.54s
# Epoch 218 | train MAE: 0.006308 | val MAE: 0.047014 | time: 1.47s
# Epoch 219 | train MAE: 0.006983 | val MAE: 0.046450 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 220
# Epoch 220 | train MAE: 0.004840 | val MAE: 0.043221 | time: 1.51s
# Epoch 221 | train MAE: 0.005586 | val MAE: 0.043777 | time: 1.53s
# Epoch 222 | train MAE: 0.006223 | val MAE: 0.045417 | time: 1.51s
# Epoch 223 | train MAE: 0.006143 | val MAE: 0.042477 | time: 1.51s
# Epoch 224 | train MAE: 0.005044 | val MAE: 0.043469 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 225
# Epoch 225 | train MAE: 0.004018 | val MAE: 0.043958 | time: 1.52s
# Epoch 226 | train MAE: 0.005048 | val MAE: 0.044657 | time: 1.58s
# Epoch 227 | train MAE: 0.006794 | val MAE: 0.045708 | time: 1.54s
# Epoch 228 | train MAE: 0.005613 | val MAE: 0.047292 | time: 1.53s
# Epoch 229 | train MAE: 0.005078 | val MAE: 0.043047 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 230
# Epoch 230 | train MAE: 0.004884 | val MAE: 0.043596 | time: 1.52s
# Epoch 231 | train MAE: 0.005516 | val MAE: 0.046760 | time: 1.56s
# Epoch 232 | train MAE: 0.006108 | val MAE: 0.045226 | time: 1.53s
# Epoch 233 | train MAE: 0.005955 | val MAE: 0.042620 | time: 1.52s
# Epoch 234 | train MAE: 0.006501 | val MAE: 0.045455 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 235
# Epoch 235 | train MAE: 0.005337 | val MAE: 0.046259 | time: 1.53s
# Epoch 236 | train MAE: 0.007208 | val MAE: 0.046157 | time: 1.54s
# Epoch 237 | train MAE: 0.006167 | val MAE: 0.043830 | time: 1.56s
# Epoch 238 | train MAE: 0.005997 | val MAE: 0.042184 | time: 1.55s
# Epoch 239 | train MAE: 0.006121 | val MAE: 0.044084 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 240
# Epoch 240 | train MAE: 0.004694 | val MAE: 0.044883 | time: 1.53s
# Epoch 241 | train MAE: 0.008132 | val MAE: 0.045459 | time: 1.51s
# Epoch 242 | train MAE: 0.007274 | val MAE: 0.044456 | time: 1.55s
# Epoch 243 | train MAE: 0.007460 | val MAE: 0.043447 | time: 1.56s
# Epoch 244 | train MAE: 0.007227 | val MAE: 0.045548 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 245
# Epoch 245 | train MAE: 0.008427 | val MAE: 0.044116 | time: 1.52s
# Epoch 246 | train MAE: 0.006392 | val MAE: 0.045557 | time: 1.51s
# Epoch 247 | train MAE: 0.007529 | val MAE: 0.041968 | time: 1.52s
# Epoch 248 | train MAE: 0.007429 | val MAE: 0.048201 | time: 1.52s
# Epoch 249 | train MAE: 0.006681 | val MAE: 0.046023 | time: 1.50s
# 😴 Cooling GPU: sleeping 5s after epoch 250
# Epoch 250 | train MAE: 0.005995 | val MAE: 0.045644 | time: 1.56s
# Epoch 251 | train MAE: 0.005283 | val MAE: 0.043719 | time: 1.53s
# Epoch 252 | train MAE: 0.006432 | val MAE: 0.045521 | time: 1.55s
# Epoch 253 | train MAE: 0.006299 | val MAE: 0.046030 | time: 1.56s
# Epoch 254 | train MAE: 0.005746 | val MAE: 0.046756 | time: 1.55s
# 😴 Cooling GPU: sleeping 5s after epoch 255
# Epoch 255 | train MAE: 0.004696 | val MAE: 0.044249 | time: 1.56s
# Epoch 256 | train MAE: 0.006826 | val MAE: 0.043901 | time: 1.51s
# Epoch 257 | train MAE: 0.005391 | val MAE: 0.044885 | time: 1.54s
# Epoch 258 | train MAE: 0.007406 | val MAE: 0.044243 | time: 1.51s
# Epoch 259 | train MAE: 0.006735 | val MAE: 0.042196 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 260
# Epoch 260 | train MAE: 0.005987 | val MAE: 0.044754 | time: 1.55s
# Epoch 261 | train MAE: 0.005674 | val MAE: 0.042627 | time: 1.49s
# Epoch 262 | train MAE: 0.006180 | val MAE: 0.045891 | time: 1.62s
# Epoch 263 | train MAE: 0.006464 | val MAE: 0.044031 | time: 1.51s
# Epoch 264 | train MAE: 0.006044 | val MAE: 0.044181 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 265
# Epoch 265 | train MAE: 0.004254 | val MAE: 0.044922 | time: 1.51s
# Epoch 266 | train MAE: 0.006694 | val MAE: 0.045888 | time: 1.51s
# Epoch 267 | train MAE: 0.005756 | val MAE: 0.045276 | time: 1.56s
# Epoch 268 | train MAE: 0.006803 | val MAE: 0.044156 | time: 1.51s
# Epoch 269 | train MAE: 0.006581 | val MAE: 0.045660 | time: 1.50s
# 😴 Cooling GPU: sleeping 5s after epoch 270
# Epoch 270 | train MAE: 0.008932 | val MAE: 0.045330 | time: 1.50s
# Epoch 271 | train MAE: 0.006833 | val MAE: 0.050433 | time: 1.54s
# Epoch 272 | train MAE: 0.004921 | val MAE: 0.043745 | time: 1.58s
# Epoch 273 | train MAE: 0.005380 | val MAE: 0.043507 | time: 1.54s
# Epoch 274 | train MAE: 0.006917 | val MAE: 0.047379 | time: 1.51s
# 😴 Cooling GPU: sleeping 5s after epoch 275
# Epoch 275 | train MAE: 0.005685 | val MAE: 0.044574 | time: 1.51s
# Epoch 276 | train MAE: 0.006467 | val MAE: 0.045334 | time: 1.52s
# Epoch 277 | train MAE: 0.004679 | val MAE: 0.043918 | time: 1.50s
# Epoch 278 | train MAE: 0.006057 | val MAE: 0.045104 | time: 1.53s
# Epoch 279 | train MAE: 0.004851 | val MAE: 0.044909 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 280
# Epoch 280 | train MAE: 0.007873 | val MAE: 0.043549 | time: 1.52s
# Epoch 281 | train MAE: 0.005535 | val MAE: 0.043683 | time: 1.52s
# Epoch 282 | train MAE: 0.005847 | val MAE: 0.043900 | time: 1.53s
# Epoch 283 | train MAE: 0.005292 | val MAE: 0.044843 | time: 1.51s
# Epoch 284 | train MAE: 0.006517 | val MAE: 0.041953 | time: 1.51s
# 😴 Cooling GPU: sleeping 5s after epoch 285
# Epoch 285 | train MAE: 0.006535 | val MAE: 0.045368 | time: 1.50s
# Epoch 286 | train MAE: 0.006143 | val MAE: 0.046178 | time: 1.52s
# Epoch 287 | train MAE: 0.005524 | val MAE: 0.046554 | time: 1.54s
# Epoch 288 | train MAE: 0.006697 | val MAE: 0.045016 | time: 1.55s
# Epoch 289 | train MAE: 0.007369 | val MAE: 0.044491 | time: 1.55s
# 😴 Cooling GPU: sleeping 5s after epoch 290
# Epoch 290 | train MAE: 0.007159 | val MAE: 0.047604 | time: 1.54s
# Epoch 291 | train MAE: 0.006109 | val MAE: 0.044902 | time: 1.51s
# Epoch 292 | train MAE: 0.005975 | val MAE: 0.045839 | time: 1.52s
# Epoch 293 | train MAE: 0.005324 | val MAE: 0.045030 | time: 1.50s
# Epoch 294 | train MAE: 0.006347 | val MAE: 0.047544 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 295
# Epoch 295 | train MAE: 0.005411 | val MAE: 0.045683 | time: 1.56s
# Epoch 296 | train MAE: 0.005883 | val MAE: 0.043022 | time: 1.52s
# Epoch 297 | train MAE: 0.004901 | val MAE: 0.045140 | time: 1.50s
# Epoch 298 | train MAE: 0.007197 | val MAE: 0.043132 | time: 1.57s
# Epoch 299 | train MAE: 0.004776 | val MAE: 0.044316 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 300
# Epoch 300 | train MAE: 0.006282 | val MAE: 0.044490 | time: 1.53s
# Epoch 301 | train MAE: 0.004456 | val MAE: 0.045507 | time: 1.54s
# Epoch 302 | train MAE: 0.004878 | val MAE: 0.044674 | time: 1.52s
# Epoch 303 | train MAE: 0.005651 | val MAE: 0.047379 | time: 1.51s
# Epoch 304 | train MAE: 0.005740 | val MAE: 0.045092 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 305
# Epoch 305 | train MAE: 0.005857 | val MAE: 0.042888 | time: 1.56s
# Epoch 306 | train MAE: 0.005706 | val MAE: 0.044599 | time: 1.52s
# Epoch 307 | train MAE: 0.007461 | val MAE: 0.046643 | time: 1.52s
# Epoch 308 | train MAE: 0.006420 | val MAE: 0.046830 | time: 1.53s
# Epoch 309 | train MAE: 0.006331 | val MAE: 0.044781 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 310
# Epoch 310 | train MAE: 0.004198 | val MAE: 0.043666 | time: 1.50s
# Epoch 311 | train MAE: 0.004387 | val MAE: 0.046313 | time: 1.56s
# Epoch 312 | train MAE: 0.006914 | val MAE: 0.043639 | time: 1.55s
# Epoch 313 | train MAE: 0.005706 | val MAE: 0.044744 | time: 1.53s
# Epoch 314 | train MAE: 0.005801 | val MAE: 0.044040 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 315
# Epoch 315 | train MAE: 0.005174 | val MAE: 0.043657 | time: 1.53s
# Epoch 316 | train MAE: 0.004735 | val MAE: 0.044685 | time: 1.50s
# Epoch 317 | train MAE: 0.005453 | val MAE: 0.045636 | time: 1.51s
# Epoch 318 | train MAE: 0.004564 | val MAE: 0.045854 | time: 1.52s
# Epoch 319 | train MAE: 0.006902 | val MAE: 0.046626 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 320
# Epoch 320 | train MAE: 0.004498 | val MAE: 0.046292 | time: 1.54s
# Epoch 321 | train MAE: 0.004886 | val MAE: 0.045451 | time: 1.55s
# Epoch 322 | train MAE: 0.005384 | val MAE: 0.046347 | time: 1.55s
# Epoch 323 | train MAE: 0.006218 | val MAE: 0.043628 | time: 1.51s
# Epoch 324 | train MAE: 0.005718 | val MAE: 0.044660 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 325
# Epoch 325 | train MAE: 0.006201 | val MAE: 0.043822 | time: 1.55s
# Epoch 326 | train MAE: 0.004916 | val MAE: 0.045783 | time: 1.56s
# Epoch 327 | train MAE: 0.004813 | val MAE: 0.045886 | time: 1.52s
# Epoch 328 | train MAE: 0.006122 | val MAE: 0.047208 | time: 1.57s
# Epoch 329 | train MAE: 0.004721 | val MAE: 0.044973 | time: 1.56s
# 😴 Cooling GPU: sleeping 5s after epoch 330
# Epoch 330 | train MAE: 0.006642 | val MAE: 0.042836 | time: 1.53s
# Epoch 331 | train MAE: 0.005075 | val MAE: 0.044388 | time: 1.55s
# Epoch 332 | train MAE: 0.004757 | val MAE: 0.046649 | time: 1.55s
# Epoch 333 | train MAE: 0.004510 | val MAE: 0.044199 | time: 1.51s
# Epoch 334 | train MAE: 0.004253 | val MAE: 0.046641 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 335
# Epoch 335 | train MAE: 0.005770 | val MAE: 0.046654 | time: 1.50s
# Epoch 336 | train MAE: 0.004828 | val MAE: 0.044744 | time: 1.54s
# Epoch 337 | train MAE: 0.004862 | val MAE: 0.045755 | time: 1.55s
# Epoch 338 | train MAE: 0.004917 | val MAE: 0.044040 | time: 1.53s
# Epoch 339 | train MAE: 0.005201 | val MAE: 0.043632 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 340
# Epoch 340 | train MAE: 0.005639 | val MAE: 0.043223 | time: 1.56s
# Epoch 341 | train MAE: 0.005676 | val MAE: 0.044975 | time: 1.58s
# Epoch 342 | train MAE: 0.005897 | val MAE: 0.046038 | time: 1.54s
# Epoch 343 | train MAE: 0.004969 | val MAE: 0.043598 | time: 1.56s
# Epoch 344 | train MAE: 0.005878 | val MAE: 0.045753 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 345
# Epoch 345 | train MAE: 0.006419 | val MAE: 0.047459 | time: 1.53s
# Epoch 346 | train MAE: 0.004183 | val MAE: 0.044946 | time: 1.51s
# Epoch 347 | train MAE: 0.004358 | val MAE: 0.046771 | time: 1.56s
# Epoch 348 | train MAE: 0.005917 | val MAE: 0.046650 | time: 1.57s
# Epoch 349 | train MAE: 0.005203 | val MAE: 0.045482 | time: 1.53s
# 😴 Cooling GPU: sleeping 5s after epoch 350
# Epoch 350 | train MAE: 0.005400 | val MAE: 0.045570 | time: 1.52s
# Epoch 351 | train MAE: 0.007306 | val MAE: 0.043000 | time: 1.56s
# Epoch 352 | train MAE: 0.005007 | val MAE: 0.045099 | time: 1.53s
# Epoch 353 | train MAE: 0.005178 | val MAE: 0.043631 | time: 1.53s
# Epoch 354 | train MAE: 0.004999 | val MAE: 0.044914 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 355
# Epoch 355 | train MAE: 0.007710 | val MAE: 0.044202 | time: 1.53s
# Epoch 356 | train MAE: 0.004761 | val MAE: 0.044318 | time: 1.52s
# Epoch 357 | train MAE: 0.004268 | val MAE: 0.044452 | time: 1.59s
# Epoch 358 | train MAE: 0.004567 | val MAE: 0.045280 | time: 1.54s
# Epoch 359 | train MAE: 0.005586 | val MAE: 0.043087 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 360
# Epoch 360 | train MAE: 0.005219 | val MAE: 0.044145 | time: 1.54s
# Epoch 361 | train MAE: 0.006002 | val MAE: 0.045064 | time: 1.57s
# Epoch 362 | train MAE: 0.006616 | val MAE: 0.048063 | time: 1.51s
# Epoch 363 | train MAE: 0.006505 | val MAE: 0.044525 | time: 1.51s
# Epoch 364 | train MAE: 0.005174 | val MAE: 0.045917 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 365
# Epoch 365 | train MAE: 0.004489 | val MAE: 0.046724 | time: 1.54s
# Epoch 366 | train MAE: 0.006057 | val MAE: 0.043956 | time: 1.52s
# Epoch 367 | train MAE: 0.005083 | val MAE: 0.044844 | time: 1.55s
# Epoch 368 | train MAE: 0.006433 | val MAE: 0.048927 | time: 1.55s
# Epoch 369 | train MAE: 0.004824 | val MAE: 0.043701 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 370
# Epoch 370 | train MAE: 0.004649 | val MAE: 0.046601 | time: 1.52s
# Epoch 371 | train MAE: 0.006466 | val MAE: 0.046142 | time: 1.56s
# Epoch 372 | train MAE: 0.006375 | val MAE: 0.044428 | time: 1.52s
# Epoch 373 | train MAE: 0.005129 | val MAE: 0.046581 | time: 1.50s
# Epoch 374 | train MAE: 0.004864 | val MAE: 0.045112 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 375
# Epoch 375 | train MAE: 0.005057 | val MAE: 0.045990 | time: 1.54s
# Epoch 376 | train MAE: 0.004866 | val MAE: 0.044004 | time: 1.54s
# Epoch 377 | train MAE: 0.004385 | val MAE: 0.044681 | time: 1.55s
# Epoch 378 | train MAE: 0.004314 | val MAE: 0.046209 | time: 1.55s
# Epoch 379 | train MAE: 0.003996 | val MAE: 0.044792 | time: 1.60s
# 😴 Cooling GPU: sleeping 5s after epoch 380
# Epoch 380 | train MAE: 0.006324 | val MAE: 0.042796 | time: 1.51s
# Epoch 381 | train MAE: 0.006100 | val MAE: 0.046834 | time: 1.49s
# Epoch 382 | train MAE: 0.003871 | val MAE: 0.046127 | time: 1.53s
# Epoch 383 | train MAE: 0.004876 | val MAE: 0.044375 | time: 1.54s
# Epoch 384 | train MAE: 0.004358 | val MAE: 0.045819 | time: 1.58s
# 😴 Cooling GPU: sleeping 5s after epoch 385
# Epoch 385 | train MAE: 0.006351 | val MAE: 0.045339 | time: 1.50s
# Epoch 386 | train MAE: 0.005028 | val MAE: 0.045359 | time: 1.59s
# Epoch 387 | train MAE: 0.005659 | val MAE: 0.046437 | time: 1.55s
# Epoch 388 | train MAE: 0.005636 | val MAE: 0.046762 | time: 1.53s
# Epoch 389 | train MAE: 0.006795 | val MAE: 0.047286 | time: 1.57s
# 😴 Cooling GPU: sleeping 5s after epoch 390
# Epoch 390 | train MAE: 0.006536 | val MAE: 0.044336 | time: 1.53s
# Epoch 391 | train MAE: 0.003960 | val MAE: 0.043978 | time: 1.54s
# Epoch 392 | train MAE: 0.004614 | val MAE: 0.044495 | time: 1.56s
# Epoch 393 | train MAE: 0.004943 | val MAE: 0.042650 | time: 1.55s
# Epoch 394 | train MAE: 0.004861 | val MAE: 0.046285 | time: 1.52s
# 😴 Cooling GPU: sleeping 5s after epoch 395
# Epoch 395 | train MAE: 0.005497 | val MAE: 0.046028 | time: 1.54s
# Epoch 396 | train MAE: 0.005767 | val MAE: 0.045256 | time: 1.55s
# Epoch 397 | train MAE: 0.004470 | val MAE: 0.044415 | time: 1.54s
# Epoch 398 | train MAE: 0.005854 | val MAE: 0.045420 | time: 1.51s
# Epoch 399 | train MAE: 0.006190 | val MAE: 0.044045 | time: 1.54s
# 😴 Cooling GPU: sleeping 5s after epoch 400
# `Trainer.fit` stopped: `max_epochs=400` reached.
# CPU times: user 10min 15s, sys: 3min 9s, total: 13min 24s
# Wall time: 16min 53s

# %% [markdown]
# #### Save the training history

# %%
CHECKPOINT_PATH
# Out:
# '/app/kdrift/decenter_+-0.5mm,tilt_+-0.6deg/pytorch/checkpoints/cnn_take1'

# %%
train_loss = np.array(plot_cb.train_losses, dtype=np.float32)
val_loss   = np.array(plot_cb.val_losses,   dtype=np.float32)
epochs = np.arange(1, len(train_loss) + 1, dtype=np.int32)

# %%
df = pd.DataFrame({
    "epoch": epochs,
    "train_loss": train_loss,
    "val_loss": val_loss,
})

df.to_csv(f"{CHECKPOINT_PATH}/training_history.csv", index=False)

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# best-059-0.039016.ckpt  last.ckpt  training_history.csv

# %%
plt.plot(epochs, train_loss, label="train")
plt.plot(epochs, val_loss, label="val")
plt.xlabel("epoch")
plt.ylabel("MAE")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluation

# %%
test_ds = NumpyDataset(X_test_scaled, y_test)
test_loader   = DataLoader(test_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
x0, y0 = test_ds[0]
print(x0.shape)   # torch.Size([5, 64, 64])
print(y0.shape)   # torch.Size([6])
# Out:
# torch.Size([5, 64, 64])
# torch.Size([6])

# %%
def get_test_predictions(model, test_loader, device):
    model.eval()

    y_true_list = []
    y_pred_list = []

    with torch.no_grad():
        for xb, yb in test_loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)

            y_hat = model(xb)          # (B, 6)

            y_true_list.append(yb.cpu().numpy())
            y_pred_list.append(y_hat.cpu().numpy())

    y_true = np.concatenate(y_true_list, axis=0)  # (N_test, 6)
    y_pred = np.concatenate(y_pred_list, axis=0)  # (N_test, 6)

    return y_true, y_pred

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# best-059-0.039016.ckpt  last.ckpt  training_history.csv

# %%
best_ckpt = f"{CHECKPOINT_PATH}/best-059-0.039016.ckpt"
lit_model = LitCNN.load_from_checkpoint(
    best_ckpt,
    model=CNNModelKerasEquivalent(),  # 🔴 구조 동일해야 함
)

# %%
# %%time
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
y_test_true, y_test_pred = get_test_predictions(lit_model, test_loader, device)
# Out:
# CPU times: user 153 ms, sys: 150 ms, total: 302 ms
# Wall time: 253 ms

# %%
print(y_test_true.shape)  # (N_test, 6)
print(y_test_pred.shape)  # (N_test, 6)
# Out:
# (4000, 6)
# (4000, 6)

# %%
mae = np.mean(np.abs(y_test_pred - y_test_true), axis=0)
print("Test MAE per y:", mae)
print("Test MAE mean :", mae.mean())
# Out:
# Test MAE per y: [0.04220643 0.07702441 0.01259346 0.01578233 0.01131122 0.06440813]
# Test MAE mean : 0.037221

# %%
import matplotlib as mpl
import seaborn as sns

sns.reset_defaults()                 # seaborn 스타일 제거
mpl.rcParams.update(mpl.rcParamsDefault)  # matplotlib 완전 초기화

# %%
import matplotlib as mpl

mpl.rcParams.update({
    "font.family": "serif",
    "font.size": 14,        # 기본 폰트
    "axes.titlesize": 16,   # subplot title
    "axes.labelsize": 14,   # x,y label
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12,
})

# %%
def plot_error_histograms(err, bins=50):
    """
    err shape: (N, 6)
    """
    fig, axes = plt.subplots(2, 3, figsize=(10, 6))
    axes = axes.ravel()

    # symmetric range for fair comparison
    vmin = err.min()
    vmax = err.max()
    vmax = max(abs(vmin), abs(vmax))
    hist_range = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        ax.hist(
            err[:, i],
            bins=bins,
            range=hist_range,
            alpha=0.8
        )

        ax.axvline(0, color="k", linestyle="--", linewidth=1)
        ax.set_title(f"y{i} error")
        ax.set_xlabel("prediction - truth")
        ax.set_ylabel("count")

    fig.suptitle("Test error distribution (y_pred - y_true)", fontsize=12)
    fig.tight_layout()
    plt.show()

# %%
err = y_test_pred - y_test_true
print(err.shape)
# Out:
# (4000, 6)

# %%
plot_error_histograms(err,bins=200)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(
    style="whitegrid",     # 🔹 whitegrid → white
    context="talk",
    font="serif"
)

# %%
import numpy as np

def plot_error_histograms_seaborn(err, bins=40):
    """
    err shape: (N_test, 6)
    """
    fig, axes = plt.subplots(3, 2, figsize=(15, 12))
    axes = axes.ravel()

    # symmetric x-range
    vmin = err.min()
    vmax = err.max()
    vmax = max(abs(vmin), abs(vmax))
    xlim = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        sns.histplot(
            err[:, i],
            bins=bins,
            stat="count",     # 🔹 COUNT, not density
            kde=False,        # 🔹 no curve
            color="tab:blue",
            alpha=0.8,
            ax=ax
        )

        # zero reference
        ax.axvline(0, color="black", linestyle="--", linewidth=1.5)

        # metrics
        mae  = np.mean(np.abs(err[:, i]))
        rmse = np.sqrt(np.mean(err[:, i] ** 2))

        ax.text(
            0.03, 0.97,
            f"MAE  = {mae:.4f}\nRMSE = {rmse:.4f}",
            transform=ax.transAxes,
            va="top",
            ha="left",
            fontsize=14,
            bbox=dict(boxstyle="round", fc="white", alpha=0.9)
        )

        ax.set_xlim(xlim)
        ax.set_title(f"y{i} error", fontsize=16)
        ax.set_xlabel("prediction − truth", fontsize=14)
        ax.set_ylabel("count", fontsize=14)

    fig.suptitle(
        "Test error distribution (histogram, count)",
        fontsize=20,
        y=0.98
    )

    fig.tight_layout()
    plt.show()

# %%
plot_error_histograms_seaborn(err,bins=200)
