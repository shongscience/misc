# %% [markdown]
# # Hybrid CNN + ViT for KDRIFT G1 Alignment
#
# - `decenter+-0.095mm,tilt+-0.075deg`
# - EDA the training set
# - CNN Stem + ViT Hybrid model
# - `MAX_CAP = 6` Normalization
# - 64x64 image, 8x8 patch size, 64 tokens (8x8 grids)
# - X_f32.npy: Image Normalization .. Let's find out what is the best "Fixed Max" value for ultimate normalization .. some modification.. not -1 to +1 .. 0 to 1 at absolute full normalization
# - y_f32.npy: also we need to rescale this ..

# %%
import os
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from tqdm import trange, notebook

import matplotlib.pyplot as plt

# %%
import matplotlib
import seaborn as sns

sns.reset_defaults()                 # seaborn 스타일 제거
matplotlib.rcParams.update(matplotlib.rcParamsDefault)  # matplotlib 완전 초기화

# Basic Settings for matplotlib
matplotlib.rcParams["font.family"] = "serif"
matplotlib.rcParams["mathtext.fontset"] = "stix"
#%matplotlib inline
#matplotlib_inline.backend_inline.set_matplotlib_formats("svg", "pdf")  # For export
matplotlib.rcParams["lines.linewidth"] = 2.0

# %% [markdown]
# ## Browsing the working directories

# %%
# %pwd
# Out:
# '/app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/notebook'

# %%
# %ls
# Out:
# cnn-align-v7-fixed-maxcap-Xy-rescaled.ipynb
# cnn_maxcap50_positive_only_norm.png
# cnn_maxcap50_positive_only_norm_y_rescaled.png
# hybrid-align-v3a-tahn-stemch64-ntok64-fixed-maxcap-Xy-rescaled.ipynb
# lightning_logs/
# no-y-rescaled/
# vit-align-v1c-ntok64-fixed-maxcap-Xy-rescaled.ipynb
# vit_64ntok_maxcap_y_rescaled_both_signs_1c.png
# vit_64ntok_maxcap_y_scaled_both_signs_1c.png

# %%
data_path = '/app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/data/'

# %%
# !ls {data_path}
# Out:
# X_f32.npy  y_f32.npy

# %% [markdown]
# ## Explore the training set

# %%
# %%time
X = np.load(data_path+'X_f32.npy')
y = np.load(data_path+'y_f32.npy')
# Out:
# CPU times: user 0 ns, sys: 224 ms, total: 224 ms
# Wall time: 223 ms

# %%
len(y),len(X)
# Out:
# (20000, 20000)

# %%
def np_array_info(a):
    print(f"shape     : {a.shape}")
    print(f"dtype     : {a.dtype}")
    print(f"ndim      : {a.ndim}")
    print(f"size      : {a.size}")
    print(f"itemsize  : {a.itemsize} bytes")
    print(f"nbytes    : {a.nbytes / 1024**2:.2f} MB")
    print(f"min / max : {a.min()} / {a.max()}")

# %%
np_array_info(X)
# Out:
# shape     : (20000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 409600000
# itemsize  : 4 bytes
# nbytes    : 1562.50 MB
# min / max : -5.8238911628723145 / 5.863417148590088

# %%
np_array_info(y)
# Out:
# shape     : (20000, 6)
# dtype     : float32
# ndim      : 2
# size      : 120000
# itemsize  : 4 bytes
# nbytes    : 0.46 MB
# min / max : -0.0949999988079071 / 0.09499000012874603

# %%
for i in range(y.shape[1]):
    print(f"channel {i}: min={y[:, i].min()}, max={y[:, i].max()}")
# Out:
# channel 0: min=-0.0949999988079071, max=0.09499000012874603
# channel 1: min=-0.0949999988079071, max=0.09498000144958496
# channel 2: min=-0.0949999988079071, max=0.09499000012874603
# channel 3: min=-0.07500000298023224, max=0.07498999685049057
# channel 4: min=-0.07500000298023224, max=0.07500000298023224
# channel 5: min=-0.07498999685049057, max=0.07498999685049057

# %% [markdown]
# #### Visualize the training set

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_trainingsample(
    X,
    y,
    selected_index_list,
    pix_min=-6.0,
    pix_max=6.0,
):
    n_samples = len(selected_index_list)
    n_views = X.shape[1]

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2)
    )

    im = None

    for row, idx in enumerate(selected_index_list):
        for j in range(n_views):
            ax = axes[row, j]
            img = X[idx, j, :, :, 0]

            im = ax.imshow(
                img,
                cmap="rainbow",
                vmin=pix_min,
                vmax=pix_max,
                aspect="equal"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            if row == 0:
                ax.set_title(f"image {j}")

            # --- min / max labels (always show actual image stats)
            img_min = img.min()
            img_max = img.max()

            labels = [
                f"min: {img_min:.2f}",
                f"max: {img_max:.2f}",
            ]

            # --- include y only on first column
            if y is not None and j == 0:
                yvals = y[idx]
                labels += [
                    f"y{i}: {val:.3f}" for i, val in enumerate(yvals)
                ]
                ax.set_ylabel(f"idx {idx}")

            handles = [
                plt.Line2D([0], [0], color="none", label=lab)
                for lab in labels
            ]

            ax.legend(
                handles=handles,
                loc="upper left" if j == 0 else "upper right",
                fontsize=8,
                frameon=True,
                borderpad=0.3,
                handlelength=0,
                handletextpad=0
            )

    fig.subplots_adjust(
        bottom=0.12,
        hspace=0.05,
        wspace=0.02
    )

    fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02,
        label=f"Pixel value (clipped to [{pix_min}, {pix_max}])"
    )

    plt.show()

# %%
selected_index_list = [0, 5, 12, 128, 2048, 9999, 15000, 19999]
plot_trainingsample(X, y, selected_index_list)

# %% [markdown]
# ## PyTorching the Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import torchvision
import pytorch_lightning as pl
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from torchvision import transforms
from torchvision.datasets import CIFAR10

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce RTX 3090 (UUID: GPU-81ef84f4-69df-ce9c-b89c-0b05c8f72ebf)

# %%
# Setting the seed
pl.seed_everything(42)

# Ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Seed set to 42

# %% [markdown]
# #### Checkpoints

# %%
CHECKPOINT_ROOT = '/app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/checkpoints/'

# %%
from time import gmtime, strftime

base_name = 'hybrid-ntok64-maxcap6-yrescaled'
#try_name = strftime('%Y.%m.%d_%H:%M', gmtime())
try_name = 'take3a'
experiment_name = f"{base_name}_{try_name}"
print("experiment:", experiment_name)
CHECKPOINT_PATH = os.path.join(CHECKPOINT_ROOT, experiment_name)
print("CHECKPOINT_PATH:", CHECKPOINT_PATH)
# Out:
# experiment: hybrid-ntok64-maxcap6-yrescaled_take3a
# CHECKPOINT_PATH: /app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/checkpoints/hybrid-ntok64-maxcap6-yrescaled_take3a

# %%
import os
import shutil

CHECKPOINT_PATH = os.path.join(CHECKPOINT_ROOT, experiment_name)

if os.path.exists(CHECKPOINT_PATH):
    print(f"⚠️ Directory exists: {CHECKPOINT_PATH}")
    print("🧹 Removing all contents...")

    # Clear all files/subfolders inside the directory
    for filename in os.listdir(CHECKPOINT_PATH):
        file_path = os.path.join(CHECKPOINT_PATH, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print(f"❌ Failed to delete {file_path}: {e}")

    print("✅ Directory has been cleared.")
else:
    os.makedirs(CHECKPOINT_PATH)
    print(f"✅ Directory created: {CHECKPOINT_PATH}")

print(f"📂 Experiment directory is ready: {os.path.abspath(CHECKPOINT_PATH)}")
# Out:
# ✅ Directory created: /app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/checkpoints/hybrid-ntok64-maxcap6-yrescaled_take3a
# 📂 Experiment directory is ready: /app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/checkpoints/hybrid-ntok64-maxcap6-yrescaled_take3a

# %% [markdown]
# ### Training Sample

# %%
num_samples = len(y)
print(num_samples)
# Out:
# 20000

# %%
indices=range(num_samples)

# %%
X_tr, X_test, y_tr, y_test, tr_indices, test_indices = \
train_test_split(X, y, indices, test_size=0.2, random_state=42)

# %%
# %%time
X_train, X_val, \
y_train, y_val, \
train_indices, val_indices = \
    train_test_split(
        X_tr,
        y_tr,
        tr_indices,
        test_size=0.2,
        random_state=42
    )
# Out:
# CPU times: user 63.2 ms, sys: 71.7 ms, total: 135 ms
# Wall time: 134 ms

# %% [markdown]
# ### Input Image Normalization by `MAX_CAP=6`

# %%
MAX_CAP = 6.0

# %%
YL_CAP = 0.095
YH_CAP = 0.075

# %%
# %%time
# symmetric rescaling per image
X_train_scaled = X_train / MAX_CAP
X_val_scaled = X_val / MAX_CAP
X_test_scaled = X_test / MAX_CAP
# Out:
# CPU times: user 64.8 ms, sys: 100 ms, total: 165 ms
# Wall time: 164 ms

# %%
np_array_info(X_train_scaled)
# Out:
# shape     : (12800, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 262144000
# itemsize  : 4 bytes
# nbytes    : 1000.00 MB
# min / max : -0.9706485271453857 / 0.9772362112998962

# %%
np_array_info(X_val_scaled)
# Out:
# shape     : (3200, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 65536000
# itemsize  : 4 bytes
# nbytes    : 250.00 MB
# min / max : -0.919867992401123 / 0.9647147059440613

# %%
np_array_info(X_test_scaled)
# Out:
# shape     : (4000, 5, 64, 64, 1)
# dtype     : float32
# ndim      : 5
# size      : 81920000
# itemsize  : 4 bytes
# nbytes    : 312.50 MB
# min / max : -0.940781831741333 / 0.9549728035926819

# %%
y_train_scaled = np.zeros_like(y_train)
y_val_scaled = np.zeros_like(y_val)
y_test_scaled = np.zeros_like(y_test)

# 채널 0~2
for i in range(3):
    y_train_scaled[:, i] = y_train[:, i]/YL_CAP
    y_val_scaled[:, i] = y_val[:, i]/YL_CAP
    y_test_scaled[:, i] = y_test[:, i]/YL_CAP

# 채널 3~5
for i in range(3, 6):
    y_train_scaled[:, i] = y_train[:, i]/YH_CAP
    y_val_scaled[:, i] = y_val[:, i]/YH_CAP
    y_test_scaled[:, i] = y_test[:, i]/YH_CAP

# %%
for i in range(y_train_scaled.shape[1]):
    print(f"channel {i}: min={y_train_scaled[:, i].min()}, \
    max={y_train_scaled[:, i].max()}")
# Out:
# channel 0: min=-1.0,     max=0.9998947381973267
# channel 1: min=-0.9996842741966248,     max=0.9996842741966248
# channel 2: min=-1.0,     max=0.9998947381973267
# channel 3: min=-1.0,     max=0.9998666048049927
# channel 4: min=-0.9995999336242676,     max=1.0
# channel 5: min=-0.9998666048049927,     max=0.9998666048049927

# %%
for i in range(y_val_scaled.shape[1]):
    print(f"channel {i}: min={y_val_scaled[:, i].min()}, \
    max={y_val_scaled[:, i].max()}")
# Out:
# channel 0: min=-0.9996842741966248,     max=0.9981052875518799
# channel 1: min=-0.9997894763946533,     max=0.9997894763946533
# channel 2: min=-0.9988421201705933,     max=0.9996842741966248
# channel 3: min=-0.9998666048049927,     max=0.9990665912628174
# channel 4: min=-1.0,     max=0.9997332692146301
# channel 5: min=-0.9997332692146301,     max=0.9982665777206421

# %%
for i in range(y_test_scaled.shape[1]):
    print(f"channel {i}: min={y_test_scaled[:, i].min()}, \
    max={y_test_scaled[:, i].max()}")
# Out:
# channel 0: min=-0.9995789527893066,     max=0.9996842741966248
# channel 1: min=-1.0,     max=0.9996842741966248
# channel 2: min=-0.9996842741966248,     max=0.9998947381973267
# channel 3: min=-0.9997332692146301,     max=0.9995999336242676
# channel 4: min=-0.9994666576385498,     max=0.9997332692146301
# channel 5: min=-0.9998666048049927,     max=0.9998666048049927

# %%
#plot_trainingsample(X_train_scaled, y,[0,1,2,3,4],pix_min=-1,pix_max=1)

# %%
#plot_trainingsample(X_val_scaled, y,[0,1,2,3,4],pix_min=-1,pix_max=1)

# %%
#plot_trainingsample(X_test_scaled, y,[0,1,2,3,4],pix_min=-1,pix_max=1)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_y_histograms_splits(y_train_train, y_train_val, y_test, bins=50):
    """
    y_* shape: (N, 6)
    """

    fig, axes = plt.subplots(2,3, figsize=(9, 6))
    axes = axes.ravel()

    # symmetric range across ALL splits
    all_y = np.concatenate([y_train_train, y_train_val, y_test], axis=0)
    vmin = all_y.min()
    vmax = all_y.max()
    vmax = max(abs(vmin), abs(vmax))
    hist_range = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        ax.hist(
            y_train_train[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='r',
            alpha=0.2,
            label="train"
        )
        ax.hist(
            y_train_val[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='g',
            alpha=0.2,
            label="val"
        )
        ax.hist(
            y_test[:, i],
            bins=bins,
            range=hist_range,
            density=True,
            color='b',
            alpha=0.2,
            label="test"
        )

        ax.axvline(0, color="k", linestyle="--", linewidth=1)
        ax.set_title(f"y{i}")
        ax.set_xlabel("value")
        ax.set_ylabel("density")

        if i == 0:
            ax.legend()

    fig.suptitle("Distribution of y components (train / val / test)", fontsize=13)
    fig.tight_layout()
    plt.show()

# %%
plot_y_histograms_splits(y_train_scaled, y_val_scaled, y_test_scaled)

# %% [markdown]
# ### DataLoader

# %%
from torch.utils.data import Dataset, DataLoader

class NumpyDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        x = torch.from_numpy(self.X[idx]).float()  # (5,64,64)
        x = x.squeeze(-1) # if (5,64,64,1)
        t = torch.from_numpy(self.y[idx]).float()  # (6,)
        return x, t

# %%
train_ds = NumpyDataset(X_train_scaled, y_train_scaled)
val_ds   = NumpyDataset(X_val_scaled, y_val_scaled)
test_ds  = NumpyDataset(X_test_scaled, y_test_scaled)

# %%
x0, y0 = train_ds[0]
print(x0.shape)   # torch.Size([5, 64, 64])
print(y0.shape)   # torch.Size([6])
# Out:
# torch.Size([5, 64, 64])
# torch.Size([6])

# %%
train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
test_loader   = DataLoader(test_ds,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
xb, yb = next(iter(train_loader))
print("xb.shape:", xb.shape)
print("yb.shape:", yb.shape)
print("xb.dtype:", xb.dtype)
# Out:
# xb.shape: torch.Size([32, 5, 64, 64])
# yb.shape: torch.Size([32, 6])
# xb.dtype: torch.float32

# %% [markdown]
# ## Train vision transformer model
#
# - ViT for 5 channels images

# %% [markdown]
# #### Hyperparameters

# %%
MAX_EPOCH = 200
NGRID = 16

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_batch_patch_grid(xb, n_samples=8, ngrid=16, cmap="rainbow",
                                   linewidth=0.5, vmin=None, vmax=None):
    """
    xb: torch.Tensor, shape (B, 5, 64, 64)
    n_samples: number of rows (samples)
    ngrid: number of grid cells per axis (e.g., 16 => patch size 4 for 64x64)
    """
    # tensor -> numpy
    x = xb[:n_samples].detach().cpu().numpy()  # (n_samples, 5, 64, 64)
    n_samples = x.shape[0]
    n_views = x.shape[1]
    H, W = x.shape[2], x.shape[3]

    assert H % ngrid == 0 and W % ngrid == 0, f"H,W must be divisible by ngrid. got {H},{W}, ngrid={ngrid}"
    patch_h = H // ngrid
    patch_w = W // ngrid

    # global color scale (consistent across all panels)
    if vmin is None:
        vmin = float(x.min())
    if vmax is None:
        vmax = float(x.max())

    fig, axes = plt.subplots(
        n_samples, n_views,
        figsize=(n_views * 2.2, n_samples * 2.2),
        constrained_layout=False
    )

    # in case n_samples == 1
    if n_samples == 1:
        axes = np.expand_dims(axes, axis=0)

    im = None
    for i in range(n_samples):
        for j in range(n_views):
            ax = axes[i, j]
            img = x[i, j]  # (64,64)

            im = ax.imshow(
                img,
                cmap=cmap,
                vmin=vmin,
                vmax=vmax,
                aspect="equal",
                interpolation="nearest"
            )

            ax.set_xticks([])
            ax.set_yticks([])

            # column titles
            if i == 0:
                ax.set_title(f"ch {j}", fontsize=11)

            # row labels
            if j == 0:
                ax.set_ylabel(f"sample {i}", fontsize=11)

            # draw patch grid boundaries
            for gy in range(0, H + 1, patch_h):
                ax.axhline(gy - 0.5, color="w", linewidth=linewidth, alpha=0.9)
            for gx in range(0, W + 1, patch_w):
                ax.axvline(gx - 0.5, color="w", linewidth=linewidth, alpha=0.9)

    # tighter spacing + bottom colorbar
    fig.subplots_adjust(bottom=0.08, hspace=0.02, wspace=0.02)

    cbar = fig.colorbar(
        im,
        ax=axes,
        orientation="horizontal",
        fraction=0.035,
        pad=0.02
    )
    cbar.set_label("pixel value")

    plt.show()

# %%
plot_batch_patch_grid(xb, n_samples=4, ngrid=8, cmap="rainbow")

# %% [markdown]
# # Vision Transformer Regressor
#
# - a
# - b

# %%
class AttentionBlock(nn.Module):
    def __init__(self, embed_dim, hidden_dim, num_heads, dropout=0.0):
        super().__init__()
        self.layer_norm_1 = nn.LayerNorm(embed_dim)
        self.attn = nn.MultiheadAttention(embed_dim, num_heads, batch_first=False)
        self.layer_norm_2 = nn.LayerNorm(embed_dim)
        self.linear = nn.Sequential(
            nn.Linear(embed_dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, embed_dim),
            nn.Dropout(dropout),
        )
        self.last_attn_weights = None  # 🆕 store attention weights here

    def forward(self, x):
        inp_x = self.layer_norm_1(x)
        #attn_out, attn_weights = self.attn(inp_x, inp_x, inp_x, need_weights=True)
        attn_out, attn_weights = self.attn(inp_x, inp_x, inp_x,need_weights=True, \
                                           average_attn_weights=False)  # 🧠 retain all heads!        
        self.last_attn_weights = attn_weights  # 🆕 save for inspection

        x = x + attn_out
        x = x + self.linear(self.layer_norm_2(x))
        return x

# %%
class VisionTransformerRegressorHybrid(nn.Module):
    def __init__(
        self,
        embed_dim=128,
        hidden_dim=256,
        num_channels=5,
        num_heads=4,
        num_layers=4,
        num_outputs=6,
        patch_size=8,
        img_size=64,
        dropout=0.1,
        stem_channels=64,
    ):
        super().__init__()
        assert img_size % patch_size == 0

        self.embed_dim = embed_dim
        self.patch_size = patch_size
        self.img_size = img_size

        # ✅ CNN stem: stride=1로 로컬 특징만 뽑음 (토큰 수는 건드리지 않음)
        # Tanh Activiation Function instead of relu or gelu
        self.stem = nn.Sequential(
            nn.Conv2d(num_channels, stem_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(stem_channels),
            nn.Tanh(),
            nn.Conv2d(stem_channels, stem_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(stem_channels),
            nn.Tanh(),
        )

        # ✅ Conv patch embedding: 여기서 토큰(8x8 grid)을 만듦
        # output: (B, embed_dim, H/P, W/P) = (B, embed_dim, 8, 8)
        self.patch_embed = nn.Conv2d(
            stem_channels,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size,
            bias=True,
        )

        num_patches = (img_size // patch_size) * (img_size // patch_size)  # 64
        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embedding = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.dropout = nn.Dropout(dropout)

        # 너 노트북에서 쓰는 transformer 블록(AttentionBlock stack) 그대로 쓰면 됨
        #self.transformer = YourTransformerStack(embed_dim, hidden_dim, num_heads, num_layers, dropout)
        # Transformer blocks (same style)
        self.transformer = nn.Sequential(
            *(AttentionBlock(embed_dim, hidden_dim, num_heads, dropout=dropout) for _ in range(num_layers))
        )
 
        self.mlp_head = nn.Sequential(
            nn.LayerNorm(embed_dim),
            nn.Linear(embed_dim, num_outputs),
        )

    def forward(self, x):
        # (B, 5, 64, 64, 1)도 허용
        if x.ndim == 5 and x.shape[-1] == 1:
            x = x.squeeze(-1)

        # ✅ CNN feature
        x = self.stem(x)                # (B, stem_channels, 64, 64)

        # ✅ tokens 만들기
        x = self.patch_embed(x)         # (B, E, 8, 8)
        x = x.flatten(2).transpose(1, 2)  # (B, 64, E)

        # CLS + pos
        B, T, E = x.shape
        cls = self.cls_token.expand(B, -1, -1)     # (B,1,E)
        x = torch.cat([cls, x], dim=1)             # (B,65,E)
        x = x + self.pos_embedding[:, :T+1]
        x = self.dropout(x)

        # transformer (너 코드가 batch_first=False면 transpose 맞춰)
        x = x.transpose(0, 1)          # (65,B,E)  (네 구현에 맞춤)
        x = self.transformer(x)
        cls_out = x[0]                 # (B,E)

        return self.mlp_head(cls_out)

# %% [markdown]
# #### Callbacks

# %%
import pytorch_lightning as pl
import torch
import torch.nn as nn

class LitViTRegressor(pl.LightningModule):
    def __init__(
        self,
        model: nn.Module,
        lr: float = 1e-3,
    ):
        super().__init__()
        self.model = model
        self.loss_fn = nn.L1Loss()
        self.lr = lr

        self.save_hyperparameters(ignore=["model"])

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.loss_fn(y_hat, y)

        self.log(
            "train_loss",
            loss,
            on_epoch=True,
            prog_bar=False,
            sync_dist=False,
        )
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.loss_fn(y_hat, y)

        self.log(
            "val_loss",
            loss,
            on_epoch=True,
            prog_bar=False,
            sync_dist=False,
        )
        return loss
        
    # optimizer settings .. AdamW vs. Adam..?!?
    #def configure_optimizers(self):
    #    return torch.optim.Adam(self.parameters(), lr=self.lr)
    def configure_optimizers(self):
        return torch.optim.AdamW(self.parameters(),lr=self.lr, \
                                 weight_decay=2e-4)

# %%
from pytorch_lightning.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    dirpath=CHECKPOINT_PATH,
    filename="best-{epoch:03d}-{val_loss:.6f}",
    monitor="val_loss",
    mode="min",
    save_top_k=20,
    save_last=True,
)

# %%
import time
import pytorch_lightning as pl

class LossHistoryAndPrinter(pl.Callback):
    def __init__(self, precision=6, print_every_epoch=True):
        self.precision = precision
        self.print_every_epoch = print_every_epoch

        # history
        self.train_loss_by_epoch = {}
        self.val_loss_by_epoch = {}
        self.epoch_times = {}

        # internal
        self._epoch_start_time = None

        # Lightning 버전/설정에 따라 이름이 달라질 수 있어 후보를 둠
        self._train_keys = ("train_loss", "train_loss_epoch")
        self._val_keys   = ("val_loss", "val_loss_epoch")

    def _get_metric_float(self, metrics, keys):
        for k in keys:
            v = metrics.get(k, None)
            if v is not None:
                try:
                    return float(v)
                except TypeError:
                    # just in case it's a tensor-like object
                    return float(v.item())
        return None

    def on_train_epoch_start(self, trainer, pl_module):
        self._epoch_start_time = time.time()

    def on_validation_epoch_end(self, trainer, pl_module):
        # sanity validation은 제외 (훈련 시작 전에 val만 도는 구간)
        if trainer.sanity_checking:
            return

        m = trainer.callback_metrics
        epoch = trainer.current_epoch

        val_loss = self._get_metric_float(m, self._val_keys)
        if val_loss is not None:
            self.val_loss_by_epoch[epoch] = val_loss

    def on_train_epoch_end(self, trainer, pl_module):
        # epoch time
        if self._epoch_start_time is not None:
            epoch_time = time.time() - self._epoch_start_time
            self.epoch_times[trainer.current_epoch] = epoch_time
        else:
            epoch_time = None

        m = trainer.callback_metrics
        epoch = trainer.current_epoch

        # train loss 저장 (키 후보 2개)
        train_loss = self._get_metric_float(m, self._train_keys)
        if train_loss is not None:
            self.train_loss_by_epoch[epoch] = train_loss

        if not self.print_every_epoch:
            return

        # val loss는 validation 훅에서 저장된 값 우선 사용
        val_loss = self.val_loss_by_epoch.get(epoch, None)

        # 출력 (둘 다 없으면 NA로 표시)
        msg = f"Epoch {epoch:03d} | "
        msg += f"train MAE: {('NA' if train_loss is None else f'{train_loss:.{self.precision}f}')} | "
        msg += f"val MAE: {('NA' if val_loss is None else f'{val_loss:.{self.precision}f}')}"

        if epoch_time is not None:
            msg += f" | time: {epoch_time:.2f}s"

        print(msg)

    def as_lists(self):
        # train/val 둘 다 있는 epoch만 정렬해서 반환 (길이 항상 같음)
        epochs = sorted(set(self.train_loss_by_epoch) & set(self.val_loss_by_epoch))
        train = [self.train_loss_by_epoch[e] for e in epochs]
        val = [self.val_loss_by_epoch[e] for e in epochs]
        times = [self.epoch_times.get(e, None) for e in epochs]
        return epochs, train, val, times

# %%
import time

class GPUSleepCallback(pl.Callback):
    def __init__(self, sleep_sec=10, every_n_epochs=10):
        self.sleep_sec = sleep_sec
        self.every_n_epochs = every_n_epochs

    def on_train_epoch_end(self, trainer, pl_module):
        stop_modulo = self.every_n_epochs - 1
        if trainer.current_epoch % self.every_n_epochs == stop_modulo:
            print(f"😴 Cooling GPU: sleeping {self.sleep_sec}s after epoch {trainer.current_epoch}")
            time.sleep(self.sleep_sec)

# %% [markdown]
# #### Hyper-parameters 64 tokens

# %% [markdown]
# > Default initializing hyper parameters

# %% [raw]
#         embed_dim=128,
#         hidden_dim=256,
#         num_channels=5,
#         num_heads=4,
#         num_layers=4,
#         num_outputs=6,
#         patch_size=8,
#         img_size=64,
#         dropout=0.1,
#         stem_channels=64,

# %%
vit_model = VisionTransformerRegressorHybrid(
    img_size=64,
    patch_size=8,      # ✅ 64 tokens
    num_channels=5,
    num_outputs=6,
    embed_dim=192,     # ✅ 줄이기
    hidden_dim=768,    # ✅ 줄이기
    num_heads=6,       # ✅ 줄이기
    num_layers=4,      # ✅ 줄이기
    dropout=0.1,
    stem_channels=64,
)

lit_model = LitViTRegressor(
    model=vit_model,
    lr=2e-4,
)

# %%
#loss_history_cb = LossHistoryCallback()
#metric_printer_cb = EpochMetricPrinter()
loss_cb = LossHistoryAndPrinter(precision=6)
gpu_sleep_cb = GPUSleepCallback(sleep_sec=10, every_n_epochs=3)

# %%
trainer = pl.Trainer(
    max_epochs=2000,
    accelerator="gpu" if torch.cuda.is_available() else "cpu",

    logger=False,                 # 👈 NO logs saved
    enable_progress_bar=False,    # 👈 no tqdm bar
    log_every_n_steps=1,          # 👈 suppress warning

    callbacks=[
        checkpoint_callback,       # (model weights only)
        loss_cb,
        gpu_sleep_cb,
    ],
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
# %%time
trainer.fit(
    lit_model,
    train_dataloaders=train_loader,
    val_dataloaders=val_loader,
)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type                             | Params | Mode  | FLOPs
# -----------------------------------------------------------------------------
# 0 | model   | VisionTransformerRegressorHybrid | 2.6 M  | train | 0
# 1 | loss_fn | L1Loss                           | 0      | train | 0
# -----------------------------------------------------------------------------
# 2.6 M     Trainable params
# 0         Non-trainable params
# 2.6 M     Total params
# 10.481    Total estimated model params size (MB)
# 59        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Epoch 000 | train MAE: 0.285930 | val MAE: 0.225256 | time: 3.87s
# Epoch 001 | train MAE: 0.190702 | val MAE: 0.183437 | time: 3.88s
# Epoch 002 | train MAE: 0.170233 | val MAE: 0.156732 | time: 3.91s
# 😴 Cooling GPU: sleeping 10s after epoch 2
# Epoch 003 | train MAE: 0.158068 | val MAE: 0.157033 | time: 3.92s
# Epoch 004 | train MAE: 0.139897 | val MAE: 0.143274 | time: 3.92s
# Epoch 005 | train MAE: 0.115236 | val MAE: 0.067211 | time: 3.93s
# 😴 Cooling GPU: sleeping 10s after epoch 5
# Epoch 006 | train MAE: 0.085704 | val MAE: 0.086665 | time: 3.93s
# Epoch 007 | train MAE: 0.067707 | val MAE: 0.078584 | time: 3.94s
# Epoch 008 | train MAE: 0.062499 | val MAE: 0.057186 | time: 3.96s
# 😴 Cooling GPU: sleeping 10s after epoch 8
# Epoch 009 | train MAE: 0.056295 | val MAE: 0.037471 | time: 3.95s
# Epoch 010 | train MAE: 0.051855 | val MAE: 0.045857 | time: 3.95s
# Epoch 011 | train MAE: 0.050905 | val MAE: 0.043125 | time: 3.96s
# 😴 Cooling GPU: sleeping 10s after epoch 11
# Epoch 012 | train MAE: 0.048599 | val MAE: 0.043027 | time: 3.96s
# Epoch 013 | train MAE: 0.049039 | val MAE: 0.044421 | time: 3.96s
# Epoch 014 | train MAE: 0.044557 | val MAE: 0.038431 | time: 3.99s
# 😴 Cooling GPU: sleeping 10s after epoch 14
# Epoch 015 | train MAE: 0.045064 | val MAE: 0.043376 | time: 3.95s
# Epoch 016 | train MAE: 0.043912 | val MAE: 0.040921 | time: 3.98s
# Epoch 017 | train MAE: 0.041079 | val MAE: 0.031321 | time: 3.99s
# 😴 Cooling GPU: sleeping 10s after epoch 17
# Epoch 018 | train MAE: 0.040322 | val MAE: 0.035959 | time: 3.95s
# Epoch 019 | train MAE: 0.038326 | val MAE: 0.051717 | time: 3.99s
# Epoch 020 | train MAE: 0.037956 | val MAE: 0.032308 | time: 4.00s
# 😴 Cooling GPU: sleeping 10s after epoch 20
# Epoch 021 | train MAE: 0.038364 | val MAE: 0.026141 | time: 3.98s
# Epoch 022 | train MAE: 0.035570 | val MAE: 0.030228 | time: 4.01s
# Epoch 023 | train MAE: 0.036825 | val MAE: 0.035047 | time: 4.03s
# 😴 Cooling GPU: sleeping 10s after epoch 23
# Epoch 024 | train MAE: 0.035371 | val MAE: 0.024196 | time: 3.98s
# Epoch 025 | train MAE: 0.035957 | val MAE: 0.035019 | time: 4.02s
# Epoch 026 | train MAE: 0.034453 | val MAE: 0.028529 | time: 4.01s
# 😴 Cooling GPU: sleeping 10s after epoch 26
# Epoch 027 | train MAE: 0.035414 | val MAE: 0.024624 | time: 3.99s
# Epoch 028 | train MAE: 0.033778 | val MAE: 0.022718 | time: 4.02s
# Epoch 029 | train MAE: 0.032489 | val MAE: 0.036319 | time: 4.01s
# 😴 Cooling GPU: sleeping 10s after epoch 29
# Epoch 030 | train MAE: 0.032556 | val MAE: 0.021684 | time: 4.02s
# Epoch 031 | train MAE: 0.032177 | val MAE: 0.019764 | time: 4.01s
# Epoch 032 | train MAE: 0.031463 | val MAE: 0.021628 | time: 4.02s
# 😴 Cooling GPU: sleeping 10s after epoch 32
# Epoch 033 | train MAE: 0.031147 | val MAE: 0.022435 | time: 4.00s
# Epoch 034 | train MAE: 0.031154 | val MAE: 0.024425 | time: 4.04s
# Epoch 035 | train MAE: 0.031020 | val MAE: 0.028923 | time: 4.04s
# 😴 Cooling GPU: sleeping 10s after epoch 35
# Epoch 036 | train MAE: 0.030440 | val MAE: 0.025747 | time: 4.02s
# Epoch 037 | train MAE: 0.029781 | val MAE: 0.020905 | time: 4.02s
# Epoch 038 | train MAE: 0.030278 | val MAE: 0.025129 | time: 4.03s
# 😴 Cooling GPU: sleeping 10s after epoch 38
# Epoch 039 | train MAE: 0.029542 | val MAE: 0.025340 | time: 4.01s
# Epoch 040 | train MAE: 0.029599 | val MAE: 0.022473 | time: 4.04s
# Epoch 041 | train MAE: 0.029795 | val MAE: 0.031573 | time: 4.04s
# 😴 Cooling GPU: sleeping 10s after epoch 41
# Epoch 042 | train MAE: 0.029116 | val MAE: 0.027998 | time: 4.01s
# Epoch 043 | train MAE: 0.029343 | val MAE: 0.025978 | time: 4.02s
# Epoch 044 | train MAE: 0.027351 | val MAE: 0.015565 | time: 4.05s
# 😴 Cooling GPU: sleeping 10s after epoch 44
# Epoch 045 | train MAE: 0.028563 | val MAE: 0.018070 | time: 4.02s
# Epoch 046 | train MAE: 0.027701 | val MAE: 0.020339 | time: 4.03s
# Epoch 047 | train MAE: 0.026671 | val MAE: 0.022631 | time: 4.04s
# 😴 Cooling GPU: sleeping 10s after epoch 47
# Epoch 048 | train MAE: 0.027424 | val MAE: 0.019909 | time: 4.01s
# Epoch 049 | train MAE: 0.026010 | val MAE: 0.022428 | time: 4.05s
# Epoch 050 | train MAE: 0.026655 | val MAE: 0.023033 | time: 4.07s
# 😴 Cooling GPU: sleeping 10s after epoch 50
# Epoch 051 | train MAE: 0.026503 | val MAE: 0.025060 | time: 4.02s
# Epoch 052 | train MAE: 0.026015 | val MAE: 0.017594 | time: 4.03s
# Epoch 053 | train MAE: 0.025972 | val MAE: 0.027326 | time: 4.07s
# 😴 Cooling GPU: sleeping 10s after epoch 53
# Epoch 054 | train MAE: 0.026223 | val MAE: 0.023421 | time: 4.02s
# Epoch 055 | train MAE: 0.025542 | val MAE: 0.026162 | time: 4.05s
# Epoch 056 | train MAE: 0.026056 | val MAE: 0.020756 | time: 4.07s
# 😴 Cooling GPU: sleeping 10s after epoch 56
# Epoch 057 | train MAE: 0.025722 | val MAE: 0.023750 | time: 4.03s
# Epoch 058 | train MAE: 0.025296 | val MAE: 0.021568 | time: 4.03s
# Epoch 059 | train MAE: 0.024732 | val MAE: 0.017852 | time: 4.09s
# 😴 Cooling GPU: sleeping 10s after epoch 59
# Epoch 060 | train MAE: 0.024479 | val MAE: 0.020953 | time: 4.02s
# Epoch 061 | train MAE: 0.024803 | val MAE: 0.017275 | time: 4.07s
# Epoch 062 | train MAE: 0.024433 | val MAE: 0.022918 | time: 4.09s
# 😴 Cooling GPU: sleeping 10s after epoch 62
# Epoch 063 | train MAE: 0.024232 | val MAE: 0.021973 | time: 4.02s
# Epoch 064 | train MAE: 0.024521 | val MAE: 0.022992 | time: 4.07s
# Epoch 065 | train MAE: 0.024542 | val MAE: 0.021058 | time: 4.10s
# 😴 Cooling GPU: sleeping 10s after epoch 65
# Epoch 066 | train MAE: 0.024025 | val MAE: 0.018294 | time: 4.03s
# Epoch 067 | train MAE: 0.024267 | val MAE: 0.018564 | time: 4.07s
# Epoch 068 | train MAE: 0.024136 | val MAE: 0.020386 | time: 4.10s
# 😴 Cooling GPU: sleeping 10s after epoch 68
# Epoch 069 | train MAE: 0.023280 | val MAE: 0.019062 | time: 4.03s
# Epoch 070 | train MAE: 0.023863 | val MAE: 0.019307 | time: 4.08s
# Epoch 071 | train MAE: 0.023451 | val MAE: 0.016493 | time: 4.13s
# 😴 Cooling GPU: sleeping 10s after epoch 71
# Epoch 072 | train MAE: 0.023574 | val MAE: 0.019103 | time: 4.04s
# Epoch 073 | train MAE: 0.024037 | val MAE: 0.017351 | time: 4.07s
# Epoch 074 | train MAE: 0.023243 | val MAE: 0.017734 | time: 4.15s
# 😴 Cooling GPU: sleeping 10s after epoch 74
# Epoch 075 | train MAE: 0.023760 | val MAE: 0.016332 | time: 4.04s
# Epoch 076 | train MAE: 0.022906 | val MAE: 0.017877 | time: 4.10s
# Epoch 077 | train MAE: 0.022757 | val MAE: 0.017085 | time: 4.12s
# 😴 Cooling GPU: sleeping 10s after epoch 77
# Epoch 078 | train MAE: 0.023050 | val MAE: 0.021277 | time: 4.01s
# Epoch 079 | train MAE: 0.022799 | val MAE: 0.020261 | time: 4.10s
# Epoch 080 | train MAE: 0.022651 | val MAE: 0.016090 | time: 4.13s
# 😴 Cooling GPU: sleeping 10s after epoch 80
# Epoch 081 | train MAE: 0.022515 | val MAE: 0.019972 | time: 4.04s
# Epoch 082 | train MAE: 0.022308 | val MAE: 0.018712 | time: 4.08s
# Epoch 083 | train MAE: 0.022371 | val MAE: 0.020736 | time: 4.14s
# 😴 Cooling GPU: sleeping 10s after epoch 83
# Epoch 084 | train MAE: 0.022067 | val MAE: 0.017802 | time: 4.06s
# Epoch 085 | train MAE: 0.023455 | val MAE: 0.018955 | time: 4.12s
# Epoch 086 | train MAE: 0.021816 | val MAE: 0.018329 | time: 4.15s
# 😴 Cooling GPU: sleeping 10s after epoch 86
# Epoch 087 | train MAE: 0.022133 | val MAE: 0.017046 | time: 4.04s
# Epoch 088 | train MAE: 0.021667 | val MAE: 0.013172 | time: 4.10s
# Epoch 089 | train MAE: 0.022352 | val MAE: 0.019537 | time: 4.13s
# 😴 Cooling GPU: sleeping 10s after epoch 89
# Epoch 090 | train MAE: 0.021687 | val MAE: 0.017344 | time: 4.05s
# Epoch 091 | train MAE: 0.021613 | val MAE: 0.021819 | time: 4.11s
# Epoch 092 | train MAE: 0.021138 | val MAE: 0.014947 | time: 4.17s
# 😴 Cooling GPU: sleeping 10s after epoch 92
# Epoch 093 | train MAE: 0.021131 | val MAE: 0.017015 | time: 4.05s
# Epoch 094 | train MAE: 0.021251 | val MAE: 0.020431 | time: 4.11s
# Epoch 095 | train MAE: 0.021063 | val MAE: 0.014830 | time: 4.15s
# 😴 Cooling GPU: sleeping 10s after epoch 95
# Epoch 096 | train MAE: 0.021538 | val MAE: 0.018444 | time: 4.07s
# Epoch 097 | train MAE: 0.020671 | val MAE: 0.016146 | time: 4.13s
# Epoch 098 | train MAE: 0.021341 | val MAE: 0.016818 | time: 4.17s
# 😴 Cooling GPU: sleeping 10s after epoch 98
# Epoch 099 | train MAE: 0.021367 | val MAE: 0.012164 | time: 4.06s
# Epoch 100 | train MAE: 0.021156 | val MAE: 0.012278 | time: 4.12s
# Epoch 101 | train MAE: 0.020609 | val MAE: 0.012669 | time: 4.17s
# 😴 Cooling GPU: sleeping 10s after epoch 101
# Epoch 102 | train MAE: 0.021245 | val MAE: 0.014046 | time: 4.05s
# Epoch 103 | train MAE: 0.020559 | val MAE: 0.014827 | time: 4.13s
# Epoch 104 | train MAE: 0.021161 | val MAE: 0.016093 | time: 4.16s
# 😴 Cooling GPU: sleeping 10s after epoch 104
# Epoch 105 | train MAE: 0.020809 | val MAE: 0.016067 | time: 4.05s
# Epoch 106 | train MAE: 0.020407 | val MAE: 0.013649 | time: 4.14s
# Epoch 107 | train MAE: 0.020750 | val MAE: 0.016464 | time: 4.18s
# 😴 Cooling GPU: sleeping 10s after epoch 107
# Epoch 108 | train MAE: 0.020588 | val MAE: 0.014274 | time: 4.06s
# Epoch 109 | train MAE: 0.020474 | val MAE: 0.018861 | time: 4.15s
# Epoch 110 | train MAE: 0.020403 | val MAE: 0.016007 | time: 4.20s
# 😴 Cooling GPU: sleeping 10s after epoch 110
# Epoch 111 | train MAE: 0.020893 | val MAE: 0.013019 | time: 4.07s
# Epoch 112 | train MAE: 0.020650 | val MAE: 0.014796 | time: 4.14s
# Epoch 113 | train MAE: 0.019831 | val MAE: 0.016188 | time: 4.18s
# 😴 Cooling GPU: sleeping 10s after epoch 113
# Epoch 114 | train MAE: 0.020113 | val MAE: 0.015083 | time: 4.07s
# Epoch 115 | train MAE: 0.020146 | val MAE: 0.014905 | time: 4.15s
# Epoch 116 | train MAE: 0.020296 | val MAE: 0.014227 | time: 4.19s
# 😴 Cooling GPU: sleeping 10s after epoch 116
# Epoch 117 | train MAE: 0.019925 | val MAE: 0.015221 | time: 4.08s
# Epoch 118 | train MAE: 0.020571 | val MAE: 0.016699 | time: 4.16s
# Epoch 119 | train MAE: 0.019657 | val MAE: 0.014674 | time: 4.18s
# 😴 Cooling GPU: sleeping 10s after epoch 119
# Epoch 120 | train MAE: 0.019568 | val MAE: 0.014446 | time: 4.06s
# Epoch 121 | train MAE: 0.019585 | val MAE: 0.016493 | time: 4.15s
# Epoch 122 | train MAE: 0.019907 | val MAE: 0.013627 | time: 4.21s
# 😴 Cooling GPU: sleeping 10s after epoch 122
# Epoch 123 | train MAE: 0.019733 | val MAE: 0.015119 | time: 4.09s
# Epoch 124 | train MAE: 0.019818 | val MAE: 0.013514 | time: 4.17s
# Epoch 125 | train MAE: 0.019854 | val MAE: 0.015509 | time: 4.20s
# 😴 Cooling GPU: sleeping 10s after epoch 125
# Epoch 126 | train MAE: 0.019138 | val MAE: 0.017343 | time: 4.10s
# Epoch 127 | train MAE: 0.019976 | val MAE: 0.012191 | time: 4.17s
# Epoch 128 | train MAE: 0.019094 | val MAE: 0.017856 | time: 4.22s
# 😴 Cooling GPU: sleeping 10s after epoch 128
# Epoch 129 | train MAE: 0.019883 | val MAE: 0.016726 | time: 4.08s
# Epoch 130 | train MAE: 0.018812 | val MAE: 0.010546 | time: 4.17s
# Epoch 131 | train MAE: 0.019382 | val MAE: 0.011163 | time: 4.22s
# 😴 Cooling GPU: sleeping 10s after epoch 131
# Epoch 132 | train MAE: 0.019120 | val MAE: 0.012701 | time: 4.09s
# Epoch 133 | train MAE: 0.019759 | val MAE: 0.014298 | time: 4.16s
# Epoch 134 | train MAE: 0.019018 | val MAE: 0.014990 | time: 4.21s
# 😴 Cooling GPU: sleeping 10s after epoch 134
# Epoch 135 | train MAE: 0.019096 | val MAE: 0.012499 | time: 4.08s
# Epoch 136 | train MAE: 0.018924 | val MAE: 0.018053 | time: 4.18s
# Epoch 137 | train MAE: 0.018858 | val MAE: 0.009519 | time: 4.24s
# 😴 Cooling GPU: sleeping 10s after epoch 137
# Epoch 138 | train MAE: 0.019206 | val MAE: 0.015781 | time: 4.08s
# Epoch 139 | train MAE: 0.018567 | val MAE: 0.012702 | time: 4.17s
# Epoch 140 | train MAE: 0.018871 | val MAE: 0.014078 | time: 4.21s
# 😴 Cooling GPU: sleeping 10s after epoch 140
# Epoch 141 | train MAE: 0.019227 | val MAE: 0.014313 | time: 4.11s
# Epoch 142 | train MAE: 0.018968 | val MAE: 0.013448 | time: 4.18s
# Epoch 143 | train MAE: 0.019035 | val MAE: 0.014447 | time: 4.21s
# 😴 Cooling GPU: sleeping 10s after epoch 143
# Epoch 144 | train MAE: 0.018836 | val MAE: 0.013484 | time: 4.09s
# Epoch 145 | train MAE: 0.019351 | val MAE: 0.017096 | time: 4.19s
# Epoch 146 | train MAE: 0.018297 | val MAE: 0.015221 | time: 4.23s
# 😴 Cooling GPU: sleeping 10s after epoch 146
# Epoch 147 | train MAE: 0.018462 | val MAE: 0.020109 | time: 4.11s
# Epoch 148 | train MAE: 0.018432 | val MAE: 0.012746 | time: 4.20s
# Epoch 149 | train MAE: 0.018688 | val MAE: 0.017279 | time: 4.25s
# 😴 Cooling GPU: sleeping 10s after epoch 149
# Epoch 150 | train MAE: 0.018626 | val MAE: 0.013377 | time: 4.09s
# Epoch 151 | train MAE: 0.018526 | val MAE: 0.013912 | time: 4.19s
# Epoch 152 | train MAE: 0.018220 | val MAE: 0.010958 | time: 4.25s
# 😴 Cooling GPU: sleeping 10s after epoch 152
# Epoch 153 | train MAE: 0.018113 | val MAE: 0.012553 | time: 4.11s
# Epoch 154 | train MAE: 0.018393 | val MAE: 0.017578 | time: 4.19s
# Epoch 155 | train MAE: 0.018163 | val MAE: 0.011444 | time: 4.27s
# 😴 Cooling GPU: sleeping 10s after epoch 155
# Epoch 156 | train MAE: 0.018303 | val MAE: 0.011594 | time: 4.13s
# Epoch 157 | train MAE: 0.018301 | val MAE: 0.013719 | time: 4.19s
# Epoch 158 | train MAE: 0.018029 | val MAE: 0.011425 | time: 4.24s
# 😴 Cooling GPU: sleeping 10s after epoch 158
# Epoch 159 | train MAE: 0.018436 | val MAE: 0.014326 | time: 4.10s
# Epoch 160 | train MAE: 0.018081 | val MAE: 0.012813 | time: 4.21s
# Epoch 161 | train MAE: 0.018301 | val MAE: 0.014603 | time: 4.24s
# 😴 Cooling GPU: sleeping 10s after epoch 161
# Epoch 162 | train MAE: 0.018033 | val MAE: 0.012179 | time: 4.10s
# Epoch 163 | train MAE: 0.017735 | val MAE: 0.009775 | time: 4.19s
# Epoch 164 | train MAE: 0.018527 | val MAE: 0.012427 | time: 4.27s
# 😴 Cooling GPU: sleeping 10s after epoch 164
# Epoch 165 | train MAE: 0.017387 | val MAE: 0.013871 | time: 4.10s
# Epoch 166 | train MAE: 0.017687 | val MAE: 0.012524 | time: 4.19s
# Epoch 167 | train MAE: 0.018765 | val MAE: 0.010492 | time: 4.27s
# 😴 Cooling GPU: sleeping 10s after epoch 167
# Epoch 168 | train MAE: 0.017859 | val MAE: 0.012941 | time: 4.09s
# Epoch 169 | train MAE: 0.017775 | val MAE: 0.012994 | time: 4.19s
# Epoch 170 | train MAE: 0.017735 | val MAE: 0.011710 | time: 4.26s
# 😴 Cooling GPU: sleeping 10s after epoch 170
# Epoch 171 | train MAE: 0.017901 | val MAE: 0.014994 | time: 4.12s
# Epoch 172 | train MAE: 0.017527 | val MAE: 0.013005 | time: 4.22s
# Epoch 173 | train MAE: 0.018504 | val MAE: 0.017567 | time: 4.26s
# 😴 Cooling GPU: sleeping 10s after epoch 173
# Epoch 174 | train MAE: 0.017883 | val MAE: 0.012585 | time: 4.12s
# Epoch 175 | train MAE: 0.017366 | val MAE: 0.014357 | time: 4.20s
# Epoch 176 | train MAE: 0.017565 | val MAE: 0.013374 | time: 4.26s
# 😴 Cooling GPU: sleeping 10s after epoch 176
# Epoch 177 | train MAE: 0.018018 | val MAE: 0.012900 | time: 4.13s
# Epoch 178 | train MAE: 0.017387 | val MAE: 0.010243 | time: 4.22s
# Epoch 179 | train MAE: 0.017181 | val MAE: 0.012028 | time: 4.26s
# 😴 Cooling GPU: sleeping 10s after epoch 179
# Epoch 180 | train MAE: 0.018124 | val MAE: 0.015141 | time: 4.12s
# Epoch 181 | train MAE: 0.017654 | val MAE: 0.010690 | time: 4.23s
# Epoch 182 | train MAE: 0.017583 | val MAE: 0.011211 | time: 4.28s
# 😴 Cooling GPU: sleeping 10s after epoch 182
# Epoch 183 | train MAE: 0.017628 | val MAE: 0.012614 | time: 4.12s
# Epoch 184 | train MAE: 0.017338 | val MAE: 0.013709 | time: 4.20s
# Epoch 185 | train MAE: 0.017780 | val MAE: 0.016401 | time: 4.30s
# 😴 Cooling GPU: sleeping 10s after epoch 185
# Epoch 186 | train MAE: 0.017587 | val MAE: 0.010665 | time: 4.14s
# Epoch 187 | train MAE: 0.017701 | val MAE: 0.014506 | time: 4.24s
# Epoch 188 | train MAE: 0.017436 | val MAE: 0.013253 | time: 4.27s
# 😴 Cooling GPU: sleeping 10s after epoch 188
# Epoch 189 | train MAE: 0.017316 | val MAE: 0.013899 | time: 4.12s
# Epoch 190 | train MAE: 0.017308 | val MAE: 0.009960 | time: 4.23s
# Epoch 191 | train MAE: 0.017183 | val MAE: 0.014208 | time: 4.27s
# 😴 Cooling GPU: sleeping 10s after epoch 191
# Epoch 192 | train MAE: 0.017648 | val MAE: 0.012521 | time: 4.13s
# Epoch 193 | train MAE: 0.017362 | val MAE: 0.012883 | time: 4.21s
# Epoch 194 | train MAE: 0.016899 | val MAE: 0.011934 | time: 4.29s
# 😴 Cooling GPU: sleeping 10s after epoch 194
# Epoch 195 | train MAE: 0.017408 | val MAE: 0.010966 | time: 4.12s
# Epoch 196 | train MAE: 0.017927 | val MAE: 0.015533 | time: 4.21s
# Epoch 197 | train MAE: 0.017162 | val MAE: 0.011063 | time: 4.28s
# 😴 Cooling GPU: sleeping 10s after epoch 197
# Epoch 198 | train MAE: 0.017179 | val MAE: 0.010618 | time: 4.12s
# Epoch 199 | train MAE: 0.017376 | val MAE: 0.010745 | time: 4.22s
# Epoch 200 | train MAE: 0.017055 | val MAE: 0.010270 | time: 4.30s
# 😴 Cooling GPU: sleeping 10s after epoch 200
# Epoch 201 | train MAE: 0.017139 | val MAE: 0.012227 | time: 4.11s
# Epoch 202 | train MAE: 0.016962 | val MAE: 0.017362 | time: 4.23s
# Epoch 203 | train MAE: 0.016928 | val MAE: 0.013499 | time: 4.29s
# 😴 Cooling GPU: sleeping 10s after epoch 203
# Epoch 204 | train MAE: 0.017282 | val MAE: 0.015460 | time: 4.12s
# Epoch 205 | train MAE: 0.016538 | val MAE: 0.015426 | time: 4.24s
# Epoch 206 | train MAE: 0.017028 | val MAE: 0.010221 | time: 4.30s
# 😴 Cooling GPU: sleeping 10s after epoch 206
# Epoch 207 | train MAE: 0.017090 | val MAE: 0.011926 | time: 4.13s
# Epoch 208 | train MAE: 0.016813 | val MAE: 0.014445 | time: 4.22s
# Epoch 209 | train MAE: 0.016864 | val MAE: 0.012950 | time: 4.28s
# 😴 Cooling GPU: sleeping 10s after epoch 209
# Epoch 210 | train MAE: 0.016769 | val MAE: 0.016364 | time: 4.13s
# Epoch 211 | train MAE: 0.016634 | val MAE: 0.014234 | time: 4.24s
# Epoch 212 | train MAE: 0.016867 | val MAE: 0.014955 | time: 4.29s
# 😴 Cooling GPU: sleeping 10s after epoch 212
# Epoch 213 | train MAE: 0.016970 | val MAE: 0.011280 | time: 4.12s
# Epoch 214 | train MAE: 0.016982 | val MAE: 0.008674 | time: 4.23s
# Epoch 215 | train MAE: 0.016452 | val MAE: 0.012155 | time: 4.27s
# 😴 Cooling GPU: sleeping 10s after epoch 215
# Epoch 216 | train MAE: 0.016862 | val MAE: 0.009496 | time: 4.12s
# Epoch 217 | train MAE: 0.016736 | val MAE: 0.012483 | time: 4.23s
# Epoch 218 | train MAE: 0.016613 | val MAE: 0.010813 | time: 4.28s
# 😴 Cooling GPU: sleeping 10s after epoch 218
# Epoch 219 | train MAE: 0.016719 | val MAE: 0.014552 | time: 4.13s
# Epoch 220 | train MAE: 0.016525 | val MAE: 0.010680 | time: 4.24s
# Epoch 221 | train MAE: 0.016722 | val MAE: 0.012150 | time: 4.28s
# 😴 Cooling GPU: sleeping 10s after epoch 221
# Epoch 222 | train MAE: 0.016908 | val MAE: 0.011549 | time: 4.12s
# Epoch 223 | train MAE: 0.016735 | val MAE: 0.009209 | time: 4.22s
# Epoch 224 | train MAE: 0.016444 | val MAE: 0.010192 | time: 4.30s
# 😴 Cooling GPU: sleeping 10s after epoch 224
# Epoch 225 | train MAE: 0.016433 | val MAE: 0.012359 | time: 4.13s
# Epoch 226 | train MAE: 0.016328 | val MAE: 0.010637 | time: 4.28s
# Epoch 227 | train MAE: 0.016478 | val MAE: 0.013481 | time: 4.29s
# 😴 Cooling GPU: sleeping 10s after epoch 227
# Epoch 228 | train MAE: 0.016702 | val MAE: 0.011091 | time: 4.14s
# Epoch 229 | train MAE: 0.016135 | val MAE: 0.010804 | time: 4.25s
# Epoch 230 | train MAE: 0.016453 | val MAE: 0.012158 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 230
# Epoch 231 | train MAE: 0.016368 | val MAE: 0.009626 | time: 4.14s
# Epoch 232 | train MAE: 0.016190 | val MAE: 0.013731 | time: 4.23s
# Epoch 233 | train MAE: 0.016619 | val MAE: 0.013871 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 233
# Epoch 234 | train MAE: 0.016253 | val MAE: 0.013649 | time: 4.13s
# Epoch 235 | train MAE: 0.016606 | val MAE: 0.010890 | time: 4.25s
# Epoch 247 | train MAE: 0.016032 | val MAE: 0.009888 | time: 4.24s
# Epoch 248 | train MAE: 0.015799 | val MAE: 0.011340 | time: 4.27s
# 😴 Cooling GPU: sleeping 10s after epoch 248
# Epoch 249 | train MAE: 0.016051 | val MAE: 0.014605 | time: 4.13s
# Epoch 250 | train MAE: 0.015901 | val MAE: 0.011862 | time: 4.26s
# Epoch 251 | train MAE: 0.016076 | val MAE: 0.014074 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 251
# Epoch 252 | train MAE: 0.015981 | val MAE: 0.011215 | time: 4.12s
# Epoch 253 | train MAE: 0.016137 | val MAE: 0.009988 | time: 4.25s
# Epoch 254 | train MAE: 0.015921 | val MAE: 0.010785 | time: 4.29s
# 😴 Cooling GPU: sleeping 10s after epoch 254
# Epoch 255 | train MAE: 0.016377 | val MAE: 0.010756 | time: 4.13s
# Epoch 256 | train MAE: 0.016030 | val MAE: 0.013159 | time: 4.25s
# Epoch 257 | train MAE: 0.015729 | val MAE: 0.010063 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 257
# Epoch 258 | train MAE: 0.015964 | val MAE: 0.011467 | time: 4.12s
# Epoch 259 | train MAE: 0.015843 | val MAE: 0.013875 | time: 4.23s
# Epoch 260 | train MAE: 0.015626 | val MAE: 0.013444 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 260
# Epoch 261 | train MAE: 0.015714 | val MAE: 0.010883 | time: 4.15s
# Epoch 262 | train MAE: 0.015688 | val MAE: 0.015015 | time: 4.23s
# Epoch 263 | train MAE: 0.015790 | val MAE: 0.011827 | time: 4.30s
# 😴 Cooling GPU: sleeping 10s after epoch 263
# Epoch 264 | train MAE: 0.015636 | val MAE: 0.009292 | time: 4.16s
# Epoch 265 | train MAE: 0.015884 | val MAE: 0.010742 | time: 4.24s
# Epoch 266 | train MAE: 0.015947 | val MAE: 0.010224 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 266
# Epoch 267 | train MAE: 0.015389 | val MAE: 0.009659 | time: 4.12s
# Epoch 268 | train MAE: 0.015521 | val MAE: 0.013029 | time: 4.25s
# Epoch 269 | train MAE: 0.015308 | val MAE: 0.012381 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 269
# Epoch 270 | train MAE: 0.015286 | val MAE: 0.012320 | time: 4.13s
# Epoch 271 | train MAE: 0.015281 | val MAE: 0.013076 | time: 4.25s
# Epoch 272 | train MAE: 0.015457 | val MAE: 0.011592 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 272
# Epoch 273 | train MAE: 0.015618 | val MAE: 0.012869 | time: 4.14s
# Epoch 274 | train MAE: 0.015318 | val MAE: 0.013620 | time: 4.25s
# Epoch 275 | train MAE: 0.015682 | val MAE: 0.013004 | time: 4.30s
# 😴 Cooling GPU: sleeping 10s after epoch 275
# Epoch 276 | train MAE: 0.015527 | val MAE: 0.011826 | time: 4.12s
# Epoch 277 | train MAE: 0.015539 | val MAE: 0.011771 | time: 4.27s
# Epoch 278 | train MAE: 0.015434 | val MAE: 0.012780 | time: 4.30s
# 😴 Cooling GPU: sleeping 10s after epoch 278
# Epoch 279 | train MAE: 0.015632 | val MAE: 0.013471 | time: 4.15s
# Epoch 280 | train MAE: 0.015403 | val MAE: 0.011908 | time: 4.28s
# Epoch 281 | train MAE: 0.015441 | val MAE: 0.013285 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 281
# Epoch 282 | train MAE: 0.015575 | val MAE: 0.011031 | time: 4.14s
# Epoch 283 | train MAE: 0.014828 | val MAE: 0.011570 | time: 4.24s
# Epoch 284 | train MAE: 0.015428 | val MAE: 0.010528 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 284
# Epoch 285 | train MAE: 0.015178 | val MAE: 0.013453 | time: 4.13s
# Epoch 286 | train MAE: 0.015307 | val MAE: 0.011731 | time: 4.26s
# Epoch 287 | train MAE: 0.015377 | val MAE: 0.011071 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 287
# Epoch 288 | train MAE: 0.015318 | val MAE: 0.011447 | time: 4.15s
# Epoch 289 | train MAE: 0.014895 | val MAE: 0.011220 | time: 4.26s
# Epoch 290 | train MAE: 0.015086 | val MAE: 0.011145 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 290
# Epoch 291 | train MAE: 0.015163 | val MAE: 0.010747 | time: 4.14s
# Epoch 292 | train MAE: 0.015250 | val MAE: 0.012034 | time: 4.26s
# Epoch 293 | train MAE: 0.014866 | val MAE: 0.010594 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 293
# Epoch 294 | train MAE: 0.014951 | val MAE: 0.013525 | time: 4.15s
# Epoch 295 | train MAE: 0.014826 | val MAE: 0.011103 | time: 4.26s
# Epoch 296 | train MAE: 0.014990 | val MAE: 0.013633 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 296
# Epoch 297 | train MAE: 0.015086 | val MAE: 0.013468 | time: 4.15s
# Epoch 298 | train MAE: 0.014923 | val MAE: 0.012570 | time: 4.27s
# Epoch 299 | train MAE: 0.014958 | val MAE: 0.012993 | time: 4.30s
# 😴 Cooling GPU: sleeping 10s after epoch 299
# Epoch 300 | train MAE: 0.015185 | val MAE: 0.017098 | time: 4.14s
# Epoch 301 | train MAE: 0.015080 | val MAE: 0.011787 | time: 4.29s
# Epoch 302 | train MAE: 0.015150 | val MAE: 0.009568 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 302
# Epoch 303 | train MAE: 0.014981 | val MAE: 0.012247 | time: 4.14s
# Epoch 304 | train MAE: 0.014820 | val MAE: 0.010585 | time: 4.25s
# Epoch 305 | train MAE: 0.014855 | val MAE: 0.013046 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 305
# Epoch 306 | train MAE: 0.014744 | val MAE: 0.011850 | time: 4.15s
# Epoch 307 | train MAE: 0.014946 | val MAE: 0.011119 | time: 4.24s
# Epoch 308 | train MAE: 0.014772 | val MAE: 0.010533 | time: 4.34s
# 😴 Cooling GPU: sleeping 10s after epoch 308
# Epoch 309 | train MAE: 0.015271 | val MAE: 0.010473 | time: 4.12s
# Epoch 310 | train MAE: 0.014569 | val MAE: 0.010245 | time: 4.25s
# Epoch 311 | train MAE: 0.014794 | val MAE: 0.011858 | time: 4.29s
# 😴 Cooling GPU: sleeping 10s after epoch 311
# Epoch 312 | train MAE: 0.014447 | val MAE: 0.011680 | time: 4.12s
# Epoch 313 | train MAE: 0.014904 | val MAE: 0.011404 | time: 4.27s
# Epoch 314 | train MAE: 0.014742 | val MAE: 0.011191 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 314
# Epoch 315 | train MAE: 0.014499 | val MAE: 0.011489 | time: 4.14s
# Epoch 316 | train MAE: 0.014985 | val MAE: 0.013266 | time: 4.25s
# Epoch 317 | train MAE: 0.014743 | val MAE: 0.010691 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 317
# Epoch 318 | train MAE: 0.014482 | val MAE: 0.012122 | time: 4.14s
# Epoch 319 | train MAE: 0.014725 | val MAE: 0.012093 | time: 4.25s
# Epoch 320 | train MAE: 0.014510 | val MAE: 0.011746 | time: 4.30s
# 😴 Cooling GPU: sleeping 10s after epoch 320
# Epoch 321 | train MAE: 0.014414 | val MAE: 0.011309 | time: 4.14s
# Epoch 322 | train MAE: 0.014709 | val MAE: 0.010340 | time: 4.24s
# Epoch 323 | train MAE: 0.014864 | val MAE: 0.011925 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 323
# Epoch 324 | train MAE: 0.014564 | val MAE: 0.013050 | time: 4.13s
# Epoch 325 | train MAE: 0.014260 | val MAE: 0.010724 | time: 4.25s
# Epoch 326 | train MAE: 0.014576 | val MAE: 0.010382 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 326
# Epoch 327 | train MAE: 0.014892 | val MAE: 0.010215 | time: 4.16s
# Epoch 328 | train MAE: 0.014649 | val MAE: 0.010270 | time: 4.25s
# Epoch 329 | train MAE: 0.014148 | val MAE: 0.010443 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 329
# Epoch 330 | train MAE: 0.014333 | val MAE: 0.010723 | time: 4.15s
# Epoch 331 | train MAE: 0.014519 | val MAE: 0.014208 | time: 4.26s
# Epoch 332 | train MAE: 0.014706 | val MAE: 0.013021 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 332
# Epoch 333 | train MAE: 0.014735 | val MAE: 0.015032 | time: 4.15s
# Epoch 334 | train MAE: 0.013929 | val MAE: 0.012420 | time: 4.27s
# Epoch 335 | train MAE: 0.014308 | val MAE: 0.012500 | time: 4.30s
# 😴 Cooling GPU: sleeping 10s after epoch 335
# Epoch 336 | train MAE: 0.014585 | val MAE: 0.013776 | time: 4.14s
# Epoch 337 | train MAE: 0.014343 | val MAE: 0.012905 | time: 4.28s
# Epoch 338 | train MAE: 0.014070 | val MAE: 0.011028 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 338
# Epoch 339 | train MAE: 0.014087 | val MAE: 0.011822 | time: 4.15s
# Epoch 340 | train MAE: 0.014526 | val MAE: 0.011388 | time: 4.25s
# Epoch 341 | train MAE: 0.014442 | val MAE: 0.014624 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 341
# Epoch 342 | train MAE: 0.014140 | val MAE: 0.011546 | time: 4.16s
# Epoch 343 | train MAE: 0.014268 | val MAE: 0.011415 | time: 4.25s
# Epoch 344 | train MAE: 0.014290 | val MAE: 0.012136 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 344
# Epoch 345 | train MAE: 0.014169 | val MAE: 0.012700 | time: 4.14s
# Epoch 346 | train MAE: 0.013932 | val MAE: 0.011766 | time: 4.25s
# Epoch 347 | train MAE: 0.014061 | val MAE: 0.011711 | time: 4.29s
# 😴 Cooling GPU: sleeping 10s after epoch 347
# Epoch 348 | train MAE: 0.014473 | val MAE: 0.010203 | time: 4.14s
# Epoch 349 | train MAE: 0.014182 | val MAE: 0.012157 | time: 4.27s
# Epoch 350 | train MAE: 0.014034 | val MAE: 0.012256 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 350
# Epoch 351 | train MAE: 0.014002 | val MAE: 0.010285 | time: 4.14s
# Epoch 352 | train MAE: 0.013845 | val MAE: 0.014272 | time: 4.26s
# Epoch 353 | train MAE: 0.014259 | val MAE: 0.012235 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 353
# Epoch 354 | train MAE: 0.013851 | val MAE: 0.011638 | time: 4.14s
# Epoch 355 | train MAE: 0.014254 | val MAE: 0.012957 | time: 4.25s
# Epoch 356 | train MAE: 0.014052 | val MAE: 0.008894 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 356
# Epoch 357 | train MAE: 0.014023 | val MAE: 0.010830 | time: 4.13s
# Epoch 358 | train MAE: 0.013911 | val MAE: 0.010197 | time: 4.28s
# Epoch 359 | train MAE: 0.014071 | val MAE: 0.013378 | time: 4.29s
# 😴 Cooling GPU: sleeping 10s after epoch 359
# Epoch 360 | train MAE: 0.013758 | val MAE: 0.011080 | time: 4.14s
# Epoch 361 | train MAE: 0.014141 | val MAE: 0.011946 | time: 4.27s
# Epoch 362 | train MAE: 0.014065 | val MAE: 0.011631 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 362
# Epoch 363 | train MAE: 0.013955 | val MAE: 0.015288 | time: 4.14s
# Epoch 364 | train MAE: 0.014000 | val MAE: 0.012963 | time: 4.27s
# Epoch 365 | train MAE: 0.014029 | val MAE: 0.014654 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 365
# Epoch 366 | train MAE: 0.013852 | val MAE: 0.013257 | time: 4.15s
# Epoch 367 | train MAE: 0.013987 | val MAE: 0.012733 | time: 4.26s
# Epoch 368 | train MAE: 0.013680 | val MAE: 0.012427 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 368
# Epoch 369 | train MAE: 0.013632 | val MAE: 0.012374 | time: 4.14s
# Epoch 370 | train MAE: 0.014008 | val MAE: 0.013620 | time: 4.29s
# Epoch 371 | train MAE: 0.013835 | val MAE: 0.011682 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 371
# Epoch 372 | train MAE: 0.013946 | val MAE: 0.013228 | time: 4.15s
# Epoch 373 | train MAE: 0.013735 | val MAE: 0.010424 | time: 4.29s
# Epoch 374 | train MAE: 0.013661 | val MAE: 0.011249 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 374
# Epoch 375 | train MAE: 0.013839 | val MAE: 0.015066 | time: 4.13s
# Epoch 376 | train MAE: 0.013720 | val MAE: 0.012651 | time: 4.27s
# Epoch 377 | train MAE: 0.013736 | val MAE: 0.013978 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 377
# Epoch 378 | train MAE: 0.013686 | val MAE: 0.011419 | time: 4.16s
# Epoch 379 | train MAE: 0.013569 | val MAE: 0.014350 | time: 4.28s
# Epoch 380 | train MAE: 0.013559 | val MAE: 0.015346 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 380
# Epoch 381 | train MAE: 0.013766 | val MAE: 0.015264 | time: 4.15s
# Epoch 382 | train MAE: 0.013508 | val MAE: 0.015541 | time: 4.29s
# Epoch 383 | train MAE: 0.013649 | val MAE: 0.012712 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 383
# Epoch 384 | train MAE: 0.013516 | val MAE: 0.013085 | time: 4.15s
# Epoch 385 | train MAE: 0.013580 | val MAE: 0.012044 | time: 4.29s
# Epoch 386 | train MAE: 0.013260 | val MAE: 0.011515 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 386
# Epoch 387 | train MAE: 0.013600 | val MAE: 0.013293 | time: 4.16s
# Epoch 388 | train MAE: 0.013458 | val MAE: 0.013259 | time: 4.28s
# Epoch 389 | train MAE: 0.013599 | val MAE: 0.015478 | time: 4.34s
# 😴 Cooling GPU: sleeping 10s after epoch 389
# Epoch 390 | train MAE: 0.013606 | val MAE: 0.011325 | time: 4.16s
# Epoch 391 | train MAE: 0.013460 | val MAE: 0.011717 | time: 4.31s
# Epoch 392 | train MAE: 0.013525 | val MAE: 0.011751 | time: 4.31s
# 😴 Cooling GPU: sleeping 10s after epoch 392
# Epoch 393 | train MAE: 0.013772 | val MAE: 0.011190 | time: 4.16s
# Epoch 394 | train MAE: 0.013711 | val MAE: 0.013195 | time: 4.28s
# Epoch 395 | train MAE: 0.013521 | val MAE: 0.013263 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 395
# Epoch 396 | train MAE: 0.013523 | val MAE: 0.012966 | time: 4.16s
# Epoch 397 | train MAE: 0.013332 | val MAE: 0.014337 | time: 4.29s
# Epoch 398 | train MAE: 0.013409 | val MAE: 0.014939 | time: 4.30s
# 😴 Cooling GPU: sleeping 10s after epoch 398
# Epoch 399 | train MAE: 0.013280 | val MAE: 0.013088 | time: 4.16s
# Epoch 400 | train MAE: 0.013374 | val MAE: 0.012565 | time: 4.27s
# Epoch 401 | train MAE: 0.013310 | val MAE: 0.012763 | time: 4.34s
# 😴 Cooling GPU: sleeping 10s after epoch 401
# Epoch 402 | train MAE: 0.013642 | val MAE: 0.010892 | time: 4.16s
# Epoch 403 | train MAE: 0.013009 | val MAE: 0.014548 | time: 4.30s
# Epoch 404 | train MAE: 0.013318 | val MAE: 0.012464 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 404
# Epoch 405 | train MAE: 0.013580 | val MAE: 0.013264 | time: 4.16s
# Epoch 406 | train MAE: 0.013435 | val MAE: 0.012080 | time: 4.29s
# Epoch 407 | train MAE: 0.013436 | val MAE: 0.014023 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 407
# Epoch 408 | train MAE: 0.013208 | val MAE: 0.012915 | time: 4.15s
# Epoch 409 | train MAE: 0.013069 | val MAE: 0.012819 | time: 4.26s
# Epoch 410 | train MAE: 0.013610 | val MAE: 0.012394 | time: 4.34s
# 😴 Cooling GPU: sleeping 10s after epoch 410
# Epoch 411 | train MAE: 0.012885 | val MAE: 0.014195 | time: 4.14s
# Epoch 412 | train MAE: 0.013466 | val MAE: 0.011738 | time: 4.30s
# Epoch 413 | train MAE: 0.013285 | val MAE: 0.016139 | time: 4.34s
# 😴 Cooling GPU: sleeping 10s after epoch 413
# Epoch 414 | train MAE: 0.012931 | val MAE: 0.014121 | time: 4.16s
# Epoch 415 | train MAE: 0.013552 | val MAE: 0.012887 | time: 4.31s
# Epoch 416 | train MAE: 0.013216 | val MAE: 0.014449 | time: 4.34s
# 😴 Cooling GPU: sleeping 10s after epoch 416
# Epoch 417 | train MAE: 0.013193 | val MAE: 0.015295 | time: 4.16s
# Epoch 418 | train MAE: 0.013418 | val MAE: 0.013322 | time: 4.34s
# Epoch 419 | train MAE: 0.012967 | val MAE: 0.012096 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 419
# Epoch 420 | train MAE: 0.013231 | val MAE: 0.014341 | time: 4.18s
# Epoch 421 | train MAE: 0.013135 | val MAE: 0.013136 | time: 4.29s
# Epoch 422 | train MAE: 0.013011 | val MAE: 0.012177 | time: 4.34s
# 😴 Cooling GPU: sleeping 10s after epoch 422
# Epoch 423 | train MAE: 0.013228 | val MAE: 0.013120 | time: 4.17s
# Epoch 424 | train MAE: 0.013307 | val MAE: 0.012720 | time: 4.28s
# Epoch 425 | train MAE: 0.013042 | val MAE: 0.012642 | time: 4.34s
# 😴 Cooling GPU: sleeping 10s after epoch 425
# Epoch 426 | train MAE: 0.013100 | val MAE: 0.017513 | time: 4.16s
# Epoch 427 | train MAE: 0.013047 | val MAE: 0.012246 | time: 4.28s
# Epoch 428 | train MAE: 0.013131 | val MAE: 0.016283 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 428
# Epoch 429 | train MAE: 0.013227 | val MAE: 0.013763 | time: 4.16s
# Epoch 430 | train MAE: 0.012859 | val MAE: 0.013209 | time: 4.29s
# Epoch 431 | train MAE: 0.012968 | val MAE: 0.013397 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 431
# Epoch 432 | train MAE: 0.012986 | val MAE: 0.013121 | time: 4.16s
# Epoch 433 | train MAE: 0.013007 | val MAE: 0.012149 | time: 4.30s
# Epoch 434 | train MAE: 0.013026 | val MAE: 0.012043 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 434
# Epoch 435 | train MAE: 0.013188 | val MAE: 0.013348 | time: 4.15s
# Epoch 436 | train MAE: 0.013019 | val MAE: 0.013352 | time: 4.32s
# Epoch 437 | train MAE: 0.012672 | val MAE: 0.014816 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 437
# Epoch 438 | train MAE: 0.012781 | val MAE: 0.013622 | time: 4.16s
# Epoch 439 | train MAE: 0.013013 | val MAE: 0.014806 | time: 4.29s
# Epoch 440 | train MAE: 0.012972 | val MAE: 0.012169 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 440
# Epoch 441 | train MAE: 0.012951 | val MAE: 0.013825 | time: 4.17s
# Epoch 442 | train MAE: 0.012945 | val MAE: 0.014359 | time: 4.31s
# Epoch 443 | train MAE: 0.012810 | val MAE: 0.018137 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 443
# Epoch 444 | train MAE: 0.012878 | val MAE: 0.014437 | time: 4.17s
# Epoch 445 | train MAE: 0.013081 | val MAE: 0.014440 | time: 4.28s
# Epoch 446 | train MAE: 0.012699 | val MAE: 0.018287 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 446
# Epoch 447 | train MAE: 0.012712 | val MAE: 0.013508 | time: 4.16s
# Epoch 448 | train MAE: 0.012792 | val MAE: 0.015450 | time: 4.30s
# Epoch 449 | train MAE: 0.012958 | val MAE: 0.014765 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 449
# Epoch 450 | train MAE: 0.012625 | val MAE: 0.012001 | time: 4.15s
# Epoch 451 | train MAE: 0.012388 | val MAE: 0.015404 | time: 4.29s
# Epoch 452 | train MAE: 0.013430 | val MAE: 0.013136 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 452
# Epoch 453 | train MAE: 0.012692 | val MAE: 0.012211 | time: 4.17s
# Epoch 454 | train MAE: 0.012772 | val MAE: 0.015230 | time: 4.32s
# Epoch 455 | train MAE: 0.012588 | val MAE: 0.013440 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 455
# Epoch 456 | train MAE: 0.012822 | val MAE: 0.012435 | time: 4.18s
# Epoch 457 | train MAE: 0.012544 | val MAE: 0.016378 | time: 4.30s
# Epoch 458 | train MAE: 0.012816 | val MAE: 0.015399 | time: 4.32s
# 😴 Cooling GPU: sleeping 10s after epoch 458
# Epoch 459 | train MAE: 0.012625 | val MAE: 0.012871 | time: 4.17s
# Epoch 460 | train MAE: 0.012866 | val MAE: 0.013863 | time: 4.30s
# Epoch 461 | train MAE: 0.012647 | val MAE: 0.014418 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 461
# Epoch 462 | train MAE: 0.013098 | val MAE: 0.013408 | time: 4.17s
# Epoch 463 | train MAE: 0.012261 | val MAE: 0.012343 | time: 4.29s
# Epoch 464 | train MAE: 0.012735 | val MAE: 0.014250 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 464
# Epoch 465 | train MAE: 0.012608 | val MAE: 0.013306 | time: 4.17s
# Epoch 466 | train MAE: 0.012618 | val MAE: 0.015839 | time: 4.33s
# Epoch 467 | train MAE: 0.012689 | val MAE: 0.013294 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 467
# Epoch 468 | train MAE: 0.012561 | val MAE: 0.016281 | time: 4.17s
# Epoch 469 | train MAE: 0.012455 | val MAE: 0.012506 | time: 4.32s
# Epoch 470 | train MAE: 0.012370 | val MAE: 0.014599 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 470
# Epoch 471 | train MAE: 0.012569 | val MAE: 0.014033 | time: 4.16s
# Epoch 472 | train MAE: 0.012445 | val MAE: 0.015360 | time: 4.28s
# Epoch 473 | train MAE: 0.012674 | val MAE: 0.014606 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 473
# Epoch 474 | train MAE: 0.012701 | val MAE: 0.012381 | time: 4.16s
# Epoch 475 | train MAE: 0.012434 | val MAE: 0.014421 | time: 4.29s
# Epoch 476 | train MAE: 0.012522 | val MAE: 0.012481 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 476
# Epoch 477 | train MAE: 0.012614 | val MAE: 0.015583 | time: 4.16s
# Epoch 478 | train MAE: 0.012549 | val MAE: 0.016070 | time: 4.28s
# Epoch 479 | train MAE: 0.012329 | val MAE: 0.014759 | time: 4.34s
# 😴 Cooling GPU: sleeping 10s after epoch 479
# Epoch 480 | train MAE: 0.012448 | val MAE: 0.016845 | time: 4.17s
# Epoch 481 | train MAE: 0.012493 | val MAE: 0.014169 | time: 4.29s
# Epoch 482 | train MAE: 0.012519 | val MAE: 0.013928 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 482
# Epoch 483 | train MAE: 0.012406 | val MAE: 0.016943 | time: 4.16s
# Epoch 484 | train MAE: 0.012381 | val MAE: 0.016925 | time: 4.29s
# Epoch 485 | train MAE: 0.012544 | val MAE: 0.015679 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 485
# Epoch 486 | train MAE: 0.012273 | val MAE: 0.013204 | time: 4.18s
# Epoch 487 | train MAE: 0.012282 | val MAE: 0.014548 | time: 4.28s
# Epoch 488 | train MAE: 0.012423 | val MAE: 0.014382 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 488
# Epoch 489 | train MAE: 0.012427 | val MAE: 0.014659 | time: 4.17s
# Epoch 490 | train MAE: 0.012452 | val MAE: 0.015239 | time: 4.32s
# Epoch 491 | train MAE: 0.012172 | val MAE: 0.014179 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 491
# Epoch 492 | train MAE: 0.012406 | val MAE: 0.015459 | time: 4.16s
# Epoch 493 | train MAE: 0.012347 | val MAE: 0.014801 | time: 4.31s
# Epoch 494 | train MAE: 0.012359 | val MAE: 0.014942 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 494
# Epoch 495 | train MAE: 0.012560 | val MAE: 0.016873 | time: 4.15s
# Epoch 496 | train MAE: 0.012252 | val MAE: 0.015830 | time: 4.30s
# Epoch 497 | train MAE: 0.012214 | val MAE: 0.013754 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 497
# Epoch 498 | train MAE: 0.012504 | val MAE: 0.012908 | time: 4.19s
# Epoch 499 | train MAE: 0.012277 | val MAE: 0.017492 | time: 4.28s
# Epoch 500 | train MAE: 0.012153 | val MAE: 0.013521 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 500
# Epoch 501 | train MAE: 0.012113 | val MAE: 0.014800 | time: 4.16s
# Epoch 502 | train MAE: 0.012531 | val MAE: 0.016287 | time: 4.29s
# Epoch 503 | train MAE: 0.012012 | val MAE: 0.018283 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 503
# Epoch 504 | train MAE: 0.012266 | val MAE: 0.014250 | time: 4.18s
# Epoch 505 | train MAE: 0.012077 | val MAE: 0.013842 | time: 4.30s
# Epoch 506 | train MAE: 0.012329 | val MAE: 0.016771 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 506
# Epoch 507 | train MAE: 0.012110 | val MAE: 0.013904 | time: 4.19s
# Epoch 508 | train MAE: 0.012193 | val MAE: 0.017781 | time: 4.39s
# Epoch 509 | train MAE: 0.012209 | val MAE: 0.015843 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 509
# Epoch 510 | train MAE: 0.012202 | val MAE: 0.014272 | time: 4.16s
# Epoch 511 | train MAE: 0.012095 | val MAE: 0.015216 | time: 4.32s
# Epoch 512 | train MAE: 0.012357 | val MAE: 0.013384 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 512
# Epoch 513 | train MAE: 0.012373 | val MAE: 0.016051 | time: 4.18s
# Epoch 514 | train MAE: 0.011619 | val MAE: 0.012586 | time: 4.33s
# Epoch 515 | train MAE: 0.012132 | val MAE: 0.013599 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 515
# Epoch 516 | train MAE: 0.012185 | val MAE: 0.014705 | time: 4.17s
# Epoch 517 | train MAE: 0.012098 | val MAE: 0.016669 | time: 4.32s
# Epoch 518 | train MAE: 0.012480 | val MAE: 0.013655 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 518
# Epoch 519 | train MAE: 0.011804 | val MAE: 0.016158 | time: 4.17s
# Epoch 520 | train MAE: 0.012129 | val MAE: 0.013090 | time: 4.31s
# Epoch 521 | train MAE: 0.012040 | val MAE: 0.016427 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 521
# Epoch 522 | train MAE: 0.012269 | val MAE: 0.016243 | time: 4.17s
# Epoch 523 | train MAE: 0.012240 | val MAE: 0.016024 | time: 4.34s
# Epoch 524 | train MAE: 0.011734 | val MAE: 0.012534 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 524
# Epoch 525 | train MAE: 0.012025 | val MAE: 0.014440 | time: 4.17s
# Epoch 526 | train MAE: 0.012172 | val MAE: 0.014464 | time: 4.33s
# Epoch 527 | train MAE: 0.012253 | val MAE: 0.016880 | time: 4.40s
# 😴 Cooling GPU: sleeping 10s after epoch 527
# Epoch 528 | train MAE: 0.012012 | val MAE: 0.014307 | time: 4.16s
# Epoch 529 | train MAE: 0.012121 | val MAE: 0.015201 | time: 4.30s
# Epoch 530 | train MAE: 0.012191 | val MAE: 0.018875 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 530
# Epoch 531 | train MAE: 0.012042 | val MAE: 0.016022 | time: 4.18s
# Epoch 532 | train MAE: 0.011781 | val MAE: 0.015489 | time: 4.30s
# Epoch 533 | train MAE: 0.011859 | val MAE: 0.015439 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 533
# Epoch 534 | train MAE: 0.012219 | val MAE: 0.014166 | time: 4.14s
# Epoch 535 | train MAE: 0.012112 | val MAE: 0.016442 | time: 4.33s
# Epoch 536 | train MAE: 0.011802 | val MAE: 0.015027 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 536
# Epoch 537 | train MAE: 0.011918 | val MAE: 0.013571 | time: 4.16s
# Epoch 538 | train MAE: 0.011891 | val MAE: 0.016085 | time: 4.32s
# Epoch 539 | train MAE: 0.011811 | val MAE: 0.014499 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 539
# Epoch 540 | train MAE: 0.011902 | val MAE: 0.017505 | time: 4.19s
# Epoch 541 | train MAE: 0.011905 | val MAE: 0.015140 | time: 4.32s
# Epoch 542 | train MAE: 0.012025 | val MAE: 0.016146 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 542
# Epoch 543 | train MAE: 0.011906 | val MAE: 0.013591 | time: 4.18s
# Epoch 544 | train MAE: 0.011836 | val MAE: 0.015712 | time: 4.33s
# Epoch 545 | train MAE: 0.011894 | val MAE: 0.013754 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 545
# Epoch 546 | train MAE: 0.011741 | val MAE: 0.015441 | time: 4.18s
# Epoch 547 | train MAE: 0.011881 | val MAE: 0.014634 | time: 4.31s
# Epoch 548 | train MAE: 0.011732 | val MAE: 0.015913 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 548
# Epoch 549 | train MAE: 0.011779 | val MAE: 0.016240 | time: 4.16s
# Epoch 550 | train MAE: 0.011671 | val MAE: 0.014491 | time: 4.29s
# Epoch 551 | train MAE: 0.011953 | val MAE: 0.015067 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 551
# Epoch 552 | train MAE: 0.011808 | val MAE: 0.015120 | time: 4.16s
# Epoch 553 | train MAE: 0.011780 | val MAE: 0.013950 | time: 4.30s
# Epoch 554 | train MAE: 0.011743 | val MAE: 0.013475 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 554
# Epoch 555 | train MAE: 0.011856 | val MAE: 0.015582 | time: 4.16s
# Epoch 556 | train MAE: 0.011772 | val MAE: 0.013869 | time: 4.32s
# Epoch 557 | train MAE: 0.011807 | val MAE: 0.016215 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 557
# Epoch 558 | train MAE: 0.012016 | val MAE: 0.016548 | time: 4.16s
# Epoch 559 | train MAE: 0.011503 | val MAE: 0.015470 | time: 4.31s
# Epoch 560 | train MAE: 0.011759 | val MAE: 0.016284 | time: 4.34s
# 😴 Cooling GPU: sleeping 10s after epoch 560
# Epoch 561 | train MAE: 0.011722 | val MAE: 0.016300 | time: 4.15s
# Epoch 562 | train MAE: 0.011477 | val MAE: 0.014302 | time: 4.31s
# Epoch 563 | train MAE: 0.011655 | val MAE: 0.016032 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 563
# Epoch 564 | train MAE: 0.011704 | val MAE: 0.014840 | time: 4.18s
# Epoch 565 | train MAE: 0.011389 | val MAE: 0.017065 | time: 4.33s
# Epoch 566 | train MAE: 0.011753 | val MAE: 0.018271 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 566
# Epoch 567 | train MAE: 0.011786 | val MAE: 0.015205 | time: 4.18s
# Epoch 568 | train MAE: 0.011816 | val MAE: 0.015849 | time: 4.31s
# Epoch 569 | train MAE: 0.011553 | val MAE: 0.016499 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 569
# Epoch 570 | train MAE: 0.011809 | val MAE: 0.016632 | time: 4.19s
# Epoch 571 | train MAE: 0.011597 | val MAE: 0.015525 | time: 4.30s
# Epoch 572 | train MAE: 0.011885 | val MAE: 0.014083 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 572
# Epoch 573 | train MAE: 0.011768 | val MAE: 0.014948 | time: 4.16s
# Epoch 574 | train MAE: 0.011685 | val MAE: 0.013853 | time: 4.29s
# Epoch 575 | train MAE: 0.011754 | val MAE: 0.017318 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 575
# Epoch 576 | train MAE: 0.011630 | val MAE: 0.017318 | time: 4.16s
# Epoch 577 | train MAE: 0.011550 | val MAE: 0.018452 | time: 4.30s
# Epoch 578 | train MAE: 0.011937 | val MAE: 0.016185 | time: 4.33s
# 😴 Cooling GPU: sleeping 10s after epoch 578
# Epoch 579 | train MAE: 0.011441 | val MAE: 0.017188 | time: 4.17s
# Epoch 580 | train MAE: 0.011658 | val MAE: 0.016756 | time: 4.30s
# Epoch 581 | train MAE: 0.011363 | val MAE: 0.014155 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 581
# Epoch 582 | train MAE: 0.011670 | val MAE: 0.014541 | time: 4.16s
# Epoch 583 | train MAE: 0.011684 | val MAE: 0.014634 | time: 4.30s
# Epoch 584 | train MAE: 0.011439 | val MAE: 0.014667 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 584
# Epoch 585 | train MAE: 0.011380 | val MAE: 0.016209 | time: 4.19s
# Epoch 586 | train MAE: 0.011425 | val MAE: 0.015098 | time: 4.34s
# Epoch 587 | train MAE: 0.011388 | val MAE: 0.014989 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 587
# Epoch 588 | train MAE: 0.011383 | val MAE: 0.015754 | time: 4.17s
# Epoch 589 | train MAE: 0.011461 | val MAE: 0.015454 | time: 4.29s
# Epoch 590 | train MAE: 0.011406 | val MAE: 0.014255 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 590
# Epoch 591 | train MAE: 0.011767 | val MAE: 0.016624 | time: 4.15s
# Epoch 592 | train MAE: 0.011407 | val MAE: 0.016704 | time: 4.32s
# Epoch 593 | train MAE: 0.011340 | val MAE: 0.016332 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 593
# ...
# Epoch 1807 | train MAE: 0.006950 | val MAE: 0.017928 | time: 4.39s
# Epoch 1808 | train MAE: 0.007083 | val MAE: 0.017252 | time: 4.44s
# 😴 Cooling GPU: sleeping 10s after epoch 1808
# Epoch 1809 | train MAE: 0.006867 | val MAE: 0.016287 | time: 4.16s
# Epoch 1810 | train MAE: 0.007071 | val MAE: 0.017260 | time: 4.34s
# Epoch 1811 | train MAE: 0.007208 | val MAE: 0.019179 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 1811
# Epoch 1812 | train MAE: 0.007018 | val MAE: 0.018247 | time: 4.17s
# Epoch 1813 | train MAE: 0.006973 | val MAE: 0.017219 | time: 4.34s
# Epoch 1814 | train MAE: 0.006948 | val MAE: 0.018063 | time: 4.42s
# 😴 Cooling GPU: sleeping 10s after epoch 1814
# Epoch 1815 | train MAE: 0.006969 | val MAE: 0.019200 | time: 4.19s
# Epoch 1816 | train MAE: 0.006806 | val MAE: 0.020645 | time: 4.34s
# Epoch 1817 | train MAE: 0.007041 | val MAE: 0.018408 | time: 4.41s
# 😴 Cooling GPU: sleeping 10s after epoch 1817
# Epoch 1818 | train MAE: 0.006942 | val MAE: 0.017888 | time: 4.17s
# Epoch 1819 | train MAE: 0.006961 | val MAE: 0.017399 | time: 4.34s
# Epoch 1820 | train MAE: 0.006963 | val MAE: 0.018991 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1820
# Epoch 1821 | train MAE: 0.006893 | val MAE: 0.019052 | time: 4.18s
# Epoch 1822 | train MAE: 0.007073 | val MAE: 0.017863 | time: 4.35s
# Epoch 1823 | train MAE: 0.006881 | val MAE: 0.017669 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1823
# Epoch 1824 | train MAE: 0.006928 | val MAE: 0.017201 | time: 4.17s
# Epoch 1825 | train MAE: 0.006943 | val MAE: 0.016384 | time: 4.33s
# Epoch 1826 | train MAE: 0.006992 | val MAE: 0.016735 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 1826
# Epoch 1827 | train MAE: 0.007151 | val MAE: 0.017061 | time: 4.18s
# Epoch 1828 | train MAE: 0.007054 | val MAE: 0.015977 | time: 4.33s
# Epoch 1829 | train MAE: 0.006857 | val MAE: 0.017695 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 1829
# Epoch 1830 | train MAE: 0.006948 | val MAE: 0.017425 | time: 4.17s
# Epoch 1831 | train MAE: 0.007045 | val MAE: 0.017856 | time: 4.32s
# Epoch 1832 | train MAE: 0.006910 | val MAE: 0.016982 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 1832
# Epoch 1833 | train MAE: 0.007064 | val MAE: 0.017592 | time: 4.17s
# Epoch 1834 | train MAE: 0.006746 | val MAE: 0.019269 | time: 4.31s
# Epoch 1835 | train MAE: 0.006867 | val MAE: 0.017583 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1835
# Epoch 1836 | train MAE: 0.006952 | val MAE: 0.016849 | time: 4.16s
# Epoch 1837 | train MAE: 0.006969 | val MAE: 0.018074 | time: 4.29s
# Epoch 1838 | train MAE: 0.006808 | val MAE: 0.016996 | time: 4.43s
# 😴 Cooling GPU: sleeping 10s after epoch 1838
# Epoch 1839 | train MAE: 0.006825 | val MAE: 0.017122 | time: 4.17s
# Epoch 1840 | train MAE: 0.006882 | val MAE: 0.017267 | time: 4.34s
# Epoch 1841 | train MAE: 0.006938 | val MAE: 0.016827 | time: 4.40s
# 😴 Cooling GPU: sleeping 10s after epoch 1841
# Epoch 1842 | train MAE: 0.006910 | val MAE: 0.017428 | time: 4.15s
# Epoch 1843 | train MAE: 0.006859 | val MAE: 0.016564 | time: 4.32s
# Epoch 1844 | train MAE: 0.006887 | val MAE: 0.017874 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1844
# Epoch 1845 | train MAE: 0.006860 | val MAE: 0.016766 | time: 4.16s
# Epoch 1846 | train MAE: 0.007032 | val MAE: 0.017499 | time: 4.32s
# Epoch 1847 | train MAE: 0.007077 | val MAE: 0.016027 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1847
# Epoch 1848 | train MAE: 0.006745 | val MAE: 0.016962 | time: 4.19s
# Epoch 1849 | train MAE: 0.006802 | val MAE: 0.018967 | time: 4.32s
# Epoch 1850 | train MAE: 0.006853 | val MAE: 0.017346 | time: 4.42s
# 😴 Cooling GPU: sleeping 10s after epoch 1850
# Epoch 1851 | train MAE: 0.007032 | val MAE: 0.018525 | time: 4.16s
# Epoch 1852 | train MAE: 0.007040 | val MAE: 0.016788 | time: 4.36s
# Epoch 1853 | train MAE: 0.007127 | val MAE: 0.016326 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 1853
# Epoch 1854 | train MAE: 0.006979 | val MAE: 0.016742 | time: 4.18s
# Epoch 1855 | train MAE: 0.007044 | val MAE: 0.016901 | time: 4.35s
# Epoch 1856 | train MAE: 0.006698 | val MAE: 0.016857 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 1856
# Epoch 1857 | train MAE: 0.006816 | val MAE: 0.017668 | time: 4.16s
# Epoch 1858 | train MAE: 0.007053 | val MAE: 0.017413 | time: 4.37s
# Epoch 1859 | train MAE: 0.006902 | val MAE: 0.016253 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1859
# Epoch 1860 | train MAE: 0.006914 | val MAE: 0.016275 | time: 4.16s
# Epoch 1861 | train MAE: 0.006797 | val MAE: 0.016224 | time: 4.33s
# Epoch 1862 | train MAE: 0.007079 | val MAE: 0.018349 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 1862
# Epoch 1863 | train MAE: 0.006955 | val MAE: 0.015732 | time: 4.16s
# Epoch 1864 | train MAE: 0.006939 | val MAE: 0.017883 | time: 4.34s
# Epoch 1865 | train MAE: 0.006649 | val MAE: 0.016230 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 1865
# Epoch 1866 | train MAE: 0.006829 | val MAE: 0.017998 | time: 4.15s
# Epoch 1867 | train MAE: 0.006910 | val MAE: 0.018376 | time: 4.34s
# Epoch 1868 | train MAE: 0.006859 | val MAE: 0.017540 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 1868
# Epoch 1869 | train MAE: 0.006969 | val MAE: 0.019735 | time: 4.17s
# Epoch 1870 | train MAE: 0.006781 | val MAE: 0.016863 | time: 4.33s
# Epoch 1871 | train MAE: 0.006892 | val MAE: 0.018472 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 1871
# Epoch 1872 | train MAE: 0.006849 | val MAE: 0.017619 | time: 4.15s
# Epoch 1873 | train MAE: 0.006729 | val MAE: 0.016784 | time: 4.33s
# Epoch 1874 | train MAE: 0.006890 | val MAE: 0.018170 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1874
# Epoch 1875 | train MAE: 0.006841 | val MAE: 0.016828 | time: 4.15s
# Epoch 1876 | train MAE: 0.007039 | val MAE: 0.017968 | time: 4.33s
# Epoch 1877 | train MAE: 0.006842 | val MAE: 0.016981 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1877
# Epoch 1878 | train MAE: 0.006953 | val MAE: 0.017794 | time: 4.16s
# Epoch 1879 | train MAE: 0.006854 | val MAE: 0.019228 | time: 4.32s
# Epoch 1880 | train MAE: 0.006973 | val MAE: 0.018089 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 1880
# Epoch 1881 | train MAE: 0.006825 | val MAE: 0.016802 | time: 4.17s
# Epoch 1882 | train MAE: 0.006999 | val MAE: 0.016961 | time: 4.34s
# Epoch 1883 | train MAE: 0.006822 | val MAE: 0.017025 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1883
# Epoch 1884 | train MAE: 0.006855 | val MAE: 0.018632 | time: 4.18s
# Epoch 1885 | train MAE: 0.006831 | val MAE: 0.015997 | time: 4.32s
# Epoch 1886 | train MAE: 0.006727 | val MAE: 0.016907 | time: 4.41s
# 😴 Cooling GPU: sleeping 10s after epoch 1886
# Epoch 1887 | train MAE: 0.006933 | val MAE: 0.017498 | time: 4.16s
# Epoch 1888 | train MAE: 0.006714 | val MAE: 0.019068 | time: 4.33s
# Epoch 1889 | train MAE: 0.006790 | val MAE: 0.019136 | time: 4.41s
# 😴 Cooling GPU: sleeping 10s after epoch 1889
# Epoch 1890 | train MAE: 0.006776 | val MAE: 0.016686 | time: 4.14s
# Epoch 1891 | train MAE: 0.006777 | val MAE: 0.017136 | time: 4.32s
# Epoch 1892 | train MAE: 0.006780 | val MAE: 0.016701 | time: 4.40s
# 😴 Cooling GPU: sleeping 10s after epoch 1892
# Epoch 1893 | train MAE: 0.006840 | val MAE: 0.017370 | time: 4.15s
# Epoch 1894 | train MAE: 0.006774 | val MAE: 0.017779 | time: 4.31s
# Epoch 1895 | train MAE: 0.006889 | val MAE: 0.016217 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1895
# Epoch 1896 | train MAE: 0.006852 | val MAE: 0.017809 | time: 4.16s
# Epoch 1897 | train MAE: 0.006929 | val MAE: 0.016765 | time: 4.31s
# Epoch 1898 | train MAE: 0.006901 | val MAE: 0.017020 | time: 4.40s
# 😴 Cooling GPU: sleeping 10s after epoch 1898
# Epoch 1899 | train MAE: 0.006769 | val MAE: 0.016115 | time: 4.18s
# Epoch 1900 | train MAE: 0.006861 | val MAE: 0.018526 | time: 4.30s
# Epoch 1901 | train MAE: 0.006768 | val MAE: 0.017511 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1901
# Epoch 1902 | train MAE: 0.006750 | val MAE: 0.018147 | time: 4.16s
# Epoch 1903 | train MAE: 0.006791 | val MAE: 0.017800 | time: 4.30s
# Epoch 1904 | train MAE: 0.006691 | val MAE: 0.016565 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 1904
# Epoch 1905 | train MAE: 0.006719 | val MAE: 0.017388 | time: 4.16s
# Epoch 1906 | train MAE: 0.006800 | val MAE: 0.018175 | time: 4.33s
# Epoch 1907 | train MAE: 0.006884 | val MAE: 0.017852 | time: 4.35s
# 😴 Cooling GPU: sleeping 10s after epoch 1907
# Epoch 1908 | train MAE: 0.006856 | val MAE: 0.017531 | time: 4.15s
# Epoch 1909 | train MAE: 0.006955 | val MAE: 0.017306 | time: 4.31s
# Epoch 1910 | train MAE: 0.006866 | val MAE: 0.018832 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 1910
# Epoch 1911 | train MAE: 0.006712 | val MAE: 0.018090 | time: 4.18s
# Epoch 1912 | train MAE: 0.006894 | val MAE: 0.017126 | time: 4.32s
# Epoch 1913 | train MAE: 0.006867 | val MAE: 0.018199 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 1913
# Epoch 1914 | train MAE: 0.006788 | val MAE: 0.016755 | time: 4.15s
# Epoch 1915 | train MAE: 0.006666 | val MAE: 0.017310 | time: 4.33s
# Epoch 1916 | train MAE: 0.006682 | val MAE: 0.016132 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1916
# Epoch 1917 | train MAE: 0.006877 | val MAE: 0.017638 | time: 4.15s
# Epoch 1918 | train MAE: 0.006803 | val MAE: 0.017090 | time: 4.32s
# Epoch 1919 | train MAE: 0.006670 | val MAE: 0.018051 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1919
# Epoch 1920 | train MAE: 0.006729 | val MAE: 0.018257 | time: 4.17s
# Epoch 1921 | train MAE: 0.006657 | val MAE: 0.017296 | time: 4.31s
# Epoch 1922 | train MAE: 0.006774 | val MAE: 0.015715 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 1922
# Epoch 1923 | train MAE: 0.006884 | val MAE: 0.016399 | time: 4.15s
# Epoch 1924 | train MAE: 0.006934 | val MAE: 0.016787 | time: 4.33s
# Epoch 1925 | train MAE: 0.006695 | val MAE: 0.016702 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1925
# Epoch 1926 | train MAE: 0.006776 | val MAE: 0.017927 | time: 4.16s
# Epoch 1927 | train MAE: 0.006860 | val MAE: 0.016946 | time: 4.30s
# Epoch 1928 | train MAE: 0.006655 | val MAE: 0.017176 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1928
# Epoch 1929 | train MAE: 0.006755 | val MAE: 0.017189 | time: 4.17s
# Epoch 1930 | train MAE: 0.006715 | val MAE: 0.016951 | time: 4.31s
# Epoch 1931 | train MAE: 0.006752 | val MAE: 0.017824 | time: 4.40s
# 😴 Cooling GPU: sleeping 10s after epoch 1931
# Epoch 1932 | train MAE: 0.006686 | val MAE: 0.017196 | time: 4.16s
# Epoch 1933 | train MAE: 0.006718 | val MAE: 0.017421 | time: 4.34s
# Epoch 1934 | train MAE: 0.006719 | val MAE: 0.015328 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 1934
# Epoch 1935 | train MAE: 0.006859 | val MAE: 0.016672 | time: 4.15s
# Epoch 1936 | train MAE: 0.006810 | val MAE: 0.017506 | time: 4.32s
# Epoch 1937 | train MAE: 0.006872 | val MAE: 0.019005 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 1937
# Epoch 1938 | train MAE: 0.006961 | val MAE: 0.018592 | time: 4.16s
# Epoch 1939 | train MAE: 0.006685 | val MAE: 0.017847 | time: 4.33s
# Epoch 1940 | train MAE: 0.006758 | val MAE: 0.017882 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1940
# Epoch 1941 | train MAE: 0.006826 | val MAE: 0.015817 | time: 4.17s
# Epoch 1942 | train MAE: 0.006773 | val MAE: 0.018831 | time: 4.34s
# Epoch 1943 | train MAE: 0.006730 | val MAE: 0.016667 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 1943
# Epoch 1944 | train MAE: 0.006790 | val MAE: 0.015671 | time: 4.14s
# Epoch 1945 | train MAE: 0.006860 | val MAE: 0.017355 | time: 4.29s
# Epoch 1946 | train MAE: 0.006811 | val MAE: 0.018144 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 1946
# Epoch 1947 | train MAE: 0.006852 | val MAE: 0.017042 | time: 4.15s
# Epoch 1948 | train MAE: 0.006680 | val MAE: 0.016989 | time: 4.30s
# Epoch 1949 | train MAE: 0.006598 | val MAE: 0.017780 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1949
# Epoch 1950 | train MAE: 0.006814 | val MAE: 0.018262 | time: 4.14s
# Epoch 1951 | train MAE: 0.006800 | val MAE: 0.017885 | time: 4.29s
# Epoch 1952 | train MAE: 0.006678 | val MAE: 0.017302 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 1952
# Epoch 1953 | train MAE: 0.006787 | val MAE: 0.016538 | time: 4.15s
# Epoch 1954 | train MAE: 0.006750 | val MAE: 0.017402 | time: 4.31s
# Epoch 1955 | train MAE: 0.006697 | val MAE: 0.017948 | time: 4.40s
# 😴 Cooling GPU: sleeping 10s after epoch 1955
# Epoch 1956 | train MAE: 0.006978 | val MAE: 0.017398 | time: 4.15s
# Epoch 1957 | train MAE: 0.006631 | val MAE: 0.016677 | time: 4.29s
# Epoch 1958 | train MAE: 0.006580 | val MAE: 0.017051 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 1958
# Epoch 1959 | train MAE: 0.006643 | val MAE: 0.016976 | time: 4.16s
# Epoch 1960 | train MAE: 0.006848 | val MAE: 0.019263 | time: 4.31s
# Epoch 1961 | train MAE: 0.006634 | val MAE: 0.015633 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1961
# Epoch 1962 | train MAE: 0.006752 | val MAE: 0.017153 | time: 4.17s
# Epoch 1963 | train MAE: 0.006538 | val MAE: 0.016855 | time: 4.31s
# Epoch 1964 | train MAE: 0.006730 | val MAE: 0.018407 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 1964
# Epoch 1965 | train MAE: 0.006743 | val MAE: 0.016883 | time: 4.15s
# Epoch 1966 | train MAE: 0.006774 | val MAE: 0.017834 | time: 4.33s
# Epoch 1967 | train MAE: 0.006838 | val MAE: 0.016592 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 1967
# Epoch 1968 | train MAE: 0.006664 | val MAE: 0.016798 | time: 4.14s
# Epoch 1969 | train MAE: 0.006525 | val MAE: 0.017296 | time: 4.32s
# Epoch 1970 | train MAE: 0.006779 | val MAE: 0.017705 | time: 4.40s
# 😴 Cooling GPU: sleeping 10s after epoch 1970
# Epoch 1971 | train MAE: 0.006569 | val MAE: 0.015803 | time: 4.15s
# Epoch 1972 | train MAE: 0.006605 | val MAE: 0.017757 | time: 4.30s
# Epoch 1973 | train MAE: 0.006578 | val MAE: 0.017616 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1973
# Epoch 1974 | train MAE: 0.006691 | val MAE: 0.018122 | time: 4.15s
# Epoch 1975 | train MAE: 0.006783 | val MAE: 0.017416 | time: 4.30s
# Epoch 1976 | train MAE: 0.006543 | val MAE: 0.015921 | time: 4.36s
# 😴 Cooling GPU: sleeping 10s after epoch 1976
# Epoch 1977 | train MAE: 0.006816 | val MAE: 0.016977 | time: 4.16s
# Epoch 1978 | train MAE: 0.006645 | val MAE: 0.016565 | time: 4.32s
# Epoch 1979 | train MAE: 0.006607 | val MAE: 0.016866 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 1979
# Epoch 1980 | train MAE: 0.006750 | val MAE: 0.016488 | time: 4.18s
# Epoch 1981 | train MAE: 0.006544 | val MAE: 0.016289 | time: 4.33s
# Epoch 1982 | train MAE: 0.006625 | val MAE: 0.015254 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1982
# Epoch 1983 | train MAE: 0.006767 | val MAE: 0.017410 | time: 4.18s
# Epoch 1984 | train MAE: 0.006560 | val MAE: 0.016980 | time: 4.33s
# Epoch 1985 | train MAE: 0.006722 | val MAE: 0.017767 | time: 4.40s
# 😴 Cooling GPU: sleeping 10s after epoch 1985
# Epoch 1986 | train MAE: 0.006667 | val MAE: 0.017973 | time: 4.17s
# Epoch 1987 | train MAE: 0.006735 | val MAE: 0.018430 | time: 4.31s
# Epoch 1988 | train MAE: 0.006561 | val MAE: 0.018073 | time: 4.42s
# 😴 Cooling GPU: sleeping 10s after epoch 1988
# Epoch 1989 | train MAE: 0.006521 | val MAE: 0.015187 | time: 4.16s
# Epoch 1990 | train MAE: 0.006705 | val MAE: 0.018042 | time: 4.31s
# Epoch 1991 | train MAE: 0.006686 | val MAE: 0.016701 | time: 4.38s
# 😴 Cooling GPU: sleeping 10s after epoch 1991
# Epoch 1992 | train MAE: 0.006859 | val MAE: 0.017109 | time: 4.17s
# Epoch 1993 | train MAE: 0.006714 | val MAE: 0.017591 | time: 4.31s
# Epoch 1994 | train MAE: 0.006575 | val MAE: 0.016774 | time: 4.37s
# 😴 Cooling GPU: sleeping 10s after epoch 1994
# Epoch 1995 | train MAE: 0.006729 | val MAE: 0.017745 | time: 4.16s
# Epoch 1996 | train MAE: 0.006721 | val MAE: 0.015881 | time: 4.33s
# Epoch 1997 | train MAE: 0.006566 | val MAE: 0.018125 | time: 4.39s
# 😴 Cooling GPU: sleeping 10s after epoch 1997
# Epoch 1998 | train MAE: 0.006844 | val MAE: 0.016494 | time: 4.18s
# `Trainer.fit` stopped: `max_epochs=2000` reached.
# Epoch 1999 | train MAE: 0.006641 | val MAE: 0.018119 | time: 4.34s
# CPU times: user 2h 10min 51s, sys: 26min 58s, total: 2h 37min 49s
# Wall time: 4h 13min 46s

# %% [markdown]
# #### Save the training history

# %%
CHECKPOINT_PATH
# Out:
# '/app/kdrift/decenter+-0.095,tilt+-0.075/pytorch/checkpoints/hybrid-ntok64-maxcap6-yrescaled_take3a'

# %%
epochs, train_losses, val_losses, times = loss_cb.as_lists()

print("n_epochs:", len(epochs))
print("n_train_losses:", len(train_losses))
print("n_val_losses:", len(val_losses))
print("train_losses[:3]:", train_losses[:3])
print("val_losses[:3]:", val_losses[:3])
# Out:
# n_epochs: 2000
# n_train_losses: 2000
# n_val_losses: 2000
# train_losses[:3]: [0.28592970967292786, 0.19070160388946533, 0.1702333688735962]
# val_losses[:3]: [0.22525618970394135, 0.18343693017959595, 0.15673190355300903]

# %%
df = pd.DataFrame({
    "epoch": epochs,
    "train_loss": train_losses,
    "val_loss": val_losses,
})

df.to_csv(f"{CHECKPOINT_PATH}/training_history.csv", index=False)

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# 'best-epoch=137-val_loss=0.009519.ckpt'
# 'best-epoch=163-val_loss=0.009775.ckpt'
# 'best-epoch=190-val_loss=0.009960.ckpt'
# 'best-epoch=214-val_loss=0.008674.ckpt'
# 'best-epoch=216-val_loss=0.009496.ckpt'
# 'best-epoch=223-val_loss=0.009209.ckpt'
# 'best-epoch=224-val_loss=0.010192.ckpt'
# 'best-epoch=231-val_loss=0.009626.ckpt'
# 'best-epoch=240-val_loss=0.009091.ckpt'
# 'best-epoch=245-val_loss=0.010065.ckpt'
# 'best-epoch=247-val_loss=0.009888.ckpt'
# 'best-epoch=253-val_loss=0.009988.ckpt'
# 'best-epoch=257-val_loss=0.010063.ckpt'
# 'best-epoch=264-val_loss=0.009292.ckpt'
# 'best-epoch=267-val_loss=0.009659.ckpt'
# 'best-epoch=302-val_loss=0.009568.ckpt'
# 'best-epoch=327-val_loss=0.010215.ckpt'
# 'best-epoch=348-val_loss=0.010203.ckpt'
# 'best-epoch=356-val_loss=0.008894.ckpt'
# 'best-epoch=358-val_loss=0.010197.ckpt'
#  last.ckpt
#  training_history.csv

# %%
title = "Hybrid StemCh64 Tanh Ntok64 MaxCap6 Y Rescaled "
save_name = "history-hybrid-stemch64-tanh-ntok64-maxcap6-y-rescaled.png"   # 예: .png, .pdf, .jpg

plt.figure(figsize=(6, 4))

plt.plot(epochs, train_losses, label="train", alpha=0.6)
plt.plot(epochs, val_losses, label="val", alpha = 0.6)

plt.xlabel("epoch")
plt.ylabel("MAE")

plt.yscale("log")
plt.grid(True, which="both", linestyle="--", alpha=0.6)

plt.title(title)
plt.legend()
plt.tight_layout()

plt.savefig(save_name, dpi=300)  # 👈 저장
plt.show()

# %% [markdown]
# ## Evaluation

# %%
def get_test_predictions(model, test_loader, device):
    model.eval()

    y_true_list = []
    y_pred_list = []

    with torch.no_grad():
        for xb, yb in test_loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)

            y_hat = model(xb)          # (B, 6)

            y_true_list.append(yb.cpu().numpy())
            y_pred_list.append(y_hat.cpu().numpy())

    y_true = np.concatenate(y_true_list, axis=0)  # (N_test, 6)
    y_pred = np.concatenate(y_pred_list, axis=0)  # (N_test, 6)

    return y_true, y_pred

# %%
# %ls {CHECKPOINT_PATH}
# Out:
# 'best-epoch=137-val_loss=0.009519.ckpt'
# 'best-epoch=163-val_loss=0.009775.ckpt'
# 'best-epoch=190-val_loss=0.009960.ckpt'
# 'best-epoch=214-val_loss=0.008674.ckpt'
# 'best-epoch=216-val_loss=0.009496.ckpt'
# 'best-epoch=223-val_loss=0.009209.ckpt'
# 'best-epoch=224-val_loss=0.010192.ckpt'
# 'best-epoch=231-val_loss=0.009626.ckpt'
# 'best-epoch=240-val_loss=0.009091.ckpt'
# 'best-epoch=245-val_loss=0.010065.ckpt'
# 'best-epoch=247-val_loss=0.009888.ckpt'
# 'best-epoch=253-val_loss=0.009988.ckpt'
# 'best-epoch=257-val_loss=0.010063.ckpt'
# 'best-epoch=264-val_loss=0.009292.ckpt'
# 'best-epoch=267-val_loss=0.009659.ckpt'
# 'best-epoch=302-val_loss=0.009568.ckpt'
# 'best-epoch=327-val_loss=0.010215.ckpt'
# 'best-epoch=348-val_loss=0.010203.ckpt'
# 'best-epoch=356-val_loss=0.008894.ckpt'
# 'best-epoch=358-val_loss=0.010197.ckpt'
#  last.ckpt
#  training_history.csv

# %%
best_ckpt = f"{CHECKPOINT_PATH}/best-epoch=214-val_loss=0.008674.ckpt"

vit_model = VisionTransformerRegressorHybrid(
    img_size=64,
    patch_size=8,      # ✅ 64 tokens
    num_channels=5,
    num_outputs=6,
    embed_dim=192,     # ✅ 줄이기
    hidden_dim=768,    # ✅ 줄이기
    num_heads=6,       # ✅ 줄이기
    num_layers=4,      # ✅ 줄이기
    dropout=0.1,
    stem_channels=64,
)


lit_model = LitViTRegressor.load_from_checkpoint(
    checkpoint_path=best_ckpt,  # ✅ 여기서만 씀
    model=vit_model,            # ✅ 반드시 넘겨야 함
    lr=2e-4,
)

# %%
# %%time
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
y_test_true, y_test_pred = get_test_predictions(lit_model, test_loader, device)
# Out:
# CPU times: user 386 ms, sys: 211 ms, total: 597 ms
# Wall time: 503 ms

# %%
print(y_test_true.shape)  # (N_test, 6)
print(y_test_pred.shape)  # (N_test, 6)
# Out:
# (4000, 6)
# (4000, 6)

# %% [markdown]
# #### Descale the y values

# %%
mae = np.mean(np.abs(y_test_pred - y_test_true), axis=0)
print("Test MAE per y:", mae)
print("Test MAE mean :", mae.mean())
# Out:
# Test MAE per y: [0.01026331 0.01052694 0.00748156 0.00768089 0.00545412 0.0098476 ]
# Test MAE mean : 0.008542403

# %%
YL_CAP, YH_CAP
# Out:
# (0.095, 0.075)

# %%
scales = np.array([YL_CAP]*3 + [YH_CAP]*3)  # shape: (6,)

y_test_true_descaled = y_test_true * scales
y_test_pred_descaled = y_test_pred * scales

# %%
mae = np.mean(np.abs(y_test_pred_descaled - y_test_true_descaled), axis=0)
print("Test MAE per y:", mae)
print("Test MAE mean :", mae.mean())
# Out:
# Test MAE per y: [0.00097501 0.00100006 0.00071075 0.00057607 0.00040906 0.00073857]
# Test MAE mean : 0.0007349199968148729

# %%
err = y_test_pred_descaled - y_test_true_descaled
print(err.shape)
# Out:
# (4000, 6)

# %%
import matplotlib as mpl

mpl.rcParams.update({
    "font.family": "serif",
    "font.size": 14,        # 기본 폰트
    "axes.titlesize": 16,   # subplot title
    "axes.labelsize": 14,   # x,y label
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12,
})

# %%
def plot_error_histograms(err, bins=50):
    """
    err shape: (N, 6)
    """
    fig, axes = plt.subplots(2, 3, figsize=(10, 6))
    axes = axes.ravel()

    # symmetric range for fair comparison
    vmin = err.min()
    vmax = err.max()
    vmax = max(abs(vmin), abs(vmax))
    hist_range = (-vmax, vmax)

    for i in range(6):
        ax = axes[i]

        ax.hist(
            err[:, i],
            bins=bins,
            range=hist_range,
            alpha=0.8
        )

        ax.axvline(0, color="k", linestyle="--", linewidth=1)
        ax.set_title(f"y{i} error")
        ax.set_xlabel("prediction - truth")
        ax.set_ylabel("count")

    fig.suptitle("Test error distribution (y_pred - y_true)", fontsize=12)
    fig.tight_layout()
    plt.show()

# %%
#plot_error_histograms(err,bins=200)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(
    style="whitegrid",     # 🔹 whitegrid → white
    context="talk",
    font="serif"
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import MaxNLocator

def plot_error_histograms_seaborn(
    err,
    bins=40,
    xmin=-0.1,
    xmax=0.1,
    save_name="default.pdf",   # 👈 디폴트 파일명
):
    fig, axes = plt.subplots(3, 2, figsize=(15, 12))
    axes = axes.ravel()

    xlim = (xmin, xmax)

    for i in range(6):
        ax = axes[i]

        sns.histplot(
            err[:, i],
            bins=bins,
            stat="count",
            kde=False,
            color="tab:blue",
            alpha=0.8,
            ax=ax
        )

        ax.axvline(0, color="black", linestyle="--", linewidth=1.5)

        mae  = np.mean(np.abs(err[:, i]))
        rmse = np.sqrt(np.mean(err[:, i] ** 2))

        ax.text(
            0.03, 0.97,
            f"MAE  = {mae:.4f}\nRMSE = {rmse:.4f}",
            transform=ax.transAxes,
            va="top",
            ha="left",
            fontsize=14,
            bbox=dict(boxstyle="round", fc="white", alpha=0.9)
        )

        ax.set_xlim(xlim)
        ax.xaxis.set_major_locator(MaxNLocator(nbins=5))

        ax.set_title(f"y{i} error", fontsize=16)
        ax.set_xlabel("prediction − truth", fontsize=14)
        ax.set_ylabel("count", fontsize=14)

    fig.suptitle(
        "Test error distribution : Hybrid StemCh64 Tanh NTok64 MaxCap6 Y Rescaled",
        fontsize=20,
        y=0.98
    )

    fig.tight_layout()

    # ✅ PDF 저장 (show 전에!)
    if save_name is not None:
        plt.savefig(save_name, bbox_inches="tight")
        print(f"Saved figure to: {save_name}")

    plt.show()

# %%
plot_error_histograms_seaborn(err,bins=200,xmin=-0.005,xmax=0.005, \
                             save_name='hybrid-stemch64-tanh-ntok64-maxcap6-y_rescaled.png')
# Out:
# Saved figure to: hybrid-stemch64-tanh-ntok64-maxcap6-y_rescaled.png
